# %%
import gensim
from gensim.test.utils import common_texts, get_tmpfile
from gensim.models import word2vec , Phrases

import numpy as np
from multiprocessing import cpu_count

import nltk
from nltk.tokenize import sent_tokenize, word_tokenize 
nltk.download('punkt')

import pandas as pd
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\pc\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
def getFV(document, model1, sizeModel): #promedio del vector caracteristico
    
    words=document.split()
    s=np.zeros(sizeModel)
    k=1
    for w in words:
        if w in model1.wv.vocab:
            s=s+model1[w]
            k=k+1
    
    return s/k

# %%
model = gensim.models.Word2Vec.load('w2v300_5.model')

# %%
model.wv.vocab
# Out:
# {'presentadora': <gensim.models.keyedvectors.Vocab at 0x19c6c437a90>,
#  'exjurado': <gensim.models.keyedvectors.Vocab at 0x19c6c44c240>,
#  'artista': <gensim.models.keyedvectors.Vocab at 0x19c6c44c2e8>,
#  'año': <gensim.models.keyedvectors.Vocab at 0x19c6c44c278>,
#  'fiorella': <gensim.models.keyedvectors.Vocab at 0x19c6c44c208>,
#  'rodríguez': <gensim.models.keyedvectors.Vocab at 0x19c6c44c198>,
#  '45': <gensim.models.keyedvectors.Vocab at 0x19c6c44c390>,
#  'presentó': <gensim.models.keyedvectors.Vocab at 0x19c6c44c400>,
#  'dueño': <gensim.models.keyedvectors.Vocab at 0x19c6c44c3c8>,
#  'corazón': <gensim.models.keyedvectors.Vocab at 0x19c6c44c358>,
#  'fotografías': <gensim.models.keyedvectors.Vocab at 0x19c6c44c048>,
#  'instagram': <gensim.models.keyedvectors.Vocab at 0x19c6c44c0b8>,
#  'fanáticos': <gensim.models.keyedvectors.Vocab at 0x19c6c44c0f0>,
#  'tardaron': <gensim.models.keyedvectors.Vocab at 0x19c6c44c128>,
#  'llenarle': <gensim.models.keyedvectors.Vocab at 0x19c6c44c080>,
#  'publicación': <gensim.models.keyedvectors.Vocab at 0x19c6c44c470>,
#  'emoticones': <gensim.models.keyedvectors.Vocab at 0x19c6c44c4a8>,
#  'corazones': <gensim.models.keyedvectors.Vocab at 0x19c6c44c518>,
#  'fotos': <gensim.models.keyedvectors.Vocab at 0x19c6c44c588>,
#  'observa': <gensim.models.keyedvectors.Vocab at 0x19c6c44c5f8>,
#  'abrazando': <gensim.models.keyedvectors.Vocab at 0x19c6c44c630>,
#  'muchacho': <gensim.models.keyedvectors.Vocab at 0x19c6c44c668>,
#  'mira': <gensim.models.keyedvectors.Vocab at 0x19c6c44c6d8>,
#  'ternura': <gensim.models.keyedvectors.Vocab at 0x19c6c44c748>,
#  'captura': <gensim.models.keyedvectors.Vocab at 0x19c6c44c7b8>,
#  'sonríe': <gensim.models.keyedvectors.Vocab at 0x19c6c44c7f0>,
#  'compartiendo': <gensim.models.keyedvectors.Vocab at 0x19c6c44c828>,
#  'mirada': <gensim.models.keyedvectors.Vocab at 0x19c6c44c898>,
#  'completa': <gensim.models.keyedvectors.Vocab at 0x19c6c44c8d0>,
#  'complicidad': <gensim.models.keyedvectors.Vocab at 0x19c6c44c908>,
#  'meses': <gensim.models.keyedvectors.Vocab at 0x19c6c44c978>,
#  'amor': <gensim.models.keyedvectors.Vocab at 0x19c6c44c9e8>,
#  'bonito': <gensim.models.keyedvectors.Vocab at 0x19c6c44ca58>,
#  'mensaje': <gensim.models.keyedvectors.Vocab at 0x19c6c44cac8>,
#  'acompaña': <gensim.models.keyedvectors.Vocab at 0x19c6c44cb00>,
#  'mantuvo': <gensim.models.keyedvectors.Vocab at 0x19c6c44cb70>,
#  'matrimonio': <gensim.models.keyedvectors.Vocab at 0x19c6c44cba8>,
#  '15': <gensim.models.keyedvectors.Vocab at 0x19c6c44cc18>,
#  'años': <gensim.models.keyedvectors.Vocab at 0x19c6c44cc50>,
#  'cineasta': <gensim.models.keyedvectors.Vocab at 0x19c6c44cc88>,
#  'sandro': <gensim.models.keyedvectors.Vocab at 0x19c6c44ccf8>,
#  'ventura': <gensim.models.keyedvectors.Vocab at 0x19c6c44cd68>,
#  'mediados': <gensim.models.keyedvectors.Vocab at 0x19c6c44cda0>,
#  '2018': <gensim.models.keyedvectors.Vocab at 0x19c6c44ce10>,
#  'anunciaron': <gensim.models.keyedvectors.Vocab at 0x19c6c44ce48>,
#  'separación': <gensim.models.keyedvectors.Vocab at 0x19c6c44ce80>,
#  'quedaron': <gensim.models.keyedvectors.Vocab at 0x19c6c44ceb8>,
#  'términos': <gensim.models.keyedvectors.Vocab at 0x19c6c44cef0>,
#  'amigo': <gensim.models.keyedvectors.Vocab at 0x19c6c44cf60>,
#  'hermosos': <gensim.models.keyedvectors.Vocab at 0x19c6c44cf98>,
#  'basados': <gensim.models.keyedvectors.Vocab at 0x19c6c481048>,
#  'comunicación': <gensim.models.keyedvectors.Vocab at 0x19c6c481080>,
#  'cariño': <gensim.models.keyedvectors.Vocab at 0x19c6c4810b8>,
#  'entrega': <gensim.models.keyedvectors.Vocab at 0x19c6c481128>,
#  'absoluta': <gensim.models.keyedvectors.Vocab at 0x19c6c481160>,
#  'persona': <gensim.models.keyedvectors.Vocab at 0x19c6c4811d0>,
#  'importante': <gensim.models.keyedvectors.Vocab at 0x19c6c481208>,
#  'vida': <gensim.models.keyedvectors.Vocab at 0x19c6c481278>,
#  'oportunidad': <gensim.models.keyedvectors.Vocab at 0x19c6c4812b0>,
#  'cerrar': <gensim.models.keyedvectors.Vocab at 0x19c6c481320>,
#  'etapa': <gensim.models.keyedvectors.Vocab at 0x19c6c481390>,
#  'abrir': <gensim.models.keyedvectors.Vocab at 0x19c6c481400>,
#  'emoción': <gensim.models.keyedvectors.Vocab at 0x19c6c481438>,
#  'expectativa': <gensim.models.keyedvectors.Vocab at 0x19c6c481470>,
#  'seguir': <gensim.models.keyedvectors.Vocab at 0x19c6c4814e0>,
#  'persiguiendo': <gensim.models.keyedvectors.Vocab at 0x19c6c481518>,
#  'sueños': <gensim.models.keyedvectors.Vocab at 0x19c6c481550>,
#  'febrero': <gensim.models.keyedvectors.Vocab at 0x19c6c4815c0>,
#  'entrevista': <gensim.models.keyedvectors.Vocab at 0x19c6c4815f8>,
#  'perú21': <gensim.models.keyedvectors.Vocab at 0x19c6c481630>,
#  'enriquez': <gensim.models.keyedvectors.Vocab at 0x19c6c481668>,
#  'luque': <gensim.models.keyedvectors.Vocab at 0x19c6c4816d8>,
#  '25': <gensim.models.keyedvectors.Vocab at 0x19c6c481748>,
#  'detenido': <gensim.models.keyedvectors.Vocab at 0x19c6c481780>,
#  'arrojado': <gensim.models.keyedvectors.Vocab at 0x19c6c4817b8>,
#  'thinner': <gensim.models.keyedvectors.Vocab at 0x19c6c481828>,
#  'padre': <gensim.models.keyedvectors.Vocab at 0x19c6c481898>,
#  'posteriormente': <gensim.models.keyedvectors.Vocab at 0x19c6c4818d0>,
#  'prenderle': <gensim.models.keyedvectors.Vocab at 0x19c6c481908>,
#  'fuego': <gensim.models.keyedvectors.Vocab at 0x19c6c481978>,
#  'acuerdo': <gensim.models.keyedvectors.Vocab at 0x19c6c4819e8>,
#  'diversos': <gensim.models.keyedvectors.Vocab at 0x19c6c481a20>,
#  'medios': <gensim.models.keyedvectors.Vocab at 0x19c6c481a90>,
#  'locales': <gensim.models.keyedvectors.Vocab at 0x19c6c481b00>,
#  'parricidio': <gensim.models.keyedvectors.Vocab at 0x19c6c481b38>,
#  'ocurrió': <gensim.models.keyedvectors.Vocab at 0x19c6c481b70>,
#  'vivienda': <gensim.models.keyedvectors.Vocab at 0x19c6c481ba8>,
#  'agraviado': <gensim.models.keyedvectors.Vocab at 0x19c6c481be0>,
#  'ubicada': <gensim.models.keyedvectors.Vocab at 0x19c6c481c50>,
#  'provincia': <gensim.models.keyedvectors.Vocab at 0x19c6c481c88>,
#  'convención': <gensim.models.keyedvectors.Vocab at 0x19c6c481cc0>,
#  'cusco': <gensim.models.keyedvectors.Vocab at 0x19c6c481d30>,
#  'vecinos': <gensim.models.keyedvectors.Vocab at 0x19c6c481da0>,
#  'zona': <gensim.models.keyedvectors.Vocab at 0x19c6c481e10>,
#  'aviso': <gensim.models.keyedvectors.Vocab at 0x19c6c481e80>,
#  'autoridades': <gensim.models.keyedvectors.Vocab at 0x19c6c481eb8>,
#  'inmediatamente': <gensim.models.keyedvectors.Vocab at 0x19c6c481ef0>,
#  'llegaron': <gensim.models.keyedvectors.Vocab at 0x19c6c481f28>,
#  'hechos': <gensim.models.keyedvectors.Vocab at 0x19c6c481f98>,
#  'domicilio': <gensim.models.keyedvectors.Vocab at 0x19c6c481fd0>,
#  'joven': <gensim.models.keyedvectors.Vocab at 0x19c6c489080>,
#  'negó': <gensim.models.keyedvectors.Vocab at 0x19c6c4890b8>,
#  'incendiado': <gensim.models.keyedvectors.Vocab at 0x19c6c4890f0>,
#  'identificado': <gensim.models.keyedvectors.Vocab at 0x19c6c489128>,
#  'víctor': <gensim.models.keyedvectors.Vocab at 0x19c6c489160>,
#  'carrion': <gensim.models.keyedvectors.Vocab at 0x19c6c4891d0>,
#  '68': <gensim.models.keyedvectors.Vocab at 0x19c6c489240>,
#  'obstante': <gensim.models.keyedvectors.Vocab at 0x19c6c489278>,
#  'graves': <gensim.models.keyedvectors.Vocab at 0x19c6c4892e8>,
#  'quemaduras': <gensim.models.keyedvectors.Vocab at 0x19c6c489320>,
#  'grado': <gensim.models.keyedvectors.Vocab at 0x19c6c489390>,
#  'salió': <gensim.models.keyedvectors.Vocab at 0x19c6c4893c8>,
#  'desmentir': <gensim.models.keyedvectors.Vocab at 0x19c6c489400>,
#  'versión': <gensim.models.keyedvectors.Vocab at 0x19c6c489438>,
#  'hijo': <gensim.models.keyedvectors.Vocab at 0x19c6c4894a8>,
#  'finalmente': <gensim.models.keyedvectors.Vocab at 0x19c6c4894e0>,
#  'trasladado': <gensim.models.keyedvectors.Vocab at 0x19c6c489518>,
#  'comisaría': <gensim.models.keyedvectors.Vocab at 0x19c6c489550>,
#  'santa': <gensim.models.keyedvectors.Vocab at 0x19c6c4895c0>,
#  'teresa': <gensim.models.keyedvectors.Vocab at 0x19c6c489630>,
#  'intervención': <gensim.models.keyedvectors.Vocab at 0x19c6c489668>,
#  'víctima': <gensim.models.keyedvectors.Vocab at 0x19c6c4896a0>,
#  'llevado': <gensim.models.keyedvectors.Vocab at 0x19c6c489710>,
#  'hospital': <gensim.models.keyedvectors.Vocab at 0x19c6c489748>,
#  'central': <gensim.models.keyedvectors.Vocab at 0x19c6c4897b8>,
#  'ciudad': <gensim.models.keyedvectors.Vocab at 0x19c6c489828>,
#  'quillabamba': <gensim.models.keyedvectors.Vocab at 0x19c6c489860>,
#  'viene': <gensim.models.keyedvectors.Vocab at 0x19c6c4898d0>,
#  'recuperándose': <gensim.models.keyedvectors.Vocab at 0x19c6c489908>,
#  'lesiones': <gensim.models.keyedvectors.Vocab at 0x19c6c489940>,
#  'fiscalía': <gensim.models.keyedvectors.Vocab at 0x19c6c489978>,
#  'turno': <gensim.models.keyedvectors.Vocab at 0x19c6c4899e8>,
#  'dispuso': <gensim.models.keyedvectors.Vocab at 0x19c6c489a58>,
#  'diligencias': <gensim.models.keyedvectors.Vocab at 0x19c6c489a90>,
#  'preliminares': <gensim.models.keyedvectors.Vocab at 0x19c6c489ac8>,
#  'correspondientes': <gensim.models.keyedvectors.Vocab at 0x19c6c489b00>,
#  'permanecerá': <gensim.models.keyedvectors.Vocab at 0x19c6c489b38>,
#  'investigaciones': <gensim.models.keyedvectors.Vocab at 0x19c6c489b70>,
#  'deberá': <gensim.models.keyedvectors.Vocab at 0x19c6c489ba8>,
#  'enfrentar': <gensim.models.keyedvectors.Vocab at 0x19c6c489be0>,
#  'cargos': <gensim.models.keyedvectors.Vocab at 0x19c6c489c50>,
#  'presunto': <gensim.models.keyedvectors.Vocab at 0x19c6c489c88>,
#  'delito': <gensim.models.keyedvectors.Vocab at 0x19c6c489cf8>,
#  'violencia': <gensim.models.keyedvectors.Vocab at 0x19c6c489d30>,
#  'familiar': <gensim.models.keyedvectors.Vocab at 0x19c6c489d68>,
#  'luis': <gensim.models.keyedvectors.Vocab at 0x19c6c489dd8>,
#  'bedoya': <gensim.models.keyedvectors.Vocab at 0x19c6c489e48>,
#  'reyes': <gensim.models.keyedvectors.Vocab at 0x19c6c489eb8>,
#  'fundadores': <gensim.models.keyedvectors.Vocab at 0x19c6c489ef0>,
#  'históricos': <gensim.models.keyedvectors.Vocab at 0x19c6c489f28>,
#  'partido': <gensim.models.keyedvectors.Vocab at 0x19c6c489f98>,
#  'popular': <gensim.models.keyedvectors.Vocab at 0x19c6c48f048>,
#  'cristiano': <gensim.models.keyedvectors.Vocab at 0x19c6c48f080>,
#  'ppc': <gensim.models.keyedvectors.Vocab at 0x19c6c48f0f0>,
#  'pronunció': <gensim.models.keyedvectors.Vocab at 0x19c6c48f128>,
#  'acerca': <gensim.models.keyedvectors.Vocab at 0x19c6c48f198>,
#  'convocatoria': <gensim.models.keyedvectors.Vocab at 0x19c6c48f1d0>,
#  'integrar': <gensim.models.keyedvectors.Vocab at 0x19c6c48f208>,
#  'junta': <gensim.models.keyedvectors.Vocab at 0x19c6c48f278>,
#  'nacional': <gensim.models.keyedvectors.Vocab at 0x19c6c48f2b0>,
#  'justicia': <gensim.models.keyedvectors.Vocab at 0x19c6c48f2e8>,
#  'jnj': <gensim.models.keyedvectors.Vocab at 0x19c6c48f358>,
#  'pequeño': <gensim.models.keyedvectors.Vocab at 0x19c6c48f390>,
#  'discurso': <gensim.models.keyedvectors.Vocab at 0x19c6c48f3c8>,
#  'importancia': <gensim.models.keyedvectors.Vocab at 0x19c6c48f400>,
#  'significa': <gensim.models.keyedvectors.Vocab at 0x19c6c48f438>,
#  'órgano': <gensim.models.keyedvectors.Vocab at 0x19c6c48f470>,
#  'político': <gensim.models.keyedvectors.Vocab at 0x19c6c48f4a8>,
#  '100': <gensim.models.keyedvectors.Vocab at 0x19c6c48f518>,
#  'edad': <gensim.models.keyedvectors.Vocab at 0x19c6c48f588>,
#  'grabó': <gensim.models.keyedvectors.Vocab at 0x19c6c48f5c0>,
#  'video': <gensim.models.keyedvectors.Vocab at 0x19c6c48f630>,
#  'explica': <gensim.models.keyedvectors.Vocab at 0x19c6c48f6a0>,
#  'razones': <gensim.models.keyedvectors.Vocab at 0x19c6c48f710>,
#  'llama': <gensim.models.keyedvectors.Vocab at 0x19c6c48f780>,
#  'juristas': <gensim.models.keyedvectors.Vocab at 0x19c6c48f7b8>,
#  'abogados': <gensim.models.keyedvectors.Vocab at 0x19c6c48f7f0>,
#  'especialistas': <gensim.models.keyedvectors.Vocab at 0x19c6c48f828>,
#  'derecho': <gensim.models.keyedvectors.Vocab at 0x19c6c48f898>,
#  'ojalá': <gensim.models.keyedvectors.Vocab at 0x19c6c48f8d0>,
#  'acostumbren': <gensim.models.keyedvectors.Vocab at 0x19c6c48f908>,
#  'acertar': <gensim.models.keyedvectors.Vocab at 0x19c6c48f978>,
#  'postulantes': <gensim.models.keyedvectors.Vocab at 0x19c6c48f9b0>,
#  'merezcan': <gensim.models.keyedvectors.Vocab at 0x19c6c48f9e8>,
#  'elegidos': <gensim.models.keyedvectors.Vocab at 0x19c6c48fa20>,
#  'razón': <gensim.models.keyedvectors.Vocab at 0x19c6c48fa58>,
#  'condiciones': <gensim.models.keyedvectors.Vocab at 0x19c6c48fa90>,
#  'cualidades': <gensim.models.keyedvectors.Vocab at 0x19c6c48fac8>,
#  'juntaremos': <gensim.models.keyedvectors.Vocab at 0x19c6c48fb00>,
#  'peruanos': <gensim.models.keyedvectors.Vocab at 0x19c6c48fb38>,
#  'vivir': <gensim.models.keyedvectors.Vocab at 0x19c6c48fba8>,
#  'discrepando': <gensim.models.keyedvectors.Vocab at 0x19c6c48fbe0>,
#  'institución': <gensim.models.keyedvectors.Vocab at 0x19c6c48fc18>,
#  'reemplazará': <gensim.models.keyedvectors.Vocab at 0x19c6c48fc50>,
#  'desaparecido': <gensim.models.keyedvectors.Vocab at 0x19c6c48fc88>,
#  'consejo': <gensim.models.keyedvectors.Vocab at 0x19c6c48fcf8>,
#  'magistratura': <gensim.models.keyedvectors.Vocab at 0x19c6c48fd30>,
#  'cnm': <gensim.models.keyedvectors.Vocab at 0x19c6c48fda0>,
#  'desactivado': <gensim.models.keyedvectors.Vocab at 0x19c6c48fdd8>,
#  'audios': <gensim.models.keyedvectors.Vocab at 0x19c6c48fe48>,
#  'vergüenza': <gensim.models.keyedvectors.Vocab at 0x19c6c48fe80>,
#  'exintegrantes': <gensim.models.keyedvectors.Vocab at 0x19c6c48feb8>,
#  'escuchaba': <gensim.models.keyedvectors.Vocab at 0x19c6c48fef0>,
#  'comprometedoras': <gensim.models.keyedvectors.Vocab at 0x19c6c48ff28>,
#  'situación': <gensim.models.keyedvectors.Vocab at 0x19c6c48ff60>,
#  'corrupción': <gensim.models.keyedvectors.Vocab at 0x19c6c48ff98>,
#  'encargará': <gensim.models.keyedvectors.Vocab at 0x19c6c48ffd0>,
#  'nombrar': <gensim.models.keyedvectors.Vocab at 0x19c6c497080>,
#  'destituir': <gensim.models.keyedvectors.Vocab at 0x19c6c4970b8>,
#  'jueces': <gensim.models.keyedvectors.Vocab at 0x19c6c497128>,
#  'fiscales': <gensim.models.keyedvectors.Vocab at 0x19c6c497160>,
#  'asimismo': <gensim.models.keyedvectors.Vocab at 0x19c6c497198>,
#  'facultad': <gensim.models.keyedvectors.Vocab at 0x19c6c4971d0>,
#  'renovar': <gensim.models.keyedvectors.Vocab at 0x19c6c497240>,
#  'cargo': <gensim.models.keyedvectors.Vocab at 0x19c6c4972b0>,
#  'jefe': <gensim.models.keyedvectors.Vocab at 0x19c6c497320>,
#  'onpe': <gensim.models.keyedvectors.Vocab at 0x19c6c497390>,
#  'reniec': <gensim.models.keyedvectors.Vocab at 0x19c6c497400>,
#  'doctor': <gensim.models.keyedvectors.Vocab at 0x19c6c497470>,
#  'juan': <gensim.models.keyedvectors.Vocab at 0x19c6c4974e0>,
#  'herrera': <gensim.models.keyedvectors.Vocab at 0x19c6c497550>,
#  'director': <gensim.models.keyedvectors.Vocab at 0x19c6c497588>,
#  'general': <gensim.models.keyedvectors.Vocab at 0x19c6c4975f8>,
#  'operaciones': <gensim.models.keyedvectors.Vocab at 0x19c6c497630>,
#  'salud': <gensim.models.keyedvectors.Vocab at 0x19c6c4976a0>,
#  'conversación': <gensim.models.keyedvectors.Vocab at 0x19c6c4976d8>,
#  'atv': <gensim.models.keyedvectors.Vocab at 0x19c6c497748>,
#  'separó': <gensim.models.keyedvectors.Vocab at 0x19c6c497780>,
#  'responsables': <gensim.models.keyedvectors.Vocab at 0x19c6c4977b8>,
#  'difundir': <gensim.models.keyedvectors.Vocab at 0x19c6c4977f0>,
#  'fallecido': <gensim.models.keyedvectors.Vocab at 0x19c6c497828>,
#  'expresidente': <gensim.models.keyedvectors.Vocab at 0x19c6c497860>,
#  'alan': <gensim.models.keyedvectors.Vocab at 0x19c6c4978d0>,
#  'garcía': <gensim.models.keyedvectors.Vocab at 0x19c6c497908>,
#  'casimiro': <gensim.models.keyedvectors.Vocab at 0x19c6c497940>,
#  'ulloa': <gensim.models.keyedvectors.Vocab at 0x19c6c4979b0>,
#  'sistema': <gensim.models.keyedvectors.Vocab at 0x19c6c497a20>,
#  'identificados': <gensim.models.keyedvectors.Vocab at 0x19c6c497a58>,
#  'vía': <gensim.models.keyedvectors.Vocab at 0x19c6c497a90>,
#  'administrativas': <gensim.models.keyedvectors.Vocab at 0x19c6c497ac8>,
#  'activada': <gensim.models.keyedvectors.Vocab at 0x19c6c497b00>,
#  'sanción': <gensim.models.keyedvectors.Vocab at 0x19c6c497b38>,
#  'correspondiente': <gensim.models.keyedvectors.Vocab at 0x19c6c497b70>,
#  'tema': <gensim.models.keyedvectors.Vocab at 0x19c6c497be0>,
#  'respeto': <gensim.models.keyedvectors.Vocab at 0x19c6c497c50>,
#  'nombre': <gensim.models.keyedvectors.Vocab at 0x19c6c497cc0>,
#  'detalle': <gensim.models.keyedvectors.Vocab at 0x19c6c497d30>,
#  'grupo': <gensim.models.keyedvectors.Vocab at 0x19c6c497da0>,
#  'ocupacional': <gensim.models.keyedvectors.Vocab at 0x19c6c497dd8>,
#  'lamentable': <gensim.models.keyedvectors.Vocab at 0x19c6c497e10>,
#  'precisó': <gensim.models.keyedvectors.Vocab at 0x19c6c497e48>,
#  'involucrados': <gensim.models.keyedvectors.Vocab at 0x19c6c497e80>,
#  'separados': <gensim.models.keyedvectors.Vocab at 0x19c6c497eb8>,
#  'nosocomio': <gensim.models.keyedvectors.Vocab at 0x19c6c497ef0>,
#  'preliminar': <gensim.models.keyedvectors.Vocab at 0x19c6c497f28>,
#  'entidad': <gensim.models.keyedvectors.Vocab at 0x19c6c497f98>,
#  'proceso': <gensim.models.keyedvectors.Vocab at 0x19c6c49d048>,
#  'administrativos': <gensim.models.keyedvectors.Vocab at 0x19c6c49d080>,
#  'corresponde': <gensim.models.keyedvectors.Vocab at 0x19c6c49d0b8>,
#  'definitiva': <gensim.models.keyedvectors.Vocab at 0x19c6c49d0f0>,
#  'mal': <gensim.models.keyedvectors.Vocab at 0x19c6c49d160>,
#  'recuerdo': <gensim.models.keyedvectors.Vocab at 0x19c6c49d198>,
#  'suspensión': <gensim.models.keyedvectors.Vocab at 0x19c6c49d1d0>,
#  'procurador': <gensim.models.keyedvectors.Vocab at 0x19c6c49d208>,
#  'tomando': <gensim.models.keyedvectors.Vocab at 0x19c6c49d278>,
#  'acciones': <gensim.models.keyedvectors.Vocab at 0x19c6c49d2b0>,
#  'administrativa': <gensim.models.keyedvectors.Vocab at 0x19c6c49d2e8>,
#  'aseveró': <gensim.models.keyedvectors.Vocab at 0x19c6c49d320>,
#  'diagnóstico': <gensim.models.keyedvectors.Vocab at 0x19c6c49d358>,
#  '17': <gensim.models.keyedvectors.Vocab at 0x19c6c49d3c8>,
#  'abril': <gensim.models.keyedvectors.Vocab at 0x19c6c49d438>,
#  'exmandatario': <gensim.models.keyedvectors.Vocab at 0x19c6c49d470>,
#  'tomó': <gensim.models.keyedvectors.Vocab at 0x19c6c49d4a8>,
#  'fatal': <gensim.models.keyedvectors.Vocab at 0x19c6c49d518>,
#  'decisión': <gensim.models.keyedvectors.Vocab at 0x19c6c49d550>,
#  'quitarse': <gensim.models.keyedvectors.Vocab at 0x19c6c49d588>,
#  'disparándose': <gensim.models.keyedvectors.Vocab at 0x19c6c49d5c0>,
#  'cabeza': <gensim.models.keyedvectors.Vocab at 0x19c6c49d630>,
#  'impacto': <gensim.models.keyedvectors.Vocab at 0x19c6c49d6a0>,
#  'proyectil': <gensim.models.keyedvectors.Vocab at 0x19c6c49d6d8>,
#  'arma': <gensim.models.keyedvectors.Vocab at 0x19c6c49d748>,
#  'orificio': <gensim.models.keyedvectors.Vocab at 0x19c6c49d780>,
#  'entrada': <gensim.models.keyedvectors.Vocab at 0x19c6c49d7f0>,
#  'salida': <gensim.models.keyedvectors.Vocab at 0x19c6c49d860>,
#  'cráneo': <gensim.models.keyedvectors.Vocab at 0x19c6c49d898>,
#  'ingresó': <gensim.models.keyedvectors.Vocab at 0x19c6c49d8d0>,
#  'sala': <gensim.models.keyedvectors.Vocab at 0x19c6c49d940>,
#  '0717': <gensim.models.keyedvectors.Vocab at 0x19c6c49d9b0>,
#  'am': <gensim.models.keyedvectors.Vocab at 0x19c6c49da20>,
#  'vano': <gensim.models.keyedvectors.Vocab at 0x19c6c49da90>,
#  'muerte': <gensim.models.keyedvectors.Vocab at 0x19c6c49db00>,
#  'consecuencia': <gensim.models.keyedvectors.Vocab at 0x19c6c49db38>,
#  'hemorragia': <gensim.models.keyedvectors.Vocab at 0x19c6c49db70>,
#  'cerebral': <gensim.models.keyedvectors.Vocab at 0x19c6c49dba8>,
#  'masiva': <gensim.models.keyedvectors.Vocab at 0x19c6c49dc18>,
#  'paro': <gensim.models.keyedvectors.Vocab at 0x19c6c49dc88>,
#  'cardiorespiratorio': <gensim.models.keyedvectors.Vocab at 0x19c6c49dcc0>,
#  'john': <gensim.models.keyedvectors.Vocab at 0x19c6c49dd30>,
#  'galliquio': <gensim.models.keyedvectors.Vocab at 0x19c6c49dd68>,
#  'exjugador': <gensim.models.keyedvectors.Vocab at 0x19c6c49dda0>,
#  'selección': <gensim.models.keyedvectors.Vocab at 0x19c6c49ddd8>,
#  'peruana': <gensim.models.keyedvectors.Vocab at 0x19c6c49de48>,
#  'apareció': <gensim.models.keyedvectors.Vocab at 0x19c6c49de80>,
#  'evento': <gensim.models.keyedvectors.Vocab at 0x19c6c49def0>,
#  'deportivo': <gensim.models.keyedvectors.Vocab at 0x19c6c49df28>,
#  'san': <gensim.models.keyedvectors.Vocab at 0x19c6c49df98>,
#  'miraflores': <gensim.models.keyedvectors.Vocab at 0x19c6c49dfd0>,
#  'consultado': <gensim.models.keyedvectors.Vocab at 0x19c6c4a4048>,
#  'denuncia': <gensim.models.keyedvectors.Vocab at 0x19c6c4a4080>,
#  'exesposa': <gensim.models.keyedvectors.Vocab at 0x19c6c4a40b8>,
#  'karla': <gensim.models.keyedvectors.Vocab at 0x19c6c4a4128>,
#  'gómez': <gensim.models.keyedvectors.Vocab at 0x19c6c4a4160>,
#  'prefirió': <gensim.models.keyedvectors.Vocab at 0x19c6c4a4198>,
#  'declarar': <gensim.models.keyedvectors.Vocab at 0x19c6c4a41d0>,
#  'aprecia': <gensim.models.keyedvectors.Vocab at 0x19c6c4a4240>,
#  'imágenes': <gensim.models.keyedvectors.Vocab at 0x19c6c4a4278>,
#  'programa': <gensim.models.keyedvectors.Vocab at 0x19c6c4a42b0>,
#  'magaly': <gensim.models.keyedvectors.Vocab at 0x19c6c4a4320>,
#  'medina': <gensim.models.keyedvectors.Vocab at 0x19c6c4a4390>,
#  'tyson': <gensim.models.keyedvectors.Vocab at 0x19c6c4a4400>,
#  'hablaría': <gensim.models.keyedvectors.Vocab at 0x19c6c4a4438>,
#  'privada': <gensim.models.keyedvectors.Vocab at 0x19c6c4a44a8>,
#  'evadió': <gensim.models.keyedvectors.Vocab at 0x19c6c4a44e0>,
#  'consultadas': <gensim.models.keyedvectors.Vocab at 0x19c6c4a4518>,
#  'reportero': <gensim.models.keyedvectors.Vocab at 0x19c6c4a4550>,
#  'presentes': <gensim.models.keyedvectors.Vocab at 0x19c6c4a4588>,
#  'paolo': <gensim.models.keyedvectors.Vocab at 0x19c6c4a45f8>,
#  'maldonado': <gensim.models.keyedvectors.Vocab at 0x19c6c4a4630>,
#  'manuel': <gensim.models.keyedvectors.Vocab at 0x19c6c4a46a0>,
#  'vargas': <gensim.models.keyedvectors.Vocab at 0x19c6c4a4710>,
#  'mostró': <gensim.models.keyedvectors.Vocab at 0x19c6c4a4748>,
#  'risueño': <gensim.models.keyedvectors.Vocab at 0x19c6c4a4780>,
#  'principio': <gensim.models.keyedvectors.Vocab at 0x19c6c4a47b8>,
#  'propiedades': <gensim.models.keyedvectors.Vocab at 0x19c6c4a47f0>,
#  'denuncias': <gensim.models.keyedvectors.Vocab at 0x19c6c4a4828>,
#  'incómodo': <gensim.models.keyedvectors.Vocab at 0x19c6c4a4860>,
#  'disculpa': <gensim.models.keyedvectors.Vocab at 0x19c6c4a4898>,
#  'hablo': <gensim.models.keyedvectors.Vocab at 0x19c6c4a4908>,
#  'favor': <gensim.models.keyedvectors.Vocab at 0x19c6c4a4978>,
#  'agradezco': <gensim.models.keyedvectors.Vocab at 0x19c6c4a49b0>,
#  'montón': <gensim.models.keyedvectors.Vocab at 0x19c6c4a49e8>,
#  'hablar': <gensim.models.keyedvectors.Vocab at 0x19c6c4a4a58>,
#  'ustedes': <gensim.models.keyedvectors.Vocab at 0x19c6c4a4ac8>,
#  'contigo': <gensim.models.keyedvectors.Vocab at 0x19c6c4a4b38>,
#  'gracias': <gensim.models.keyedvectors.Vocab at 0x19c6c4a4ba8>,
#  'puedes': <gensim.models.keyedvectors.Vocab at 0x19c6c4a4c18>,
#  'obligar': <gensim.models.keyedvectors.Vocab at 0x19c6c4a4c88>,
#  'hable': <gensim.models.keyedvectors.Vocab at 0x19c6c4a4cf8>,
#  'declaró': <gensim.models.keyedvectors.Vocab at 0x19c6c4a4d30>,
#  'jhon': <gensim.models.keyedvectors.Vocab at 0x19c6c4a4da0>,
#  'recordar': <gensim.models.keyedvectors.Vocab at 0x19c6c4a4dd8>,
#  'medidas': <gensim.models.keyedvectors.Vocab at 0x19c6c4a4e48>,
#  'protección': <gensim.models.keyedvectors.Vocab at 0x19c6c4a4e80>,
#  'pisco': <gensim.models.keyedvectors.Vocab at 0x19c6c4a4ef0>,
#  'denunciar': <gensim.models.keyedvectors.Vocab at 0x19c6c4a4f28>,
#  'agentes': <gensim.models.keyedvectors.Vocab at 0x19c6c4a4f98>,
#  'ignoran': <gensim.models.keyedvectors.Vocab at 0x19c6c4ac048>,
#  'informa': <gensim.models.keyedvectors.Vocab at 0x19c6c4ac0b8>,
#  'marzo': <gensim.models.keyedvectors.Vocab at 0x19c6c4ac128>,
#  'denunciado': <gensim.models.keyedvectors.Vocab at 0x19c6c4ac160>,
#  'doméstica': <gensim.models.keyedvectors.Vocab at 0x19c6c4ac198>,
#  'querido': <gensim.models.keyedvectors.Vocab at 0x19c6c4ac208>,
#  'ahogar': <gensim.models.keyedvectors.Vocab at 0x19c6c4ac278>,
#  'mar': <gensim.models.keyedvectors.Vocab at 0x19c6c4ac2e8>,
#  'discusión': <gensim.models.keyedvectors.Vocab at 0x19c6c4ac320>,
#  'pateaba': <gensim.models.keyedvectors.Vocab at 0x19c6c4ac390>,
#  'punto': <gensim.models.keyedvectors.Vocab at 0x19c6c4ac400>,
#  'hacerme': <gensim.models.keyedvectors.Vocab at 0x19c6c4ac470>,
#  'vomitar': <gensim.models.keyedvectors.Vocab at 0x19c6c4ac4e0>,
#  'sangre': <gensim.models.keyedvectors.Vocab at 0x19c6c4ac550>,
#  'rompe': <gensim.models.keyedvectors.Vocab at 0x19c6c4ac5c0>,
#  'mandíbula': <gensim.models.keyedvectors.Vocab at 0x19c6c4ac5f8>,
#  'patea': <gensim.models.keyedvectors.Vocab at 0x19c6c4ac668>,
#  'calle': <gensim.models.keyedvectors.Vocab at 0x19c6c4ac6d8>,
#  'esperando': <gensim.models.keyedvectors.Vocab at 0x19c6c4ac710>,
#  'mate': <gensim.models.keyedvectors.Vocab at 0x19c6c4ac780>,
#  'medio': <gensim.models.keyedvectors.Vocab at 0x19c6c4ac7f0>,
#  'lágrimas': <gensim.models.keyedvectors.Vocab at 0x19c6c4ac828>,
#  'denunciante': <gensim.models.keyedvectors.Vocab at 0x19c6c4ac860>,
#  'jugador': <gensim.models.keyedvectors.Vocab at 0x19c6c4ac8d0>,
#  'aparece': <gensim.models.keyedvectors.Vocab at 0x19c6c4ac940>,
#  'cuchillo': <gensim.models.keyedvectors.Vocab at 0x19c6c4ac978>,
#  'audio': <gensim.models.keyedvectors.Vocab at 0x19c6c4ac9e8>,
#  'cárcel': <gensim.models.keyedvectors.Vocab at 0x19c6c4aca20>,
#  'matar': <gensim.models.keyedvectors.Vocab at 0x19c6c4aca90>,
#  'duras': <gensim.models.keyedvectors.Vocab at 0x19c6c4acb00>,
#  'críticas': <gensim.models.keyedvectors.Vocab at 0x19c6c4acb38>,
#  'recibiendo': <gensim.models.keyedvectors.Vocab at 0x19c6c4acb70>,
#  'comentarista': <gensim.models.keyedvectors.Vocab at 0x19c6c4acba8>,
#  'silvio': <gensim.models.keyedvectors.Vocab at 0x19c6c4acc18>,
#  'valencia': <gensim.models.keyedvectors.Vocab at 0x19c6c4acc50>,
#  'vivo': <gensim.models.keyedvectors.Vocab at 0x19c6c4accc0>,
#  'hinchas': <gensim.models.keyedvectors.Vocab at 0x19c6c4acd30>,
#  'sport': <gensim.models.keyedvectors.Vocab at 0x19c6c4acda0>,
#  'boys': <gensim.models.keyedvectors.Vocab at 0x19c6c4ace10>,
#  'plato': <gensim.models.keyedvectors.Vocab at 0x19c6c4ace80>,
#  'comida': <gensim.models.keyedvectors.Vocab at 0x19c6c4acef0>,
#  'penosas': <gensim.models.keyedvectors.Vocab at 0x19c6c4acf60>,
#  'declaraciones': <gensim.models.keyedvectors.Vocab at 0x19c6c4acf98>,
#  'difundió': <gensim.models.keyedvectors.Vocab at 0x19c6c4acfd0>,
#  'espacio': <gensim.models.keyedvectors.Vocab at 0x19c6c4b2080>,
#  'televisivo': <gensim.models.keyedvectors.Vocab at 0x19c6c4b20b8>,
#  'conduce': <gensim.models.keyedvectors.Vocab at 0x19c6c4b2128>,
#  'conductores': <gensim.models.keyedvectors.Vocab at 0x19c6c4b2160>,
#  'cobra': <gensim.models.keyedvectors.Vocab at 0x19c6c4b21d0>,
#  'entradas': <gensim.models.keyedvectors.Vocab at 0x19c6c4b2208>,
#  'asistentes': <gensim.models.keyedvectors.Vocab at 0x19c6c4b2240>,
#  'estrategia': <gensim.models.keyedvectors.Vocab at 0x19c6c4b2278>,
#  'misilera': <gensim.models.keyedvectors.Vocab at 0x19c6c4b22b0>,
#  'consiste': <gensim.models.keyedvectors.Vocab at 0x19c6c4b22e8>,
#  'pago': <gensim.models.keyedvectors.Vocab at 0x19c6c4b2358>,
#  'voluntario': <gensim.models.keyedvectors.Vocab at 0x19c6c4b2390>,
#  'concepto': <gensim.models.keyedvectors.Vocab at 0x19c6c4b23c8>,
#  'precio': <gensim.models.keyedvectors.Vocab at 0x19c6c4b2438>,
#  'compañeros': <gensim.models.keyedvectors.Vocab at 0x19c6c4b2470>,
#  'sostuvo': <gensim.models.keyedvectors.Vocab at 0x19c6c4b24e0>,
#  'montos': <gensim.models.keyedvectors.Vocab at 0x19c6c4b2550>,
#  'cobran': <gensim.models.keyedvectors.Vocab at 0x19c6c4b25c0>,
#  'recuperan': <gensim.models.keyedvectors.Vocab at 0x19c6c4b25f8>,
#  'venta': <gensim.models.keyedvectors.Vocab at 0x19c6c4b2668>,
#  'estadio': <gensim.models.keyedvectors.Vocab at 0x19c6c4b26d8>,
#  'miguel': <gensim.models.keyedvectors.Vocab at 0x19c6c4b2748>,
#  'grau': <gensim.models.keyedvectors.Vocab at 0x19c6c4b27b8>,
#  'callao': <gensim.models.keyedvectors.Vocab at 0x19c6c4b2828>,
#  'táctica': <gensim.models.keyedvectors.Vocab at 0x19c6c4b2860>,
#  'busca': <gensim.models.keyedvectors.Vocab at 0x19c6c4b28d0>,
#  'asistencia': <gensim.models.keyedvectors.Vocab at 0x19c6c4b2908>,
#  'personas': <gensim.models.keyedvectors.Vocab at 0x19c6c4b2940>,
#  'alentar': <gensim.models.keyedvectors.Vocab at 0x19c6c4b29b0>,
#  'equipo': <gensim.models.keyedvectors.Vocab at 0x19c6c4b2a20>,
#  'evitar': <gensim.models.keyedvectors.Vocab at 0x19c6c4b2a90>,
#  'descenso': <gensim.models.keyedvectors.Vocab at 0x19c6c4b2ac8>,
#  'división': <gensim.models.keyedvectors.Vocab at 0x19c6c4b2b00>,
#  'incorrecta': <gensim.models.keyedvectors.Vocab at 0x19c6c4b2b38>,
#  'postura': <gensim.models.keyedvectors.Vocab at 0x19c6c4b2ba8>,
#  'gente': <gensim.models.keyedvectors.Vocab at 0x19c6c4b2c18>,
#  'chicos': <gensim.models.keyedvectors.Vocab at 0x19c6c4b2c88>,
#  'paran': <gensim.models.keyedvectors.Vocab at 0x19c6c4b2cf8>,
#  '5': <gensim.models.keyedvectors.Vocab at 0x19c6c4b2d30>,
#  '3': <gensim.models.keyedvectors.Vocab at 0x19c6c4b2d68>,
#  'soles': <gensim.models.keyedvectors.Vocab at 0x19c6c4b2dd8>,
#  'pagar': <gensim.models.keyedvectors.Vocab at 0x19c6c4b2e48>,
#  'menú': <gensim.models.keyedvectors.Vocab at 0x19c6c4b2e80>,
#  'actualización': <gensim.models.keyedvectors.Vocab at 0x19c6c4b2eb8>,
#  'fiscal': <gensim.models.keyedvectors.Vocab at 0x19c6c4b2f28>,
#  'josé': <gensim.models.keyedvectors.Vocab at 0x19c6c4b2f60>,
#  'domingo': <gensim.models.keyedvectors.Vocab at 0x19c6c4b2fd0>,
#  'pérez': <gensim.models.keyedvectors.Vocab at 0x19c6c4b7048>,
#  'reprogramó': <gensim.models.keyedvectors.Vocab at 0x19c6c4b7080>,
#  'interrogatorio': <gensim.models.keyedvectors.Vocab at 0x19c6c4b70b8>,
#  'exasesor': <gensim.models.keyedvectors.Vocab at 0x19c6c4b70f0>,
#  'presidencial': <gensim.models.keyedvectors.Vocab at 0x19c6c4b7128>,
#  'vladimiro': <gensim.models.keyedvectors.Vocab at 0x19c6c4b7160>,
#  'montesinos': <gensim.models.keyedvectors.Vocab at 0x19c6c4b7198>,
#  'lunes': <gensim.models.keyedvectors.Vocab at 0x19c6c4b7208>,
#  '7': <gensim.models.keyedvectors.Vocab at 0x19c6c4b7240>,
#  'octubre': <gensim.models.keyedvectors.Vocab at 0x19c6c4b72b0>,
#  'disposición': <gensim.models.keyedvectors.Vocab at 0x19c6c4b72e8>,
#  'accedió': <gensim.models.keyedvectors.Vocab at 0x19c6c4b7320>,
#  'cambio': <gensim.models.keyedvectors.Vocab at 0x19c6c4b7390>,
#  'fecha': <gensim.models.keyedvectors.Vocab at 0x19c6c4b7400>,
#  'participar': <gensim.models.keyedvectors.Vocab at 0x19c6c4b7438>,
#  'audiencias': <gensim.models.keyedvectors.Vocab at 0x19c6c4b7470>,
#  'convocadas': <gensim.models.keyedvectors.Vocab at 0x19c6c4b74a8>,
#  'penal': <gensim.models.keyedvectors.Vocab at 0x19c6c4b7518>,
#  'superior': <gensim.models.keyedvectors.Vocab at 0x19c6c4b7550>,
#  'transitoria': <gensim.models.keyedvectors.Vocab at 0x19c6c4b7588>,
#  'corte': <gensim.models.keyedvectors.Vocab at 0x19c6c4b75f8>,
#  'especializada': <gensim.models.keyedvectors.Vocab at 0x19c6c4b7630>,
#  'analizar': <gensim.models.keyedvectors.Vocab at 0x19c6c4b7668>,
#  'casos': <gensim.models.keyedvectors.Vocab at 0x19c6c4b76d8>,
#  'derechos': <gensim.models.keyedvectors.Vocab at 0x19c6c4b7710>,
#  'humanos': <gensim.models.keyedvectors.Vocab at 0x19c6c4b7780>,
#  'pedro': <gensim.models.keyedvectors.Vocab at 0x19c6c4b77f0>,
#  'huilca': <gensim.models.keyedvectors.Vocab at 0x19c6c4b7860>,
#  'mariella': <gensim.models.keyedvectors.Vocab at 0x19c6c4b7898>,
#  'barreto': <gensim.models.keyedvectors.Vocab at 0x19c6c4b7908>,
#  'imposible': <gensim.models.keyedvectors.Vocab at 0x19c6c4b7940>,
#  'doc': <gensim.models.keyedvectors.Vocab at 0x19c6c4b79b0>,
#  'responder': <gensim.models.keyedvectors.Vocab at 0x19c6c4b79e8>,
#  'interrogantes': <gensim.models.keyedvectors.Vocab at 0x19c6c4b7a20>,
#  'documento': <gensim.models.keyedvectors.Vocab at 0x19c6c4b7a58>,
#  'señala': <gensim.models.keyedvectors.Vocab at 0x19c6c4b7a90>,
#  '14': <gensim.models.keyedvectors.Vocab at 0x19c6c4b7b00>,
#  'tomará': <gensim.models.keyedvectors.Vocab at 0x19c6c4b7b38>,
#  'declaración': <gensim.models.keyedvectors.Vocab at 0x19c6c4b7b70>,
#  'eduardo': <gensim.models.keyedvectors.Vocab at 0x19c6c4b7be0>,
#  'felipe': <gensim.models.keyedvectors.Vocab at 0x19c6c4b7c50>,
#  'cabrera': <gensim.models.keyedvectors.Vocab at 0x19c6c4b7cc0>,
#  'ganoza': <gensim.models.keyedvectors.Vocab at 0x19c6c4b7d30>,
#  'congresista': <gensim.models.keyedvectors.Vocab at 0x19c6c4b7d68>,
#  'república': <gensim.models.keyedvectors.Vocab at 0x19c6c4b7da0>,
#  'ica': <gensim.models.keyedvectors.Vocab at 0x19c6c4b7e10>,
#  'representando': <gensim.models.keyedvectors.Vocab at 0x19c6c4b7e48>,
#  'fuerza': <gensim.models.keyedvectors.Vocab at 0x19c6c4b7eb8>,
#  '2011': <gensim.models.keyedvectors.Vocab at 0x19c6c4b7f28>,
#  'postuló': <gensim.models.keyedvectors.Vocab at 0x19c6c4b7f60>,
#  'presidente': <gensim.models.keyedvectors.Vocab at 0x19c6c4b7f98>,
#  'regional': <gensim.models.keyedvectors.Vocab at 0x19c6c4b7fd0>,
#  'nota': <gensim.models.keyedvectors.Vocab at 0x19c6c4bf080>,
#  'original': <gensim.models.keyedvectors.Vocab at 0x19c6c4bf0b8>,
#  'martes': <gensim.models.keyedvectors.Vocab at 0x19c6c4bf128>,
#  'irá': <gensim.models.keyedvectors.Vocab at 0x19c6c4bf160>,
#  'base': <gensim.models.keyedvectors.Vocab at 0x19c6c4bf1d0>,
#  'naval': <gensim.models.keyedvectors.Vocab at 0x19c6c4bf240>,
#  'interrogar': <gensim.models.keyedvectors.Vocab at 0x19c6c4bf278>,
#  'purga': <gensim.models.keyedvectors.Vocab at 0x19c6c4bf2e8>,
#  'condena': <gensim.models.keyedvectors.Vocab at 0x19c6c4bf358>,
#  'distintos': <gensim.models.keyedvectors.Vocab at 0x19c6c4bf390>,
#  'delitos': <gensim.models.keyedvectors.Vocab at 0x19c6c4bf400>,
#  'cometidos': <gensim.models.keyedvectors.Vocab at 0x19c6c4bf438>,
#  'gobierno': <gensim.models.keyedvectors.Vocab at 0x19c6c4bf470>,
#  'alberto': <gensim.models.keyedvectors.Vocab at 0x19c6c4bf4e0>,
#  'fujimori': <gensim.models.keyedvectors.Vocab at 0x19c6c4bf518>,
#  'diligencia': <gensim.models.keyedvectors.Vocab at 0x19c6c4bf550>,
#  'fijada': <gensim.models.keyedvectors.Vocab at 0x19c6c4bf5c0>,
#  '10': <gensim.models.keyedvectors.Vocab at 0x19c6c4bf630>,
#  'mañana': <gensim.models.keyedvectors.Vocab at 0x19c6c4bf668>,
#  'especial': <gensim.models.keyedvectors.Vocab at 0x19c6c4bf6a0>,
#  'lava': <gensim.models.keyedvectors.Vocab at 0x19c6c4bf710>,
#  'jato': <gensim.models.keyedvectors.Vocab at 0x19c6c4bf780>,
#  'formulará': <gensim.models.keyedvectors.Vocab at 0x19c6c4bf7b8>,
#  'pliego': <gensim.models.keyedvectors.Vocab at 0x19c6c4bf828>,
#  'preguntas': <gensim.models.keyedvectors.Vocab at 0x19c6c4bf860>,
#  'encontrar': <gensim.models.keyedvectors.Vocab at 0x19c6c4bf898>,
#  'luces': <gensim.models.keyedvectors.Vocab at 0x19c6c4bf908>,
#  'verdadero': <gensim.models.keyedvectors.Vocab at 0x19c6c4bf940>,
#  'rol': <gensim.models.keyedvectors.Vocab at 0x19c6c4bf9b0>,
#  'cumplió': <gensim.models.keyedvectors.Vocab at 0x19c6c4bf9e8>,
#  'abogado': <gensim.models.keyedvectors.Vocab at 0x19c6c4bfa58>,
#  'vicente': <gensim.models.keyedvectors.Vocab at 0x19c6c4bfac8>,
#  'silva': <gensim.models.keyedvectors.Vocab at 0x19c6c4bfb38>,
#  'checa': <gensim.models.keyedvectors.Vocab at 0x19c6c4bfba8>,
#  'campaña': <gensim.models.keyedvectors.Vocab at 0x19c6c4bfbe0>,
#  '2016': <gensim.models.keyedvectors.Vocab at 0x19c6c4bfc50>,
#  'tesis': <gensim.models.keyedvectors.Vocab at 0x19c6c4bfcc0>,
#  'lidera': <gensim.models.keyedvectors.Vocab at 0x19c6c4bfd30>,
#  'keiko': <gensim.models.keyedvectors.Vocab at 0x19c6c4bfda0>,
#  'recibido': <gensim.models.keyedvectors.Vocab at 0x19c6c4bfdd8>,
#  'aportes': <gensim.models.keyedvectors.Vocab at 0x19c6c4bfe48>,
#  'irregulares': <gensim.models.keyedvectors.Vocab at 0x19c6c4bfe80>,
#  'constructora': <gensim.models.keyedvectors.Vocab at 0x19c6c4bfeb8>,
#  'brasileña': <gensim.models.keyedvectors.Vocab at 0x19c6c4bfef0>,
#  'odebrecht': <gensim.models.keyedvectors.Vocab at 0x19c6c4bff28>,
#  'financiamiento': <gensim.models.keyedvectors.Vocab at 0x19c6c4bff60>,
#  'motivo': <gensim.models.keyedvectors.Vocab at 0x19c6c4bffd0>,
#  'lideresa': <gensim.models.keyedvectors.Vocab at 0x19c6c4c6048>,
#  'cumple': <gensim.models.keyedvectors.Vocab at 0x19c6c4c60b8>,
#  'orden': <gensim.models.keyedvectors.Vocab at 0x19c6c4c6128>,
#  'prisión': <gensim.models.keyedvectors.Vocab at 0x19c6c4c6160>,
#  'preventiva': <gensim.models.keyedvectors.Vocab at 0x19c6c4c6198>,
#  '18': <gensim.models.keyedvectors.Vocab at 0x19c6c4c6208>,
#  'lavado': <gensim.models.keyedvectors.Vocab at 0x19c6c4c6278>,
#  'activos': <gensim.models.keyedvectors.Vocab at 0x19c6c4c62e8>,
#  'ministerio': <gensim.models.keyedvectors.Vocab at 0x19c6c4c6320>,
#  'público': <gensim.models.keyedvectors.Vocab at 0x19c6c4c6358>,
#  'sindica': <gensim.models.keyedvectors.Vocab at 0x19c6c4c63c8>,
#  'asesor': <gensim.models.keyedvectors.Vocab at 0x19c6c4c6438>,
#  'sombras': <gensim.models.keyedvectors.Vocab at 0x19c6c4c64a8>,
#  'higuchi': <gensim.models.keyedvectors.Vocab at 0x19c6c4c6518>,
#  'consiguiente': <gensim.models.keyedvectors.Vocab at 0x19c6c4c6550>,
#  'presunta': <gensim.models.keyedvectors.Vocab at 0x19c6c4c6588>,
#  'organización': <gensim.models.keyedvectors.Vocab at 0x19c6c4c65c0>,
#  'criminal': <gensim.models.keyedvectors.Vocab at 0x19c6c4c65f8>,
#  'enquistado': <gensim.models.keyedvectors.Vocab at 0x19c6c4c6630>,
#  'relación': <gensim.models.keyedvectors.Vocab at 0x19c6c4c6668>,
#  'señalado': <gensim.models.keyedvectors.Vocab at 0x19c6c4c66a0>,
#  'testaferros': <gensim.models.keyedvectors.Vocab at 0x19c6c4c66d8>,
#  'vladivideo': <gensim.models.keyedvectors.Vocab at 0x19c6c4c6710>,
#  'compra': <gensim.models.keyedvectors.Vocab at 0x19c6c4c6780>,
#  'línea': <gensim.models.keyedvectors.Vocab at 0x19c6c4c67b8>,
#  'editorial': <gensim.models.keyedvectors.Vocab at 0x19c6c4c67f0>,
#  'cable': <gensim.models.keyedvectors.Vocab at 0x19c6c4c6860>,
#  'canal': <gensim.models.keyedvectors.Vocab at 0x19c6c4c68d0>,
#  'noticias': <gensim.models.keyedvectors.Vocab at 0x19c6c4c6908>,
#  'ccn': <gensim.models.keyedvectors.Vocab at 0x19c6c4c6978>,
#  'yolanda': <gensim.models.keyedvectors.Vocab at 0x19c6c4c69e8>,
#  'rivera': <gensim.models.keyedvectors.Vocab at 0x19c6c4c6a58>,
#  'mujer': <gensim.models.keyedvectors.Vocab at 0x19c6c4c6ac8>,
#  'murió': <gensim.models.keyedvectors.Vocab at 0x19c6c4c6b00>,
#  'atacada': <gensim.models.keyedvectors.Vocab at 0x19c6c4c6b70>,
#  'delincuentes': <gensim.models.keyedvectors.Vocab at 0x19c6c4c6ba8>,
#  'huían': <gensim.models.keyedvectors.Vocab at 0x19c6c4c6be0>,
#  'policía': <gensim.models.keyedvectors.Vocab at 0x19c6c4c6c18>,
#  'distrito': <gensim.models.keyedvectors.Vocab at 0x19c6c4c6c50>,
#  'surco': <gensim.models.keyedvectors.Vocab at 0x19c6c4c6cc0>,
#  'pidió': <gensim.models.keyedvectors.Vocab at 0x19c6c4c6cf8>,
#  'realicen': <gensim.models.keyedvectors.Vocab at 0x19c6c4c6d30>,
#  'necesarias': <gensim.models.keyedvectors.Vocab at 0x19c6c4c6d68>,
#  'capturar': <gensim.models.keyedvectors.Vocab at 0x19c6c4c6da0>,
#  'criminales': <gensim.models.keyedvectors.Vocab at 0x19c6c4c6dd8>,
#  'hija': <gensim.models.keyedvectors.Vocab at 0x19c6c4c6e48>,
#  'hombre': <gensim.models.keyedvectors.Vocab at 0x19c6c4c6eb8>,
#  'conmocionado': <gensim.models.keyedvectors.Vocab at 0x19c6c4c6ef0>,
#  'determina': <gensim.models.keyedvectors.Vocab at 0x19c6c4c6f28>,
#  'bala': <gensim.models.keyedvectors.Vocab at 0x19c6c4c6f98>,
#  'impactó': <gensim.models.keyedvectors.Vocab at 0x19c6c4c6fd0>,
#  'policías': <gensim.models.keyedvectors.Vocab at 0x19c6c4cb048>,
#  'ladrones': <gensim.models.keyedvectors.Vocab at 0x19c6c4cb080>,
#  'culparse': <gensim.models.keyedvectors.Vocab at 0x19c6c4cb0b8>,
#  'efectivos': <gensim.models.keyedvectors.Vocab at 0x19c6c4cb0f0>,
#  'cumplían': <gensim.models.keyedvectors.Vocab at 0x19c6c4cb128>,
#  'culpen': <gensim.models.keyedvectors.Vocab at 0x19c6c4cb198>,
#  'colegas': <gensim.models.keyedvectors.Vocab at 0x19c6c4cb208>,
#  'seguiré': <gensim.models.keyedvectors.Vocab at 0x19c6c4cb240>,
#  'siéndolo': <gensim.models.keyedvectors.Vocab at 0x19c6c4cb278>,
#  'muera': <gensim.models.keyedvectors.Vocab at 0x19c6c4cb2e8>,
#  'oficial': <gensim.models.keyedvectors.Vocab at 0x19c6c4cb358>,
#  'retiro': <gensim.models.keyedvectors.Vocab at 0x19c6c4cb3c8>,
#  'necesita': <gensim.models.keyedvectors.Vocab at 0x19c6c4cb400>,
#  'urgencia': <gensim.models.keyedvectors.Vocab at 0x19c6c4cb438>,
#  'país': <gensim.models.keyedvectors.Vocab at 0x19c6c4cb470>,
#  'empezando': <gensim.models.keyedvectors.Vocab at 0x19c6c4cb4a8>,
#  'falta': <gensim.models.keyedvectors.Vocab at 0x19c6c4cb518>,
#  'intervengan': <gensim.models.keyedvectors.Vocab at 0x19c6c4cb550>,
#  'vendan': <gensim.models.keyedvectors.Vocab at 0x19c6c4cb5c0>,
#  'dinero': <gensim.models.keyedvectors.Vocab at 0x19c6c4cb630>,
#  'impartan': <gensim.models.keyedvectors.Vocab at 0x19c6c4cb668>,
#  'quiénes': <gensim.models.keyedvectors.Vocab at 0x19c6c4cb6a0>,
#  'corruptos': <gensim.models.keyedvectors.Vocab at 0x19c6c4cb6d8>,
#  'corrupta': <gensim.models.keyedvectors.Vocab at 0x19c6c4cb710>,
#  'manipulan': <gensim.models.keyedvectors.Vocab at 0x19c6c4cb748>,
#  'juez': <gensim.models.keyedvectors.Vocab at 0x19c6c4cb7b8>,
#  'pobre': <gensim.models.keyedvectors.Vocab at 0x19c6c4cb828>,
#  'mete': <gensim.models.keyedvectors.Vocab at 0x19c6c4cb898>,
#  'balazo': <gensim.models.keyedvectors.Vocab at 0x19c6c4cb908>,
#  'choro': <gensim.models.keyedvectors.Vocab at 0x19c6c4cb978>,
#  'queda': <gensim.models.keyedvectors.Vocab at 0x19c6c4cb9e8>,
#  'preso': <gensim.models.keyedvectors.Vocab at 0x19c6c4cba58>,
#  'pido': <gensim.models.keyedvectors.Vocab at 0x19c6c4cbac8>,
#  'luchen': <gensim.models.keyedvectors.Vocab at 0x19c6c4cbb38>,
#  'quiero': <gensim.models.keyedvectors.Vocab at 0x19c6c4cbba8>,
#  'capture': <gensim.models.keyedvectors.Vocab at 0x19c6c4cbc18>,
#  'interesa': <gensim.models.keyedvectors.Vocab at 0x19c6c4cbc50>,
#  'balas': <gensim.models.keyedvectors.Vocab at 0x19c6c4cbcc0>,
#  'muerta': <gensim.models.keyedvectors.Vocab at 0x19c6c4cbd30>,
#  'culpa': <gensim.models.keyedvectors.Vocab at 0x19c6c4cbda0>,
#  'única': <gensim.models.keyedvectors.Vocab at 0x19c6c4cbdd8>,
#  'quebrarse': <gensim.models.keyedvectors.Vocab at 0x19c6c4cbe10>,
#  'datos': <gensim.models.keyedvectors.Vocab at 0x19c6c4cbe80>,
#  '29': <gensim.models.keyedvectors.Vocab at 0x19c6c4cbef0>,
#  'casquillos': <gensim.models.keyedvectors.Vocab at 0x19c6c4cbf28>,
#  'encontraron': <gensim.models.keyedvectors.Vocab at 0x19c6c4cbf60>,
#  'balacera': <gensim.models.keyedvectors.Vocab at 0x19c6c4cbf98>,
#  'molina': <gensim.models.keyedvectors.Vocab at 0x19c6c4d2048>,
#  'esposo': <gensim.models.keyedvectors.Vocab at 0x19c6c4d20b8>,
#  'herido': <gensim.models.keyedvectors.Vocab at 0x19c6c4d2128>,
#  'brazo': <gensim.models.keyedvectors.Vocab at 0x19c6c4d2198>,
#  'exjuez': <gensim.models.keyedvectors.Vocab at 0x19c6c4d2208>,
#  'supremo': <gensim.models.keyedvectors.Vocab at 0x19c6c4d2278>,
#  'césar': <gensim.models.keyedvectors.Vocab at 0x19c6c4d22b0>,
#  'hinostroza': <gensim.models.keyedvectors.Vocab at 0x19c6c4d22e8>,
#  'confirmó': <gensim.models.keyedvectors.Vocab at 0x19c6c4d2320>,
#  'recurrirá': <gensim.models.keyedvectors.Vocab at 0x19c6c4d2358>,
#  'tribunal': <gensim.models.keyedvectors.Vocab at 0x19c6c4d2390>,
#  'constitucional': <gensim.models.keyedvectors.Vocab at 0x19c6c4d23c8>,
#  'españa': <gensim.models.keyedvectors.Vocab at 0x19c6c4d2400>,
#  'buscar': <gensim.models.keyedvectors.Vocab at 0x19c6c4d2470>,
#  'anular': <gensim.models.keyedvectors.Vocab at 0x19c6c4d24e0>,
#  'extradición': <gensim.models.keyedvectors.Vocab at 0x19c6c4d2518>,
#  'aprobada': <gensim.models.keyedvectors.Vocab at 0x19c6c4d2550>,
#  'audiencia': <gensim.models.keyedvectors.Vocab at 0x19c6c4d2588>,
#  'difundido': <gensim.models.keyedvectors.Vocab at 0x19c6c4d25c0>,
#  'rpp': <gensim.models.keyedvectors.Vocab at 0x19c6c4d2630>,
#  'asegura': <gensim.models.keyedvectors.Vocab at 0x19c6c4d26a0>,
#  'sentencia': <gensim.models.keyedvectors.Vocab at 0x19c6c4d26d8>,
#  'rechazó': <gensim.models.keyedvectors.Vocab at 0x19c6c4d2710>,
#  'repatriación': <gensim.models.keyedvectors.Vocab at 0x19c6c4d2748>,
#  'cuestionó': <gensim.models.keyedvectors.Vocab at 0x19c6c4d2780>,
#  'aceptado': <gensim.models.keyedvectors.Vocab at 0x19c6c4d27b8>,
#  'imputan': <gensim.models.keyedvectors.Vocab at 0x19c6c4d2828>,
#  'conformes': <gensim.models.keyedvectors.Vocab at 0x19c6c4d2860>,
#  'rechazo': <gensim.models.keyedvectors.Vocab at 0x19c6c4d28d0>,
#  'patrocinio': <gensim.models.keyedvectors.Vocab at 0x19c6c4d2908>,
#  'ilegal': <gensim.models.keyedvectors.Vocab at 0x19c6c4d2978>,
#  'tráfico': <gensim.models.keyedvectors.Vocab at 0x19c6c4d29b0>,
#  'influencias': <gensim.models.keyedvectors.Vocab at 0x19c6c4d29e8>,
#  'negociación': <gensim.models.keyedvectors.Vocab at 0x19c6c4d2a20>,
#  'incompatible': <gensim.models.keyedvectors.Vocab at 0x19c6c4d2a58>,
#  'españoles': <gensim.models.keyedvectors.Vocab at 0x19c6c4d2a90>,
#  'erróneamente': <gensim.models.keyedvectors.Vocab at 0x19c6c4d2ac8>,
#  'interpretado': <gensim.models.keyedvectors.Vocab at 0x19c6c4d2b00>,
#  'exmagistrado': <gensim.models.keyedvectors.Vocab at 0x19c6c4d2b38>,
#  'interponer': <gensim.models.keyedvectors.Vocab at 0x19c6c4d2b70>,
#  'recurso': <gensim.models.keyedvectors.Vocab at 0x19c6c4d2be0>,
#  'amparo': <gensim.models.keyedvectors.Vocab at 0x19c6c4d2c50>,
#  'español': <gensim.models.keyedvectors.Vocab at 0x19c6c4d2c88>,
#  'eventualmente': <gensim.models.keyedvectors.Vocab at 0x19c6c4d2cc0>,
#  'europeo': <gensim.models.keyedvectors.Vocab at 0x19c6c4d2d30>,
#  'defensa': <gensim.models.keyedvectors.Vocab at 0x19c6c4d2da0>,
#  'carácter': <gensim.models.keyedvectors.Vocab at 0x19c6c4d2dd8>,
#  'universal': <gensim.models.keyedvectors.Vocab at 0x19c6c4d2e10>,
#  'reiteró': <gensim.models.keyedvectors.Vocab at 0x19c6c4d2e48>,
#  'imputados': <gensim.models.keyedvectors.Vocab at 0x19c6c4d2e80>,
#  'aprobados': <gensim.models.keyedvectors.Vocab at 0x19c6c4d2eb8>,
#  'congreso': <gensim.models.keyedvectors.Vocab at 0x19c6c4d2ef0>,
#  'actuó': <gensim.models.keyedvectors.Vocab at 0x19c6c4d2f28>,
#  'presión': <gensim.models.keyedvectors.Vocab at 0x19c6c4d2f60>,
#  'ley': <gensim.models.keyedvectors.Vocab at 0x19c6c4d2fd0>,
#  'española': <gensim.models.keyedvectors.Vocab at 0x19c6c4d9048>,
#  'penalistas': <gensim.models.keyedvectors.Vocab at 0x19c6c4d9080>,
#  'sindicado': <gensim.models.keyedvectors.Vocab at 0x19c6c4d90b8>,
#  'cabecilla': <gensim.models.keyedvectors.Vocab at 0x19c6c4d90f0>,
#  'cuellos': <gensim.models.keyedvectors.Vocab at 0x19c6c4d9160>,
#  'blancos': <gensim.models.keyedvectors.Vocab at 0x19c6c4d91d0>,
#  'puerto': <gensim.models.keyedvectors.Vocab at 0x19c6c4d9240>,
#  'pesan': <gensim.models.keyedvectors.Vocab at 0x19c6c4d92b0>,
#  'órdenes': <gensim.models.keyedvectors.Vocab at 0x19c6c4d92e8>,
#  'caso': <gensim.models.keyedvectors.Vocab at 0x19c6c4d9358>,
#  'salido': <gensim.models.keyedvectors.Vocab at 0x19c6c4d93c8>,
#  'pese': <gensim.models.keyedvectors.Vocab at 0x19c6c4d9438>,
#  'impedimento': <gensim.models.keyedvectors.Vocab at 0x19c6c4d9470>,
#  'abandonar': <gensim.models.keyedvectors.Vocab at 0x19c6c4d94a8>,
#  'perú': <gensim.models.keyedvectors.Vocab at 0x19c6c4d94e0>,
#  'salir': <gensim.models.keyedvectors.Vocab at 0x19c6c4d9550>,
#  'internacional': <gensim.models.keyedvectors.Vocab at 0x19c6c4d9588>,
#  'respetan': <gensim.models.keyedvectors.Vocab at 0x19c6c4d95c0>,
#  'evadir': <gensim.models.keyedvectors.Vocab at 0x19c6c4d9630>,
#  'fugar': <gensim.models.keyedvectors.Vocab at 0x19c6c4d96a0>,
#  'falsamente': <gensim.models.keyedvectors.Vocab at 0x19c6c4d96d8>,
#  'menciona': <gensim.models.keyedvectors.Vocab at 0x19c6c4d9710>,
#  'saludado': <gensim.models.keyedvectors.Vocab at 0x19c6c4d9748>,
#  'extraditarlo': <gensim.models.keyedvectors.Vocab at 0x19c6c4d9780>,
#  'sigan': <gensim.models.keyedvectors.Vocab at 0x19c6c4d97f0>,
#  'acusando': <gensim.models.keyedvectors.Vocab at 0x19c6c4d9828>,
#  'espero': <gensim.models.keyedvectors.Vocab at 0x19c6c4d9898>,
#  'dejen': <gensim.models.keyedvectors.Vocab at 0x19c6c4d9908>,
#  'dignidad': <gensim.models.keyedvectors.Vocab at 0x19c6c4d9940>,
#  'humana': <gensim.models.keyedvectors.Vocab at 0x19c6c4d99b0>,
#  'horas': <gensim.models.keyedvectors.Vocab at 0x19c6c4d9a20>,
#  'oficina': <gensim.models.keyedvectors.Vocab at 0x19c6c4d9a90>,
#  'volvían': <gensim.models.keyedvectors.Vocab at 0x19c6c4d9ac8>,
#  'eternas': <gensim.models.keyedvectors.Vocab at 0x19c6c4d9b38>,
# ...
#  'inconclusos': <gensim.models.keyedvectors.Vocab at 0x19c6c4e1358>,
#  'finalizar': <gensim.models.keyedvectors.Vocab at 0x19c6c4e1390>,
#  'escuela': <gensim.models.keyedvectors.Vocab at 0x19c6c4e1400>,
#  'cocinero': <gensim.models.keyedvectors.Vocab at 0x19c6c4e1438>,
#  'regresaría': <gensim.models.keyedvectors.Vocab at 0x19c6c4e1470>,
#  'tarde': <gensim.models.keyedvectors.Vocab at 0x19c6c4e14e0>,
#  'perteneció': <gensim.models.keyedvectors.Vocab at 0x19c6c4e1518>,
#  'empresas': <gensim.models.keyedvectors.Vocab at 0x19c66d41c18>,
#  'importantes': <gensim.models.keyedvectors.Vocab at 0x19c6c437c88>,
#  'semanas': <gensim.models.keyedvectors.Vocab at 0x19c6c4e1588>,
#  'llegaban': <gensim.models.keyedvectors.Vocab at 0x19c6c4e15c0>,
#  'ajenas': <gensim.models.keyedvectors.Vocab at 0x19c6c4e1630>,
#  'debía': <gensim.models.keyedvectors.Vocab at 0x19c6c4e1668>,
#  'encaminar': <gensim.models.keyedvectors.Vocab at 0x19c6c4e16a0>,
#  'pensó': <gensim.models.keyedvectors.Vocab at 0x19c6c4e16d8>,
#  'destino': <gensim.models.keyedvectors.Vocab at 0x19c6c4e1748>,
#  'saco': <gensim.models.keyedvectors.Vocab at 0x19c6c4e17b8>,
#  'corbata': <gensim.models.keyedvectors.Vocab at 0x19c6c4e1828>,
#  'sentado': <gensim.models.keyedvectors.Vocab at 0x19c6c4e1898>,
#  'frente': <gensim.models.keyedvectors.Vocab at 0x19c6c4e1908>,
#  'pantalla': <gensim.models.keyedvectors.Vocab at 0x19c6c4e1940>,
#  'escritorio': <gensim.models.keyedvectors.Vocab at 0x19c6c4e1978>,
#  'viaje': <gensim.models.keyedvectors.Vocab at 0x19c6c4e19e8>,
#  'sao': <gensim.models.keyedvectors.Vocab at 0x19c6c4e1a58>,
#  'paulo': <gensim.models.keyedvectors.Vocab at 0x19c6c4e1ac8>,
#  'probó': <gensim.models.keyedvectors.Vocab at 0x19c6c4e1b00>,
#  'pizza': <gensim.models.keyedvectors.Vocab at 0x19c6c4e1b70>,
#  'común': <gensim.models.keyedvectors.Vocab at 0x19c6c4e1ba8>,
#  'insumos': <gensim.models.keyedvectors.Vocab at 0x19c6c4e1c18>,
#  'brasileños': <gensim.models.keyedvectors.Vocab at 0x19c6c4e1c50>,
#  'masa': <gensim.models.keyedvectors.Vocab at 0x19c6c4e1cc0>,
#  'tradicional': <gensim.models.keyedvectors.Vocab at 0x19c6c4e1cf8>,
#  'dejando': <gensim.models.keyedvectors.Vocab at 0x19c6c4e1d68>,
#  'típica': <gensim.models.keyedvectors.Vocab at 0x19c6c4e1da0>,
#  'americana': <gensim.models.keyedvectors.Vocab at 0x19c6c4e1dd8>,
#  'pepperoni': <gensim.models.keyedvectors.Vocab at 0x19c6c4e1e10>,
#  'allí': <gensim.models.keyedvectors.Vocab at 0x19c6c4e1e48>,
#  'supo': <gensim.models.keyedvectors.Vocab at 0x19c6c4e1eb8>,
#  'cuál': <gensim.models.keyedvectors.Vocab at 0x19c6c4e1ef0>,
#  'camino': <gensim.models.keyedvectors.Vocab at 0x19c6c4e1f60>,
#  'jefes': <gensim.models.keyedvectors.Vocab at 0x19c6c4e1fd0>,
#  'inauguró': <gensim.models.keyedvectors.Vocab at 0x19c6c4e8048>,
#  'oficialmente': <gensim.models.keyedvectors.Vocab at 0x19c6c4e8080>,
#  'agosto': <gensim.models.keyedvectors.Vocab at 0x19c6c4e80f0>,
#  '2017': <gensim.models.keyedvectors.Vocab at 0x19c6c4e8160>,
#  'surquillo': <gensim.models.keyedvectors.Vocab at 0x19c6c4e8198>,
#  'ahorros': <gensim.models.keyedvectors.Vocab at 0x19c6c4e8208>,
#  'bastaron': <gensim.models.keyedvectors.Vocab at 0x19c6c4e8240>,
#  'alquilar': <gensim.models.keyedvectors.Vocab at 0x19c6c4e8278>,
#  'local': <gensim.models.keyedvectors.Vocab at 0x19c6c4e82e8>,
#  'adquirir': <gensim.models.keyedvectors.Vocab at 0x19c6c4e8320>,
#  'maquinaria': <gensim.models.keyedvectors.Vocab at 0x19c6c4e8358>,
#  'preguntaba': <gensim.models.keyedvectors.Vocab at 0x19c6c4e8390>,
#  'metido': <gensim.models.keyedvectors.Vocab at 0x19c6c4e8400>,
#  'mano': <gensim.models.keyedvectors.Vocab at 0x19c6c4e8470>,
#  'empezó': <gensim.models.keyedvectors.Vocab at 0x19c6c4e84a8>,
#  'platos': <gensim.models.keyedvectors.Vocab at 0x19c6c4e8518>,
#  'adecuarlos': <gensim.models.keyedvectors.Vocab at 0x19c6c4e8550>,
#  'vea': <gensim.models.keyedvectors.Vocab at 0x19c6c4e85c0>,
#  'sepa': <gensim.models.keyedvectors.Vocab at 0x19c6c4e8630>,
#  'decidió': <gensim.models.keyedvectors.Vocab at 0x19c6c4e8668>,
#  'negocio': <gensim.models.keyedvectors.Vocab at 0x19c6c4e86d8>,
#  'demandar': <gensim.models.keyedvectors.Vocab at 0x19c6c4e8710>,
#  'tantas': <gensim.models.keyedvectors.Vocab at 0x19c6c4e8780>,
#  'creó': <gensim.models.keyedvectors.Vocab at 0x19c6c4e87b8>,
#  'cocina': <gensim.models.keyedvectors.Vocab at 0x19c6c4e8828>,
#  'fantasma': <gensim.models.keyedvectors.Vocab at 0x19c6c4e8860>,
#  'producción': <gensim.models.keyedvectors.Vocab at 0x19c6c4e8898>,
#  'repartida': <gensim.models.keyedvectors.Vocab at 0x19c6c4e88d0>,
#  'horario': <gensim.models.keyedvectors.Vocab at 0x19c6c4e8940>,
#  '6': <gensim.models.keyedvectors.Vocab at 0x19c6c4e8978>,
#  '11': <gensim.models.keyedvectors.Vocab at 0x19c6c4e89e8>,
#  'pm': <gensim.models.keyedvectors.Vocab at 0x19c6c4e8a58>,
#  'intención': <gensim.models.keyedvectors.Vocab at 0x19c6c4e8a90>,
#  'imitar': <gensim.models.keyedvectors.Vocab at 0x19c6c4e8b00>,
#  'corriente': <gensim.models.keyedvectors.Vocab at 0x19c6c4e8b38>,
#  'proviene': <gensim.models.keyedvectors.Vocab at 0x19c6c4e8b70>,
#  'europa': <gensim.models.keyedvectors.Vocab at 0x19c6c4e8be0>,
#  'asia': <gensim.models.keyedvectors.Vocab at 0x19c6c4e8c50>,
#  'unidos': <gensim.models.keyedvectors.Vocab at 0x19c6c4e8cc0>,
#  'aplicó': <gensim.models.keyedvectors.Vocab at 0x19c6c4e8cf8>,
#  'teoría': <gensim.models.keyedvectors.Vocab at 0x19c6c4e8d30>,
#  'empresa': <gensim.models.keyedvectors.Vocab at 0x19c6c4e8da0>,
#  'presencia': <gensim.models.keyedvectors.Vocab at 0x19c6c4e8dd8>,
#  'aplicaciones': <gensim.models.keyedvectors.Vocab at 0x19c6c4e8e10>,
#  'físico': <gensim.models.keyedvectors.Vocab at 0x19c6c4e8e48>,
#  'emprendimiento': <gensim.models.keyedvectors.Vocab at 0x19c6c4e8e80>,
#  'agregado': <gensim.models.keyedvectors.Vocab at 0x19c6c4e8eb8>,
#  'cajas': <gensim.models.keyedvectors.Vocab at 0x19c6c4e8f28>,
#  'obras': <gensim.models.keyedvectors.Vocab at 0x19c6c4e8f98>,
#  'arte': <gensim.models.keyedvectors.Vocab at 0x19c6c4ee048>,
#  'exhibe': <gensim.models.keyedvectors.Vocab at 0x19c6c4ee0b8>,
#  'creaciones': <gensim.models.keyedvectors.Vocab at 0x19c6c4ee0f0>,
#  'ilustradores': <gensim.models.keyedvectors.Vocab at 0x19c6c4ee128>,
#  'temas': <gensim.models.keyedvectors.Vocab at 0x19c6c4ee198>,
#  'nacionales': <gensim.models.keyedvectors.Vocab at 0x19c6c4ee1d0>,
#  'lema': <gensim.models.keyedvectors.Vocab at 0x19c6c4ee240>,
#  'consenso': <gensim.models.keyedvectors.Vocab at 0x19c6c4ee278>,
#  'u': <gensim.models.keyedvectors.Vocab at 0x19c6c4ee2b0>,
#  'cambie': <gensim.models.keyedvectors.Vocab at 0x19c6c4ee320>,
#  'lote': <gensim.models.keyedvectors.Vocab at 0x19c6c4ee390>,
#  'primeras': <gensim.models.keyedvectors.Vocab at 0x19c6c4ee3c8>,
#  'diseñadas': <gensim.models.keyedvectors.Vocab at 0x19c6c4ee400>,
#  'rojas': <gensim.models.keyedvectors.Vocab at 0x19c6c4ee470>,
#  'perros': <gensim.models.keyedvectors.Vocab at 0x19c6c4ee4e0>,
#  'alpaca': <gensim.models.keyedvectors.Vocab at 0x19c6c4ee550>,
#  'temporada': <gensim.models.keyedvectors.Vocab at 0x19c6c4ee588>,
#  'alegre': <gensim.models.keyedvectors.Vocab at 0x19c6c4ee5f8>,
#  'llegue': <gensim.models.keyedvectors.Vocab at 0x19c6c4ee668>,
#  'hogares': <gensim.models.keyedvectors.Vocab at 0x19c6c4ee6d8>,
#  'limeños': <gensim.models.keyedvectors.Vocab at 0x19c6c4ee710>,
#  'aureola': <gensim.models.keyedvectors.Vocab at 0x19c6c4ee780>,
#  'princesa': <gensim.models.keyedvectors.Vocab at 0x19c6c4ee7b8>,
#  'promueve': <gensim.models.keyedvectors.Vocab at 0x19c6c4ee7f0>,
#  'peruano': <gensim.models.keyedvectors.Vocab at 0x19c6c4ee860>,
#  'voltee': <gensim.models.keyedvectors.Vocab at 0x19c6c4ee8d0>,
#  'éxito': <gensim.models.keyedvectors.Vocab at 0x19c6c4ee908>,
#  'vertiginoso': <gensim.models.keyedvectors.Vocab at 0x19c6c4ee940>,
#  '2x1': <gensim.models.keyedvectors.Vocab at 0x19c6c4ee9b0>,
#  'distribuir': <gensim.models.keyedvectors.Vocab at 0x19c6c4ee9e8>,
#  'pizzas': <gensim.models.keyedvectors.Vocab at 0x19c6c4eea58>,
#  'comensales': <gensim.models.keyedvectors.Vocab at 0x19c6c4eea90>,
#  'enamoraron': <gensim.models.keyedvectors.Vocab at 0x19c6c4eeac8>,
#  'sabores': <gensim.models.keyedvectors.Vocab at 0x19c6c4eeb38>,
#  'langostinos': <gensim.models.keyedvectors.Vocab at 0x19c6c4eeb70>,
#  'anticucheros': <gensim.models.keyedvectors.Vocab at 0x19c6c4eeba8>,
#  'lanzado': <gensim.models.keyedvectors.Vocab at 0x19c6c4eec18>,
#  'verano': <gensim.models.keyedvectors.Vocab at 0x19c6c4eec88>,
#  'quedado': <gensim.models.keyedvectors.Vocab at 0x19c6c4eecf8>,
#  'butifarra': <gensim.models.keyedvectors.Vocab at 0x19c6c4eed30>,
#  'huachana': <gensim.models.keyedvectors.Vocab at 0x19c6c4eed68>,
#  'llegar': <gensim.models.keyedvectors.Vocab at 0x19c6c4eedd8>,
#  'plasmar': <gensim.models.keyedvectors.Vocab at 0x19c6c4eee48>,
#  'idea': <gensim.models.keyedvectors.Vocab at 0x19c6c4eeeb8>,
#  'unir': <gensim.models.keyedvectors.Vocab at 0x19c6c4eef28>,
#  'tradiciones': <gensim.models.keyedvectors.Vocab at 0x19c6c4eef60>,
#  'italiana': <gensim.models.keyedvectors.Vocab at 0x19c6c4eef98>,
#  'difícil': <gensim.models.keyedvectors.Vocab at 0x19c6c4eefd0>,
#  'constante': <gensim.models.keyedvectors.Vocab at 0x19c6c4f5048>,
#  'prueba': <gensim.models.keyedvectors.Vocab at 0x19c6c4f50b8>,
#  'error': <gensim.models.keyedvectors.Vocab at 0x19c6c4f5128>,
#  'parecían': <gensim.models.keyedvectors.Vocab at 0x19c6c4f5160>,
#  'contundentes': <gensim.models.keyedvectors.Vocab at 0x19c6c4f5198>,
#  'faltaba': <gensim.models.keyedvectors.Vocab at 0x19c6c4f5208>,
#  'arroz': <gensim.models.keyedvectors.Vocab at 0x19c6c4f5278>,
#  'bota': <gensim.models.keyedvectors.Vocab at 0x19c6c4f52e8>,
#  'carcajada': <gensim.models.keyedvectors.Vocab at 0x19c6c4f5320>,
#  'cómplice': <gensim.models.keyedvectors.Vocab at 0x19c6c4f5358>,
#  'colaboradores': <gensim.models.keyedvectors.Vocab at 0x19c6c4f5390>,
#  'desarrollado': <gensim.models.keyedvectors.Vocab at 0x19c6c4f53c8>,
#  'entramos': <gensim.models.keyedvectors.Vocab at 0x19c6c4f5400>,
#  'fase': <gensim.models.keyedvectors.Vocab at 0x19c6c4f5470>,
#  'multiplicar': <gensim.models.keyedvectors.Vocab at 0x19c6c4f54a8>,
#  'planea': <gensim.models.keyedvectors.Vocab at 0x19c6c4f5518>,
#  'meta': <gensim.models.keyedvectors.Vocab at 0x19c6c4f5588>,
#  'denominación': <gensim.models.keyedvectors.Vocab at 0x19c6c4f55c0>,
#  'mundial': <gensim.models.keyedvectors.Vocab at 0x19c6c4f5630>,
#  'gringo': <gensim.models.keyedvectors.Vocab at 0x19c6c4f56a0>,
#  'diga': <gensim.models.keyedvectors.Vocab at 0x19c6c4f5710>,
#  'are': <gensim.models.keyedvectors.Vocab at 0x19c6c4f5780>,
#  'you': <gensim.models.keyedvectors.Vocab at 0x19c6c4f57f0>,
#  'eating': <gensim.models.keyedvectors.Vocab at 0x19c6c4f5860>,
#  'respondas': <gensim.models.keyedvectors.Vocab at 0x19c6c4f5898>,
#  'rapidez': <gensim.models.keyedvectors.Vocab at 0x19c6c4f5908>,
#  'calidad': <gensim.models.keyedvectors.Vocab at 0x19c6c4f5978>,
#  'maneja': <gensim.models.keyedvectors.Vocab at 0x19c6c4f59e8>,
#  'fast': <gensim.models.keyedvectors.Vocab at 0x19c6c4f5a58>,
#  'food': <gensim.models.keyedvectors.Vocab at 0x19c6c4f5ac8>,
#  'estándares': <gensim.models.keyedvectors.Vocab at 0x19c6c4f5b00>,
#  'exactos': <gensim.models.keyedvectors.Vocab at 0x19c6c4f5b70>,
#  'señalización': <gensim.models.keyedvectors.Vocab at 0x19c6c4f5ba8>,
#  'porciones': <gensim.models.keyedvectors.Vocab at 0x19c6c4f5be0>,
#  'tiempos': <gensim.models.keyedvectors.Vocab at 0x19c6c4f5c50>,
#  'digital': <gensim.models.keyedvectors.Vocab at 0x19c6c4f5cc0>,
#  'facebook': <gensim.models.keyedvectors.Vocab at 0x19c6c4f5cf8>,
#  'lapiczaperu': <gensim.models.keyedvectors.Vocab at 0x19c6c4f5d30>,
#  'rappi': <gensim.models.keyedvectors.Vocab at 0x19c6c4f5da0>,
#  'vital': <gensim.models.keyedvectors.Vocab at 0x19c6c4f5e10>,
#  'dejar': <gensim.models.keyedvectors.Vocab at 0x19c6c4f5e80>,
#  'escuchar': <gensim.models.keyedvectors.Vocab at 0x19c6c4f5eb8>,
#  'aconseja': <gensim.models.keyedvectors.Vocab at 0x19c6c4f5ef0>,
#  'recomendaciones': <gensim.models.keyedvectors.Vocab at 0x19c6c4f5f28>,
#  'emprender': <gensim.models.keyedvectors.Vocab at 0x19c6c4f5f60>,
#  'resuelve': <gensim.models.keyedvectors.Vocab at 0x19c6c4f5f98>,
#  'pensar': <gensim.models.keyedvectors.Vocab at 0x19c6c4fc048>,
#  'locura': <gensim.models.keyedvectors.Vocab at 0x19c6c4fc0b8>,
#  'números': <gensim.models.keyedvectors.Vocab at 0x19c6c4fc0f0>,
#  'equilibrio': <gensim.models.keyedvectors.Vocab at 0x19c6c4fc128>,
#  'proyecciones': <gensim.models.keyedvectors.Vocab at 0x19c6c4fc160>,
#  'futuro': <gensim.models.keyedvectors.Vocab at 0x19c6c4fc1d0>,
#  'piensa': <gensim.models.keyedvectors.Vocab at 0x19c6c4fc240>,
#  'generar': <gensim.models.keyedvectors.Vocab at 0x19c6c4fc2b0>,
#  'franquicias': <gensim.models.keyedvectors.Vocab at 0x19c6c4fc2e8>,
#  'caiga': <gensim.models.keyedvectors.Vocab at 0x19c6c4fc358>,
#  'peso': <gensim.models.keyedvectors.Vocab at 0x19c6c4fc3c8>,
#  'anhela': <gensim.models.keyedvectors.Vocab at 0x19c6c4fc438>,
#  'imite': <gensim.models.keyedvectors.Vocab at 0x19c6c4fc4a8>,
#  'cree': <gensim.models.keyedvectors.Vocab at 0x19c6c4fc518>,
#  'genérico': <gensim.models.keyedvectors.Vocab at 0x19c6c4fc550>,
#  'metió': <gensim.models.keyedvectors.Vocab at 0x19c6c4fc588>,
#  'masificar': <gensim.models.keyedvectors.Vocab at 0x19c6c4fc5c0>,
#  'producto': <gensim.models.keyedvectors.Vocab at 0x19c6c4fc5f8>,
#  'sabor': <gensim.models.keyedvectors.Vocab at 0x19c6c4fc668>,
#  'proporciones': <gensim.models.keyedvectors.Vocab at 0x19c6c4fc6a0>,
#  'generosas': <gensim.models.keyedvectors.Vocab at 0x19c6c4fc6d8>,
#  'gusta': <gensim.models.keyedvectors.Vocab at 0x19c6c4fc748>,
#  'principal': <gensim.models.keyedvectors.Vocab at 0x19c6c4fc780>,
#  'motivación': <gensim.models.keyedvectors.Vocab at 0x19c6c4fc7b8>,
#  'cuestionas': <gensim.models.keyedvectors.Vocab at 0x19c6c4fc7f0>,
#  'veía': <gensim.models.keyedvectors.Vocab at 0x19c6c4fc828>,
#  'trabajando': <gensim.models.keyedvectors.Vocab at 0x19c6c4fc860>,
#  'empleado': <gensim.models.keyedvectors.Vocab at 0x19c6c4fc898>,
#  'di': <gensim.models.keyedvectors.Vocab at 0x19c6c4fc908>,
#  'quise': <gensim.models.keyedvectors.Vocab at 0x19c6c4fc978>,
#  'aprobar': <gensim.models.keyedvectors.Vocab at 0x19c6c4fc9e8>,
#  'dificultad': <gensim.models.keyedvectors.Vocab at 0x19c6c4fca20>,
#  'encontraste': <gensim.models.keyedvectors.Vocab at 0x19c6c4fca58>,
#  'superaste': <gensim.models.keyedvectors.Vocab at 0x19c6c4fca90>,
#  'cercana': <gensim.models.keyedvectors.Vocab at 0x19c6c4fcb00>,
#  'ayude': <gensim.models.keyedvectors.Vocab at 0x19c6c4fcb70>,
#  'asesorarse': <gensim.models.keyedvectors.Vocab at 0x19c6c4fcba8>,
#  'pedir': <gensim.models.keyedvectors.Vocab at 0x19c6c4fcc18>,
#  'ayuda': <gensim.models.keyedvectors.Vocab at 0x19c6c4fcc88>,
#  'ahorrado': <gensim.models.keyedvectors.Vocab at 0x19c6c4fccc0>,
#  'comprarme': <gensim.models.keyedvectors.Vocab at 0x19c6c4fccf8>,
#  'depa': <gensim.models.keyedvectors.Vocab at 0x19c6c4fcd68>,
#  'decidí': <gensim.models.keyedvectors.Vocab at 0x19c6c4fcda0>,
#  'invertir': <gensim.models.keyedvectors.Vocab at 0x19c6c4fcdd8>,
#  'plata': <gensim.models.keyedvectors.Vocab at 0x19c6c4fce48>,
#  'contratan': <gensim.models.keyedvectors.Vocab at 0x19c6c4fce80>,
#  'decirles': <gensim.models.keyedvectors.Vocab at 0x19c6c4fceb8>,
#  'fortaleza': <gensim.models.keyedvectors.Vocab at 0x19c6c4fcef0>,
#  'creer': <gensim.models.keyedvectors.Vocab at 0x19c6c4fcf60>,
#  'crear': <gensim.models.keyedvectors.Vocab at 0x19c6c4fcfd0>,
#  'día': <gensim.models.keyedvectors.Vocab at 0x19c6c501048>,
#  'casa': <gensim.models.keyedvectors.Vocab at 0x19c6c5010b8>,
#  'haga': <gensim.models.keyedvectors.Vocab at 0x19c6c501128>,
#  'vacilón': <gensim.models.keyedvectors.Vocab at 0x19c6c501160>,
#  'salchicha': <gensim.models.keyedvectors.Vocab at 0x19c6c501198>,
#  'huacho': <gensim.models.keyedvectors.Vocab at 0x19c6c501208>,
#  'gastronomía': <gensim.models.keyedvectors.Vocab at 0x19c6c501240>,
#  'mallory': <gensim.models.keyedvectors.Vocab at 0x19c6c5012b0>,
#  'aco': <gensim.models.keyedvectors.Vocab at 0x19c6c501320>,
#  'logró': <gensim.models.keyedvectors.Vocab at 0x19c6c501358>,
#  'medalla': <gensim.models.keyedvectors.Vocab at 0x19c6c5013c8>,
#  ...}

# %%
df_noticias_train = pd.read_csv('complete_clean_news.csv')
df_noticias_train.drop(df_noticias_train.columns[0],axis=1,inplace=True)
df_noticias_train.head()
# Out:
#    Categoria             Autor  \
# 0  farándula  redacción perú21
# 1       perú  redacción perú21
# 2   política  redacción perú21
# 3       lima  redacción perú21
# 4       lima  redacción perú21
#
#                                               Titulo  \
# 0  fiorella rodríguez presentó dueño corazón mese...
# 1  sujeto arrojó thinner padre 68 años prendió fu...
# 2  luis bedoya reyes llama abogados juristas inte...
# 3  separan responsables difundir fotos expresiden...
# 4  reaccionó john galliquio cuestionado denuncia ...
#
#                                              Resumen  \
# 0  conductora sorprendió fanáticos fotos amor red...
# 1  joven negó incendiado padre víctima graves que...
# 2  político 100 años pronunció importancia postul...
# 3  involucrados hospital casimiro ulloa suspendid...
# 4  exjugador selección peruana reapareció mostró ...
#
#                                            Contenido
# 0  presentadora exjurado artista año fiorella rod...
# 1  wandherlay enriquez luque 25 detenido arrojado...
# 2  luis bedoya reyes fundadores históricos partid...
# 3  doctor juan luis herrera director general oper...
# 4  john galliquio exjugador selección peruana apa...

# %%
df_2 = df_noticias_train.dropna()

# %% [markdown]
# ## Entrenamiento de modelos

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score

import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np

# Obteniendo vectores de caracteristicas
df_2['Vector'] = df_2['Contenido'].apply(lambda x: getFV(x,model,300))
# Out:
# E:\INSTALACIONES\Anaconda\lib\site-packages\ipykernel_launcher.py:8: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).

# %%
from sklearn.model_selection import train_test_split
import model_library as mdl

X = list(df_2['Vector'])
X_train, X_test = train_test_split(X, test_size=0.2, random_state=0)
print(len(X), len(X_train), len(X_test))

# %%
nc = 3
kmeans = KMeans(n_clusters=nc, random_state=0)
kmeans.fit(X_train)
mdl.grafico_silueta(kmeans, X_test, nc)

# %%
nc = 4
kmeans = KMeans(n_clusters=nc, random_state=0)
kmeans.fit(X_train)
mdl.grafico_silueta(kmeans, X_test, nc)

# %%
nc = 5
kmeans = KMeans(n_clusters=nc, random_state=0)
kmeans.fit(X_train)
mdl.grafico_silueta(kmeans, X_test, nc)

# %% [markdown]
# ## Prueba de data clasif
