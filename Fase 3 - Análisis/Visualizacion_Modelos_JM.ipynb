# %%
import gensim
from gensim.test.utils import common_texts, get_tmpfile
from gensim.models import word2vec , Phrases

import numpy as np
from multiprocessing import cpu_count

import nltk
from nltk.tokenize import sent_tokenize, word_tokenize 
nltk.download('punkt')

import pandas as pd
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\pc\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
def getFV(document, model1, sizeModel): #promedio del vector caracteristico
    
    words=document.split()
    s=np.zeros(sizeModel)
    k=1
    for w in words:
        if w in model1.wv.vocab:
            s=s+model1[w]
            k=k+1
    
    return s/k

# %%
model = gensim.models.Word2Vec.load('w2v300_5.model')

# %%
model.wv.vocab
# Out:
# {'presentadora': <gensim.models.keyedvectors.Vocab at 0x203c37fc400>,
#  'exjurado': <gensim.models.keyedvectors.Vocab at 0x203c37fc2b0>,
#  'artista': <gensim.models.keyedvectors.Vocab at 0x203c37fc4a8>,
#  'año': <gensim.models.keyedvectors.Vocab at 0x203c37fc518>,
#  'fiorella': <gensim.models.keyedvectors.Vocab at 0x203c37fc4e0>,
#  'rodríguez': <gensim.models.keyedvectors.Vocab at 0x203c37fc470>,
#  '45': <gensim.models.keyedvectors.Vocab at 0x203c37fc208>,
#  'presentó': <gensim.models.keyedvectors.Vocab at 0x203c37fc240>,
#  'dueño': <gensim.models.keyedvectors.Vocab at 0x203c37fc278>,
#  'corazón': <gensim.models.keyedvectors.Vocab at 0x203c37fc1d0>,
#  'fotografías': <gensim.models.keyedvectors.Vocab at 0x203c37fc128>,
#  'instagram': <gensim.models.keyedvectors.Vocab at 0x203c37fc0f0>,
#  'fanáticos': <gensim.models.keyedvectors.Vocab at 0x203c37fc588>,
#  'tardaron': <gensim.models.keyedvectors.Vocab at 0x203c37fc5c0>,
#  'llenarle': <gensim.models.keyedvectors.Vocab at 0x203c37fc630>,
#  'publicación': <gensim.models.keyedvectors.Vocab at 0x203c37fc5f8>,
#  'emoticones': <gensim.models.keyedvectors.Vocab at 0x203c37fc6a0>,
#  'corazones': <gensim.models.keyedvectors.Vocab at 0x203c37fc668>,
#  'fotos': <gensim.models.keyedvectors.Vocab at 0x203c37fc748>,
#  'observa': <gensim.models.keyedvectors.Vocab at 0x203c37fc7b8>,
#  'abrazando': <gensim.models.keyedvectors.Vocab at 0x203c37fc7f0>,
#  'muchacho': <gensim.models.keyedvectors.Vocab at 0x203c37fc828>,
#  'mira': <gensim.models.keyedvectors.Vocab at 0x203c37fc898>,
#  'ternura': <gensim.models.keyedvectors.Vocab at 0x203c37fc908>,
#  'captura': <gensim.models.keyedvectors.Vocab at 0x203c37fc978>,
#  'sonríe': <gensim.models.keyedvectors.Vocab at 0x203c37fc9b0>,
#  'compartiendo': <gensim.models.keyedvectors.Vocab at 0x203c37fc9e8>,
#  'mirada': <gensim.models.keyedvectors.Vocab at 0x203c37fca58>,
#  'completa': <gensim.models.keyedvectors.Vocab at 0x203c37fca90>,
#  'complicidad': <gensim.models.keyedvectors.Vocab at 0x203c37fcac8>,
#  'meses': <gensim.models.keyedvectors.Vocab at 0x203c37fcb38>,
#  'amor': <gensim.models.keyedvectors.Vocab at 0x203c37fcba8>,
#  'bonito': <gensim.models.keyedvectors.Vocab at 0x203c37fcc18>,
#  'mensaje': <gensim.models.keyedvectors.Vocab at 0x203c37fcc88>,
#  'acompaña': <gensim.models.keyedvectors.Vocab at 0x203c37fccc0>,
#  'mantuvo': <gensim.models.keyedvectors.Vocab at 0x203c37fcd30>,
#  'matrimonio': <gensim.models.keyedvectors.Vocab at 0x203c37fcd68>,
#  '15': <gensim.models.keyedvectors.Vocab at 0x203c37fcdd8>,
#  'años': <gensim.models.keyedvectors.Vocab at 0x203c37fce10>,
#  'cineasta': <gensim.models.keyedvectors.Vocab at 0x203c37fce48>,
#  'sandro': <gensim.models.keyedvectors.Vocab at 0x203c37fceb8>,
#  'ventura': <gensim.models.keyedvectors.Vocab at 0x203c37fcf28>,
#  'mediados': <gensim.models.keyedvectors.Vocab at 0x203c37fcf60>,
#  '2018': <gensim.models.keyedvectors.Vocab at 0x203c37fcfd0>,
#  'anunciaron': <gensim.models.keyedvectors.Vocab at 0x203c3831048>,
#  'separación': <gensim.models.keyedvectors.Vocab at 0x203c3831080>,
#  'quedaron': <gensim.models.keyedvectors.Vocab at 0x203c38310b8>,
#  'términos': <gensim.models.keyedvectors.Vocab at 0x203c38310f0>,
#  'amigo': <gensim.models.keyedvectors.Vocab at 0x203c3831160>,
#  'hermosos': <gensim.models.keyedvectors.Vocab at 0x203c3831198>,
#  'basados': <gensim.models.keyedvectors.Vocab at 0x203c3831208>,
#  'comunicación': <gensim.models.keyedvectors.Vocab at 0x203c3831240>,
#  'cariño': <gensim.models.keyedvectors.Vocab at 0x203c3831278>,
#  'entrega': <gensim.models.keyedvectors.Vocab at 0x203c38312e8>,
#  'absoluta': <gensim.models.keyedvectors.Vocab at 0x203c3831320>,
#  'persona': <gensim.models.keyedvectors.Vocab at 0x203c3831390>,
#  'importante': <gensim.models.keyedvectors.Vocab at 0x203c38313c8>,
#  'vida': <gensim.models.keyedvectors.Vocab at 0x203c3831438>,
#  'oportunidad': <gensim.models.keyedvectors.Vocab at 0x203c3831470>,
#  'cerrar': <gensim.models.keyedvectors.Vocab at 0x203c38314e0>,
#  'etapa': <gensim.models.keyedvectors.Vocab at 0x203c3831550>,
#  'abrir': <gensim.models.keyedvectors.Vocab at 0x203c38315c0>,
#  'emoción': <gensim.models.keyedvectors.Vocab at 0x203c38315f8>,
#  'expectativa': <gensim.models.keyedvectors.Vocab at 0x203c3831630>,
#  'seguir': <gensim.models.keyedvectors.Vocab at 0x203c38316a0>,
#  'persiguiendo': <gensim.models.keyedvectors.Vocab at 0x203c38316d8>,
#  'sueños': <gensim.models.keyedvectors.Vocab at 0x203c3831710>,
#  'febrero': <gensim.models.keyedvectors.Vocab at 0x203c3831780>,
#  'entrevista': <gensim.models.keyedvectors.Vocab at 0x203c38317b8>,
#  'perú21': <gensim.models.keyedvectors.Vocab at 0x203c38317f0>,
#  'enriquez': <gensim.models.keyedvectors.Vocab at 0x203c3831828>,
#  'luque': <gensim.models.keyedvectors.Vocab at 0x203c3831898>,
#  '25': <gensim.models.keyedvectors.Vocab at 0x203c3831908>,
#  'detenido': <gensim.models.keyedvectors.Vocab at 0x203c3831940>,
#  'arrojado': <gensim.models.keyedvectors.Vocab at 0x203c3831978>,
#  'thinner': <gensim.models.keyedvectors.Vocab at 0x203c38319e8>,
#  'padre': <gensim.models.keyedvectors.Vocab at 0x203c3831a58>,
#  'posteriormente': <gensim.models.keyedvectors.Vocab at 0x203c3831a90>,
#  'prenderle': <gensim.models.keyedvectors.Vocab at 0x203c3831ac8>,
#  'fuego': <gensim.models.keyedvectors.Vocab at 0x203c3831b38>,
#  'acuerdo': <gensim.models.keyedvectors.Vocab at 0x203c3831ba8>,
#  'diversos': <gensim.models.keyedvectors.Vocab at 0x203c3831be0>,
#  'medios': <gensim.models.keyedvectors.Vocab at 0x203c3831c50>,
#  'locales': <gensim.models.keyedvectors.Vocab at 0x203c3831cc0>,
#  'parricidio': <gensim.models.keyedvectors.Vocab at 0x203c3831cf8>,
#  'ocurrió': <gensim.models.keyedvectors.Vocab at 0x203c3831d30>,
#  'vivienda': <gensim.models.keyedvectors.Vocab at 0x203c3831d68>,
#  'agraviado': <gensim.models.keyedvectors.Vocab at 0x203c3831da0>,
#  'ubicada': <gensim.models.keyedvectors.Vocab at 0x203c3831e10>,
#  'provincia': <gensim.models.keyedvectors.Vocab at 0x203c3831e48>,
#  'convención': <gensim.models.keyedvectors.Vocab at 0x203c3831e80>,
#  'cusco': <gensim.models.keyedvectors.Vocab at 0x203c3831ef0>,
#  'vecinos': <gensim.models.keyedvectors.Vocab at 0x203c3831f60>,
#  'zona': <gensim.models.keyedvectors.Vocab at 0x203c3831fd0>,
#  'aviso': <gensim.models.keyedvectors.Vocab at 0x203c3838080>,
#  'autoridades': <gensim.models.keyedvectors.Vocab at 0x203c38380b8>,
#  'inmediatamente': <gensim.models.keyedvectors.Vocab at 0x203c38380f0>,
#  'llegaron': <gensim.models.keyedvectors.Vocab at 0x203c3838128>,
#  'hechos': <gensim.models.keyedvectors.Vocab at 0x203c3838198>,
#  'domicilio': <gensim.models.keyedvectors.Vocab at 0x203c38381d0>,
#  'joven': <gensim.models.keyedvectors.Vocab at 0x203c3838240>,
#  'negó': <gensim.models.keyedvectors.Vocab at 0x203c3838278>,
#  'incendiado': <gensim.models.keyedvectors.Vocab at 0x203c38382b0>,
#  'identificado': <gensim.models.keyedvectors.Vocab at 0x203c38382e8>,
#  'víctor': <gensim.models.keyedvectors.Vocab at 0x203c3838320>,
#  'carrion': <gensim.models.keyedvectors.Vocab at 0x203c3838390>,
#  '68': <gensim.models.keyedvectors.Vocab at 0x203c3838400>,
#  'obstante': <gensim.models.keyedvectors.Vocab at 0x203c3838438>,
#  'graves': <gensim.models.keyedvectors.Vocab at 0x203c38384a8>,
#  'quemaduras': <gensim.models.keyedvectors.Vocab at 0x203c38384e0>,
#  'grado': <gensim.models.keyedvectors.Vocab at 0x203c3838550>,
#  'salió': <gensim.models.keyedvectors.Vocab at 0x203c3838588>,
#  'desmentir': <gensim.models.keyedvectors.Vocab at 0x203c38385c0>,
#  'versión': <gensim.models.keyedvectors.Vocab at 0x203c38385f8>,
#  'hijo': <gensim.models.keyedvectors.Vocab at 0x203c3838668>,
#  'finalmente': <gensim.models.keyedvectors.Vocab at 0x203c38386a0>,
#  'trasladado': <gensim.models.keyedvectors.Vocab at 0x203c38386d8>,
#  'comisaría': <gensim.models.keyedvectors.Vocab at 0x203c3838710>,
#  'santa': <gensim.models.keyedvectors.Vocab at 0x203c3838780>,
#  'teresa': <gensim.models.keyedvectors.Vocab at 0x203c38387f0>,
#  'intervención': <gensim.models.keyedvectors.Vocab at 0x203c3838828>,
#  'víctima': <gensim.models.keyedvectors.Vocab at 0x203c3838860>,
#  'llevado': <gensim.models.keyedvectors.Vocab at 0x203c38388d0>,
#  'hospital': <gensim.models.keyedvectors.Vocab at 0x203c3838908>,
#  'central': <gensim.models.keyedvectors.Vocab at 0x203c3838978>,
#  'ciudad': <gensim.models.keyedvectors.Vocab at 0x203c38389e8>,
#  'quillabamba': <gensim.models.keyedvectors.Vocab at 0x203c3838a20>,
#  'viene': <gensim.models.keyedvectors.Vocab at 0x203c3838a90>,
#  'recuperándose': <gensim.models.keyedvectors.Vocab at 0x203c3838ac8>,
#  'lesiones': <gensim.models.keyedvectors.Vocab at 0x203c3838b00>,
#  'fiscalía': <gensim.models.keyedvectors.Vocab at 0x203c3838b38>,
#  'turno': <gensim.models.keyedvectors.Vocab at 0x203c3838ba8>,
#  'dispuso': <gensim.models.keyedvectors.Vocab at 0x203c3838c18>,
#  'diligencias': <gensim.models.keyedvectors.Vocab at 0x203c3838c50>,
#  'preliminares': <gensim.models.keyedvectors.Vocab at 0x203c3838c88>,
#  'correspondientes': <gensim.models.keyedvectors.Vocab at 0x203c3838cc0>,
#  'permanecerá': <gensim.models.keyedvectors.Vocab at 0x203c3838cf8>,
#  'investigaciones': <gensim.models.keyedvectors.Vocab at 0x203c3838d30>,
#  'deberá': <gensim.models.keyedvectors.Vocab at 0x203c3838d68>,
#  'enfrentar': <gensim.models.keyedvectors.Vocab at 0x203c3838da0>,
#  'cargos': <gensim.models.keyedvectors.Vocab at 0x203c3838e10>,
#  'presunto': <gensim.models.keyedvectors.Vocab at 0x203c3838e48>,
#  'delito': <gensim.models.keyedvectors.Vocab at 0x203c3838eb8>,
#  'violencia': <gensim.models.keyedvectors.Vocab at 0x203c3838ef0>,
#  'familiar': <gensim.models.keyedvectors.Vocab at 0x203c3838f28>,
#  'luis': <gensim.models.keyedvectors.Vocab at 0x203c3838f98>,
#  'bedoya': <gensim.models.keyedvectors.Vocab at 0x203c383f048>,
#  'reyes': <gensim.models.keyedvectors.Vocab at 0x203c383f0b8>,
#  'fundadores': <gensim.models.keyedvectors.Vocab at 0x203c383f0f0>,
#  'históricos': <gensim.models.keyedvectors.Vocab at 0x203c383f128>,
#  'partido': <gensim.models.keyedvectors.Vocab at 0x203c383f198>,
#  'popular': <gensim.models.keyedvectors.Vocab at 0x203c383f208>,
#  'cristiano': <gensim.models.keyedvectors.Vocab at 0x203c383f240>,
#  'ppc': <gensim.models.keyedvectors.Vocab at 0x203c383f2b0>,
#  'pronunció': <gensim.models.keyedvectors.Vocab at 0x203c383f2e8>,
#  'acerca': <gensim.models.keyedvectors.Vocab at 0x203c383f358>,
#  'convocatoria': <gensim.models.keyedvectors.Vocab at 0x203c383f390>,
#  'integrar': <gensim.models.keyedvectors.Vocab at 0x203c383f3c8>,
#  'junta': <gensim.models.keyedvectors.Vocab at 0x203c37e8ba8>,
#  'nacional': <gensim.models.keyedvectors.Vocab at 0x203c383f400>,
#  'justicia': <gensim.models.keyedvectors.Vocab at 0x203c383f438>,
#  'jnj': <gensim.models.keyedvectors.Vocab at 0x203c383f4a8>,
#  'pequeño': <gensim.models.keyedvectors.Vocab at 0x203c383f4e0>,
#  'discurso': <gensim.models.keyedvectors.Vocab at 0x203c383f518>,
#  'importancia': <gensim.models.keyedvectors.Vocab at 0x203c383f550>,
#  'significa': <gensim.models.keyedvectors.Vocab at 0x203c383f588>,
#  'órgano': <gensim.models.keyedvectors.Vocab at 0x203c383f5c0>,
#  'político': <gensim.models.keyedvectors.Vocab at 0x203c383f5f8>,
#  '100': <gensim.models.keyedvectors.Vocab at 0x203c383f668>,
#  'edad': <gensim.models.keyedvectors.Vocab at 0x203c383f6d8>,
#  'grabó': <gensim.models.keyedvectors.Vocab at 0x203c383f710>,
#  'video': <gensim.models.keyedvectors.Vocab at 0x203c383f780>,
#  'explica': <gensim.models.keyedvectors.Vocab at 0x203c383f7f0>,
#  'razones': <gensim.models.keyedvectors.Vocab at 0x203c383f860>,
#  'llama': <gensim.models.keyedvectors.Vocab at 0x203c383f8d0>,
#  'juristas': <gensim.models.keyedvectors.Vocab at 0x203c383f908>,
#  'abogados': <gensim.models.keyedvectors.Vocab at 0x203c383f940>,
#  'especialistas': <gensim.models.keyedvectors.Vocab at 0x203c383f978>,
#  'derecho': <gensim.models.keyedvectors.Vocab at 0x203c383f9e8>,
#  'ojalá': <gensim.models.keyedvectors.Vocab at 0x203c383fa20>,
#  'acostumbren': <gensim.models.keyedvectors.Vocab at 0x203c383fa58>,
#  'acertar': <gensim.models.keyedvectors.Vocab at 0x203c383fac8>,
#  'postulantes': <gensim.models.keyedvectors.Vocab at 0x203c383fb00>,
#  'merezcan': <gensim.models.keyedvectors.Vocab at 0x203c383fb38>,
#  'elegidos': <gensim.models.keyedvectors.Vocab at 0x203c383fb70>,
#  'razón': <gensim.models.keyedvectors.Vocab at 0x203c383fba8>,
#  'condiciones': <gensim.models.keyedvectors.Vocab at 0x203c383fbe0>,
#  'cualidades': <gensim.models.keyedvectors.Vocab at 0x203c383fc18>,
#  'juntaremos': <gensim.models.keyedvectors.Vocab at 0x203c383fc50>,
#  'peruanos': <gensim.models.keyedvectors.Vocab at 0x203c383fc88>,
#  'vivir': <gensim.models.keyedvectors.Vocab at 0x203c383fcf8>,
#  'discrepando': <gensim.models.keyedvectors.Vocab at 0x203c383fd30>,
#  'institución': <gensim.models.keyedvectors.Vocab at 0x203c383fd68>,
#  'reemplazará': <gensim.models.keyedvectors.Vocab at 0x203c383fda0>,
#  'desaparecido': <gensim.models.keyedvectors.Vocab at 0x203c383fdd8>,
#  'consejo': <gensim.models.keyedvectors.Vocab at 0x203c383fe48>,
#  'magistratura': <gensim.models.keyedvectors.Vocab at 0x203c383fe80>,
#  'cnm': <gensim.models.keyedvectors.Vocab at 0x203c383fef0>,
#  'desactivado': <gensim.models.keyedvectors.Vocab at 0x203c383ff28>,
#  'audios': <gensim.models.keyedvectors.Vocab at 0x203c383ff98>,
#  'vergüenza': <gensim.models.keyedvectors.Vocab at 0x203c383ffd0>,
#  'exintegrantes': <gensim.models.keyedvectors.Vocab at 0x203c3847048>,
#  'escuchaba': <gensim.models.keyedvectors.Vocab at 0x203c3847080>,
#  'comprometedoras': <gensim.models.keyedvectors.Vocab at 0x203c38470b8>,
#  'situación': <gensim.models.keyedvectors.Vocab at 0x203c38470f0>,
#  'corrupción': <gensim.models.keyedvectors.Vocab at 0x203c3847128>,
#  'encargará': <gensim.models.keyedvectors.Vocab at 0x203c3847160>,
#  'nombrar': <gensim.models.keyedvectors.Vocab at 0x203c38471d0>,
#  'destituir': <gensim.models.keyedvectors.Vocab at 0x203c3847208>,
#  'jueces': <gensim.models.keyedvectors.Vocab at 0x203c3847278>,
#  'fiscales': <gensim.models.keyedvectors.Vocab at 0x203c38472b0>,
#  'asimismo': <gensim.models.keyedvectors.Vocab at 0x203c38472e8>,
#  'facultad': <gensim.models.keyedvectors.Vocab at 0x203c3847320>,
#  'renovar': <gensim.models.keyedvectors.Vocab at 0x203c3847390>,
#  'cargo': <gensim.models.keyedvectors.Vocab at 0x203c3847400>,
#  'jefe': <gensim.models.keyedvectors.Vocab at 0x203c3847470>,
#  'onpe': <gensim.models.keyedvectors.Vocab at 0x203c38474e0>,
#  'reniec': <gensim.models.keyedvectors.Vocab at 0x203c3847550>,
#  'doctor': <gensim.models.keyedvectors.Vocab at 0x203c38475c0>,
#  'juan': <gensim.models.keyedvectors.Vocab at 0x203c3847630>,
#  'herrera': <gensim.models.keyedvectors.Vocab at 0x203c38476a0>,
#  'director': <gensim.models.keyedvectors.Vocab at 0x203c38476d8>,
#  'general': <gensim.models.keyedvectors.Vocab at 0x203c3847748>,
#  'operaciones': <gensim.models.keyedvectors.Vocab at 0x203c3847780>,
#  'salud': <gensim.models.keyedvectors.Vocab at 0x203c38477f0>,
#  'conversación': <gensim.models.keyedvectors.Vocab at 0x203c3847828>,
#  'atv': <gensim.models.keyedvectors.Vocab at 0x203c3847898>,
#  'separó': <gensim.models.keyedvectors.Vocab at 0x203c38478d0>,
#  'responsables': <gensim.models.keyedvectors.Vocab at 0x203c3847908>,
#  'difundir': <gensim.models.keyedvectors.Vocab at 0x203c3847940>,
#  'fallecido': <gensim.models.keyedvectors.Vocab at 0x203c3847978>,
#  'expresidente': <gensim.models.keyedvectors.Vocab at 0x203c38479b0>,
#  'alan': <gensim.models.keyedvectors.Vocab at 0x203c3847a20>,
#  'garcía': <gensim.models.keyedvectors.Vocab at 0x203c3847a58>,
#  'casimiro': <gensim.models.keyedvectors.Vocab at 0x203c3847a90>,
#  'ulloa': <gensim.models.keyedvectors.Vocab at 0x203c3847b00>,
#  'sistema': <gensim.models.keyedvectors.Vocab at 0x203c3847b70>,
#  'identificados': <gensim.models.keyedvectors.Vocab at 0x203c3847ba8>,
#  'vía': <gensim.models.keyedvectors.Vocab at 0x203c3847be0>,
#  'administrativas': <gensim.models.keyedvectors.Vocab at 0x203c3847c18>,
#  'activada': <gensim.models.keyedvectors.Vocab at 0x203c3847c50>,
#  'sanción': <gensim.models.keyedvectors.Vocab at 0x203c3847c88>,
#  'correspondiente': <gensim.models.keyedvectors.Vocab at 0x203c3847cc0>,
#  'tema': <gensim.models.keyedvectors.Vocab at 0x203c3847d30>,
#  'respeto': <gensim.models.keyedvectors.Vocab at 0x203c3847da0>,
#  'nombre': <gensim.models.keyedvectors.Vocab at 0x203c3847e10>,
#  'detalle': <gensim.models.keyedvectors.Vocab at 0x203c3847e80>,
#  'grupo': <gensim.models.keyedvectors.Vocab at 0x203c3847ef0>,
#  'ocupacional': <gensim.models.keyedvectors.Vocab at 0x203c3847f28>,
#  'lamentable': <gensim.models.keyedvectors.Vocab at 0x203c3847f60>,
#  'precisó': <gensim.models.keyedvectors.Vocab at 0x203c3847f98>,
#  'involucrados': <gensim.models.keyedvectors.Vocab at 0x203c3847fd0>,
#  'separados': <gensim.models.keyedvectors.Vocab at 0x203c384d048>,
#  'nosocomio': <gensim.models.keyedvectors.Vocab at 0x203c384d080>,
#  'preliminar': <gensim.models.keyedvectors.Vocab at 0x203c384d0b8>,
#  'entidad': <gensim.models.keyedvectors.Vocab at 0x203c384d128>,
#  'proceso': <gensim.models.keyedvectors.Vocab at 0x203c384d198>,
#  'administrativos': <gensim.models.keyedvectors.Vocab at 0x203c384d1d0>,
#  'corresponde': <gensim.models.keyedvectors.Vocab at 0x203c384d208>,
#  'definitiva': <gensim.models.keyedvectors.Vocab at 0x203c384d240>,
#  'mal': <gensim.models.keyedvectors.Vocab at 0x203c384d2b0>,
#  'recuerdo': <gensim.models.keyedvectors.Vocab at 0x203c384d2e8>,
#  'suspensión': <gensim.models.keyedvectors.Vocab at 0x203c384d320>,
#  'procurador': <gensim.models.keyedvectors.Vocab at 0x203c384d358>,
#  'tomando': <gensim.models.keyedvectors.Vocab at 0x203c384d3c8>,
#  'acciones': <gensim.models.keyedvectors.Vocab at 0x203c384d400>,
#  'administrativa': <gensim.models.keyedvectors.Vocab at 0x203c384d438>,
#  'aseveró': <gensim.models.keyedvectors.Vocab at 0x203c384d470>,
#  'diagnóstico': <gensim.models.keyedvectors.Vocab at 0x203c384d4a8>,
#  '17': <gensim.models.keyedvectors.Vocab at 0x203c384d518>,
#  'abril': <gensim.models.keyedvectors.Vocab at 0x203c384d588>,
#  'exmandatario': <gensim.models.keyedvectors.Vocab at 0x203c384d5c0>,
#  'tomó': <gensim.models.keyedvectors.Vocab at 0x203c384d5f8>,
#  'fatal': <gensim.models.keyedvectors.Vocab at 0x203c384d668>,
#  'decisión': <gensim.models.keyedvectors.Vocab at 0x203c384d6a0>,
#  'quitarse': <gensim.models.keyedvectors.Vocab at 0x203c384d6d8>,
#  'disparándose': <gensim.models.keyedvectors.Vocab at 0x203c384d710>,
#  'cabeza': <gensim.models.keyedvectors.Vocab at 0x203c384d780>,
#  'impacto': <gensim.models.keyedvectors.Vocab at 0x203c384d7f0>,
#  'proyectil': <gensim.models.keyedvectors.Vocab at 0x203c384d828>,
#  'arma': <gensim.models.keyedvectors.Vocab at 0x203c384d898>,
#  'orificio': <gensim.models.keyedvectors.Vocab at 0x203c384d8d0>,
#  'entrada': <gensim.models.keyedvectors.Vocab at 0x203c384d940>,
#  'salida': <gensim.models.keyedvectors.Vocab at 0x203c384d9b0>,
#  'cráneo': <gensim.models.keyedvectors.Vocab at 0x203c384d9e8>,
#  'ingresó': <gensim.models.keyedvectors.Vocab at 0x203c384da20>,
#  'sala': <gensim.models.keyedvectors.Vocab at 0x203c384da90>,
#  '0717': <gensim.models.keyedvectors.Vocab at 0x203c384db00>,
#  'am': <gensim.models.keyedvectors.Vocab at 0x203c384db70>,
#  'vano': <gensim.models.keyedvectors.Vocab at 0x203c384dbe0>,
#  'muerte': <gensim.models.keyedvectors.Vocab at 0x203c384dc50>,
#  'consecuencia': <gensim.models.keyedvectors.Vocab at 0x203c384dc88>,
#  'hemorragia': <gensim.models.keyedvectors.Vocab at 0x203c384dcc0>,
#  'cerebral': <gensim.models.keyedvectors.Vocab at 0x203c384dcf8>,
#  'masiva': <gensim.models.keyedvectors.Vocab at 0x203c384dd68>,
#  'paro': <gensim.models.keyedvectors.Vocab at 0x203c384ddd8>,
#  'cardiorespiratorio': <gensim.models.keyedvectors.Vocab at 0x203c384de10>,
#  'john': <gensim.models.keyedvectors.Vocab at 0x203c384de80>,
#  'galliquio': <gensim.models.keyedvectors.Vocab at 0x203c384deb8>,
#  'exjugador': <gensim.models.keyedvectors.Vocab at 0x203c384def0>,
#  'selección': <gensim.models.keyedvectors.Vocab at 0x203c384df28>,
#  'peruana': <gensim.models.keyedvectors.Vocab at 0x203c384df98>,
#  'apareció': <gensim.models.keyedvectors.Vocab at 0x203c384dfd0>,
#  'evento': <gensim.models.keyedvectors.Vocab at 0x203c3856080>,
#  'deportivo': <gensim.models.keyedvectors.Vocab at 0x203c38560b8>,
#  'san': <gensim.models.keyedvectors.Vocab at 0x203c3856128>,
#  'miraflores': <gensim.models.keyedvectors.Vocab at 0x203c3856160>,
#  'consultado': <gensim.models.keyedvectors.Vocab at 0x203c3856198>,
#  'denuncia': <gensim.models.keyedvectors.Vocab at 0x203c38561d0>,
#  'exesposa': <gensim.models.keyedvectors.Vocab at 0x203c3856208>,
#  'karla': <gensim.models.keyedvectors.Vocab at 0x203c3856278>,
#  'gómez': <gensim.models.keyedvectors.Vocab at 0x203c38562b0>,
#  'prefirió': <gensim.models.keyedvectors.Vocab at 0x203c38562e8>,
#  'declarar': <gensim.models.keyedvectors.Vocab at 0x203c3856320>,
#  'aprecia': <gensim.models.keyedvectors.Vocab at 0x203c3856390>,
#  'imágenes': <gensim.models.keyedvectors.Vocab at 0x203c38563c8>,
#  'programa': <gensim.models.keyedvectors.Vocab at 0x203c3856400>,
#  'magaly': <gensim.models.keyedvectors.Vocab at 0x203c3856470>,
#  'medina': <gensim.models.keyedvectors.Vocab at 0x203c38564e0>,
#  'tyson': <gensim.models.keyedvectors.Vocab at 0x203c3856550>,
#  'hablaría': <gensim.models.keyedvectors.Vocab at 0x203c3856588>,
#  'privada': <gensim.models.keyedvectors.Vocab at 0x203c38565f8>,
#  'evadió': <gensim.models.keyedvectors.Vocab at 0x203c3856630>,
#  'consultadas': <gensim.models.keyedvectors.Vocab at 0x203c3856668>,
#  'reportero': <gensim.models.keyedvectors.Vocab at 0x203c38566a0>,
#  'presentes': <gensim.models.keyedvectors.Vocab at 0x203c38566d8>,
#  'paolo': <gensim.models.keyedvectors.Vocab at 0x203c3856748>,
#  'maldonado': <gensim.models.keyedvectors.Vocab at 0x203c3856780>,
#  'manuel': <gensim.models.keyedvectors.Vocab at 0x203c38567f0>,
#  'vargas': <gensim.models.keyedvectors.Vocab at 0x203c3856860>,
#  'mostró': <gensim.models.keyedvectors.Vocab at 0x203c3856898>,
#  'risueño': <gensim.models.keyedvectors.Vocab at 0x203c38568d0>,
#  'principio': <gensim.models.keyedvectors.Vocab at 0x203c3856908>,
#  'propiedades': <gensim.models.keyedvectors.Vocab at 0x203c3856940>,
#  'denuncias': <gensim.models.keyedvectors.Vocab at 0x203c3856978>,
#  'incómodo': <gensim.models.keyedvectors.Vocab at 0x203c38569b0>,
#  'disculpa': <gensim.models.keyedvectors.Vocab at 0x203c38569e8>,
#  'hablo': <gensim.models.keyedvectors.Vocab at 0x203c3856a58>,
#  'favor': <gensim.models.keyedvectors.Vocab at 0x203c3856ac8>,
#  'agradezco': <gensim.models.keyedvectors.Vocab at 0x203c3856b00>,
#  'montón': <gensim.models.keyedvectors.Vocab at 0x203c3856b38>,
#  'hablar': <gensim.models.keyedvectors.Vocab at 0x203c3856ba8>,
#  'ustedes': <gensim.models.keyedvectors.Vocab at 0x203c3856c18>,
#  'contigo': <gensim.models.keyedvectors.Vocab at 0x203c3856c88>,
#  'gracias': <gensim.models.keyedvectors.Vocab at 0x203c3856cf8>,
#  'puedes': <gensim.models.keyedvectors.Vocab at 0x203c3856d68>,
#  'obligar': <gensim.models.keyedvectors.Vocab at 0x203c3856dd8>,
#  'hable': <gensim.models.keyedvectors.Vocab at 0x203c3856e48>,
#  'declaró': <gensim.models.keyedvectors.Vocab at 0x203c3856e80>,
#  'jhon': <gensim.models.keyedvectors.Vocab at 0x203c3856ef0>,
#  'recordar': <gensim.models.keyedvectors.Vocab at 0x203c3856f28>,
#  'medidas': <gensim.models.keyedvectors.Vocab at 0x203c3856f98>,
#  'protección': <gensim.models.keyedvectors.Vocab at 0x203c3856fd0>,
#  'pisco': <gensim.models.keyedvectors.Vocab at 0x203c385c080>,
#  'denunciar': <gensim.models.keyedvectors.Vocab at 0x203c385c0b8>,
#  'agentes': <gensim.models.keyedvectors.Vocab at 0x203c385c128>,
#  'ignoran': <gensim.models.keyedvectors.Vocab at 0x203c385c198>,
#  'informa': <gensim.models.keyedvectors.Vocab at 0x203c385c208>,
#  'marzo': <gensim.models.keyedvectors.Vocab at 0x203c385c278>,
#  'denunciado': <gensim.models.keyedvectors.Vocab at 0x203c385c2b0>,
#  'doméstica': <gensim.models.keyedvectors.Vocab at 0x203c385c2e8>,
#  'querido': <gensim.models.keyedvectors.Vocab at 0x203c385c358>,
#  'ahogar': <gensim.models.keyedvectors.Vocab at 0x203c385c3c8>,
#  'mar': <gensim.models.keyedvectors.Vocab at 0x203c385c438>,
#  'discusión': <gensim.models.keyedvectors.Vocab at 0x203c385c470>,
#  'pateaba': <gensim.models.keyedvectors.Vocab at 0x203c385c4e0>,
#  'punto': <gensim.models.keyedvectors.Vocab at 0x203c385c550>,
#  'hacerme': <gensim.models.keyedvectors.Vocab at 0x203c385c5c0>,
#  'vomitar': <gensim.models.keyedvectors.Vocab at 0x203c385c630>,
#  'sangre': <gensim.models.keyedvectors.Vocab at 0x203c385c6a0>,
#  'rompe': <gensim.models.keyedvectors.Vocab at 0x203c385c710>,
#  'mandíbula': <gensim.models.keyedvectors.Vocab at 0x203c385c748>,
#  'patea': <gensim.models.keyedvectors.Vocab at 0x203c385c7b8>,
#  'calle': <gensim.models.keyedvectors.Vocab at 0x203c385c828>,
#  'esperando': <gensim.models.keyedvectors.Vocab at 0x203c385c860>,
#  'mate': <gensim.models.keyedvectors.Vocab at 0x203c385c8d0>,
#  'medio': <gensim.models.keyedvectors.Vocab at 0x203c385c940>,
#  'lágrimas': <gensim.models.keyedvectors.Vocab at 0x203c385c978>,
#  'denunciante': <gensim.models.keyedvectors.Vocab at 0x203c385c9b0>,
#  'jugador': <gensim.models.keyedvectors.Vocab at 0x203c385ca20>,
#  'aparece': <gensim.models.keyedvectors.Vocab at 0x203c385ca90>,
#  'cuchillo': <gensim.models.keyedvectors.Vocab at 0x203c385cac8>,
#  'audio': <gensim.models.keyedvectors.Vocab at 0x203c385cb38>,
#  'cárcel': <gensim.models.keyedvectors.Vocab at 0x203c385cb70>,
#  'matar': <gensim.models.keyedvectors.Vocab at 0x203c385cbe0>,
#  'duras': <gensim.models.keyedvectors.Vocab at 0x203c385cc50>,
#  'críticas': <gensim.models.keyedvectors.Vocab at 0x203c385cc88>,
#  'recibiendo': <gensim.models.keyedvectors.Vocab at 0x203c385ccc0>,
#  'comentarista': <gensim.models.keyedvectors.Vocab at 0x203c385ccf8>,
#  'silvio': <gensim.models.keyedvectors.Vocab at 0x203c385cd68>,
#  'valencia': <gensim.models.keyedvectors.Vocab at 0x203c385cda0>,
#  'vivo': <gensim.models.keyedvectors.Vocab at 0x203c385ce10>,
#  'hinchas': <gensim.models.keyedvectors.Vocab at 0x203c385ce80>,
#  'sport': <gensim.models.keyedvectors.Vocab at 0x203c385cef0>,
#  'boys': <gensim.models.keyedvectors.Vocab at 0x203c385cf60>,
#  'plato': <gensim.models.keyedvectors.Vocab at 0x203c385cfd0>,
#  'comida': <gensim.models.keyedvectors.Vocab at 0x203c3862080>,
#  'penosas': <gensim.models.keyedvectors.Vocab at 0x203c38620f0>,
#  'declaraciones': <gensim.models.keyedvectors.Vocab at 0x203c3862128>,
#  'difundió': <gensim.models.keyedvectors.Vocab at 0x203c3862160>,
#  'espacio': <gensim.models.keyedvectors.Vocab at 0x203c38621d0>,
#  'televisivo': <gensim.models.keyedvectors.Vocab at 0x203c3862208>,
#  'conduce': <gensim.models.keyedvectors.Vocab at 0x203c3862278>,
#  'conductores': <gensim.models.keyedvectors.Vocab at 0x203c38622b0>,
#  'cobra': <gensim.models.keyedvectors.Vocab at 0x203c3862320>,
#  'entradas': <gensim.models.keyedvectors.Vocab at 0x203c3862358>,
#  'asistentes': <gensim.models.keyedvectors.Vocab at 0x203c3862390>,
#  'estrategia': <gensim.models.keyedvectors.Vocab at 0x203c38623c8>,
#  'misilera': <gensim.models.keyedvectors.Vocab at 0x203c3862400>,
#  'consiste': <gensim.models.keyedvectors.Vocab at 0x203c3862438>,
#  'pago': <gensim.models.keyedvectors.Vocab at 0x203c38624a8>,
#  'voluntario': <gensim.models.keyedvectors.Vocab at 0x203c38624e0>,
#  'concepto': <gensim.models.keyedvectors.Vocab at 0x203c3862518>,
#  'precio': <gensim.models.keyedvectors.Vocab at 0x203c3862588>,
#  'compañeros': <gensim.models.keyedvectors.Vocab at 0x203c38625c0>,
#  'sostuvo': <gensim.models.keyedvectors.Vocab at 0x203c3862630>,
#  'montos': <gensim.models.keyedvectors.Vocab at 0x203c38626a0>,
#  'cobran': <gensim.models.keyedvectors.Vocab at 0x203c3862710>,
#  'recuperan': <gensim.models.keyedvectors.Vocab at 0x203c3862748>,
#  'venta': <gensim.models.keyedvectors.Vocab at 0x203c38627b8>,
#  'estadio': <gensim.models.keyedvectors.Vocab at 0x203c3862828>,
#  'miguel': <gensim.models.keyedvectors.Vocab at 0x203c3862898>,
#  'grau': <gensim.models.keyedvectors.Vocab at 0x203c3862908>,
#  'callao': <gensim.models.keyedvectors.Vocab at 0x203c3862978>,
#  'táctica': <gensim.models.keyedvectors.Vocab at 0x203c38629b0>,
#  'busca': <gensim.models.keyedvectors.Vocab at 0x203c3862a20>,
#  'asistencia': <gensim.models.keyedvectors.Vocab at 0x203c3862a58>,
#  'personas': <gensim.models.keyedvectors.Vocab at 0x203c3862a90>,
#  'alentar': <gensim.models.keyedvectors.Vocab at 0x203c3862b00>,
#  'equipo': <gensim.models.keyedvectors.Vocab at 0x203c3862b70>,
#  'evitar': <gensim.models.keyedvectors.Vocab at 0x203c3862be0>,
#  'descenso': <gensim.models.keyedvectors.Vocab at 0x203c3862c18>,
#  'división': <gensim.models.keyedvectors.Vocab at 0x203c3862c50>,
#  'incorrecta': <gensim.models.keyedvectors.Vocab at 0x203c3862c88>,
#  'postura': <gensim.models.keyedvectors.Vocab at 0x203c3862cf8>,
#  'gente': <gensim.models.keyedvectors.Vocab at 0x203c3862d68>,
#  'chicos': <gensim.models.keyedvectors.Vocab at 0x203c3862dd8>,
#  'paran': <gensim.models.keyedvectors.Vocab at 0x203c3862e48>,
#  '5': <gensim.models.keyedvectors.Vocab at 0x203c3862e80>,
#  '3': <gensim.models.keyedvectors.Vocab at 0x203c3862eb8>,
#  'soles': <gensim.models.keyedvectors.Vocab at 0x203c3862f28>,
#  'pagar': <gensim.models.keyedvectors.Vocab at 0x203c3862f98>,
#  'menú': <gensim.models.keyedvectors.Vocab at 0x203c3862fd0>,
#  'actualización': <gensim.models.keyedvectors.Vocab at 0x203c3868048>,
#  'fiscal': <gensim.models.keyedvectors.Vocab at 0x203c38680b8>,
#  'josé': <gensim.models.keyedvectors.Vocab at 0x203c38680f0>,
#  'domingo': <gensim.models.keyedvectors.Vocab at 0x203c3868160>,
#  'pérez': <gensim.models.keyedvectors.Vocab at 0x203c3868198>,
#  'reprogramó': <gensim.models.keyedvectors.Vocab at 0x203c38681d0>,
#  'interrogatorio': <gensim.models.keyedvectors.Vocab at 0x203c3868208>,
#  'exasesor': <gensim.models.keyedvectors.Vocab at 0x203c3868240>,
#  'presidencial': <gensim.models.keyedvectors.Vocab at 0x203c3868278>,
#  'vladimiro': <gensim.models.keyedvectors.Vocab at 0x203c38682b0>,
#  'montesinos': <gensim.models.keyedvectors.Vocab at 0x203c38682e8>,
#  'lunes': <gensim.models.keyedvectors.Vocab at 0x203c3868358>,
#  '7': <gensim.models.keyedvectors.Vocab at 0x203c3868390>,
#  'octubre': <gensim.models.keyedvectors.Vocab at 0x203c3868400>,
#  'disposición': <gensim.models.keyedvectors.Vocab at 0x203c3868438>,
#  'accedió': <gensim.models.keyedvectors.Vocab at 0x203c3868470>,
#  'cambio': <gensim.models.keyedvectors.Vocab at 0x203c38684e0>,
#  'fecha': <gensim.models.keyedvectors.Vocab at 0x203c3868550>,
#  'participar': <gensim.models.keyedvectors.Vocab at 0x203c3868588>,
#  'audiencias': <gensim.models.keyedvectors.Vocab at 0x203c38685c0>,
#  'convocadas': <gensim.models.keyedvectors.Vocab at 0x203c38685f8>,
#  'penal': <gensim.models.keyedvectors.Vocab at 0x203c3868668>,
#  'superior': <gensim.models.keyedvectors.Vocab at 0x203c38686a0>,
#  'transitoria': <gensim.models.keyedvectors.Vocab at 0x203c38686d8>,
#  'corte': <gensim.models.keyedvectors.Vocab at 0x203c3868748>,
#  'especializada': <gensim.models.keyedvectors.Vocab at 0x203c3868780>,
#  'analizar': <gensim.models.keyedvectors.Vocab at 0x203c38687b8>,
#  'casos': <gensim.models.keyedvectors.Vocab at 0x203c3868828>,
#  'derechos': <gensim.models.keyedvectors.Vocab at 0x203c3868860>,
#  'humanos': <gensim.models.keyedvectors.Vocab at 0x203c38688d0>,
#  'pedro': <gensim.models.keyedvectors.Vocab at 0x203c3868940>,
#  'huilca': <gensim.models.keyedvectors.Vocab at 0x203c38689b0>,
#  'mariella': <gensim.models.keyedvectors.Vocab at 0x203c38689e8>,
#  'barreto': <gensim.models.keyedvectors.Vocab at 0x203c3868a58>,
#  'imposible': <gensim.models.keyedvectors.Vocab at 0x203c3868a90>,
#  'doc': <gensim.models.keyedvectors.Vocab at 0x203c3868b00>,
#  'responder': <gensim.models.keyedvectors.Vocab at 0x203c3868b38>,
#  'interrogantes': <gensim.models.keyedvectors.Vocab at 0x203c3868b70>,
#  'documento': <gensim.models.keyedvectors.Vocab at 0x203c3868ba8>,
#  'señala': <gensim.models.keyedvectors.Vocab at 0x203c3868be0>,
#  '14': <gensim.models.keyedvectors.Vocab at 0x203c3868c50>,
#  'tomará': <gensim.models.keyedvectors.Vocab at 0x203c3868c88>,
#  'declaración': <gensim.models.keyedvectors.Vocab at 0x203c3868cc0>,
#  'eduardo': <gensim.models.keyedvectors.Vocab at 0x203c3868d30>,
#  'felipe': <gensim.models.keyedvectors.Vocab at 0x203c3868da0>,
#  'cabrera': <gensim.models.keyedvectors.Vocab at 0x203c3868e10>,
#  'ganoza': <gensim.models.keyedvectors.Vocab at 0x203c3868e80>,
#  'congresista': <gensim.models.keyedvectors.Vocab at 0x203c3868eb8>,
#  'república': <gensim.models.keyedvectors.Vocab at 0x203c3868ef0>,
#  'ica': <gensim.models.keyedvectors.Vocab at 0x203c3868f60>,
#  'representando': <gensim.models.keyedvectors.Vocab at 0x203c3868f98>,
#  'fuerza': <gensim.models.keyedvectors.Vocab at 0x203c386f048>,
#  '2011': <gensim.models.keyedvectors.Vocab at 0x203c386f0b8>,
#  'postuló': <gensim.models.keyedvectors.Vocab at 0x203c386f0f0>,
#  'presidente': <gensim.models.keyedvectors.Vocab at 0x203c386f128>,
#  'regional': <gensim.models.keyedvectors.Vocab at 0x203c386f160>,
#  'nota': <gensim.models.keyedvectors.Vocab at 0x203c386f1d0>,
#  'original': <gensim.models.keyedvectors.Vocab at 0x203c386f208>,
#  'martes': <gensim.models.keyedvectors.Vocab at 0x203c386f278>,
#  'irá': <gensim.models.keyedvectors.Vocab at 0x203c386f2b0>,
#  'base': <gensim.models.keyedvectors.Vocab at 0x203c386f320>,
#  'naval': <gensim.models.keyedvectors.Vocab at 0x203c386f390>,
#  'interrogar': <gensim.models.keyedvectors.Vocab at 0x203c386f3c8>,
#  'purga': <gensim.models.keyedvectors.Vocab at 0x203c386f438>,
#  'condena': <gensim.models.keyedvectors.Vocab at 0x203c386f4a8>,
#  'distintos': <gensim.models.keyedvectors.Vocab at 0x203c386f4e0>,
#  'delitos': <gensim.models.keyedvectors.Vocab at 0x203c386f550>,
#  'cometidos': <gensim.models.keyedvectors.Vocab at 0x203c386f588>,
#  'gobierno': <gensim.models.keyedvectors.Vocab at 0x203c386f5c0>,
#  'alberto': <gensim.models.keyedvectors.Vocab at 0x203c386f630>,
#  'fujimori': <gensim.models.keyedvectors.Vocab at 0x203c386f668>,
#  'diligencia': <gensim.models.keyedvectors.Vocab at 0x203c386f6a0>,
#  'fijada': <gensim.models.keyedvectors.Vocab at 0x203c386f710>,
#  '10': <gensim.models.keyedvectors.Vocab at 0x203c386f780>,
#  'mañana': <gensim.models.keyedvectors.Vocab at 0x203c386f7b8>,
#  'especial': <gensim.models.keyedvectors.Vocab at 0x203c386f7f0>,
#  'lava': <gensim.models.keyedvectors.Vocab at 0x203c386f860>,
#  'jato': <gensim.models.keyedvectors.Vocab at 0x203c386f8d0>,
#  'formulará': <gensim.models.keyedvectors.Vocab at 0x203c386f908>,
#  'pliego': <gensim.models.keyedvectors.Vocab at 0x203c386f978>,
#  'preguntas': <gensim.models.keyedvectors.Vocab at 0x203c386f9b0>,
#  'encontrar': <gensim.models.keyedvectors.Vocab at 0x203c386f9e8>,
#  'luces': <gensim.models.keyedvectors.Vocab at 0x203c386fa58>,
#  'verdadero': <gensim.models.keyedvectors.Vocab at 0x203c386fa90>,
#  'rol': <gensim.models.keyedvectors.Vocab at 0x203c386fb00>,
#  'cumplió': <gensim.models.keyedvectors.Vocab at 0x203c386fb38>,
#  'abogado': <gensim.models.keyedvectors.Vocab at 0x203c386fba8>,
#  'vicente': <gensim.models.keyedvectors.Vocab at 0x203c386fc18>,
#  'silva': <gensim.models.keyedvectors.Vocab at 0x203c386fc88>,
#  'checa': <gensim.models.keyedvectors.Vocab at 0x203c386fcf8>,
#  'campaña': <gensim.models.keyedvectors.Vocab at 0x203c386fd30>,
#  '2016': <gensim.models.keyedvectors.Vocab at 0x203c386fda0>,
#  'tesis': <gensim.models.keyedvectors.Vocab at 0x203c386fe10>,
#  'lidera': <gensim.models.keyedvectors.Vocab at 0x203c386fe80>,
#  'keiko': <gensim.models.keyedvectors.Vocab at 0x203c386fef0>,
#  'recibido': <gensim.models.keyedvectors.Vocab at 0x203c386ff28>,
#  'aportes': <gensim.models.keyedvectors.Vocab at 0x203c386ff98>,
#  'irregulares': <gensim.models.keyedvectors.Vocab at 0x203c386ffd0>,
#  'constructora': <gensim.models.keyedvectors.Vocab at 0x203c3875048>,
#  'brasileña': <gensim.models.keyedvectors.Vocab at 0x203c3875080>,
#  'odebrecht': <gensim.models.keyedvectors.Vocab at 0x203c38750b8>,
#  'financiamiento': <gensim.models.keyedvectors.Vocab at 0x203c38750f0>,
#  'motivo': <gensim.models.keyedvectors.Vocab at 0x203c3875160>,
#  'lideresa': <gensim.models.keyedvectors.Vocab at 0x203c3875198>,
#  'cumple': <gensim.models.keyedvectors.Vocab at 0x203c3875208>,
#  'orden': <gensim.models.keyedvectors.Vocab at 0x203c3875278>,
#  'prisión': <gensim.models.keyedvectors.Vocab at 0x203c38752b0>,
#  'preventiva': <gensim.models.keyedvectors.Vocab at 0x203c38752e8>,
#  '18': <gensim.models.keyedvectors.Vocab at 0x203c3875358>,
#  'lavado': <gensim.models.keyedvectors.Vocab at 0x203c38753c8>,
#  'activos': <gensim.models.keyedvectors.Vocab at 0x203c3875438>,
#  'ministerio': <gensim.models.keyedvectors.Vocab at 0x203c3875470>,
#  'público': <gensim.models.keyedvectors.Vocab at 0x203c38754a8>,
#  'sindica': <gensim.models.keyedvectors.Vocab at 0x203c3875518>,
#  'asesor': <gensim.models.keyedvectors.Vocab at 0x203c3875588>,
#  'sombras': <gensim.models.keyedvectors.Vocab at 0x203c38755f8>,
#  'higuchi': <gensim.models.keyedvectors.Vocab at 0x203c3875668>,
#  'consiguiente': <gensim.models.keyedvectors.Vocab at 0x203c38756a0>,
#  'presunta': <gensim.models.keyedvectors.Vocab at 0x203c38756d8>,
#  'organización': <gensim.models.keyedvectors.Vocab at 0x203c3875710>,
#  'criminal': <gensim.models.keyedvectors.Vocab at 0x203c3875748>,
#  'enquistado': <gensim.models.keyedvectors.Vocab at 0x203c3875780>,
#  'relación': <gensim.models.keyedvectors.Vocab at 0x203c38757b8>,
#  'señalado': <gensim.models.keyedvectors.Vocab at 0x203c38757f0>,
#  'testaferros': <gensim.models.keyedvectors.Vocab at 0x203c3875828>,
#  'vladivideo': <gensim.models.keyedvectors.Vocab at 0x203c3875860>,
#  'compra': <gensim.models.keyedvectors.Vocab at 0x203c38758d0>,
#  'línea': <gensim.models.keyedvectors.Vocab at 0x203c3875908>,
#  'editorial': <gensim.models.keyedvectors.Vocab at 0x203c3875940>,
#  'cable': <gensim.models.keyedvectors.Vocab at 0x203c38759b0>,
#  'canal': <gensim.models.keyedvectors.Vocab at 0x203c3875a20>,
#  'noticias': <gensim.models.keyedvectors.Vocab at 0x203c3875a58>,
#  'ccn': <gensim.models.keyedvectors.Vocab at 0x203c3875ac8>,
#  'yolanda': <gensim.models.keyedvectors.Vocab at 0x203c3875b38>,
#  'rivera': <gensim.models.keyedvectors.Vocab at 0x203c3875ba8>,
#  'mujer': <gensim.models.keyedvectors.Vocab at 0x203c3875c18>,
#  'murió': <gensim.models.keyedvectors.Vocab at 0x203c3875c50>,
#  'atacada': <gensim.models.keyedvectors.Vocab at 0x203c3875cc0>,
#  'delincuentes': <gensim.models.keyedvectors.Vocab at 0x203c3875cf8>,
#  'huían': <gensim.models.keyedvectors.Vocab at 0x203c3875d30>,
#  'policía': <gensim.models.keyedvectors.Vocab at 0x203c3875d68>,
#  'distrito': <gensim.models.keyedvectors.Vocab at 0x203c3875da0>,
#  'surco': <gensim.models.keyedvectors.Vocab at 0x203c3875e10>,
#  'pidió': <gensim.models.keyedvectors.Vocab at 0x203c3875e48>,
#  'realicen': <gensim.models.keyedvectors.Vocab at 0x203c3875e80>,
#  'necesarias': <gensim.models.keyedvectors.Vocab at 0x203c3875eb8>,
#  'capturar': <gensim.models.keyedvectors.Vocab at 0x203c3875ef0>,
#  'criminales': <gensim.models.keyedvectors.Vocab at 0x203c3875f28>,
#  'hija': <gensim.models.keyedvectors.Vocab at 0x203c3875f98>,
#  'hombre': <gensim.models.keyedvectors.Vocab at 0x203c387d048>,
#  'conmocionado': <gensim.models.keyedvectors.Vocab at 0x203c387d080>,
#  'determina': <gensim.models.keyedvectors.Vocab at 0x203c387d0b8>,
#  'bala': <gensim.models.keyedvectors.Vocab at 0x203c387d128>,
#  'impactó': <gensim.models.keyedvectors.Vocab at 0x203c387d160>,
#  'policías': <gensim.models.keyedvectors.Vocab at 0x203c387d198>,
#  'ladrones': <gensim.models.keyedvectors.Vocab at 0x203c387d1d0>,
#  'culparse': <gensim.models.keyedvectors.Vocab at 0x203c387d208>,
#  'efectivos': <gensim.models.keyedvectors.Vocab at 0x203c387d240>,
#  'cumplían': <gensim.models.keyedvectors.Vocab at 0x203c387d278>,
#  'culpen': <gensim.models.keyedvectors.Vocab at 0x203c387d2e8>,
#  'colegas': <gensim.models.keyedvectors.Vocab at 0x203c387d358>,
#  'seguiré': <gensim.models.keyedvectors.Vocab at 0x203c387d390>,
#  'siéndolo': <gensim.models.keyedvectors.Vocab at 0x203c387d3c8>,
#  'muera': <gensim.models.keyedvectors.Vocab at 0x203c387d438>,
#  'oficial': <gensim.models.keyedvectors.Vocab at 0x203c387d4a8>,
#  'retiro': <gensim.models.keyedvectors.Vocab at 0x203c387d518>,
#  'necesita': <gensim.models.keyedvectors.Vocab at 0x203c387d550>,
#  'urgencia': <gensim.models.keyedvectors.Vocab at 0x203c387d588>,
#  'país': <gensim.models.keyedvectors.Vocab at 0x203c387d5c0>,
#  'empezando': <gensim.models.keyedvectors.Vocab at 0x203c387d5f8>,
#  'falta': <gensim.models.keyedvectors.Vocab at 0x203c387d668>,
#  'intervengan': <gensim.models.keyedvectors.Vocab at 0x203c387d6a0>,
#  'vendan': <gensim.models.keyedvectors.Vocab at 0x203c387d710>,
#  'dinero': <gensim.models.keyedvectors.Vocab at 0x203c387d780>,
#  'impartan': <gensim.models.keyedvectors.Vocab at 0x203c387d7b8>,
#  'quiénes': <gensim.models.keyedvectors.Vocab at 0x203c387d7f0>,
#  'corruptos': <gensim.models.keyedvectors.Vocab at 0x203c387d828>,
#  'corrupta': <gensim.models.keyedvectors.Vocab at 0x203c387d860>,
#  'manipulan': <gensim.models.keyedvectors.Vocab at 0x203c387d898>,
#  'juez': <gensim.models.keyedvectors.Vocab at 0x203c387d908>,
#  'pobre': <gensim.models.keyedvectors.Vocab at 0x203c387d978>,
#  'mete': <gensim.models.keyedvectors.Vocab at 0x203c387d9e8>,
#  'balazo': <gensim.models.keyedvectors.Vocab at 0x203c387da58>,
#  'choro': <gensim.models.keyedvectors.Vocab at 0x203c387dac8>,
#  'queda': <gensim.models.keyedvectors.Vocab at 0x203c387db38>,
#  'preso': <gensim.models.keyedvectors.Vocab at 0x203c387dba8>,
#  'pido': <gensim.models.keyedvectors.Vocab at 0x203c387dc18>,
#  'luchen': <gensim.models.keyedvectors.Vocab at 0x203c387dc88>,
#  'quiero': <gensim.models.keyedvectors.Vocab at 0x203c387dcf8>,
#  'capture': <gensim.models.keyedvectors.Vocab at 0x203c387dd68>,
#  'interesa': <gensim.models.keyedvectors.Vocab at 0x203c387dda0>,
#  'balas': <gensim.models.keyedvectors.Vocab at 0x203c387de10>,
#  'muerta': <gensim.models.keyedvectors.Vocab at 0x203c387de80>,
#  'culpa': <gensim.models.keyedvectors.Vocab at 0x203c387def0>,
#  'única': <gensim.models.keyedvectors.Vocab at 0x203c387df28>,
#  'quebrarse': <gensim.models.keyedvectors.Vocab at 0x203c387df60>,
#  'datos': <gensim.models.keyedvectors.Vocab at 0x203c387dfd0>,
#  '29': <gensim.models.keyedvectors.Vocab at 0x203c3883080>,
#  'casquillos': <gensim.models.keyedvectors.Vocab at 0x203c38830b8>,
#  'encontraron': <gensim.models.keyedvectors.Vocab at 0x203c38830f0>,
#  'balacera': <gensim.models.keyedvectors.Vocab at 0x203c3883128>,
#  'molina': <gensim.models.keyedvectors.Vocab at 0x203c3883198>,
#  'esposo': <gensim.models.keyedvectors.Vocab at 0x203c3883208>,
#  'herido': <gensim.models.keyedvectors.Vocab at 0x203c3883278>,
#  'brazo': <gensim.models.keyedvectors.Vocab at 0x203c38832e8>,
#  'exjuez': <gensim.models.keyedvectors.Vocab at 0x203c3883358>,
#  'supremo': <gensim.models.keyedvectors.Vocab at 0x203c38833c8>,
#  'césar': <gensim.models.keyedvectors.Vocab at 0x203c3883400>,
#  'hinostroza': <gensim.models.keyedvectors.Vocab at 0x203c3883438>,
#  'confirmó': <gensim.models.keyedvectors.Vocab at 0x203c3883470>,
#  'recurrirá': <gensim.models.keyedvectors.Vocab at 0x203c38834a8>,
#  'tribunal': <gensim.models.keyedvectors.Vocab at 0x203c38834e0>,
#  'constitucional': <gensim.models.keyedvectors.Vocab at 0x203c3883518>,
#  'españa': <gensim.models.keyedvectors.Vocab at 0x203c3883550>,
#  'buscar': <gensim.models.keyedvectors.Vocab at 0x203c38835c0>,
#  'anular': <gensim.models.keyedvectors.Vocab at 0x203c3883630>,
#  'extradición': <gensim.models.keyedvectors.Vocab at 0x203c3883668>,
#  'aprobada': <gensim.models.keyedvectors.Vocab at 0x203c38836a0>,
#  'audiencia': <gensim.models.keyedvectors.Vocab at 0x203c38836d8>,
#  'difundido': <gensim.models.keyedvectors.Vocab at 0x203c3883710>,
#  'rpp': <gensim.models.keyedvectors.Vocab at 0x203c3883780>,
#  'asegura': <gensim.models.keyedvectors.Vocab at 0x203c38837f0>,
#  'sentencia': <gensim.models.keyedvectors.Vocab at 0x203c3883828>,
#  'rechazó': <gensim.models.keyedvectors.Vocab at 0x203c3883860>,
#  'repatriación': <gensim.models.keyedvectors.Vocab at 0x203c3883898>,
#  'cuestionó': <gensim.models.keyedvectors.Vocab at 0x203c38838d0>,
#  'aceptado': <gensim.models.keyedvectors.Vocab at 0x203c3883908>,
#  'imputan': <gensim.models.keyedvectors.Vocab at 0x203c3883978>,
#  'conformes': <gensim.models.keyedvectors.Vocab at 0x203c38839b0>,
#  'rechazo': <gensim.models.keyedvectors.Vocab at 0x203c3883a20>,
#  'patrocinio': <gensim.models.keyedvectors.Vocab at 0x203c3883a58>,
#  'ilegal': <gensim.models.keyedvectors.Vocab at 0x203c3883ac8>,
#  'tráfico': <gensim.models.keyedvectors.Vocab at 0x203c3883b00>,
#  'influencias': <gensim.models.keyedvectors.Vocab at 0x203c3883b38>,
#  'negociación': <gensim.models.keyedvectors.Vocab at 0x203c3883b70>,
#  'incompatible': <gensim.models.keyedvectors.Vocab at 0x203c3883ba8>,
#  'españoles': <gensim.models.keyedvectors.Vocab at 0x203c3883be0>,
#  'erróneamente': <gensim.models.keyedvectors.Vocab at 0x203c3883c18>,
#  'interpretado': <gensim.models.keyedvectors.Vocab at 0x203c3883c50>,
#  'exmagistrado': <gensim.models.keyedvectors.Vocab at 0x203c3883c88>,
#  'interponer': <gensim.models.keyedvectors.Vocab at 0x203c3883cc0>,
#  'recurso': <gensim.models.keyedvectors.Vocab at 0x203c3883d30>,
#  'amparo': <gensim.models.keyedvectors.Vocab at 0x203c3883da0>,
#  'español': <gensim.models.keyedvectors.Vocab at 0x203c3883dd8>,
#  'eventualmente': <gensim.models.keyedvectors.Vocab at 0x203c3883e10>,
#  'europeo': <gensim.models.keyedvectors.Vocab at 0x203c3883e80>,
#  'defensa': <gensim.models.keyedvectors.Vocab at 0x203c3883ef0>,
#  'carácter': <gensim.models.keyedvectors.Vocab at 0x203c3883f28>,
#  'universal': <gensim.models.keyedvectors.Vocab at 0x203c3883f60>,
#  'reiteró': <gensim.models.keyedvectors.Vocab at 0x203c3883f98>,
#  'imputados': <gensim.models.keyedvectors.Vocab at 0x203c3883fd0>,
#  'aprobados': <gensim.models.keyedvectors.Vocab at 0x203c388b048>,
#  'congreso': <gensim.models.keyedvectors.Vocab at 0x203c388b080>,
#  'actuó': <gensim.models.keyedvectors.Vocab at 0x203c388b0b8>,
#  'presión': <gensim.models.keyedvectors.Vocab at 0x203c388b0f0>,
#  'ley': <gensim.models.keyedvectors.Vocab at 0x203c388b160>,
#  'española': <gensim.models.keyedvectors.Vocab at 0x203c388b198>,
#  'penalistas': <gensim.models.keyedvectors.Vocab at 0x203c388b1d0>,
#  'sindicado': <gensim.models.keyedvectors.Vocab at 0x203c388b208>,
#  'cabecilla': <gensim.models.keyedvectors.Vocab at 0x203c388b240>,
#  'cuellos': <gensim.models.keyedvectors.Vocab at 0x203c388b2b0>,
#  'blancos': <gensim.models.keyedvectors.Vocab at 0x203c388b320>,
#  'puerto': <gensim.models.keyedvectors.Vocab at 0x203c388b390>,
#  'pesan': <gensim.models.keyedvectors.Vocab at 0x203c388b400>,
#  'órdenes': <gensim.models.keyedvectors.Vocab at 0x203c388b438>,
#  'caso': <gensim.models.keyedvectors.Vocab at 0x203c388b4a8>,
#  'salido': <gensim.models.keyedvectors.Vocab at 0x203c388b518>,
#  'pese': <gensim.models.keyedvectors.Vocab at 0x203c388b588>,
#  'impedimento': <gensim.models.keyedvectors.Vocab at 0x203c388b5c0>,
#  'abandonar': <gensim.models.keyedvectors.Vocab at 0x203c388b5f8>,
#  'perú': <gensim.models.keyedvectors.Vocab at 0x203c388b630>,
#  'salir': <gensim.models.keyedvectors.Vocab at 0x203c388b6a0>,
#  'internacional': <gensim.models.keyedvectors.Vocab at 0x203c388b6d8>,
#  'respetan': <gensim.models.keyedvectors.Vocab at 0x203c388b710>,
#  'evadir': <gensim.models.keyedvectors.Vocab at 0x203c388b780>,
#  'fugar': <gensim.models.keyedvectors.Vocab at 0x203c388b7f0>,
#  'falsamente': <gensim.models.keyedvectors.Vocab at 0x203c388b828>,
#  'menciona': <gensim.models.keyedvectors.Vocab at 0x203c388b860>,
#  'saludado': <gensim.models.keyedvectors.Vocab at 0x203c388b898>,
#  'extraditarlo': <gensim.models.keyedvectors.Vocab at 0x203c388b8d0>,
#  'sigan': <gensim.models.keyedvectors.Vocab at 0x203c388b940>,
#  'acusando': <gensim.models.keyedvectors.Vocab at 0x203c388b978>,
#  'espero': <gensim.models.keyedvectors.Vocab at 0x203c388b9e8>,
#  'dejen': <gensim.models.keyedvectors.Vocab at 0x203c388ba58>,
#  'dignidad': <gensim.models.keyedvectors.Vocab at 0x203c388ba90>,
#  'humana': <gensim.models.keyedvectors.Vocab at 0x203c388bb00>,
#  'horas': <gensim.models.keyedvectors.Vocab at 0x203c388bb70>,
#  'oficina': <gensim.models.keyedvectors.Vocab at 0x203c388bbe0>,
#  'volvían': <gensim.models.keyedvectors.Vocab at 0x203c388bc18>,
#  'eternas': <gensim.models.keyedvectors.Vocab at 0x203c388bc88>,
# ...
#  'inconclusos': <gensim.models.keyedvectors.Vocab at 0x203c38914a8>,
#  'finalizar': <gensim.models.keyedvectors.Vocab at 0x203c38914e0>,
#  'escuela': <gensim.models.keyedvectors.Vocab at 0x203c3891550>,
#  'cocinero': <gensim.models.keyedvectors.Vocab at 0x203c3891588>,
#  'regresaría': <gensim.models.keyedvectors.Vocab at 0x203c38915c0>,
#  'tarde': <gensim.models.keyedvectors.Vocab at 0x203c3891630>,
#  'perteneció': <gensim.models.keyedvectors.Vocab at 0x203c3891668>,
#  'empresas': <gensim.models.keyedvectors.Vocab at 0x203c38916a0>,
#  'importantes': <gensim.models.keyedvectors.Vocab at 0x203c38916d8>,
#  'semanas': <gensim.models.keyedvectors.Vocab at 0x203c3891748>,
#  'llegaban': <gensim.models.keyedvectors.Vocab at 0x203c3891780>,
#  'ajenas': <gensim.models.keyedvectors.Vocab at 0x203c38917f0>,
#  'debía': <gensim.models.keyedvectors.Vocab at 0x203c3891828>,
#  'encaminar': <gensim.models.keyedvectors.Vocab at 0x203c3891860>,
#  'pensó': <gensim.models.keyedvectors.Vocab at 0x203c3891898>,
#  'destino': <gensim.models.keyedvectors.Vocab at 0x203c3891908>,
#  'saco': <gensim.models.keyedvectors.Vocab at 0x203c3891978>,
#  'corbata': <gensim.models.keyedvectors.Vocab at 0x203c38919e8>,
#  'sentado': <gensim.models.keyedvectors.Vocab at 0x203c3891a58>,
#  'frente': <gensim.models.keyedvectors.Vocab at 0x203c3891ac8>,
#  'pantalla': <gensim.models.keyedvectors.Vocab at 0x203c3891b00>,
#  'escritorio': <gensim.models.keyedvectors.Vocab at 0x203c3891b38>,
#  'viaje': <gensim.models.keyedvectors.Vocab at 0x203c3891ba8>,
#  'sao': <gensim.models.keyedvectors.Vocab at 0x203c3891c18>,
#  'paulo': <gensim.models.keyedvectors.Vocab at 0x203c3891c88>,
#  'probó': <gensim.models.keyedvectors.Vocab at 0x203c3891cc0>,
#  'pizza': <gensim.models.keyedvectors.Vocab at 0x203c3891d30>,
#  'común': <gensim.models.keyedvectors.Vocab at 0x203c3891d68>,
#  'insumos': <gensim.models.keyedvectors.Vocab at 0x203c3891dd8>,
#  'brasileños': <gensim.models.keyedvectors.Vocab at 0x203c3891e10>,
#  'masa': <gensim.models.keyedvectors.Vocab at 0x203c3891e80>,
#  'tradicional': <gensim.models.keyedvectors.Vocab at 0x203c3891eb8>,
#  'dejando': <gensim.models.keyedvectors.Vocab at 0x203c3891f28>,
#  'típica': <gensim.models.keyedvectors.Vocab at 0x203c3891f60>,
#  'americana': <gensim.models.keyedvectors.Vocab at 0x203c3891f98>,
#  'pepperoni': <gensim.models.keyedvectors.Vocab at 0x203c3891fd0>,
#  'allí': <gensim.models.keyedvectors.Vocab at 0x203c3898048>,
#  'supo': <gensim.models.keyedvectors.Vocab at 0x203c38980b8>,
#  'cuál': <gensim.models.keyedvectors.Vocab at 0x203c38980f0>,
#  'camino': <gensim.models.keyedvectors.Vocab at 0x203c3898160>,
#  'jefes': <gensim.models.keyedvectors.Vocab at 0x203c38981d0>,
#  'inauguró': <gensim.models.keyedvectors.Vocab at 0x203c3898208>,
#  'oficialmente': <gensim.models.keyedvectors.Vocab at 0x203c3898240>,
#  'agosto': <gensim.models.keyedvectors.Vocab at 0x203c38982b0>,
#  '2017': <gensim.models.keyedvectors.Vocab at 0x203c3898320>,
#  'surquillo': <gensim.models.keyedvectors.Vocab at 0x203c3898358>,
#  'ahorros': <gensim.models.keyedvectors.Vocab at 0x203c38983c8>,
#  'bastaron': <gensim.models.keyedvectors.Vocab at 0x203c3898400>,
#  'alquilar': <gensim.models.keyedvectors.Vocab at 0x203c3898438>,
#  'local': <gensim.models.keyedvectors.Vocab at 0x203c38984a8>,
#  'adquirir': <gensim.models.keyedvectors.Vocab at 0x203c38984e0>,
#  'maquinaria': <gensim.models.keyedvectors.Vocab at 0x203c3898518>,
#  'preguntaba': <gensim.models.keyedvectors.Vocab at 0x203c3898550>,
#  'metido': <gensim.models.keyedvectors.Vocab at 0x203c38985c0>,
#  'mano': <gensim.models.keyedvectors.Vocab at 0x203c3898630>,
#  'empezó': <gensim.models.keyedvectors.Vocab at 0x203c3898668>,
#  'platos': <gensim.models.keyedvectors.Vocab at 0x203c38986d8>,
#  'adecuarlos': <gensim.models.keyedvectors.Vocab at 0x203c3898710>,
#  'vea': <gensim.models.keyedvectors.Vocab at 0x203c3898780>,
#  'sepa': <gensim.models.keyedvectors.Vocab at 0x203c38987f0>,
#  'decidió': <gensim.models.keyedvectors.Vocab at 0x203c3898828>,
#  'negocio': <gensim.models.keyedvectors.Vocab at 0x203c3898898>,
#  'demandar': <gensim.models.keyedvectors.Vocab at 0x203c38988d0>,
#  'tantas': <gensim.models.keyedvectors.Vocab at 0x203c3898940>,
#  'creó': <gensim.models.keyedvectors.Vocab at 0x203c3898978>,
#  'cocina': <gensim.models.keyedvectors.Vocab at 0x203c38989e8>,
#  'fantasma': <gensim.models.keyedvectors.Vocab at 0x203c3898a20>,
#  'producción': <gensim.models.keyedvectors.Vocab at 0x203c3898a58>,
#  'repartida': <gensim.models.keyedvectors.Vocab at 0x203c3898a90>,
#  'horario': <gensim.models.keyedvectors.Vocab at 0x203c3898b00>,
#  '6': <gensim.models.keyedvectors.Vocab at 0x203c3898b38>,
#  '11': <gensim.models.keyedvectors.Vocab at 0x203c3898ba8>,
#  'pm': <gensim.models.keyedvectors.Vocab at 0x203c3898c18>,
#  'intención': <gensim.models.keyedvectors.Vocab at 0x203c3898c50>,
#  'imitar': <gensim.models.keyedvectors.Vocab at 0x203c3898cc0>,
#  'corriente': <gensim.models.keyedvectors.Vocab at 0x203c3898cf8>,
#  'proviene': <gensim.models.keyedvectors.Vocab at 0x203c3898d30>,
#  'europa': <gensim.models.keyedvectors.Vocab at 0x203c3898da0>,
#  'asia': <gensim.models.keyedvectors.Vocab at 0x203c3898e10>,
#  'unidos': <gensim.models.keyedvectors.Vocab at 0x203c3898e80>,
#  'aplicó': <gensim.models.keyedvectors.Vocab at 0x203c3898eb8>,
#  'teoría': <gensim.models.keyedvectors.Vocab at 0x203c3898ef0>,
#  'empresa': <gensim.models.keyedvectors.Vocab at 0x203c3898f60>,
#  'presencia': <gensim.models.keyedvectors.Vocab at 0x203c3898f98>,
#  'aplicaciones': <gensim.models.keyedvectors.Vocab at 0x203c3898fd0>,
#  'físico': <gensim.models.keyedvectors.Vocab at 0x203c38a0048>,
#  'emprendimiento': <gensim.models.keyedvectors.Vocab at 0x203c38a0080>,
#  'agregado': <gensim.models.keyedvectors.Vocab at 0x203c38a00b8>,
#  'cajas': <gensim.models.keyedvectors.Vocab at 0x203c38a0128>,
#  'obras': <gensim.models.keyedvectors.Vocab at 0x203c38a0198>,
#  'arte': <gensim.models.keyedvectors.Vocab at 0x203c38a0208>,
#  'exhibe': <gensim.models.keyedvectors.Vocab at 0x203c38a0278>,
#  'creaciones': <gensim.models.keyedvectors.Vocab at 0x203c38a02b0>,
#  'ilustradores': <gensim.models.keyedvectors.Vocab at 0x203c38a02e8>,
#  'temas': <gensim.models.keyedvectors.Vocab at 0x203c38a0358>,
#  'nacionales': <gensim.models.keyedvectors.Vocab at 0x203c38a0390>,
#  'lema': <gensim.models.keyedvectors.Vocab at 0x203c38a0400>,
#  'consenso': <gensim.models.keyedvectors.Vocab at 0x203c38a0438>,
#  'u': <gensim.models.keyedvectors.Vocab at 0x203c38a0470>,
#  'cambie': <gensim.models.keyedvectors.Vocab at 0x203c38a04e0>,
#  'lote': <gensim.models.keyedvectors.Vocab at 0x203c38a0550>,
#  'primeras': <gensim.models.keyedvectors.Vocab at 0x203c38a0588>,
#  'diseñadas': <gensim.models.keyedvectors.Vocab at 0x203c38a05c0>,
#  'rojas': <gensim.models.keyedvectors.Vocab at 0x203c38a0630>,
#  'perros': <gensim.models.keyedvectors.Vocab at 0x203c38a06a0>,
#  'alpaca': <gensim.models.keyedvectors.Vocab at 0x203c38a0710>,
#  'temporada': <gensim.models.keyedvectors.Vocab at 0x203c38a0748>,
#  'alegre': <gensim.models.keyedvectors.Vocab at 0x203c38a07b8>,
#  'llegue': <gensim.models.keyedvectors.Vocab at 0x203c38a0828>,
#  'hogares': <gensim.models.keyedvectors.Vocab at 0x203c38a0898>,
#  'limeños': <gensim.models.keyedvectors.Vocab at 0x203c38a08d0>,
#  'aureola': <gensim.models.keyedvectors.Vocab at 0x203c38a0940>,
#  'princesa': <gensim.models.keyedvectors.Vocab at 0x203c38a0978>,
#  'promueve': <gensim.models.keyedvectors.Vocab at 0x203c38a09b0>,
#  'peruano': <gensim.models.keyedvectors.Vocab at 0x203c38a0a20>,
#  'voltee': <gensim.models.keyedvectors.Vocab at 0x203c38a0a90>,
#  'éxito': <gensim.models.keyedvectors.Vocab at 0x203c38a0ac8>,
#  'vertiginoso': <gensim.models.keyedvectors.Vocab at 0x203c38a0b00>,
#  '2x1': <gensim.models.keyedvectors.Vocab at 0x203c38a0b70>,
#  'distribuir': <gensim.models.keyedvectors.Vocab at 0x203c38a0ba8>,
#  'pizzas': <gensim.models.keyedvectors.Vocab at 0x203c38a0c18>,
#  'comensales': <gensim.models.keyedvectors.Vocab at 0x203c38a0c50>,
#  'enamoraron': <gensim.models.keyedvectors.Vocab at 0x203c38a0c88>,
#  'sabores': <gensim.models.keyedvectors.Vocab at 0x203c38a0cf8>,
#  'langostinos': <gensim.models.keyedvectors.Vocab at 0x203c38a0d30>,
#  'anticucheros': <gensim.models.keyedvectors.Vocab at 0x203c38a0d68>,
#  'lanzado': <gensim.models.keyedvectors.Vocab at 0x203c38a0dd8>,
#  'verano': <gensim.models.keyedvectors.Vocab at 0x203c38a0e48>,
#  'quedado': <gensim.models.keyedvectors.Vocab at 0x203c38a0eb8>,
#  'butifarra': <gensim.models.keyedvectors.Vocab at 0x203c38a0ef0>,
#  'huachana': <gensim.models.keyedvectors.Vocab at 0x203c38a0f28>,
#  'llegar': <gensim.models.keyedvectors.Vocab at 0x203c38a0f98>,
#  'plasmar': <gensim.models.keyedvectors.Vocab at 0x203c38a6048>,
#  'idea': <gensim.models.keyedvectors.Vocab at 0x203c38a60b8>,
#  'unir': <gensim.models.keyedvectors.Vocab at 0x203c38a6128>,
#  'tradiciones': <gensim.models.keyedvectors.Vocab at 0x203c38a6160>,
#  'italiana': <gensim.models.keyedvectors.Vocab at 0x203c38a6198>,
#  'difícil': <gensim.models.keyedvectors.Vocab at 0x203c38a61d0>,
#  'constante': <gensim.models.keyedvectors.Vocab at 0x203c38a6208>,
#  'prueba': <gensim.models.keyedvectors.Vocab at 0x203c38a6278>,
#  'error': <gensim.models.keyedvectors.Vocab at 0x203c38a62e8>,
#  'parecían': <gensim.models.keyedvectors.Vocab at 0x203c38a6320>,
#  'contundentes': <gensim.models.keyedvectors.Vocab at 0x203c38a6358>,
#  'faltaba': <gensim.models.keyedvectors.Vocab at 0x203c38a63c8>,
#  'arroz': <gensim.models.keyedvectors.Vocab at 0x203c38a6438>,
#  'bota': <gensim.models.keyedvectors.Vocab at 0x203c38a64a8>,
#  'carcajada': <gensim.models.keyedvectors.Vocab at 0x203c38a64e0>,
#  'cómplice': <gensim.models.keyedvectors.Vocab at 0x203c38a6518>,
#  'colaboradores': <gensim.models.keyedvectors.Vocab at 0x203c38a6550>,
#  'desarrollado': <gensim.models.keyedvectors.Vocab at 0x203c38a6588>,
#  'entramos': <gensim.models.keyedvectors.Vocab at 0x203c38a65c0>,
#  'fase': <gensim.models.keyedvectors.Vocab at 0x203c38a6630>,
#  'multiplicar': <gensim.models.keyedvectors.Vocab at 0x203c38a6668>,
#  'planea': <gensim.models.keyedvectors.Vocab at 0x203c38a66d8>,
#  'meta': <gensim.models.keyedvectors.Vocab at 0x203c38a6748>,
#  'denominación': <gensim.models.keyedvectors.Vocab at 0x203c38a6780>,
#  'mundial': <gensim.models.keyedvectors.Vocab at 0x203c38a67f0>,
#  'gringo': <gensim.models.keyedvectors.Vocab at 0x203c38a6860>,
#  'diga': <gensim.models.keyedvectors.Vocab at 0x203c38a68d0>,
#  'are': <gensim.models.keyedvectors.Vocab at 0x203c38a6940>,
#  'you': <gensim.models.keyedvectors.Vocab at 0x203c38a69b0>,
#  'eating': <gensim.models.keyedvectors.Vocab at 0x203c38a6a20>,
#  'respondas': <gensim.models.keyedvectors.Vocab at 0x203c38a6a58>,
#  'rapidez': <gensim.models.keyedvectors.Vocab at 0x203c38a6ac8>,
#  'calidad': <gensim.models.keyedvectors.Vocab at 0x203c38a6b38>,
#  'maneja': <gensim.models.keyedvectors.Vocab at 0x203c38a6ba8>,
#  'fast': <gensim.models.keyedvectors.Vocab at 0x203c38a6c18>,
#  'food': <gensim.models.keyedvectors.Vocab at 0x203c38a6c88>,
#  'estándares': <gensim.models.keyedvectors.Vocab at 0x203c38a6cc0>,
#  'exactos': <gensim.models.keyedvectors.Vocab at 0x203c38a6d30>,
#  'señalización': <gensim.models.keyedvectors.Vocab at 0x203c38a6d68>,
#  'porciones': <gensim.models.keyedvectors.Vocab at 0x203c38a6da0>,
#  'tiempos': <gensim.models.keyedvectors.Vocab at 0x203c38a6e10>,
#  'digital': <gensim.models.keyedvectors.Vocab at 0x203c38a6e80>,
#  'facebook': <gensim.models.keyedvectors.Vocab at 0x203c38a6eb8>,
#  'lapiczaperu': <gensim.models.keyedvectors.Vocab at 0x203c38a6ef0>,
#  'rappi': <gensim.models.keyedvectors.Vocab at 0x203c38a6f60>,
#  'vital': <gensim.models.keyedvectors.Vocab at 0x203c38a6fd0>,
#  'dejar': <gensim.models.keyedvectors.Vocab at 0x203c38ac080>,
#  'escuchar': <gensim.models.keyedvectors.Vocab at 0x203c38ac0b8>,
#  'aconseja': <gensim.models.keyedvectors.Vocab at 0x203c38ac0f0>,
#  'recomendaciones': <gensim.models.keyedvectors.Vocab at 0x203c38ac128>,
#  'emprender': <gensim.models.keyedvectors.Vocab at 0x203c38ac160>,
#  'resuelve': <gensim.models.keyedvectors.Vocab at 0x203c38ac198>,
#  'pensar': <gensim.models.keyedvectors.Vocab at 0x203c38ac208>,
#  'locura': <gensim.models.keyedvectors.Vocab at 0x203c38ac278>,
#  'números': <gensim.models.keyedvectors.Vocab at 0x203c38ac2b0>,
#  'equilibrio': <gensim.models.keyedvectors.Vocab at 0x203c38ac2e8>,
#  'proyecciones': <gensim.models.keyedvectors.Vocab at 0x203c38ac320>,
#  'futuro': <gensim.models.keyedvectors.Vocab at 0x203c38ac390>,
#  'piensa': <gensim.models.keyedvectors.Vocab at 0x203c38ac400>,
#  'generar': <gensim.models.keyedvectors.Vocab at 0x203c38ac470>,
#  'franquicias': <gensim.models.keyedvectors.Vocab at 0x203c38ac4a8>,
#  'caiga': <gensim.models.keyedvectors.Vocab at 0x203c38ac518>,
#  'peso': <gensim.models.keyedvectors.Vocab at 0x203c38ac588>,
#  'anhela': <gensim.models.keyedvectors.Vocab at 0x203c38ac5f8>,
#  'imite': <gensim.models.keyedvectors.Vocab at 0x203c38ac668>,
#  'cree': <gensim.models.keyedvectors.Vocab at 0x203c38ac6d8>,
#  'genérico': <gensim.models.keyedvectors.Vocab at 0x203c38ac710>,
#  'metió': <gensim.models.keyedvectors.Vocab at 0x203c38ac748>,
#  'masificar': <gensim.models.keyedvectors.Vocab at 0x203c38ac780>,
#  'producto': <gensim.models.keyedvectors.Vocab at 0x203c38ac7b8>,
#  'sabor': <gensim.models.keyedvectors.Vocab at 0x203c38ac828>,
#  'proporciones': <gensim.models.keyedvectors.Vocab at 0x203c38ac860>,
#  'generosas': <gensim.models.keyedvectors.Vocab at 0x203c38ac898>,
#  'gusta': <gensim.models.keyedvectors.Vocab at 0x203c38ac908>,
#  'principal': <gensim.models.keyedvectors.Vocab at 0x203c38ac940>,
#  'motivación': <gensim.models.keyedvectors.Vocab at 0x203c38ac978>,
#  'cuestionas': <gensim.models.keyedvectors.Vocab at 0x203c38ac9b0>,
#  'veía': <gensim.models.keyedvectors.Vocab at 0x203c38ac9e8>,
#  'trabajando': <gensim.models.keyedvectors.Vocab at 0x203c38aca20>,
#  'empleado': <gensim.models.keyedvectors.Vocab at 0x203c38aca58>,
#  'di': <gensim.models.keyedvectors.Vocab at 0x203c38acac8>,
#  'quise': <gensim.models.keyedvectors.Vocab at 0x203c38acb38>,
#  'aprobar': <gensim.models.keyedvectors.Vocab at 0x203c38acba8>,
#  'dificultad': <gensim.models.keyedvectors.Vocab at 0x203c38acbe0>,
#  'encontraste': <gensim.models.keyedvectors.Vocab at 0x203c38acc18>,
#  'superaste': <gensim.models.keyedvectors.Vocab at 0x203c38acc50>,
#  'cercana': <gensim.models.keyedvectors.Vocab at 0x203c38accc0>,
#  'ayude': <gensim.models.keyedvectors.Vocab at 0x203c38acd30>,
#  'asesorarse': <gensim.models.keyedvectors.Vocab at 0x203c38acd68>,
#  'pedir': <gensim.models.keyedvectors.Vocab at 0x203c38acdd8>,
#  'ayuda': <gensim.models.keyedvectors.Vocab at 0x203c38ace48>,
#  'ahorrado': <gensim.models.keyedvectors.Vocab at 0x203c38ace80>,
#  'comprarme': <gensim.models.keyedvectors.Vocab at 0x203c38aceb8>,
#  'depa': <gensim.models.keyedvectors.Vocab at 0x203c38acf28>,
#  'decidí': <gensim.models.keyedvectors.Vocab at 0x203c38acf60>,
#  'invertir': <gensim.models.keyedvectors.Vocab at 0x203c38acf98>,
#  'plata': <gensim.models.keyedvectors.Vocab at 0x203c38b3048>,
#  'contratan': <gensim.models.keyedvectors.Vocab at 0x203c38b3080>,
#  'decirles': <gensim.models.keyedvectors.Vocab at 0x203c38b30b8>,
#  'fortaleza': <gensim.models.keyedvectors.Vocab at 0x203c38b30f0>,
#  'creer': <gensim.models.keyedvectors.Vocab at 0x203c38b3160>,
#  'crear': <gensim.models.keyedvectors.Vocab at 0x203c38b31d0>,
#  'día': <gensim.models.keyedvectors.Vocab at 0x203c38b3208>,
#  'casa': <gensim.models.keyedvectors.Vocab at 0x203c38b3278>,
#  'haga': <gensim.models.keyedvectors.Vocab at 0x203c38b32e8>,
#  'vacilón': <gensim.models.keyedvectors.Vocab at 0x203c38b3320>,
#  'salchicha': <gensim.models.keyedvectors.Vocab at 0x203c38b3358>,
#  'huacho': <gensim.models.keyedvectors.Vocab at 0x203c38b33c8>,
#  'gastronomía': <gensim.models.keyedvectors.Vocab at 0x203c38b3400>,
#  'mallory': <gensim.models.keyedvectors.Vocab at 0x203c38b3470>,
#  'aco': <gensim.models.keyedvectors.Vocab at 0x203c38b34e0>,
#  'logró': <gensim.models.keyedvectors.Vocab at 0x203c38b3518>,
#  'medalla': <gensim.models.keyedvectors.Vocab at 0x203c38b3588>,
#  ...}

# %%
df_noticias_train = pd.read_csv('complete_clean_news.csv')
df_noticias_train.drop(df_noticias_train.columns[0],axis=1,inplace=True)
df_noticias_train.head()
# Out:
#    Categoria             Autor  \
# 0  farándula  redacción perú21
# 1       perú  redacción perú21
# 2   política  redacción perú21
# 3       lima  redacción perú21
# 4       lima  redacción perú21
#
#                                               Titulo  \
# 0  fiorella rodríguez presentó dueño corazón mese...
# 1  sujeto arrojó thinner padre 68 años prendió fu...
# 2  luis bedoya reyes llama abogados juristas inte...
# 3  separan responsables difundir fotos expresiden...
# 4  reaccionó john galliquio cuestionado denuncia ...
#
#                                              Resumen  \
# 0  conductora sorprendió fanáticos fotos amor red...
# 1  joven negó incendiado padre víctima graves que...
# 2  político 100 años pronunció importancia postul...
# 3  involucrados hospital casimiro ulloa suspendid...
# 4  exjugador selección peruana reapareció mostró ...
#
#                                            Contenido
# 0  presentadora exjurado artista año fiorella rod...
# 1  wandherlay enriquez luque 25 detenido arrojado...
# 2  luis bedoya reyes fundadores históricos partid...
# 3  doctor juan luis herrera director general oper...
# 4  john galliquio exjugador selección peruana apa...

# %%
df_2 = df_noticias_train.dropna()

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score

import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np

df_2['Vector'] = df_2['Contenido'].apply(lambda x: getFV(x,model,300))
# Out:
# E:\INSTALACIONES\Anaconda\lib\site-packages\ipykernel_launcher.py:8: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# E:\INSTALACIONES\Anaconda\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_2.head()
# Out:
#    Categoria             Autor  \
# 0  farándula  redacción perú21
# 1       perú  redacción perú21
# 2   política  redacción perú21
# 3       lima  redacción perú21
# 4       lima  redacción perú21
#
#                                               Titulo  \
# 0  fiorella rodríguez presentó dueño corazón mese...
# 1  sujeto arrojó thinner padre 68 años prendió fu...
# 2  luis bedoya reyes llama abogados juristas inte...
# 3  separan responsables difundir fotos expresiden...
# 4  reaccionó john galliquio cuestionado denuncia ...
#
#                                              Resumen  \
# 0  conductora sorprendió fanáticos fotos amor red...
# 1  joven negó incendiado padre víctima graves que...
# 2  político 100 años pronunció importancia postul...
# 3  involucrados hospital casimiro ulloa suspendid...
# 4  exjugador selección peruana reapareció mostró ...
#
#                                            Contenido  \
# 0  presentadora exjurado artista año fiorella rod...
# 1  wandherlay enriquez luque 25 detenido arrojado...
# 2  luis bedoya reyes fundadores históricos partid...
# 3  doctor juan luis herrera director general oper...
# 4  john galliquio exjugador selección peruana apa...
#
#                                               Vector
# 0  [0.004521261801710352, -0.35131151823734397, 0...
# 1  [0.26227770111567916, 0.2556349137864475, -0.0...
# 2  [0.18556199327439946, -0.24287225660484504, -0...
# 3  [-0.2011724293903064, -0.08155904694770773, -0...
# 4  [0.048363614192271795, -0.1913235466210888, -0...

# %%
data_train = list(df_2['Vector'])

# %%
len(data_train)
# Out:
# 125890

# %%
from sklearn.model_selection import train_test_split

X = list(df_2['Vector'])
X_train, X_test = train_test_split(X, test_size=0.2, random_state=0)
print(len(X), len(X_train), len(X_test))
# Out:
# 125890 100712 25178

# %%
import model_library as mdl

# %%
nc = 3
kmeans = KMeans(n_clusters=nc, random_state=0)
kmeans.fit(X_train)
mdl.grafico_silueta(kmeans, X_test, nc)

# %%
nc = 4
kmeans2 = KMeans(n_clusters=nc, random_state=0)
kmeans2.fit(X_train)
mdl.grafico_silueta(kmeans2, X_test, nc)

# %%
# !pip install joblib
# Out:
# Requirement already satisfied: joblib in e:\instalaciones\anaconda\lib\site-packages (0.14.0)

# %%
from joblib import dump, load
#dump(kmeans, 'km1_c4_300-5.joblib')

# %%
c5 = load('km1_c5_300-5.joblib') 
nc= 5
mdl.grafico_silueta(c5, X_test, nc)
