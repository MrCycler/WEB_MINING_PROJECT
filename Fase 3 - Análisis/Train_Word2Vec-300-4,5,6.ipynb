# %% [markdown]
# # Se importan las librerías

# %%
import gensim
from gensim.test.utils import common_texts, get_tmpfile
from gensim.models import word2vec , Phrases

import numpy as np
from multiprocessing import cpu_count

import nltk
from nltk.tokenize import sent_tokenize, word_tokenize 
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\pc\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# # Se lee el corpus y se obtiene el modelo

# %%
cpu_count()
# Out:
# 4

# %% [markdown]
# ### sizemodel 300 window 4

# %%
sentences = word2vec.Text8Corpus('corpus_general_news.txt')
sizeModel = 300
model = word2vec.Word2Vec(sentences, size=sizeModel, window=4, min_count=2, workers=cpu_count())

# %%
model.wv.vocab
# Out:
# {'presentadora': <gensim.models.keyedvectors.Vocab at 0x261a176e2b0>,
#  'exjurado': <gensim.models.keyedvectors.Vocab at 0x261a176e518>,
#  'artista': <gensim.models.keyedvectors.Vocab at 0x261a176e160>,
#  'año': <gensim.models.keyedvectors.Vocab at 0x261a1870710>,
#  'fiorella': <gensim.models.keyedvectors.Vocab at 0x261a1870898>,
#  'rodríguez': <gensim.models.keyedvectors.Vocab at 0x261a1870b70>,
#  '45': <gensim.models.keyedvectors.Vocab at 0x261a1870c18>,
#  'presentó': <gensim.models.keyedvectors.Vocab at 0x261a1870e48>,
#  'dueño': <gensim.models.keyedvectors.Vocab at 0x261a18703c8>,
#  'corazón': <gensim.models.keyedvectors.Vocab at 0x261a15b3320>,
#  'fotografías': <gensim.models.keyedvectors.Vocab at 0x261a15b3da0>,
#  'instagram': <gensim.models.keyedvectors.Vocab at 0x261a06811d0>,
#  'fanáticos': <gensim.models.keyedvectors.Vocab at 0x261a1885908>,
#  'tardaron': <gensim.models.keyedvectors.Vocab at 0x261a1885198>,
#  'llenarle': <gensim.models.keyedvectors.Vocab at 0x261a1885400>,
#  'publicación': <gensim.models.keyedvectors.Vocab at 0x261a191e780>,
#  'emoticones': <gensim.models.keyedvectors.Vocab at 0x261a191e978>,
#  'corazones': <gensim.models.keyedvectors.Vocab at 0x261a191eb38>,
#  'fotos': <gensim.models.keyedvectors.Vocab at 0x261a191eb70>,
#  'observa': <gensim.models.keyedvectors.Vocab at 0x261a191eba8>,
#  'abrazando': <gensim.models.keyedvectors.Vocab at 0x261a191ec88>,
#  'muchacho': <gensim.models.keyedvectors.Vocab at 0x261a191edd8>,
#  'mira': <gensim.models.keyedvectors.Vocab at 0x261a191ee80>,
#  'ternura': <gensim.models.keyedvectors.Vocab at 0x261a191e320>,
#  'captura': <gensim.models.keyedvectors.Vocab at 0x261a191e438>,
#  'sonríe': <gensim.models.keyedvectors.Vocab at 0x261a191efd0>,
#  'compartiendo': <gensim.models.keyedvectors.Vocab at 0x261a0db7048>,
#  'mirada': <gensim.models.keyedvectors.Vocab at 0x261a0db7080>,
#  'completa': <gensim.models.keyedvectors.Vocab at 0x261a0db70b8>,
#  'complicidad': <gensim.models.keyedvectors.Vocab at 0x261a0db70f0>,
#  'meses': <gensim.models.keyedvectors.Vocab at 0x261a0db7128>,
#  'amor': <gensim.models.keyedvectors.Vocab at 0x261a0db7160>,
#  'bonito': <gensim.models.keyedvectors.Vocab at 0x261a0db7198>,
#  'mensaje': <gensim.models.keyedvectors.Vocab at 0x261a0db71d0>,
#  'acompaña': <gensim.models.keyedvectors.Vocab at 0x261a0db7208>,
#  'mantuvo': <gensim.models.keyedvectors.Vocab at 0x261a0db7240>,
#  'matrimonio': <gensim.models.keyedvectors.Vocab at 0x261a0db7278>,
#  '15': <gensim.models.keyedvectors.Vocab at 0x261a0db72b0>,
#  'años': <gensim.models.keyedvectors.Vocab at 0x261a0db72e8>,
#  'cineasta': <gensim.models.keyedvectors.Vocab at 0x261a0db7320>,
#  'sandro': <gensim.models.keyedvectors.Vocab at 0x261a0db7390>,
#  'ventura': <gensim.models.keyedvectors.Vocab at 0x261a0db73c8>,
#  'mediados': <gensim.models.keyedvectors.Vocab at 0x261a0db7400>,
#  '2018': <gensim.models.keyedvectors.Vocab at 0x261a0db7438>,
#  'anunciaron': <gensim.models.keyedvectors.Vocab at 0x261a0db7470>,
#  'separación': <gensim.models.keyedvectors.Vocab at 0x261a0db74a8>,
#  'quedaron': <gensim.models.keyedvectors.Vocab at 0x261a0db74e0>,
#  'términos': <gensim.models.keyedvectors.Vocab at 0x261a0db7518>,
#  'amigo': <gensim.models.keyedvectors.Vocab at 0x261a0db7550>,
#  'hermosos': <gensim.models.keyedvectors.Vocab at 0x261a0db7588>,
#  'basados': <gensim.models.keyedvectors.Vocab at 0x261a0db75c0>,
#  'comunicación': <gensim.models.keyedvectors.Vocab at 0x261a0db75f8>,
#  'cariño': <gensim.models.keyedvectors.Vocab at 0x261a0db7668>,
#  'entrega': <gensim.models.keyedvectors.Vocab at 0x261a0db76d8>,
#  'absoluta': <gensim.models.keyedvectors.Vocab at 0x261a0db7710>,
#  'persona': <gensim.models.keyedvectors.Vocab at 0x261a0db7748>,
#  'importante': <gensim.models.keyedvectors.Vocab at 0x261a0db7780>,
#  'vida': <gensim.models.keyedvectors.Vocab at 0x261a0db77b8>,
#  'oportunidad': <gensim.models.keyedvectors.Vocab at 0x261a0db77f0>,
#  'cerrar': <gensim.models.keyedvectors.Vocab at 0x261a0db7828>,
#  'etapa': <gensim.models.keyedvectors.Vocab at 0x261a0db7860>,
#  'abrir': <gensim.models.keyedvectors.Vocab at 0x261a0db7898>,
#  'emoción': <gensim.models.keyedvectors.Vocab at 0x261a0db78d0>,
#  'expectativa': <gensim.models.keyedvectors.Vocab at 0x261a0db7908>,
#  'seguir': <gensim.models.keyedvectors.Vocab at 0x261a0db7940>,
#  'persiguiendo': <gensim.models.keyedvectors.Vocab at 0x261a0db7978>,
#  'sueños': <gensim.models.keyedvectors.Vocab at 0x261a0db79b0>,
#  'febrero': <gensim.models.keyedvectors.Vocab at 0x261a0db79e8>,
#  'entrevista': <gensim.models.keyedvectors.Vocab at 0x261a0db7a20>,
#  'perú21': <gensim.models.keyedvectors.Vocab at 0x261a0db7a58>,
#  'enriquez': <gensim.models.keyedvectors.Vocab at 0x261a0db7a90>,
#  'luque': <gensim.models.keyedvectors.Vocab at 0x261a0db7ac8>,
#  '25': <gensim.models.keyedvectors.Vocab at 0x261a0db7b00>,
#  'detenido': <gensim.models.keyedvectors.Vocab at 0x261a0db7b38>,
#  'arrojado': <gensim.models.keyedvectors.Vocab at 0x261a0db7b70>,
#  'thinner': <gensim.models.keyedvectors.Vocab at 0x261a0db7ba8>,
#  'padre': <gensim.models.keyedvectors.Vocab at 0x261a0db7be0>,
#  'posteriormente': <gensim.models.keyedvectors.Vocab at 0x261a0db7c18>,
#  'prenderle': <gensim.models.keyedvectors.Vocab at 0x261a0db7c50>,
#  'fuego': <gensim.models.keyedvectors.Vocab at 0x261a0db7c88>,
#  'acuerdo': <gensim.models.keyedvectors.Vocab at 0x261a0db7cc0>,
#  'diversos': <gensim.models.keyedvectors.Vocab at 0x261a0db7cf8>,
#  'medios': <gensim.models.keyedvectors.Vocab at 0x261a0db7d30>,
#  'locales': <gensim.models.keyedvectors.Vocab at 0x261a0db7d68>,
#  'parricidio': <gensim.models.keyedvectors.Vocab at 0x261a0db7da0>,
#  'ocurrió': <gensim.models.keyedvectors.Vocab at 0x261a0db7dd8>,
#  'vivienda': <gensim.models.keyedvectors.Vocab at 0x261a0db7e48>,
#  'agraviado': <gensim.models.keyedvectors.Vocab at 0x261a0db7e80>,
#  'ubicada': <gensim.models.keyedvectors.Vocab at 0x261a0db7eb8>,
#  'provincia': <gensim.models.keyedvectors.Vocab at 0x261a0db7ef0>,
#  'convención': <gensim.models.keyedvectors.Vocab at 0x261a0db7f28>,
#  'cusco': <gensim.models.keyedvectors.Vocab at 0x261a0db7f60>,
#  'vecinos': <gensim.models.keyedvectors.Vocab at 0x261a0db7f98>,
#  'zona': <gensim.models.keyedvectors.Vocab at 0x261a0db7fd0>,
#  'aviso': <gensim.models.keyedvectors.Vocab at 0x261a197e6a0>,
#  'autoridades': <gensim.models.keyedvectors.Vocab at 0x261a197ecc0>,
#  'inmediatamente': <gensim.models.keyedvectors.Vocab at 0x261a197edd8>,
#  'llegaron': <gensim.models.keyedvectors.Vocab at 0x261a197eef0>,
#  'hechos': <gensim.models.keyedvectors.Vocab at 0x261a197e128>,
#  'domicilio': <gensim.models.keyedvectors.Vocab at 0x261a197e1d0>,
#  'joven': <gensim.models.keyedvectors.Vocab at 0x261a197e4e0>,
#  'negó': <gensim.models.keyedvectors.Vocab at 0x261a197e588>,
#  'incendiado': <gensim.models.keyedvectors.Vocab at 0x261a197e5f8>,
#  'identificado': <gensim.models.keyedvectors.Vocab at 0x261a197e668>,
#  'víctor': <gensim.models.keyedvectors.Vocab at 0x261a197e710>,
#  'carrion': <gensim.models.keyedvectors.Vocab at 0x261a197e8d0>,
#  '68': <gensim.models.keyedvectors.Vocab at 0x261a197e940>,
#  'obstante': <gensim.models.keyedvectors.Vocab at 0x261a0dd8668>,
#  'graves': <gensim.models.keyedvectors.Vocab at 0x261a0dd8048>,
#  'quemaduras': <gensim.models.keyedvectors.Vocab at 0x261a0dd8080>,
#  'grado': <gensim.models.keyedvectors.Vocab at 0x261a0dd80b8>,
#  'salió': <gensim.models.keyedvectors.Vocab at 0x261a0dd80f0>,
#  'desmentir': <gensim.models.keyedvectors.Vocab at 0x261a0dd8128>,
#  'versión': <gensim.models.keyedvectors.Vocab at 0x261a0dd8160>,
#  'hijo': <gensim.models.keyedvectors.Vocab at 0x261a0dd8198>,
#  'finalmente': <gensim.models.keyedvectors.Vocab at 0x261a0dd81d0>,
#  'trasladado': <gensim.models.keyedvectors.Vocab at 0x261a0dd8240>,
#  'comisaría': <gensim.models.keyedvectors.Vocab at 0x261a0dd8278>,
#  'santa': <gensim.models.keyedvectors.Vocab at 0x261a0dd82b0>,
#  'teresa': <gensim.models.keyedvectors.Vocab at 0x261a0dd82e8>,
#  'intervención': <gensim.models.keyedvectors.Vocab at 0x261a0dd8320>,
#  'víctima': <gensim.models.keyedvectors.Vocab at 0x261a0dd8358>,
#  'llevado': <gensim.models.keyedvectors.Vocab at 0x261a0dd8390>,
#  'hospital': <gensim.models.keyedvectors.Vocab at 0x261a0dd83c8>,
#  'central': <gensim.models.keyedvectors.Vocab at 0x261a0dd8400>,
#  'ciudad': <gensim.models.keyedvectors.Vocab at 0x261a0dd8438>,
#  'quillabamba': <gensim.models.keyedvectors.Vocab at 0x261a0dd8470>,
#  'viene': <gensim.models.keyedvectors.Vocab at 0x261a0dd84a8>,
#  'recuperándose': <gensim.models.keyedvectors.Vocab at 0x261a0dd84e0>,
#  'lesiones': <gensim.models.keyedvectors.Vocab at 0x261a0dd8518>,
#  'fiscalía': <gensim.models.keyedvectors.Vocab at 0x261a0dd8550>,
#  'turno': <gensim.models.keyedvectors.Vocab at 0x261a0dd8588>,
#  'dispuso': <gensim.models.keyedvectors.Vocab at 0x261a0dd85c0>,
#  'diligencias': <gensim.models.keyedvectors.Vocab at 0x261a0dd85f8>,
#  'preliminares': <gensim.models.keyedvectors.Vocab at 0x261a0dd8630>,
#  'correspondientes': <gensim.models.keyedvectors.Vocab at 0x261a0dd86a0>,
#  'permanecerá': <gensim.models.keyedvectors.Vocab at 0x261a0dd86d8>,
#  'investigaciones': <gensim.models.keyedvectors.Vocab at 0x261a0dd8710>,
#  'deberá': <gensim.models.keyedvectors.Vocab at 0x261a0dd8748>,
#  'enfrentar': <gensim.models.keyedvectors.Vocab at 0x261a0dd8780>,
#  'cargos': <gensim.models.keyedvectors.Vocab at 0x261a0dd87b8>,
#  'presunto': <gensim.models.keyedvectors.Vocab at 0x261a0dd87f0>,
#  'delito': <gensim.models.keyedvectors.Vocab at 0x261a0dd8828>,
#  'violencia': <gensim.models.keyedvectors.Vocab at 0x261a0dd8860>,
#  'familiar': <gensim.models.keyedvectors.Vocab at 0x261a0dd8898>,
#  'luis': <gensim.models.keyedvectors.Vocab at 0x261a0dd88d0>,
#  'bedoya': <gensim.models.keyedvectors.Vocab at 0x261a0dd8908>,
#  'reyes': <gensim.models.keyedvectors.Vocab at 0x261a0dd8940>,
#  'fundadores': <gensim.models.keyedvectors.Vocab at 0x261a0dd8978>,
#  'históricos': <gensim.models.keyedvectors.Vocab at 0x261a0dd89b0>,
#  'partido': <gensim.models.keyedvectors.Vocab at 0x261a0dd89e8>,
#  'popular': <gensim.models.keyedvectors.Vocab at 0x261a0dd8a20>,
#  'cristiano': <gensim.models.keyedvectors.Vocab at 0x261a0dd8a58>,
#  'ppc': <gensim.models.keyedvectors.Vocab at 0x261a0dd8a90>,
#  'pronunció': <gensim.models.keyedvectors.Vocab at 0x261a0dd8ac8>,
#  'acerca': <gensim.models.keyedvectors.Vocab at 0x261a0dd8b00>,
#  'convocatoria': <gensim.models.keyedvectors.Vocab at 0x261a0dd8b38>,
#  'integrar': <gensim.models.keyedvectors.Vocab at 0x261a0dd8b70>,
#  'junta': <gensim.models.keyedvectors.Vocab at 0x261a0dd8ba8>,
#  'nacional': <gensim.models.keyedvectors.Vocab at 0x261a0dd8be0>,
#  'justicia': <gensim.models.keyedvectors.Vocab at 0x261a0dd8c18>,
#  'jnj': <gensim.models.keyedvectors.Vocab at 0x261a0dd8c50>,
#  'pequeño': <gensim.models.keyedvectors.Vocab at 0x261a0dd8c88>,
#  'discurso': <gensim.models.keyedvectors.Vocab at 0x261a0dd8cc0>,
#  'importancia': <gensim.models.keyedvectors.Vocab at 0x261a0dd8cf8>,
#  'significa': <gensim.models.keyedvectors.Vocab at 0x261a0dd8d30>,
#  'órgano': <gensim.models.keyedvectors.Vocab at 0x261a0dd8d68>,
#  'político': <gensim.models.keyedvectors.Vocab at 0x261a0dd8da0>,
#  '100': <gensim.models.keyedvectors.Vocab at 0x261a0dd8dd8>,
#  'edad': <gensim.models.keyedvectors.Vocab at 0x261a0dd8e10>,
#  'grabó': <gensim.models.keyedvectors.Vocab at 0x261a0dd8e48>,
#  'video': <gensim.models.keyedvectors.Vocab at 0x261a0dd8e80>,
#  'explica': <gensim.models.keyedvectors.Vocab at 0x261a0dd8eb8>,
#  'razones': <gensim.models.keyedvectors.Vocab at 0x261a0dd8ef0>,
#  'llama': <gensim.models.keyedvectors.Vocab at 0x261a0dd8f28>,
#  'juristas': <gensim.models.keyedvectors.Vocab at 0x261a0dd8f60>,
#  'abogados': <gensim.models.keyedvectors.Vocab at 0x261a0dd8f98>,
#  'especialistas': <gensim.models.keyedvectors.Vocab at 0x261a196a198>,
#  'derecho': <gensim.models.keyedvectors.Vocab at 0x261a196a240>,
#  'ojalá': <gensim.models.keyedvectors.Vocab at 0x261a196a2e8>,
#  'acostumbren': <gensim.models.keyedvectors.Vocab at 0x261a196a320>,
#  'acertar': <gensim.models.keyedvectors.Vocab at 0x261a196a390>,
#  'postulantes': <gensim.models.keyedvectors.Vocab at 0x261a196a4e0>,
#  'merezcan': <gensim.models.keyedvectors.Vocab at 0x261a196ada0>,
#  'elegidos': <gensim.models.keyedvectors.Vocab at 0x261a196aeb8>,
#  'razón': <gensim.models.keyedvectors.Vocab at 0x261a196a160>,
#  'condiciones': <gensim.models.keyedvectors.Vocab at 0x261a196a128>,
#  'cualidades': <gensim.models.keyedvectors.Vocab at 0x261a19e36d8>,
#  'juntaremos': <gensim.models.keyedvectors.Vocab at 0x261a19e3748>,
#  'peruanos': <gensim.models.keyedvectors.Vocab at 0x261a19e3780>,
#  'vivir': <gensim.models.keyedvectors.Vocab at 0x261a19e39e8>,
#  'discrepando': <gensim.models.keyedvectors.Vocab at 0x261a19e3a58>,
#  'institución': <gensim.models.keyedvectors.Vocab at 0x261a19e3b00>,
#  'reemplazará': <gensim.models.keyedvectors.Vocab at 0x261a19e3ef0>,
#  'desaparecido': <gensim.models.keyedvectors.Vocab at 0x261a19e30b8>,
#  'consejo': <gensim.models.keyedvectors.Vocab at 0x261a19e3128>,
#  'magistratura': <gensim.models.keyedvectors.Vocab at 0x261a19e33c8>,
#  'cnm': <gensim.models.keyedvectors.Vocab at 0x261a19e3550>,
#  'desactivado': <gensim.models.keyedvectors.Vocab at 0x261a19e3668>,
#  'audios': <gensim.models.keyedvectors.Vocab at 0x261a189db38>,
#  'vergüenza': <gensim.models.keyedvectors.Vocab at 0x261a189d8d0>,
#  'exintegrantes': <gensim.models.keyedvectors.Vocab at 0x261a19db7b8>,
#  'escuchaba': <gensim.models.keyedvectors.Vocab at 0x261a19db860>,
#  'comprometedoras': <gensim.models.keyedvectors.Vocab at 0x261a19db978>,
#  'situación': <gensim.models.keyedvectors.Vocab at 0x261a19dba20>,
#  'corrupción': <gensim.models.keyedvectors.Vocab at 0x261a19dbb70>,
#  'encargará': <gensim.models.keyedvectors.Vocab at 0x261a19dbba8>,
#  'nombrar': <gensim.models.keyedvectors.Vocab at 0x261a19dbc50>,
#  'destituir': <gensim.models.keyedvectors.Vocab at 0x261a19db0b8>,
#  'jueces': <gensim.models.keyedvectors.Vocab at 0x261a19db2b0>,
#  'fiscales': <gensim.models.keyedvectors.Vocab at 0x261a19db320>,
#  'asimismo': <gensim.models.keyedvectors.Vocab at 0x261a19db518>,
#  'facultad': <gensim.models.keyedvectors.Vocab at 0x261a19db588>,
#  'renovar': <gensim.models.keyedvectors.Vocab at 0x261a19db5c0>,
#  'cargo': <gensim.models.keyedvectors.Vocab at 0x261a19db630>,
#  'jefe': <gensim.models.keyedvectors.Vocab at 0x261a19db6d8>,
#  'onpe': <gensim.models.keyedvectors.Vocab at 0x261a1956860>,
#  'reniec': <gensim.models.keyedvectors.Vocab at 0x261a19560f0>,
#  'doctor': <gensim.models.keyedvectors.Vocab at 0x261a1956470>,
#  'juan': <gensim.models.keyedvectors.Vocab at 0x261a19564e0>,
#  'herrera': <gensim.models.keyedvectors.Vocab at 0x261a1956668>,
#  'director': <gensim.models.keyedvectors.Vocab at 0x261a1956c88>,
#  'general': <gensim.models.keyedvectors.Vocab at 0x261a1956d30>,
#  'operaciones': <gensim.models.keyedvectors.Vocab at 0x261a1956da0>,
#  'salud': <gensim.models.keyedvectors.Vocab at 0x261a1956908>,
#  'conversación': <gensim.models.keyedvectors.Vocab at 0x261a189b240>,
#  'atv': <gensim.models.keyedvectors.Vocab at 0x261a189b5c0>,
#  'separó': <gensim.models.keyedvectors.Vocab at 0x261a189b9e8>,
#  'responsables': <gensim.models.keyedvectors.Vocab at 0x261a189bac8>,
#  'difundir': <gensim.models.keyedvectors.Vocab at 0x261a189bb00>,
#  'fallecido': <gensim.models.keyedvectors.Vocab at 0x261a189bbe0>,
#  'expresidente': <gensim.models.keyedvectors.Vocab at 0x261a189bcf8>,
#  'alan': <gensim.models.keyedvectors.Vocab at 0x261a189bef0>,
#  'garcía': <gensim.models.keyedvectors.Vocab at 0x261a1c13048>,
#  'casimiro': <gensim.models.keyedvectors.Vocab at 0x261a1c13080>,
#  'ulloa': <gensim.models.keyedvectors.Vocab at 0x261a1c131d0>,
#  'sistema': <gensim.models.keyedvectors.Vocab at 0x261a1c13208>,
#  'identificados': <gensim.models.keyedvectors.Vocab at 0x261a1c13278>,
#  'vía': <gensim.models.keyedvectors.Vocab at 0x261a1c132b0>,
#  'administrativas': <gensim.models.keyedvectors.Vocab at 0x261a1c134a8>,
#  'activada': <gensim.models.keyedvectors.Vocab at 0x261a1c13588>,
#  'sanción': <gensim.models.keyedvectors.Vocab at 0x261a1c135c0>,
#  'correspondiente': <gensim.models.keyedvectors.Vocab at 0x261a1c135f8>,
#  'tema': <gensim.models.keyedvectors.Vocab at 0x261a1c136a0>,
#  'respeto': <gensim.models.keyedvectors.Vocab at 0x261a1c136d8>,
#  'nombre': <gensim.models.keyedvectors.Vocab at 0x261a1c13748>,
#  'detalle': <gensim.models.keyedvectors.Vocab at 0x261a1c13780>,
#  'grupo': <gensim.models.keyedvectors.Vocab at 0x261a1c137f0>,
#  'ocupacional': <gensim.models.keyedvectors.Vocab at 0x261a1c13828>,
#  'lamentable': <gensim.models.keyedvectors.Vocab at 0x261a1c13860>,
#  'precisó': <gensim.models.keyedvectors.Vocab at 0x261a1c13898>,
#  'involucrados': <gensim.models.keyedvectors.Vocab at 0x261a1c13a58>,
#  'separados': <gensim.models.keyedvectors.Vocab at 0x261a1c13a90>,
#  'nosocomio': <gensim.models.keyedvectors.Vocab at 0x261a1c13b38>,
#  'preliminar': <gensim.models.keyedvectors.Vocab at 0x261a1c13b70>,
#  'entidad': <gensim.models.keyedvectors.Vocab at 0x261a1c13ba8>,
#  'proceso': <gensim.models.keyedvectors.Vocab at 0x261a1c13be0>,
#  'administrativos': <gensim.models.keyedvectors.Vocab at 0x261a1c13c18>,
#  'corresponde': <gensim.models.keyedvectors.Vocab at 0x261a1c13c50>,
#  'definitiva': <gensim.models.keyedvectors.Vocab at 0x261a1c13cf8>,
#  'mal': <gensim.models.keyedvectors.Vocab at 0x261a1c13d68>,
#  'recuerdo': <gensim.models.keyedvectors.Vocab at 0x261a1c13dd8>,
#  'suspensión': <gensim.models.keyedvectors.Vocab at 0x261a1c13e10>,
#  'procurador': <gensim.models.keyedvectors.Vocab at 0x261a1c13e48>,
#  'tomando': <gensim.models.keyedvectors.Vocab at 0x261a1c13e80>,
#  'acciones': <gensim.models.keyedvectors.Vocab at 0x261a1c13eb8>,
#  'administrativa': <gensim.models.keyedvectors.Vocab at 0x261a1c13f60>,
#  'aseveró': <gensim.models.keyedvectors.Vocab at 0x261a1c13fd0>,
#  'diagnóstico': <gensim.models.keyedvectors.Vocab at 0x261a189c048>,
#  '17': <gensim.models.keyedvectors.Vocab at 0x261a189c2e8>,
#  'abril': <gensim.models.keyedvectors.Vocab at 0x261a189c588>,
#  'exmandatario': <gensim.models.keyedvectors.Vocab at 0x261a189c7b8>,
#  'tomó': <gensim.models.keyedvectors.Vocab at 0x261a189c8d0>,
#  'fatal': <gensim.models.keyedvectors.Vocab at 0x261a189c940>,
#  'decisión': <gensim.models.keyedvectors.Vocab at 0x261a189c9e8>,
#  'quitarse': <gensim.models.keyedvectors.Vocab at 0x261a189ce10>,
#  'disparándose': <gensim.models.keyedvectors.Vocab at 0x261a189ceb8>,
#  'cabeza': <gensim.models.keyedvectors.Vocab at 0x261a19df080>,
#  'impacto': <gensim.models.keyedvectors.Vocab at 0x261a19df0b8>,
#  'proyectil': <gensim.models.keyedvectors.Vocab at 0x261a19df128>,
#  'arma': <gensim.models.keyedvectors.Vocab at 0x261a19df198>,
#  'orificio': <gensim.models.keyedvectors.Vocab at 0x261a19df1d0>,
#  'entrada': <gensim.models.keyedvectors.Vocab at 0x261a19df438>,
#  'salida': <gensim.models.keyedvectors.Vocab at 0x261a19df4e0>,
#  'cráneo': <gensim.models.keyedvectors.Vocab at 0x261a19df518>,
#  'ingresó': <gensim.models.keyedvectors.Vocab at 0x261a19df668>,
#  'sala': <gensim.models.keyedvectors.Vocab at 0x261a19df748>,
#  '0717': <gensim.models.keyedvectors.Vocab at 0x261a19df828>,
#  'am': <gensim.models.keyedvectors.Vocab at 0x261a19df860>,
#  'vano': <gensim.models.keyedvectors.Vocab at 0x261a19dfa58>,
#  'muerte': <gensim.models.keyedvectors.Vocab at 0x261a19dfbe0>,
#  'consecuencia': <gensim.models.keyedvectors.Vocab at 0x261a19dfc88>,
#  'hemorragia': <gensim.models.keyedvectors.Vocab at 0x261a15dffd0>,
#  'cerebral': <gensim.models.keyedvectors.Vocab at 0x261a15df550>,
#  'masiva': <gensim.models.keyedvectors.Vocab at 0x261a15df588>,
#  'paro': <gensim.models.keyedvectors.Vocab at 0x261a15dfa20>,
#  'cardiorespiratorio': <gensim.models.keyedvectors.Vocab at 0x261a09e18d0>,
#  'john': <gensim.models.keyedvectors.Vocab at 0x261a06e8278>,
#  'galliquio': <gensim.models.keyedvectors.Vocab at 0x261a076a0f0>,
#  'exjugador': <gensim.models.keyedvectors.Vocab at 0x261a076a240>,
#  'selección': <gensim.models.keyedvectors.Vocab at 0x261a07b0c18>,
#  'peruana': <gensim.models.keyedvectors.Vocab at 0x261a05598d0>,
#  'apareció': <gensim.models.keyedvectors.Vocab at 0x261a0db2048>,
#  'evento': <gensim.models.keyedvectors.Vocab at 0x261a0db2080>,
#  'deportivo': <gensim.models.keyedvectors.Vocab at 0x261a0db20b8>,
#  'san': <gensim.models.keyedvectors.Vocab at 0x261a0db20f0>,
#  'miraflores': <gensim.models.keyedvectors.Vocab at 0x261a0db2128>,
#  'consultado': <gensim.models.keyedvectors.Vocab at 0x261a0db2160>,
#  'denuncia': <gensim.models.keyedvectors.Vocab at 0x261a0db21d0>,
#  'exesposa': <gensim.models.keyedvectors.Vocab at 0x261a0db2240>,
#  'karla': <gensim.models.keyedvectors.Vocab at 0x261a0db2278>,
#  'gómez': <gensim.models.keyedvectors.Vocab at 0x261a0db22b0>,
#  'prefirió': <gensim.models.keyedvectors.Vocab at 0x261a0db2320>,
#  'declarar': <gensim.models.keyedvectors.Vocab at 0x261a0db2358>,
#  'aprecia': <gensim.models.keyedvectors.Vocab at 0x261a0db2390>,
#  'imágenes': <gensim.models.keyedvectors.Vocab at 0x261a0db23c8>,
#  'programa': <gensim.models.keyedvectors.Vocab at 0x261a0db2400>,
#  'magaly': <gensim.models.keyedvectors.Vocab at 0x261a0db2438>,
#  'medina': <gensim.models.keyedvectors.Vocab at 0x261a0db2470>,
#  'tyson': <gensim.models.keyedvectors.Vocab at 0x261a0db24a8>,
#  'hablaría': <gensim.models.keyedvectors.Vocab at 0x261a0db2518>,
#  'privada': <gensim.models.keyedvectors.Vocab at 0x261a0db2550>,
#  'evadió': <gensim.models.keyedvectors.Vocab at 0x261a0db2588>,
#  'consultadas': <gensim.models.keyedvectors.Vocab at 0x261a0db25c0>,
#  'reportero': <gensim.models.keyedvectors.Vocab at 0x261a0db25f8>,
#  'presentes': <gensim.models.keyedvectors.Vocab at 0x261a0db2630>,
#  'paolo': <gensim.models.keyedvectors.Vocab at 0x261a0db2668>,
#  'maldonado': <gensim.models.keyedvectors.Vocab at 0x261a0db26a0>,
#  'manuel': <gensim.models.keyedvectors.Vocab at 0x261a0db26d8>,
#  'vargas': <gensim.models.keyedvectors.Vocab at 0x261a0db2710>,
#  'mostró': <gensim.models.keyedvectors.Vocab at 0x261a0db2748>,
#  'risueño': <gensim.models.keyedvectors.Vocab at 0x261a0db2780>,
#  'principio': <gensim.models.keyedvectors.Vocab at 0x261a0db27b8>,
#  'propiedades': <gensim.models.keyedvectors.Vocab at 0x261a0db27f0>,
#  'denuncias': <gensim.models.keyedvectors.Vocab at 0x261a0db2828>,
#  'incómodo': <gensim.models.keyedvectors.Vocab at 0x261a0db2860>,
#  'disculpa': <gensim.models.keyedvectors.Vocab at 0x261a0db2898>,
#  'hablo': <gensim.models.keyedvectors.Vocab at 0x261a0db2908>,
#  'favor': <gensim.models.keyedvectors.Vocab at 0x261a0db2940>,
#  'agradezco': <gensim.models.keyedvectors.Vocab at 0x261a0db2978>,
#  'montón': <gensim.models.keyedvectors.Vocab at 0x261a0db29e8>,
#  'hablar': <gensim.models.keyedvectors.Vocab at 0x261a0db2a20>,
#  'ustedes': <gensim.models.keyedvectors.Vocab at 0x261a0db2a58>,
#  'contigo': <gensim.models.keyedvectors.Vocab at 0x261a0db2a90>,
#  'gracias': <gensim.models.keyedvectors.Vocab at 0x261a0db2ac8>,
#  'puedes': <gensim.models.keyedvectors.Vocab at 0x261a0db2b00>,
#  'obligar': <gensim.models.keyedvectors.Vocab at 0x261a0db2b38>,
#  'hable': <gensim.models.keyedvectors.Vocab at 0x261a0db2b70>,
#  'declaró': <gensim.models.keyedvectors.Vocab at 0x261a0db2ba8>,
#  'jhon': <gensim.models.keyedvectors.Vocab at 0x261a0db2c18>,
#  'recordar': <gensim.models.keyedvectors.Vocab at 0x261a0db2c50>,
#  'medidas': <gensim.models.keyedvectors.Vocab at 0x261a0db2c88>,
#  'protección': <gensim.models.keyedvectors.Vocab at 0x261a0db2cc0>,
#  'pisco': <gensim.models.keyedvectors.Vocab at 0x261a0db2cf8>,
#  'denunciar': <gensim.models.keyedvectors.Vocab at 0x261a0db2d68>,
#  'agentes': <gensim.models.keyedvectors.Vocab at 0x261a0db2da0>,
#  'ignoran': <gensim.models.keyedvectors.Vocab at 0x261a0db2dd8>,
#  'informa': <gensim.models.keyedvectors.Vocab at 0x261a0db2e10>,
#  'marzo': <gensim.models.keyedvectors.Vocab at 0x261a0db2e48>,
#  'denunciado': <gensim.models.keyedvectors.Vocab at 0x261a0db2e80>,
#  'doméstica': <gensim.models.keyedvectors.Vocab at 0x261a0db2eb8>,
#  'querido': <gensim.models.keyedvectors.Vocab at 0x261a0db2ef0>,
#  'ahogar': <gensim.models.keyedvectors.Vocab at 0x261a0db2f28>,
#  'mar': <gensim.models.keyedvectors.Vocab at 0x261a0db2f60>,
#  'discusión': <gensim.models.keyedvectors.Vocab at 0x261a0db2f98>,
#  'pateaba': <gensim.models.keyedvectors.Vocab at 0x261a0db2fd0>,
#  'punto': <gensim.models.keyedvectors.Vocab at 0x261a0db62e8>,
#  'hacerme': <gensim.models.keyedvectors.Vocab at 0x261a0db6320>,
#  'vomitar': <gensim.models.keyedvectors.Vocab at 0x261a0db6358>,
#  'sangre': <gensim.models.keyedvectors.Vocab at 0x261a0db6390>,
#  'rompe': <gensim.models.keyedvectors.Vocab at 0x261a0db63c8>,
#  'mandíbula': <gensim.models.keyedvectors.Vocab at 0x261a0db6400>,
#  'patea': <gensim.models.keyedvectors.Vocab at 0x261a0db6438>,
#  'calle': <gensim.models.keyedvectors.Vocab at 0x261a0db6470>,
#  'esperando': <gensim.models.keyedvectors.Vocab at 0x261a0db64a8>,
#  'mate': <gensim.models.keyedvectors.Vocab at 0x261a0db64e0>,
#  'medio': <gensim.models.keyedvectors.Vocab at 0x261a0db6518>,
#  'lágrimas': <gensim.models.keyedvectors.Vocab at 0x261a0db6550>,
#  'denunciante': <gensim.models.keyedvectors.Vocab at 0x261a0db6588>,
#  'jugador': <gensim.models.keyedvectors.Vocab at 0x261a0db65c0>,
#  'aparece': <gensim.models.keyedvectors.Vocab at 0x261a0db65f8>,
#  'cuchillo': <gensim.models.keyedvectors.Vocab at 0x261a0db6630>,
#  'audio': <gensim.models.keyedvectors.Vocab at 0x261a0db6668>,
#  'cárcel': <gensim.models.keyedvectors.Vocab at 0x261a0db66a0>,
#  'matar': <gensim.models.keyedvectors.Vocab at 0x261a0db66d8>,
#  'duras': <gensim.models.keyedvectors.Vocab at 0x261a0db6710>,
#  'críticas': <gensim.models.keyedvectors.Vocab at 0x261a0db6748>,
#  'recibiendo': <gensim.models.keyedvectors.Vocab at 0x261a0db6780>,
#  'comentarista': <gensim.models.keyedvectors.Vocab at 0x261a0db67b8>,
#  'silvio': <gensim.models.keyedvectors.Vocab at 0x261a0db67f0>,
#  'valencia': <gensim.models.keyedvectors.Vocab at 0x261a0db6828>,
#  'vivo': <gensim.models.keyedvectors.Vocab at 0x261a0db6860>,
#  'hinchas': <gensim.models.keyedvectors.Vocab at 0x261a0db6898>,
#  'sport': <gensim.models.keyedvectors.Vocab at 0x261a0db6908>,
#  'boys': <gensim.models.keyedvectors.Vocab at 0x261a0db6940>,
#  'plato': <gensim.models.keyedvectors.Vocab at 0x261a0db6978>,
#  'comida': <gensim.models.keyedvectors.Vocab at 0x261a0db69b0>,
#  'penosas': <gensim.models.keyedvectors.Vocab at 0x261a0db69e8>,
#  'declaraciones': <gensim.models.keyedvectors.Vocab at 0x261a0db6a20>,
#  'difundió': <gensim.models.keyedvectors.Vocab at 0x261a0db6a58>,
#  'espacio': <gensim.models.keyedvectors.Vocab at 0x261a0db6a90>,
#  'televisivo': <gensim.models.keyedvectors.Vocab at 0x261a0db6ac8>,
#  'conduce': <gensim.models.keyedvectors.Vocab at 0x261a0db6b00>,
#  'conductores': <gensim.models.keyedvectors.Vocab at 0x261a0db6b38>,
#  'cobra': <gensim.models.keyedvectors.Vocab at 0x261a0db6b70>,
#  'entradas': <gensim.models.keyedvectors.Vocab at 0x261a0db6ba8>,
#  'asistentes': <gensim.models.keyedvectors.Vocab at 0x261a0db6be0>,
#  'estrategia': <gensim.models.keyedvectors.Vocab at 0x261a0db6c50>,
#  'misilera': <gensim.models.keyedvectors.Vocab at 0x261a0db6c88>,
#  'consiste': <gensim.models.keyedvectors.Vocab at 0x261a0db6cc0>,
#  'pago': <gensim.models.keyedvectors.Vocab at 0x261a0db6cf8>,
#  'voluntario': <gensim.models.keyedvectors.Vocab at 0x261a0db6d68>,
#  'concepto': <gensim.models.keyedvectors.Vocab at 0x261a0db6da0>,
#  'precio': <gensim.models.keyedvectors.Vocab at 0x261a0db6dd8>,
#  'compañeros': <gensim.models.keyedvectors.Vocab at 0x261a0db6e10>,
#  'sostuvo': <gensim.models.keyedvectors.Vocab at 0x261a0db6e48>,
#  'montos': <gensim.models.keyedvectors.Vocab at 0x261a0db6e80>,
#  'cobran': <gensim.models.keyedvectors.Vocab at 0x261a0db6eb8>,
#  'recuperan': <gensim.models.keyedvectors.Vocab at 0x261a0db6ef0>,
#  'venta': <gensim.models.keyedvectors.Vocab at 0x261a0db6f28>,
#  'estadio': <gensim.models.keyedvectors.Vocab at 0x261a0db6f60>,
#  'miguel': <gensim.models.keyedvectors.Vocab at 0x261a0db6f98>,
#  'grau': <gensim.models.keyedvectors.Vocab at 0x261a0db6fd0>,
#  'callao': <gensim.models.keyedvectors.Vocab at 0x261a0db62b0>,
#  'táctica': <gensim.models.keyedvectors.Vocab at 0x261a0db6048>,
#  'busca': <gensim.models.keyedvectors.Vocab at 0x261a0db6080>,
#  'asistencia': <gensim.models.keyedvectors.Vocab at 0x261a0db60b8>,
#  'personas': <gensim.models.keyedvectors.Vocab at 0x261a0db60f0>,
#  'alentar': <gensim.models.keyedvectors.Vocab at 0x261a0db6128>,
#  'equipo': <gensim.models.keyedvectors.Vocab at 0x261a0db6160>,
#  'evitar': <gensim.models.keyedvectors.Vocab at 0x261a0db6198>,
#  'descenso': <gensim.models.keyedvectors.Vocab at 0x261a0db61d0>,
#  'división': <gensim.models.keyedvectors.Vocab at 0x261a0db6240>,
#  'incorrecta': <gensim.models.keyedvectors.Vocab at 0x261a0db6278>,
#  'postura': <gensim.models.keyedvectors.Vocab at 0x261a18e8cf8>,
#  'gente': <gensim.models.keyedvectors.Vocab at 0x261a18e8dd8>,
#  'chicos': <gensim.models.keyedvectors.Vocab at 0x261a18e8e80>,
#  'paran': <gensim.models.keyedvectors.Vocab at 0x261a18e82b0>,
#  '5': <gensim.models.keyedvectors.Vocab at 0x261a18e8320>,
#  '3': <gensim.models.keyedvectors.Vocab at 0x261a18e85f8>,
#  'soles': <gensim.models.keyedvectors.Vocab at 0x261a19800b8>,
#  'pagar': <gensim.models.keyedvectors.Vocab at 0x261a1980198>,
#  'menú': <gensim.models.keyedvectors.Vocab at 0x261a1980278>,
#  'actualización': <gensim.models.keyedvectors.Vocab at 0x261a19802e8>,
#  'fiscal': <gensim.models.keyedvectors.Vocab at 0x261a1980390>,
#  'josé': <gensim.models.keyedvectors.Vocab at 0x261a19806d8>,
#  'domingo': <gensim.models.keyedvectors.Vocab at 0x261a1980a58>,
#  'pérez': <gensim.models.keyedvectors.Vocab at 0x261a1980d30>,
#  'reprogramó': <gensim.models.keyedvectors.Vocab at 0x261a1980dd8>,
#  'interrogatorio': <gensim.models.keyedvectors.Vocab at 0x261a1980f98>,
#  'exasesor': <gensim.models.keyedvectors.Vocab at 0x261a18a5dd8>,
#  'presidencial': <gensim.models.keyedvectors.Vocab at 0x261a18a54a8>,
#  'vladimiro': <gensim.models.keyedvectors.Vocab at 0x261a18a50b8>,
#  'montesinos': <gensim.models.keyedvectors.Vocab at 0x261a18a5128>,
#  'lunes': <gensim.models.keyedvectors.Vocab at 0x261a18a5a58>,
#  '7': <gensim.models.keyedvectors.Vocab at 0x261a161c9e8>,
#  'octubre': <gensim.models.keyedvectors.Vocab at 0x261a05bb908>,
#  'disposición': <gensim.models.keyedvectors.Vocab at 0x261a1896fd0>,
#  'accedió': <gensim.models.keyedvectors.Vocab at 0x261a1896ef0>,
#  'cambio': <gensim.models.keyedvectors.Vocab at 0x261a18961d0>,
#  'fecha': <gensim.models.keyedvectors.Vocab at 0x261a1896320>,
#  'participar': <gensim.models.keyedvectors.Vocab at 0x261a18964a8>,
#  'audiencias': <gensim.models.keyedvectors.Vocab at 0x261a1896518>,
#  'convocadas': <gensim.models.keyedvectors.Vocab at 0x261a18967b8>,
#  'penal': <gensim.models.keyedvectors.Vocab at 0x261a1896e10>,
#  'superior': <gensim.models.keyedvectors.Vocab at 0x261a1896e80>,
#  'transitoria': <gensim.models.keyedvectors.Vocab at 0x261a18a6a58>,
#  'corte': <gensim.models.keyedvectors.Vocab at 0x261a18a6b70>,
#  'especializada': <gensim.models.keyedvectors.Vocab at 0x261a18a6d68>,
#  'analizar': <gensim.models.keyedvectors.Vocab at 0x261a18a6fd0>,
#  'casos': <gensim.models.keyedvectors.Vocab at 0x261a18a6198>,
#  'derechos': <gensim.models.keyedvectors.Vocab at 0x261a18a6390>,
#  'humanos': <gensim.models.keyedvectors.Vocab at 0x261a18a69b0>,
#  'pedro': <gensim.models.keyedvectors.Vocab at 0x261a17f2fd0>,
#  'huilca': <gensim.models.keyedvectors.Vocab at 0x261a17f2eb8>,
#  'mariella': <gensim.models.keyedvectors.Vocab at 0x261a17f2278>,
#  'barreto': <gensim.models.keyedvectors.Vocab at 0x261a17f2518>,
#  'imposible': <gensim.models.keyedvectors.Vocab at 0x261a17f26d8>,
#  'doc': <gensim.models.keyedvectors.Vocab at 0x261a17f2748>,
#  'responder': <gensim.models.keyedvectors.Vocab at 0x261a17f28d0>,
#  'interrogantes': <gensim.models.keyedvectors.Vocab at 0x261a17f2c88>,
#  'documento': <gensim.models.keyedvectors.Vocab at 0x261a17eec88>,
#  'señala': <gensim.models.keyedvectors.Vocab at 0x261a17eee48>,
#  '14': <gensim.models.keyedvectors.Vocab at 0x261a17ee2b0>,
#  'tomará': <gensim.models.keyedvectors.Vocab at 0x261a17ee518>,
#  'declaración': <gensim.models.keyedvectors.Vocab at 0x261a17ee588>,
#  'eduardo': <gensim.models.keyedvectors.Vocab at 0x261a17ee5f8>,
#  'felipe': <gensim.models.keyedvectors.Vocab at 0x261a17ee828>,
#  'cabrera': <gensim.models.keyedvectors.Vocab at 0x261a17ee9e8>,
#  'ganoza': <gensim.models.keyedvectors.Vocab at 0x261a17eea58>,
#  'congresista': <gensim.models.keyedvectors.Vocab at 0x261a17eeb38>,
#  'república': <gensim.models.keyedvectors.Vocab at 0x261a17eeba8>,
#  'ica': <gensim.models.keyedvectors.Vocab at 0x261a183ae10>,
#  'representando': <gensim.models.keyedvectors.Vocab at 0x261a183a5f8>,
#  'fuerza': <gensim.models.keyedvectors.Vocab at 0x261a183a6d8>,
#  '2011': <gensim.models.keyedvectors.Vocab at 0x261a183aba8>,
#  'postuló': <gensim.models.keyedvectors.Vocab at 0x261a15e2898>,
#  'presidente': <gensim.models.keyedvectors.Vocab at 0x261a15e2908>,
#  'regional': <gensim.models.keyedvectors.Vocab at 0x261a1983b00>,
#  'nota': <gensim.models.keyedvectors.Vocab at 0x261a1983be0>,
#  'original': <gensim.models.keyedvectors.Vocab at 0x261a1983cf8>,
#  'martes': <gensim.models.keyedvectors.Vocab at 0x261a1983eb8>,
#  'irá': <gensim.models.keyedvectors.Vocab at 0x261a1983550>,
#  'base': <gensim.models.keyedvectors.Vocab at 0x261a1983588>,
#  'naval': <gensim.models.keyedvectors.Vocab at 0x261a19835c0>,
#  'interrogar': <gensim.models.keyedvectors.Vocab at 0x261a1983048>,
#  'purga': <gensim.models.keyedvectors.Vocab at 0x261a1983080>,
#  'condena': <gensim.models.keyedvectors.Vocab at 0x261a1983160>,
#  'distintos': <gensim.models.keyedvectors.Vocab at 0x261a1983198>,
#  'delitos': <gensim.models.keyedvectors.Vocab at 0x261a1983240>,
#  'cometidos': <gensim.models.keyedvectors.Vocab at 0x261a19832e8>,
#  'gobierno': <gensim.models.keyedvectors.Vocab at 0x261a1983668>,
#  'alberto': <gensim.models.keyedvectors.Vocab at 0x261a1983748>,
#  'fujimori': <gensim.models.keyedvectors.Vocab at 0x261a19839e8>,
#  'diligencia': <gensim.models.keyedvectors.Vocab at 0x261a1983978>,
#  'fijada': <gensim.models.keyedvectors.Vocab at 0x261a19839b0>,
#  '10': <gensim.models.keyedvectors.Vocab at 0x261a19ee1d0>,
#  'mañana': <gensim.models.keyedvectors.Vocab at 0x261a19ee240>,
#  'especial': <gensim.models.keyedvectors.Vocab at 0x261a19ee2e8>,
#  'lava': <gensim.models.keyedvectors.Vocab at 0x261a19ee4e0>,
#  'jato': <gensim.models.keyedvectors.Vocab at 0x261a19ee518>,
#  'formulará': <gensim.models.keyedvectors.Vocab at 0x261a19ee588>,
#  'pliego': <gensim.models.keyedvectors.Vocab at 0x261a19ee630>,
#  'preguntas': <gensim.models.keyedvectors.Vocab at 0x261a19ee7f0>,
#  'encontrar': <gensim.models.keyedvectors.Vocab at 0x261a19ee860>,
#  'luces': <gensim.models.keyedvectors.Vocab at 0x261a19eea90>,
#  'verdadero': <gensim.models.keyedvectors.Vocab at 0x261a19eeac8>,
#  'rol': <gensim.models.keyedvectors.Vocab at 0x261a19eed30>,
#  'cumplió': <gensim.models.keyedvectors.Vocab at 0x261a19eee48>,
#  'abogado': <gensim.models.keyedvectors.Vocab at 0x261a19eeef0>,
#  'vicente': <gensim.models.keyedvectors.Vocab at 0x261a19d76d8>,
#  'silva': <gensim.models.keyedvectors.Vocab at 0x261a19d7780>,
#  'checa': <gensim.models.keyedvectors.Vocab at 0x261a19d7828>,
#  'campaña': <gensim.models.keyedvectors.Vocab at 0x261a19d79b0>,
#  '2016': <gensim.models.keyedvectors.Vocab at 0x261a19d79e8>,
#  'tesis': <gensim.models.keyedvectors.Vocab at 0x261a19d7a20>,
#  'lidera': <gensim.models.keyedvectors.Vocab at 0x261a19d7c50>,
#  'keiko': <gensim.models.keyedvectors.Vocab at 0x261a19d7e48>,
#  'recibido': <gensim.models.keyedvectors.Vocab at 0x261a19d7e80>,
#  'aportes': <gensim.models.keyedvectors.Vocab at 0x261a19d7080>,
#  'irregulares': <gensim.models.keyedvectors.Vocab at 0x261a19d70f0>,
#  'constructora': <gensim.models.keyedvectors.Vocab at 0x261a19d74e0>,
#  'brasileña': <gensim.models.keyedvectors.Vocab at 0x261a1a71f60>,
#  'odebrecht': <gensim.models.keyedvectors.Vocab at 0x261a1a71fd0>,
#  'financiamiento': <gensim.models.keyedvectors.Vocab at 0x261a1a71198>,
#  'motivo': <gensim.models.keyedvectors.Vocab at 0x261a1a711d0>,
#  'lideresa': <gensim.models.keyedvectors.Vocab at 0x261a1a71278>,
#  'cumple': <gensim.models.keyedvectors.Vocab at 0x261a1a713c8>,
#  'orden': <gensim.models.keyedvectors.Vocab at 0x261a1a71400>,
#  'prisión': <gensim.models.keyedvectors.Vocab at 0x261a1a71518>,
#  'preventiva': <gensim.models.keyedvectors.Vocab at 0x261a1a716a0>,
#  '18': <gensim.models.keyedvectors.Vocab at 0x261a1a71748>,
#  'lavado': <gensim.models.keyedvectors.Vocab at 0x261a1a71860>,
#  'activos': <gensim.models.keyedvectors.Vocab at 0x261a1a718d0>,
#  'ministerio': <gensim.models.keyedvectors.Vocab at 0x261a1a719e8>,
#  'público': <gensim.models.keyedvectors.Vocab at 0x261a1922438>,
#  'sindica': <gensim.models.keyedvectors.Vocab at 0x261a19224e0>,
#  'asesor': <gensim.models.keyedvectors.Vocab at 0x261a1922710>,
#  'sombras': <gensim.models.keyedvectors.Vocab at 0x261a1922908>,
#  'higuchi': <gensim.models.keyedvectors.Vocab at 0x261a19229b0>,
#  'consiguiente': <gensim.models.keyedvectors.Vocab at 0x261a19229e8>,
#  'presunta': <gensim.models.keyedvectors.Vocab at 0x261a1922c88>,
#  'organización': <gensim.models.keyedvectors.Vocab at 0x261a1922e48>,
#  'criminal': <gensim.models.keyedvectors.Vocab at 0x261a1922e80>,
#  'enquistado': <gensim.models.keyedvectors.Vocab at 0x261a1922eb8>,
#  'relación': <gensim.models.keyedvectors.Vocab at 0x261a1922f28>,
#  'señalado': <gensim.models.keyedvectors.Vocab at 0x261a1922080>,
#  'testaferros': <gensim.models.keyedvectors.Vocab at 0x261a19221d0>,
#  'vladivideo': <gensim.models.keyedvectors.Vocab at 0x261a19222e8>,
#  'compra': <gensim.models.keyedvectors.Vocab at 0x261a0ba3da0>,
#  'línea': <gensim.models.keyedvectors.Vocab at 0x261a0ba3dd8>,
#  'editorial': <gensim.models.keyedvectors.Vocab at 0x261a0ba3e10>,
#  'cable': <gensim.models.keyedvectors.Vocab at 0x261a0ba3eb8>,
#  'canal': <gensim.models.keyedvectors.Vocab at 0x261a0ba3f60>,
#  'noticias': <gensim.models.keyedvectors.Vocab at 0x261a0ba3f98>,
#  'ccn': <gensim.models.keyedvectors.Vocab at 0x261a0ba3fd0>,
#  'yolanda': <gensim.models.keyedvectors.Vocab at 0x261a0ba3080>,
#  'rivera': <gensim.models.keyedvectors.Vocab at 0x261a0ba30b8>,
#  'mujer': <gensim.models.keyedvectors.Vocab at 0x261a0ba30f0>,
#  'murió': <gensim.models.keyedvectors.Vocab at 0x261a0ba3160>,
#  'atacada': <gensim.models.keyedvectors.Vocab at 0x261a0ba31d0>,
#  'delincuentes': <gensim.models.keyedvectors.Vocab at 0x261a0ba3240>,
#  'huían': <gensim.models.keyedvectors.Vocab at 0x261a0ba3358>,
#  'policía': <gensim.models.keyedvectors.Vocab at 0x261a0ba3400>,
#  'distrito': <gensim.models.keyedvectors.Vocab at 0x261a0ba34e0>,
#  'surco': <gensim.models.keyedvectors.Vocab at 0x261a0ba3898>,
#  'pidió': <gensim.models.keyedvectors.Vocab at 0x261a0ba3908>,
#  'realicen': <gensim.models.keyedvectors.Vocab at 0x261a0ba3940>,
#  'necesarias': <gensim.models.keyedvectors.Vocab at 0x261a0ba3978>,
#  'capturar': <gensim.models.keyedvectors.Vocab at 0x261a0ba39e8>,
#  'criminales': <gensim.models.keyedvectors.Vocab at 0x261a0ba3a58>,
#  'hija': <gensim.models.keyedvectors.Vocab at 0x261a0ba3ac8>,
#  'hombre': <gensim.models.keyedvectors.Vocab at 0x261a0ba3b38>,
#  'conmocionado': <gensim.models.keyedvectors.Vocab at 0x261a0ba3c50>,
#  'determina': <gensim.models.keyedvectors.Vocab at 0x261a0ba3c88>,
#  'bala': <gensim.models.keyedvectors.Vocab at 0x261a0ba3cf8>,
#  'impactó': <gensim.models.keyedvectors.Vocab at 0x261a0ba3d68>,
#  'policías': <gensim.models.keyedvectors.Vocab at 0x261a19d82b0>,
#  'ladrones': <gensim.models.keyedvectors.Vocab at 0x261a19d8748>,
#  'culparse': <gensim.models.keyedvectors.Vocab at 0x261a19d87f0>,
#  'efectivos': <gensim.models.keyedvectors.Vocab at 0x261a19d8828>,
#  'cumplían': <gensim.models.keyedvectors.Vocab at 0x261a19d88d0>,
#  'culpen': <gensim.models.keyedvectors.Vocab at 0x261a19d8ba8>,
#  'colegas': <gensim.models.keyedvectors.Vocab at 0x261a19d8cf8>,
#  'seguiré': <gensim.models.keyedvectors.Vocab at 0x261a19d8710>,
#  'siéndolo': <gensim.models.keyedvectors.Vocab at 0x261a19d80b8>,
#  'muera': <gensim.models.keyedvectors.Vocab at 0x261a19d8240>,
#  'oficial': <gensim.models.keyedvectors.Vocab at 0x261a19d8470>,
#  'retiro': <gensim.models.keyedvectors.Vocab at 0x261a19d84a8>,
#  'necesita': <gensim.models.keyedvectors.Vocab at 0x261a19d8630>,
#  'urgencia': <gensim.models.keyedvectors.Vocab at 0x261a19d8668>,
#  'país': <gensim.models.keyedvectors.Vocab at 0x261a0463da0>,
#  'empezando': <gensim.models.keyedvectors.Vocab at 0x261a0a72908>,
#  'falta': <gensim.models.keyedvectors.Vocab at 0x261a04e3550>,
#  'intervengan': <gensim.models.keyedvectors.Vocab at 0x261a07b83c8>,
#  'vendan': <gensim.models.keyedvectors.Vocab at 0x261a07b85c0>,
#  'dinero': <gensim.models.keyedvectors.Vocab at 0x261a0c0fbe0>,
#  'impartan': <gensim.models.keyedvectors.Vocab at 0x261a0c0fc50>,
#  'quiénes': <gensim.models.keyedvectors.Vocab at 0x261a0c0fc88>,
#  'corruptos': <gensim.models.keyedvectors.Vocab at 0x261a0c0fcc0>,
#  'corrupta': <gensim.models.keyedvectors.Vocab at 0x261a0c0fd30>,
#  'manipulan': <gensim.models.keyedvectors.Vocab at 0x261a0c0fd68>,
#  'juez': <gensim.models.keyedvectors.Vocab at 0x261a0c0fe48>,
#  'pobre': <gensim.models.keyedvectors.Vocab at 0x261a0c0fe80>,
#  'mete': <gensim.models.keyedvectors.Vocab at 0x261a0c0feb8>,
#  'balazo': <gensim.models.keyedvectors.Vocab at 0x261a0c0fef0>,
#  'choro': <gensim.models.keyedvectors.Vocab at 0x261a0c0ff28>,
#  'queda': <gensim.models.keyedvectors.Vocab at 0x261a0c0ff60>,
#  'preso': <gensim.models.keyedvectors.Vocab at 0x261a0c0ff98>,
#  'pido': <gensim.models.keyedvectors.Vocab at 0x261a0c0f198>,
#  'luchen': <gensim.models.keyedvectors.Vocab at 0x261a0c0f240>,
#  'quiero': <gensim.models.keyedvectors.Vocab at 0x261a0c0f320>,
#  'capture': <gensim.models.keyedvectors.Vocab at 0x261a0c0f358>,
#  'interesa': <gensim.models.keyedvectors.Vocab at 0x261a0c0f080>,
#  'balas': <gensim.models.keyedvectors.Vocab at 0x261a0c0f0b8>,
#  'muerta': <gensim.models.keyedvectors.Vocab at 0x261a0c0f160>,
#  'culpa': <gensim.models.keyedvectors.Vocab at 0x261a0c0f390>,
#  'única': <gensim.models.keyedvectors.Vocab at 0x261a0c0f3c8>,
#  'quebrarse': <gensim.models.keyedvectors.Vocab at 0x261a0c0f438>,
#  'datos': <gensim.models.keyedvectors.Vocab at 0x261a0c0f4a8>,
#  '29': <gensim.models.keyedvectors.Vocab at 0x261a0c0f550>,
#  'casquillos': <gensim.models.keyedvectors.Vocab at 0x261a0c0f588>,
#  'encontraron': <gensim.models.keyedvectors.Vocab at 0x261a0c0f630>,
#  'balacera': <gensim.models.keyedvectors.Vocab at 0x261a0c0f668>,
#  'molina': <gensim.models.keyedvectors.Vocab at 0x261a0c0f6a0>,
#  'esposo': <gensim.models.keyedvectors.Vocab at 0x261a0c0f6d8>,
#  'herido': <gensim.models.keyedvectors.Vocab at 0x261a0c0f710>,
#  'brazo': <gensim.models.keyedvectors.Vocab at 0x261a0c0f748>,
#  'exjuez': <gensim.models.keyedvectors.Vocab at 0x261a0c0f780>,
#  'supremo': <gensim.models.keyedvectors.Vocab at 0x261a0c0f7f0>,
#  'césar': <gensim.models.keyedvectors.Vocab at 0x261a0c0f860>,
#  'hinostroza': <gensim.models.keyedvectors.Vocab at 0x261a0c0f898>,
#  'confirmó': <gensim.models.keyedvectors.Vocab at 0x261a0c0f940>,
#  'recurrirá': <gensim.models.keyedvectors.Vocab at 0x261a0c0fa20>,
#  'tribunal': <gensim.models.keyedvectors.Vocab at 0x261a0c0fa90>,
#  'constitucional': <gensim.models.keyedvectors.Vocab at 0x261a0c0fac8>,
#  'españa': <gensim.models.keyedvectors.Vocab at 0x261a0c0fb00>,
#  'buscar': <gensim.models.keyedvectors.Vocab at 0x261a0c0fb38>,
#  'anular': <gensim.models.keyedvectors.Vocab at 0x261a0c0fb70>,
#  'extradición': <gensim.models.keyedvectors.Vocab at 0x261a0c0fba8>,
#  'aprobada': <gensim.models.keyedvectors.Vocab at 0x261a0caa240>,
#  'audiencia': <gensim.models.keyedvectors.Vocab at 0x261a0caa278>,
#  'difundido': <gensim.models.keyedvectors.Vocab at 0x261a0caa2b0>,
#  'rpp': <gensim.models.keyedvectors.Vocab at 0x261a0caa2e8>,
#  'asegura': <gensim.models.keyedvectors.Vocab at 0x261a0caa320>,
#  'sentencia': <gensim.models.keyedvectors.Vocab at 0x261a0caa358>,
#  'rechazó': <gensim.models.keyedvectors.Vocab at 0x261a0caa390>,
#  'repatriación': <gensim.models.keyedvectors.Vocab at 0x261a0caa3c8>,
#  'cuestionó': <gensim.models.keyedvectors.Vocab at 0x261a0caa438>,
#  'aceptado': <gensim.models.keyedvectors.Vocab at 0x261a0caa4a8>,
#  'imputan': <gensim.models.keyedvectors.Vocab at 0x261a0caa4e0>,
#  'conformes': <gensim.models.keyedvectors.Vocab at 0x261a0caa5c0>,
#  'rechazo': <gensim.models.keyedvectors.Vocab at 0x261a0caa5f8>,
#  'patrocinio': <gensim.models.keyedvectors.Vocab at 0x261a0caa668>,
#  'ilegal': <gensim.models.keyedvectors.Vocab at 0x261a0caa6a0>,
#  'tráfico': <gensim.models.keyedvectors.Vocab at 0x261a0caa6d8>,
#  'influencias': <gensim.models.keyedvectors.Vocab at 0x261a0caa710>,
#  'negociación': <gensim.models.keyedvectors.Vocab at 0x261a0caa748>,
#  'incompatible': <gensim.models.keyedvectors.Vocab at 0x261a0caa780>,
#  'españoles': <gensim.models.keyedvectors.Vocab at 0x261a0caa7b8>,
#  'erróneamente': <gensim.models.keyedvectors.Vocab at 0x261a0caa828>,
#  'interpretado': <gensim.models.keyedvectors.Vocab at 0x261a0caa860>,
#  'exmagistrado': <gensim.models.keyedvectors.Vocab at 0x261a0caa898>,
#  'interponer': <gensim.models.keyedvectors.Vocab at 0x261a0caa8d0>,
#  'recurso': <gensim.models.keyedvectors.Vocab at 0x261a0caa908>,
#  'amparo': <gensim.models.keyedvectors.Vocab at 0x261a0caa940>,
#  'español': <gensim.models.keyedvectors.Vocab at 0x261a0caa978>,
#  'eventualmente': <gensim.models.keyedvectors.Vocab at 0x261a0caa9b0>,
#  'europeo': <gensim.models.keyedvectors.Vocab at 0x261a0caaa58>,
#  'defensa': <gensim.models.keyedvectors.Vocab at 0x261a0caaa90>,
#  'carácter': <gensim.models.keyedvectors.Vocab at 0x261a0caaac8>,
#  'universal': <gensim.models.keyedvectors.Vocab at 0x261a0caab00>,
#  'reiteró': <gensim.models.keyedvectors.Vocab at 0x261a0caab38>,
#  'imputados': <gensim.models.keyedvectors.Vocab at 0x261a0caab70>,
#  'aprobados': <gensim.models.keyedvectors.Vocab at 0x261a0caaba8>,
#  'congreso': <gensim.models.keyedvectors.Vocab at 0x261a0caabe0>,
#  'actuó': <gensim.models.keyedvectors.Vocab at 0x261a0caac18>,
#  'presión': <gensim.models.keyedvectors.Vocab at 0x261a0caac50>,
#  'ley': <gensim.models.keyedvectors.Vocab at 0x261a0caacc0>,
#  'española': <gensim.models.keyedvectors.Vocab at 0x261a0caacf8>,
#  'penalistas': <gensim.models.keyedvectors.Vocab at 0x261a0caada0>,
#  'sindicado': <gensim.models.keyedvectors.Vocab at 0x261a0caadd8>,
#  'cabecilla': <gensim.models.keyedvectors.Vocab at 0x261a0caae10>,
#  'cuellos': <gensim.models.keyedvectors.Vocab at 0x261a0caae48>,
#  'blancos': <gensim.models.keyedvectors.Vocab at 0x261a0caae80>,
#  'puerto': <gensim.models.keyedvectors.Vocab at 0x261a0caaeb8>,
#  'pesan': <gensim.models.keyedvectors.Vocab at 0x261a0caaef0>,
#  'órdenes': <gensim.models.keyedvectors.Vocab at 0x261a0caaf60>,
#  'caso': <gensim.models.keyedvectors.Vocab at 0x261a0caafd0>,
#  'salido': <gensim.models.keyedvectors.Vocab at 0x261a0caa208>,
#  'pese': <gensim.models.keyedvectors.Vocab at 0x261a0caa080>,
#  'impedimento': <gensim.models.keyedvectors.Vocab at 0x261a0caa0f0>,
#  'abandonar': <gensim.models.keyedvectors.Vocab at 0x261a0caa1d0>,
#  'perú': <gensim.models.keyedvectors.Vocab at 0x261a1c03080>,
#  'salir': <gensim.models.keyedvectors.Vocab at 0x261a1c031d0>,
#  'internacional': <gensim.models.keyedvectors.Vocab at 0x261a1c03278>,
#  'respetan': <gensim.models.keyedvectors.Vocab at 0x261a1c032b0>,
#  'evadir': <gensim.models.keyedvectors.Vocab at 0x261a1c03320>,
#  'fugar': <gensim.models.keyedvectors.Vocab at 0x261a1c03390>,
#  'falsamente': <gensim.models.keyedvectors.Vocab at 0x261a1c03470>,
#  'menciona': <gensim.models.keyedvectors.Vocab at 0x261a1c034a8>,
#  'saludado': <gensim.models.keyedvectors.Vocab at 0x261a1c03518>,
#  'extraditarlo': <gensim.models.keyedvectors.Vocab at 0x261a1c03588>,
#  'sigan': <gensim.models.keyedvectors.Vocab at 0x261a1c035c0>,
#  'acusando': <gensim.models.keyedvectors.Vocab at 0x261a1c035f8>,
#  'espero': <gensim.models.keyedvectors.Vocab at 0x261a1c03630>,
#  'dejen': <gensim.models.keyedvectors.Vocab at 0x261a1c036a0>,
#  'dignidad': <gensim.models.keyedvectors.Vocab at 0x261a1c03710>,
#  'humana': <gensim.models.keyedvectors.Vocab at 0x261a1c03780>,
#  'horas': <gensim.models.keyedvectors.Vocab at 0x261a1c037b8>,
#  'oficina': <gensim.models.keyedvectors.Vocab at 0x261a1c03898>,
#  'volvían': <gensim.models.keyedvectors.Vocab at 0x261a1c038d0>,
#  'eternas': <gensim.models.keyedvectors.Vocab at 0x261a1c03978>,
# ...
#  'inconclusos': <gensim.models.keyedvectors.Vocab at 0x261a0dab0b8>,
#  'finalizar': <gensim.models.keyedvectors.Vocab at 0x261a0dab0f0>,
#  'escuela': <gensim.models.keyedvectors.Vocab at 0x261a0dab128>,
#  'cocinero': <gensim.models.keyedvectors.Vocab at 0x261a0dab160>,
#  'regresaría': <gensim.models.keyedvectors.Vocab at 0x261a0dab198>,
#  'tarde': <gensim.models.keyedvectors.Vocab at 0x261a0dab1d0>,
#  'perteneció': <gensim.models.keyedvectors.Vocab at 0x261a0dab208>,
#  'empresas': <gensim.models.keyedvectors.Vocab at 0x261a0dab240>,
#  'importantes': <gensim.models.keyedvectors.Vocab at 0x261a0dab278>,
#  'semanas': <gensim.models.keyedvectors.Vocab at 0x261a0dab2b0>,
#  'llegaban': <gensim.models.keyedvectors.Vocab at 0x261a0dab2e8>,
#  'ajenas': <gensim.models.keyedvectors.Vocab at 0x261a0dab320>,
#  'debía': <gensim.models.keyedvectors.Vocab at 0x261a0dab358>,
#  'encaminar': <gensim.models.keyedvectors.Vocab at 0x261a0dab390>,
#  'pensó': <gensim.models.keyedvectors.Vocab at 0x261a0dab3c8>,
#  'destino': <gensim.models.keyedvectors.Vocab at 0x261a0dab400>,
#  'saco': <gensim.models.keyedvectors.Vocab at 0x261a0dab438>,
#  'corbata': <gensim.models.keyedvectors.Vocab at 0x261a0dab470>,
#  'sentado': <gensim.models.keyedvectors.Vocab at 0x261a0dab4a8>,
#  'frente': <gensim.models.keyedvectors.Vocab at 0x261a0dab4e0>,
#  'pantalla': <gensim.models.keyedvectors.Vocab at 0x261a0dab518>,
#  'escritorio': <gensim.models.keyedvectors.Vocab at 0x261a0dab550>,
#  'viaje': <gensim.models.keyedvectors.Vocab at 0x261a0dab588>,
#  'sao': <gensim.models.keyedvectors.Vocab at 0x261a0dab5c0>,
#  'paulo': <gensim.models.keyedvectors.Vocab at 0x261a0dab5f8>,
#  'probó': <gensim.models.keyedvectors.Vocab at 0x261a0dab630>,
#  'pizza': <gensim.models.keyedvectors.Vocab at 0x261a0dab668>,
#  'común': <gensim.models.keyedvectors.Vocab at 0x261a0dab6a0>,
#  'insumos': <gensim.models.keyedvectors.Vocab at 0x261a0dab6d8>,
#  'brasileños': <gensim.models.keyedvectors.Vocab at 0x261a0dab710>,
#  'masa': <gensim.models.keyedvectors.Vocab at 0x261a0dab748>,
#  'tradicional': <gensim.models.keyedvectors.Vocab at 0x261a0dab780>,
#  'dejando': <gensim.models.keyedvectors.Vocab at 0x261a0dab7f0>,
#  'típica': <gensim.models.keyedvectors.Vocab at 0x261a0dab828>,
#  'americana': <gensim.models.keyedvectors.Vocab at 0x261a0dab898>,
#  'pepperoni': <gensim.models.keyedvectors.Vocab at 0x261a0dab8d0>,
#  'allí': <gensim.models.keyedvectors.Vocab at 0x261a0dab908>,
#  'supo': <gensim.models.keyedvectors.Vocab at 0x261a0dab940>,
#  'cuál': <gensim.models.keyedvectors.Vocab at 0x261a0dab978>,
#  'camino': <gensim.models.keyedvectors.Vocab at 0x261a0dab9b0>,
#  'jefes': <gensim.models.keyedvectors.Vocab at 0x261a0dab9e8>,
#  'inauguró': <gensim.models.keyedvectors.Vocab at 0x261a0daba20>,
#  'oficialmente': <gensim.models.keyedvectors.Vocab at 0x261a0daba58>,
#  'agosto': <gensim.models.keyedvectors.Vocab at 0x261a0daba90>,
#  '2017': <gensim.models.keyedvectors.Vocab at 0x261a0dabac8>,
#  'surquillo': <gensim.models.keyedvectors.Vocab at 0x261a0dabb00>,
#  'ahorros': <gensim.models.keyedvectors.Vocab at 0x261a0dabb38>,
#  'bastaron': <gensim.models.keyedvectors.Vocab at 0x261a0dabb70>,
#  'alquilar': <gensim.models.keyedvectors.Vocab at 0x261a0dabba8>,
#  'local': <gensim.models.keyedvectors.Vocab at 0x261a0dabbe0>,
#  'adquirir': <gensim.models.keyedvectors.Vocab at 0x261a0dabc18>,
#  'maquinaria': <gensim.models.keyedvectors.Vocab at 0x261a0dabc50>,
#  'preguntaba': <gensim.models.keyedvectors.Vocab at 0x261a0dabc88>,
#  'metido': <gensim.models.keyedvectors.Vocab at 0x261a0dabcc0>,
#  'mano': <gensim.models.keyedvectors.Vocab at 0x261a0dabcf8>,
#  'empezó': <gensim.models.keyedvectors.Vocab at 0x261a0dabd30>,
#  'platos': <gensim.models.keyedvectors.Vocab at 0x261a0dabd68>,
#  'adecuarlos': <gensim.models.keyedvectors.Vocab at 0x261a0dabda0>,
#  'vea': <gensim.models.keyedvectors.Vocab at 0x261a0dabdd8>,
#  'sepa': <gensim.models.keyedvectors.Vocab at 0x261a0dabe10>,
#  'decidió': <gensim.models.keyedvectors.Vocab at 0x261a0dabe48>,
#  'negocio': <gensim.models.keyedvectors.Vocab at 0x261a0dabe80>,
#  'demandar': <gensim.models.keyedvectors.Vocab at 0x261a0dabeb8>,
#  'tantas': <gensim.models.keyedvectors.Vocab at 0x261a0dabef0>,
#  'creó': <gensim.models.keyedvectors.Vocab at 0x261a0dabf60>,
#  'cocina': <gensim.models.keyedvectors.Vocab at 0x261a0dabf98>,
#  'fantasma': <gensim.models.keyedvectors.Vocab at 0x261a0db3048>,
#  'producción': <gensim.models.keyedvectors.Vocab at 0x261a0db3080>,
#  'repartida': <gensim.models.keyedvectors.Vocab at 0x261a0db30b8>,
#  'horario': <gensim.models.keyedvectors.Vocab at 0x261a0db30f0>,
#  '6': <gensim.models.keyedvectors.Vocab at 0x261a0db3128>,
#  '11': <gensim.models.keyedvectors.Vocab at 0x261a0db3160>,
#  'pm': <gensim.models.keyedvectors.Vocab at 0x261a0db3198>,
#  'intención': <gensim.models.keyedvectors.Vocab at 0x261a0db31d0>,
#  'imitar': <gensim.models.keyedvectors.Vocab at 0x261a0db3208>,
#  'corriente': <gensim.models.keyedvectors.Vocab at 0x261a0db3240>,
#  'proviene': <gensim.models.keyedvectors.Vocab at 0x261a0db3278>,
#  'europa': <gensim.models.keyedvectors.Vocab at 0x261a0db32b0>,
#  'asia': <gensim.models.keyedvectors.Vocab at 0x261a0db32e8>,
#  'unidos': <gensim.models.keyedvectors.Vocab at 0x261a0db3320>,
#  'aplicó': <gensim.models.keyedvectors.Vocab at 0x261a0db3358>,
#  'teoría': <gensim.models.keyedvectors.Vocab at 0x261a0db3390>,
#  'empresa': <gensim.models.keyedvectors.Vocab at 0x261a0db33c8>,
#  'presencia': <gensim.models.keyedvectors.Vocab at 0x261a0db3400>,
#  'aplicaciones': <gensim.models.keyedvectors.Vocab at 0x261a0db3438>,
#  'físico': <gensim.models.keyedvectors.Vocab at 0x261a0db3470>,
#  'emprendimiento': <gensim.models.keyedvectors.Vocab at 0x261a0db34e0>,
#  'agregado': <gensim.models.keyedvectors.Vocab at 0x261a0db3518>,
#  'cajas': <gensim.models.keyedvectors.Vocab at 0x261a0db3550>,
#  'obras': <gensim.models.keyedvectors.Vocab at 0x261a0db3588>,
#  'arte': <gensim.models.keyedvectors.Vocab at 0x261a0db35c0>,
#  'exhibe': <gensim.models.keyedvectors.Vocab at 0x261a0db35f8>,
#  'creaciones': <gensim.models.keyedvectors.Vocab at 0x261a0db3630>,
#  'ilustradores': <gensim.models.keyedvectors.Vocab at 0x261a0db3668>,
#  'temas': <gensim.models.keyedvectors.Vocab at 0x261a0db36a0>,
#  'nacionales': <gensim.models.keyedvectors.Vocab at 0x261a0db36d8>,
#  'lema': <gensim.models.keyedvectors.Vocab at 0x261a0db3710>,
#  'consenso': <gensim.models.keyedvectors.Vocab at 0x261a0db3748>,
#  'u': <gensim.models.keyedvectors.Vocab at 0x261a0db3780>,
#  'cambie': <gensim.models.keyedvectors.Vocab at 0x261a0db37b8>,
#  'lote': <gensim.models.keyedvectors.Vocab at 0x261a0db37f0>,
#  'primeras': <gensim.models.keyedvectors.Vocab at 0x261a0db3828>,
#  'diseñadas': <gensim.models.keyedvectors.Vocab at 0x261a0db3860>,
#  'rojas': <gensim.models.keyedvectors.Vocab at 0x261a0db3898>,
#  'perros': <gensim.models.keyedvectors.Vocab at 0x261a0db38d0>,
#  'alpaca': <gensim.models.keyedvectors.Vocab at 0x261a0db3908>,
#  'temporada': <gensim.models.keyedvectors.Vocab at 0x261a0db3940>,
#  'alegre': <gensim.models.keyedvectors.Vocab at 0x261a0db3978>,
#  'llegue': <gensim.models.keyedvectors.Vocab at 0x261a0db39b0>,
#  'hogares': <gensim.models.keyedvectors.Vocab at 0x261a0db39e8>,
#  'limeños': <gensim.models.keyedvectors.Vocab at 0x261a0db3a20>,
#  'aureola': <gensim.models.keyedvectors.Vocab at 0x261a0db3a58>,
#  'princesa': <gensim.models.keyedvectors.Vocab at 0x261a0db3a90>,
#  'promueve': <gensim.models.keyedvectors.Vocab at 0x261a0db3ac8>,
#  'peruano': <gensim.models.keyedvectors.Vocab at 0x261a0db3b00>,
#  'voltee': <gensim.models.keyedvectors.Vocab at 0x261a0db3b38>,
#  'éxito': <gensim.models.keyedvectors.Vocab at 0x261a0db3b70>,
#  'vertiginoso': <gensim.models.keyedvectors.Vocab at 0x261a0db3ba8>,
#  '2x1': <gensim.models.keyedvectors.Vocab at 0x261a0db3be0>,
#  'distribuir': <gensim.models.keyedvectors.Vocab at 0x261a0db3c18>,
#  'pizzas': <gensim.models.keyedvectors.Vocab at 0x261a0db3c50>,
#  'comensales': <gensim.models.keyedvectors.Vocab at 0x261a0db3c88>,
#  'enamoraron': <gensim.models.keyedvectors.Vocab at 0x261a0db3cc0>,
#  'sabores': <gensim.models.keyedvectors.Vocab at 0x261a0db3cf8>,
#  'langostinos': <gensim.models.keyedvectors.Vocab at 0x261a0db3d68>,
#  'anticucheros': <gensim.models.keyedvectors.Vocab at 0x261a0db3da0>,
#  'lanzado': <gensim.models.keyedvectors.Vocab at 0x261a0db3dd8>,
#  'verano': <gensim.models.keyedvectors.Vocab at 0x261a0db3e10>,
#  'quedado': <gensim.models.keyedvectors.Vocab at 0x261a0db3e48>,
#  'butifarra': <gensim.models.keyedvectors.Vocab at 0x261a0db3e80>,
#  'huachana': <gensim.models.keyedvectors.Vocab at 0x261a0db3eb8>,
#  'llegar': <gensim.models.keyedvectors.Vocab at 0x261a0db3ef0>,
#  'plasmar': <gensim.models.keyedvectors.Vocab at 0x261a0db3f28>,
#  'idea': <gensim.models.keyedvectors.Vocab at 0x261a0db3f60>,
#  'unir': <gensim.models.keyedvectors.Vocab at 0x261a0db3f98>,
#  'tradiciones': <gensim.models.keyedvectors.Vocab at 0x261a0db3fd0>,
#  'italiana': <gensim.models.keyedvectors.Vocab at 0x261a19e2358>,
#  'difícil': <gensim.models.keyedvectors.Vocab at 0x261a19e2400>,
#  'constante': <gensim.models.keyedvectors.Vocab at 0x261a19e2d68>,
#  'prueba': <gensim.models.keyedvectors.Vocab at 0x261a19e2e48>,
#  'error': <gensim.models.keyedvectors.Vocab at 0x261a19e2ef0>,
#  'parecían': <gensim.models.keyedvectors.Vocab at 0x261a19e2f60>,
#  'contundentes': <gensim.models.keyedvectors.Vocab at 0x261a19e2eb8>,
#  'faltaba': <gensim.models.keyedvectors.Vocab at 0x261a19e2080>,
#  'arroz': <gensim.models.keyedvectors.Vocab at 0x261a19e22b0>,
#  'bota': <gensim.models.keyedvectors.Vocab at 0x261a19e24e0>,
#  'carcajada': <gensim.models.keyedvectors.Vocab at 0x261a19e25f8>,
#  'cómplice': <gensim.models.keyedvectors.Vocab at 0x261a19e26a0>,
#  'colaboradores': <gensim.models.keyedvectors.Vocab at 0x261a19e26d8>,
#  'desarrollado': <gensim.models.keyedvectors.Vocab at 0x261a19e2710>,
#  'entramos': <gensim.models.keyedvectors.Vocab at 0x261a19e2828>,
#  'fase': <gensim.models.keyedvectors.Vocab at 0x261a19e2908>,
#  'multiplicar': <gensim.models.keyedvectors.Vocab at 0x261a19e2b70>,
#  'planea': <gensim.models.keyedvectors.Vocab at 0x261a19e2c88>,
#  'meta': <gensim.models.keyedvectors.Vocab at 0x261a187ac18>,
#  'denominación': <gensim.models.keyedvectors.Vocab at 0x261a187ab70>,
#  'mundial': <gensim.models.keyedvectors.Vocab at 0x261a187a1d0>,
#  'gringo': <gensim.models.keyedvectors.Vocab at 0x261a187a208>,
#  'diga': <gensim.models.keyedvectors.Vocab at 0x261a187a4a8>,
#  'are': <gensim.models.keyedvectors.Vocab at 0x261a187a710>,
#  'you': <gensim.models.keyedvectors.Vocab at 0x261a187a7f0>,
#  'eating': <gensim.models.keyedvectors.Vocab at 0x261a187a860>,
#  'respondas': <gensim.models.keyedvectors.Vocab at 0x261a187a940>,
#  'rapidez': <gensim.models.keyedvectors.Vocab at 0x261a185b7b8>,
#  'calidad': <gensim.models.keyedvectors.Vocab at 0x261a185ba90>,
#  'maneja': <gensim.models.keyedvectors.Vocab at 0x261a185bac8>,
#  'fast': <gensim.models.keyedvectors.Vocab at 0x261a185b160>,
#  'food': <gensim.models.keyedvectors.Vocab at 0x261a185b2e8>,
#  'estándares': <gensim.models.keyedvectors.Vocab at 0x261a185b4a8>,
#  'exactos': <gensim.models.keyedvectors.Vocab at 0x261a185b6d8>,
#  'señalización': <gensim.models.keyedvectors.Vocab at 0x261a185b710>,
#  'porciones': <gensim.models.keyedvectors.Vocab at 0x261a185b780>,
#  'tiempos': <gensim.models.keyedvectors.Vocab at 0x261a0dc0fd0>,
#  'digital': <gensim.models.keyedvectors.Vocab at 0x261a0dc0f98>,
#  'facebook': <gensim.models.keyedvectors.Vocab at 0x261a0dc0048>,
#  'lapiczaperu': <gensim.models.keyedvectors.Vocab at 0x261a0dc0080>,
#  'rappi': <gensim.models.keyedvectors.Vocab at 0x261a0dc00b8>,
#  'vital': <gensim.models.keyedvectors.Vocab at 0x261a0dc00f0>,
#  'dejar': <gensim.models.keyedvectors.Vocab at 0x261a0dc0128>,
#  'escuchar': <gensim.models.keyedvectors.Vocab at 0x261a0dc0160>,
#  'aconseja': <gensim.models.keyedvectors.Vocab at 0x261a0dc0198>,
#  'recomendaciones': <gensim.models.keyedvectors.Vocab at 0x261a0dc01d0>,
#  'emprender': <gensim.models.keyedvectors.Vocab at 0x261a0dc0208>,
#  'resuelve': <gensim.models.keyedvectors.Vocab at 0x261a0dc0240>,
#  'pensar': <gensim.models.keyedvectors.Vocab at 0x261a0dc02b0>,
#  'locura': <gensim.models.keyedvectors.Vocab at 0x261a0dc02e8>,
#  'números': <gensim.models.keyedvectors.Vocab at 0x261a0dc0320>,
#  'equilibrio': <gensim.models.keyedvectors.Vocab at 0x261a0dc0390>,
#  'proyecciones': <gensim.models.keyedvectors.Vocab at 0x261a0dc0400>,
#  'futuro': <gensim.models.keyedvectors.Vocab at 0x261a0dc0438>,
#  'piensa': <gensim.models.keyedvectors.Vocab at 0x261a0dc0470>,
#  'generar': <gensim.models.keyedvectors.Vocab at 0x261a0dc04a8>,
#  'franquicias': <gensim.models.keyedvectors.Vocab at 0x261a0dc04e0>,
#  'caiga': <gensim.models.keyedvectors.Vocab at 0x261a0dc0518>,
#  'peso': <gensim.models.keyedvectors.Vocab at 0x261a0dc0550>,
#  'anhela': <gensim.models.keyedvectors.Vocab at 0x261a0dc0588>,
#  'imite': <gensim.models.keyedvectors.Vocab at 0x261a0dc05c0>,
#  'cree': <gensim.models.keyedvectors.Vocab at 0x261a0dc05f8>,
#  'genérico': <gensim.models.keyedvectors.Vocab at 0x261a0dc0630>,
#  'metió': <gensim.models.keyedvectors.Vocab at 0x261a0dc0668>,
#  'masificar': <gensim.models.keyedvectors.Vocab at 0x261a0dc06a0>,
#  'producto': <gensim.models.keyedvectors.Vocab at 0x261a0dc06d8>,
#  'sabor': <gensim.models.keyedvectors.Vocab at 0x261a0dc0710>,
#  'proporciones': <gensim.models.keyedvectors.Vocab at 0x261a0dc0748>,
#  'generosas': <gensim.models.keyedvectors.Vocab at 0x261a0dc0780>,
#  'gusta': <gensim.models.keyedvectors.Vocab at 0x261a0dc07b8>,
#  'principal': <gensim.models.keyedvectors.Vocab at 0x261a0dc07f0>,
#  'motivación': <gensim.models.keyedvectors.Vocab at 0x261a0dc0860>,
#  'cuestionas': <gensim.models.keyedvectors.Vocab at 0x261a0dc0898>,
#  'veía': <gensim.models.keyedvectors.Vocab at 0x261a0dc08d0>,
#  'trabajando': <gensim.models.keyedvectors.Vocab at 0x261a0dc0908>,
#  'empleado': <gensim.models.keyedvectors.Vocab at 0x261a0dc0940>,
#  'di': <gensim.models.keyedvectors.Vocab at 0x261a0dc0978>,
#  'quise': <gensim.models.keyedvectors.Vocab at 0x261a0dc09b0>,
#  'aprobar': <gensim.models.keyedvectors.Vocab at 0x261a0dc09e8>,
#  'dificultad': <gensim.models.keyedvectors.Vocab at 0x261a0dc0a20>,
#  'encontraste': <gensim.models.keyedvectors.Vocab at 0x261a0dc0a58>,
#  'superaste': <gensim.models.keyedvectors.Vocab at 0x261a0dc0a90>,
#  'cercana': <gensim.models.keyedvectors.Vocab at 0x261a0dc0ac8>,
#  'ayude': <gensim.models.keyedvectors.Vocab at 0x261a0dc0b00>,
#  'asesorarse': <gensim.models.keyedvectors.Vocab at 0x261a0dc0b38>,
#  'pedir': <gensim.models.keyedvectors.Vocab at 0x261a0dc0b70>,
#  'ayuda': <gensim.models.keyedvectors.Vocab at 0x261a0dc0ba8>,
#  'ahorrado': <gensim.models.keyedvectors.Vocab at 0x261a0dc0be0>,
#  'comprarme': <gensim.models.keyedvectors.Vocab at 0x261a0dc0c18>,
#  'depa': <gensim.models.keyedvectors.Vocab at 0x261a0dc0c50>,
#  'decidí': <gensim.models.keyedvectors.Vocab at 0x261a0dc0c88>,
#  'invertir': <gensim.models.keyedvectors.Vocab at 0x261a0dc0cc0>,
#  'plata': <gensim.models.keyedvectors.Vocab at 0x261a0dc0cf8>,
#  'contratan': <gensim.models.keyedvectors.Vocab at 0x261a0dc0d30>,
#  'decirles': <gensim.models.keyedvectors.Vocab at 0x261a0dc0d68>,
#  'fortaleza': <gensim.models.keyedvectors.Vocab at 0x261a0dc0da0>,
#  'creer': <gensim.models.keyedvectors.Vocab at 0x261a0dc0dd8>,
#  'crear': <gensim.models.keyedvectors.Vocab at 0x261a0dc0e10>,
#  'día': <gensim.models.keyedvectors.Vocab at 0x261a0dc0e48>,
#  'casa': <gensim.models.keyedvectors.Vocab at 0x261a0dc0e80>,
#  'haga': <gensim.models.keyedvectors.Vocab at 0x261a0dc0eb8>,
#  'vacilón': <gensim.models.keyedvectors.Vocab at 0x261a0dc0ef0>,
#  'salchicha': <gensim.models.keyedvectors.Vocab at 0x261a0dc0f28>,
#  'huacho': <gensim.models.keyedvectors.Vocab at 0x261a0dc0f60>,
#  'gastronomía': <gensim.models.keyedvectors.Vocab at 0x261a1b799b0>,
#  'mallory': <gensim.models.keyedvectors.Vocab at 0x261a1b790b8>,
#  'aco': <gensim.models.keyedvectors.Vocab at 0x261a1b790f0>,
#  'logró': <gensim.models.keyedvectors.Vocab at 0x261a1b79128>,
#  'medalla': <gensim.models.keyedvectors.Vocab at 0x261a1b79198>,
#  ...}

# %%
len(model.wv.vocab)
# Out:
# 195410

# %%
model.save('w2v300_4.model')

# %% [markdown]
# ### sizemodel 300 window 5

# %%
sentences = word2vec.Text8Corpus('corpus_general_news.txt')
sizeModel = 300
model = word2vec.Word2Vec(sentences, size=sizeModel, window=5, min_count=2, workers=cpu_count())

# %%
model.wv.vocab
# Out:
# {'presentadora': <gensim.models.keyedvectors.Vocab at 0x261a23a4048>,
#  'exjurado': <gensim.models.keyedvectors.Vocab at 0x261a23a4240>,
#  'artista': <gensim.models.keyedvectors.Vocab at 0x261a23a4c18>,
#  'año': <gensim.models.keyedvectors.Vocab at 0x261a23a4f98>,
#  'fiorella': <gensim.models.keyedvectors.Vocab at 0x261a22b31d0>,
#  'rodríguez': <gensim.models.keyedvectors.Vocab at 0x261a22b34e0>,
#  '45': <gensim.models.keyedvectors.Vocab at 0x261a23eeef0>,
#  'presentó': <gensim.models.keyedvectors.Vocab at 0x261a23eef98>,
#  'dueño': <gensim.models.keyedvectors.Vocab at 0x261a22ee710>,
#  'corazón': <gensim.models.keyedvectors.Vocab at 0x261a265bcf8>,
#  'fotografías': <gensim.models.keyedvectors.Vocab at 0x261a265bd68>,
#  'instagram': <gensim.models.keyedvectors.Vocab at 0x261a265be10>,
#  'fanáticos': <gensim.models.keyedvectors.Vocab at 0x261a265be48>,
#  'tardaron': <gensim.models.keyedvectors.Vocab at 0x261a265be80>,
#  'llenarle': <gensim.models.keyedvectors.Vocab at 0x261a265beb8>,
#  'publicación': <gensim.models.keyedvectors.Vocab at 0x261a265bef0>,
#  'emoticones': <gensim.models.keyedvectors.Vocab at 0x261a265bf60>,
#  'corazones': <gensim.models.keyedvectors.Vocab at 0x261a265bf98>,
#  'fotos': <gensim.models.keyedvectors.Vocab at 0x261a265bfd0>,
#  'observa': <gensim.models.keyedvectors.Vocab at 0x261a265b0b8>,
#  'abrazando': <gensim.models.keyedvectors.Vocab at 0x261a265b0f0>,
#  'muchacho': <gensim.models.keyedvectors.Vocab at 0x261a265b128>,
#  'mira': <gensim.models.keyedvectors.Vocab at 0x261a265b160>,
#  'ternura': <gensim.models.keyedvectors.Vocab at 0x261a265b198>,
#  'captura': <gensim.models.keyedvectors.Vocab at 0x261a265b208>,
#  'sonríe': <gensim.models.keyedvectors.Vocab at 0x261a265b278>,
#  'compartiendo': <gensim.models.keyedvectors.Vocab at 0x261a265b2b0>,
#  'mirada': <gensim.models.keyedvectors.Vocab at 0x261a265b2e8>,
#  'completa': <gensim.models.keyedvectors.Vocab at 0x261a265b358>,
#  'complicidad': <gensim.models.keyedvectors.Vocab at 0x261a265b390>,
#  'meses': <gensim.models.keyedvectors.Vocab at 0x261a265b3c8>,
#  'amor': <gensim.models.keyedvectors.Vocab at 0x261a265b438>,
#  'bonito': <gensim.models.keyedvectors.Vocab at 0x261a265b470>,
#  'mensaje': <gensim.models.keyedvectors.Vocab at 0x261a265b518>,
#  'acompaña': <gensim.models.keyedvectors.Vocab at 0x261a265b588>,
#  'mantuvo': <gensim.models.keyedvectors.Vocab at 0x261a265b5c0>,
#  'matrimonio': <gensim.models.keyedvectors.Vocab at 0x261a265b630>,
#  '15': <gensim.models.keyedvectors.Vocab at 0x261a265b668>,
#  'años': <gensim.models.keyedvectors.Vocab at 0x261a265b6a0>,
#  'cineasta': <gensim.models.keyedvectors.Vocab at 0x261a265b6d8>,
#  'sandro': <gensim.models.keyedvectors.Vocab at 0x261a265b710>,
#  'ventura': <gensim.models.keyedvectors.Vocab at 0x261a265b748>,
#  'mediados': <gensim.models.keyedvectors.Vocab at 0x261a265b7b8>,
#  '2018': <gensim.models.keyedvectors.Vocab at 0x261a265b828>,
#  'anunciaron': <gensim.models.keyedvectors.Vocab at 0x261a265b860>,
#  'separación': <gensim.models.keyedvectors.Vocab at 0x261a265b898>,
#  'quedaron': <gensim.models.keyedvectors.Vocab at 0x261a265b8d0>,
#  'términos': <gensim.models.keyedvectors.Vocab at 0x261a265b9e8>,
#  'amigo': <gensim.models.keyedvectors.Vocab at 0x261a265ba20>,
#  'hermosos': <gensim.models.keyedvectors.Vocab at 0x261a265ba90>,
#  'basados': <gensim.models.keyedvectors.Vocab at 0x261a265bb38>,
#  'comunicación': <gensim.models.keyedvectors.Vocab at 0x261a265bba8>,
#  'cariño': <gensim.models.keyedvectors.Vocab at 0x261a265bbe0>,
#  'entrega': <gensim.models.keyedvectors.Vocab at 0x261a265bc18>,
#  'absoluta': <gensim.models.keyedvectors.Vocab at 0x261a265bc50>,
#  'persona': <gensim.models.keyedvectors.Vocab at 0x261a265bc88>,
#  'importante': <gensim.models.keyedvectors.Vocab at 0x261a2f64240>,
#  'vida': <gensim.models.keyedvectors.Vocab at 0x261a2f648d0>,
#  'oportunidad': <gensim.models.keyedvectors.Vocab at 0x261a2f64908>,
#  'cerrar': <gensim.models.keyedvectors.Vocab at 0x261a2f64a20>,
#  'etapa': <gensim.models.keyedvectors.Vocab at 0x261a2f64ac8>,
#  'abrir': <gensim.models.keyedvectors.Vocab at 0x261a2f64c88>,
#  'emoción': <gensim.models.keyedvectors.Vocab at 0x261a2f64d30>,
#  'expectativa': <gensim.models.keyedvectors.Vocab at 0x261a2f64f60>,
#  'seguir': <gensim.models.keyedvectors.Vocab at 0x261a2f64198>,
#  'persiguiendo': <gensim.models.keyedvectors.Vocab at 0x261a2f640f0>,
#  'sueños': <gensim.models.keyedvectors.Vocab at 0x261a2f7a5c0>,
#  'febrero': <gensim.models.keyedvectors.Vocab at 0x261a2f7a668>,
#  'entrevista': <gensim.models.keyedvectors.Vocab at 0x261a2f7a6a0>,
#  'perú21': <gensim.models.keyedvectors.Vocab at 0x261a2f7a748>,
#  'enriquez': <gensim.models.keyedvectors.Vocab at 0x261a2f7a7b8>,
#  'luque': <gensim.models.keyedvectors.Vocab at 0x261a2f7a908>,
#  '25': <gensim.models.keyedvectors.Vocab at 0x261a2f7a550>,
#  'detenido': <gensim.models.keyedvectors.Vocab at 0x261a2f7ac50>,
#  'arrojado': <gensim.models.keyedvectors.Vocab at 0x261a2f7a048>,
#  'thinner': <gensim.models.keyedvectors.Vocab at 0x261a2f7a358>,
#  'padre': <gensim.models.keyedvectors.Vocab at 0x261a2f7a390>,
#  'posteriormente': <gensim.models.keyedvectors.Vocab at 0x261a2f7a400>,
#  'prenderle': <gensim.models.keyedvectors.Vocab at 0x261a2f7a518>,
#  'fuego': <gensim.models.keyedvectors.Vocab at 0x261a2f7ada0>,
#  'acuerdo': <gensim.models.keyedvectors.Vocab at 0x261a2f7ae10>,
#  'diversos': <gensim.models.keyedvectors.Vocab at 0x261a2f7af98>,
#  'medios': <gensim.models.keyedvectors.Vocab at 0x261a2f7afd0>,
#  'locales': <gensim.models.keyedvectors.Vocab at 0x261c2199128>,
#  'parricidio': <gensim.models.keyedvectors.Vocab at 0x261c2199048>,
#  'ocurrió': <gensim.models.keyedvectors.Vocab at 0x261c21990f0>,
#  'vivienda': <gensim.models.keyedvectors.Vocab at 0x261c2199278>,
#  'agraviado': <gensim.models.keyedvectors.Vocab at 0x261c21992e8>,
#  'ubicada': <gensim.models.keyedvectors.Vocab at 0x261c2199320>,
#  'provincia': <gensim.models.keyedvectors.Vocab at 0x261c2199390>,
#  'convención': <gensim.models.keyedvectors.Vocab at 0x261c2199400>,
#  'cusco': <gensim.models.keyedvectors.Vocab at 0x261c2199438>,
#  'vecinos': <gensim.models.keyedvectors.Vocab at 0x261c2199470>,
#  'zona': <gensim.models.keyedvectors.Vocab at 0x261c21994a8>,
#  'aviso': <gensim.models.keyedvectors.Vocab at 0x261c21994e0>,
#  'autoridades': <gensim.models.keyedvectors.Vocab at 0x261c2199518>,
#  'inmediatamente': <gensim.models.keyedvectors.Vocab at 0x261c2199550>,
#  'llegaron': <gensim.models.keyedvectors.Vocab at 0x261c2199588>,
#  'hechos': <gensim.models.keyedvectors.Vocab at 0x261c21995c0>,
#  'domicilio': <gensim.models.keyedvectors.Vocab at 0x261c2199630>,
#  'joven': <gensim.models.keyedvectors.Vocab at 0x261c21996a0>,
#  'negó': <gensim.models.keyedvectors.Vocab at 0x261c21996d8>,
#  'incendiado': <gensim.models.keyedvectors.Vocab at 0x261c2199710>,
#  'identificado': <gensim.models.keyedvectors.Vocab at 0x261c2199748>,
#  'víctor': <gensim.models.keyedvectors.Vocab at 0x261c21997f0>,
#  'carrion': <gensim.models.keyedvectors.Vocab at 0x261c2199828>,
#  '68': <gensim.models.keyedvectors.Vocab at 0x261c2199860>,
#  'obstante': <gensim.models.keyedvectors.Vocab at 0x261c21998d0>,
#  'graves': <gensim.models.keyedvectors.Vocab at 0x261c2199908>,
#  'quemaduras': <gensim.models.keyedvectors.Vocab at 0x261c2199940>,
#  'grado': <gensim.models.keyedvectors.Vocab at 0x261c21999b0>,
#  'salió': <gensim.models.keyedvectors.Vocab at 0x261c21999e8>,
#  'desmentir': <gensim.models.keyedvectors.Vocab at 0x261c2199a58>,
#  'versión': <gensim.models.keyedvectors.Vocab at 0x261c2199a90>,
#  'hijo': <gensim.models.keyedvectors.Vocab at 0x261c2199b00>,
#  'finalmente': <gensim.models.keyedvectors.Vocab at 0x261c2199b38>,
#  'trasladado': <gensim.models.keyedvectors.Vocab at 0x261c2199c50>,
#  'comisaría': <gensim.models.keyedvectors.Vocab at 0x261c2199cf8>,
#  'santa': <gensim.models.keyedvectors.Vocab at 0x261c2199d30>,
#  'teresa': <gensim.models.keyedvectors.Vocab at 0x261c2199d68>,
#  'intervención': <gensim.models.keyedvectors.Vocab at 0x261c2199da0>,
#  'víctima': <gensim.models.keyedvectors.Vocab at 0x261c2199e10>,
#  'llevado': <gensim.models.keyedvectors.Vocab at 0x261c2199e48>,
#  'hospital': <gensim.models.keyedvectors.Vocab at 0x261c2199e80>,
#  'central': <gensim.models.keyedvectors.Vocab at 0x261c2199eb8>,
#  'ciudad': <gensim.models.keyedvectors.Vocab at 0x261c2199ef0>,
#  'quillabamba': <gensim.models.keyedvectors.Vocab at 0x261c2199f28>,
#  'viene': <gensim.models.keyedvectors.Vocab at 0x261c2199f60>,
#  'recuperándose': <gensim.models.keyedvectors.Vocab at 0x261c2199fd0>,
#  'lesiones': <gensim.models.keyedvectors.Vocab at 0x261a22f13c8>,
#  'fiscalía': <gensim.models.keyedvectors.Vocab at 0x261a22f19e8>,
#  'turno': <gensim.models.keyedvectors.Vocab at 0x261a235b0b8>,
#  'dispuso': <gensim.models.keyedvectors.Vocab at 0x261a235b438>,
#  'diligencias': <gensim.models.keyedvectors.Vocab at 0x261a235b550>,
#  'preliminares': <gensim.models.keyedvectors.Vocab at 0x261a2146438>,
#  'correspondientes': <gensim.models.keyedvectors.Vocab at 0x261a2498208>,
#  'permanecerá': <gensim.models.keyedvectors.Vocab at 0x261a2498080>,
#  'investigaciones': <gensim.models.keyedvectors.Vocab at 0x261a24982b0>,
#  'deberá': <gensim.models.keyedvectors.Vocab at 0x261a2498710>,
#  'enfrentar': <gensim.models.keyedvectors.Vocab at 0x261a2498748>,
#  'cargos': <gensim.models.keyedvectors.Vocab at 0x261a24989b0>,
#  'presunto': <gensim.models.keyedvectors.Vocab at 0x261a2498d68>,
#  'delito': <gensim.models.keyedvectors.Vocab at 0x261a2498e10>,
#  'violencia': <gensim.models.keyedvectors.Vocab at 0x261a2fe00b8>,
#  'familiar': <gensim.models.keyedvectors.Vocab at 0x261a2fe0588>,
#  'luis': <gensim.models.keyedvectors.Vocab at 0x261a2fe0668>,
#  'bedoya': <gensim.models.keyedvectors.Vocab at 0x261a2fe07f0>,
#  'reyes': <gensim.models.keyedvectors.Vocab at 0x261a30569b0>,
#  'fundadores': <gensim.models.keyedvectors.Vocab at 0x261a30569e8>,
#  'históricos': <gensim.models.keyedvectors.Vocab at 0x261a3056a58>,
#  'partido': <gensim.models.keyedvectors.Vocab at 0x261a3056b00>,
#  'popular': <gensim.models.keyedvectors.Vocab at 0x261a3056ba8>,
#  'cristiano': <gensim.models.keyedvectors.Vocab at 0x261a3056c50>,
#  'ppc': <gensim.models.keyedvectors.Vocab at 0x261a3056c88>,
#  'pronunció': <gensim.models.keyedvectors.Vocab at 0x261a3056cf8>,
#  'acerca': <gensim.models.keyedvectors.Vocab at 0x261a3056908>,
#  'convocatoria': <gensim.models.keyedvectors.Vocab at 0x261a3056a90>,
#  'integrar': <gensim.models.keyedvectors.Vocab at 0x261a30560f0>,
#  'junta': <gensim.models.keyedvectors.Vocab at 0x261a30562b0>,
#  'nacional': <gensim.models.keyedvectors.Vocab at 0x261a30564a8>,
#  'justicia': <gensim.models.keyedvectors.Vocab at 0x261a30565c0>,
#  'jnj': <gensim.models.keyedvectors.Vocab at 0x261a30566a0>,
#  'pequeño': <gensim.models.keyedvectors.Vocab at 0x261a30566d8>,
#  'discurso': <gensim.models.keyedvectors.Vocab at 0x261c2189048>,
#  'importancia': <gensim.models.keyedvectors.Vocab at 0x261c2189080>,
#  'significa': <gensim.models.keyedvectors.Vocab at 0x261c21890b8>,
#  'órgano': <gensim.models.keyedvectors.Vocab at 0x261c21890f0>,
#  'político': <gensim.models.keyedvectors.Vocab at 0x261c2189240>,
#  '100': <gensim.models.keyedvectors.Vocab at 0x261c21892b0>,
#  'edad': <gensim.models.keyedvectors.Vocab at 0x261c2189320>,
#  'grabó': <gensim.models.keyedvectors.Vocab at 0x261c2189358>,
#  'video': <gensim.models.keyedvectors.Vocab at 0x261c2189390>,
#  'explica': <gensim.models.keyedvectors.Vocab at 0x261c2189438>,
#  'razones': <gensim.models.keyedvectors.Vocab at 0x261c2189470>,
#  'llama': <gensim.models.keyedvectors.Vocab at 0x261c21894a8>,
#  'juristas': <gensim.models.keyedvectors.Vocab at 0x261c21894e0>,
#  'abogados': <gensim.models.keyedvectors.Vocab at 0x261c2189588>,
#  'especialistas': <gensim.models.keyedvectors.Vocab at 0x261c21895f8>,
#  'derecho': <gensim.models.keyedvectors.Vocab at 0x261c2189668>,
#  'ojalá': <gensim.models.keyedvectors.Vocab at 0x261c21896a0>,
#  'acostumbren': <gensim.models.keyedvectors.Vocab at 0x261c2189710>,
#  'acertar': <gensim.models.keyedvectors.Vocab at 0x261c2189748>,
#  'postulantes': <gensim.models.keyedvectors.Vocab at 0x261c2189780>,
#  'merezcan': <gensim.models.keyedvectors.Vocab at 0x261c21897f0>,
#  'elegidos': <gensim.models.keyedvectors.Vocab at 0x261c2189908>,
#  'razón': <gensim.models.keyedvectors.Vocab at 0x261c2189978>,
#  'condiciones': <gensim.models.keyedvectors.Vocab at 0x261c2189a90>,
#  'cualidades': <gensim.models.keyedvectors.Vocab at 0x261c2189b00>,
#  'juntaremos': <gensim.models.keyedvectors.Vocab at 0x261c2189b38>,
#  'peruanos': <gensim.models.keyedvectors.Vocab at 0x261c2189b70>,
#  'vivir': <gensim.models.keyedvectors.Vocab at 0x261c2189c18>,
#  'discrepando': <gensim.models.keyedvectors.Vocab at 0x261c2189c88>,
#  'institución': <gensim.models.keyedvectors.Vocab at 0x261c2189cf8>,
#  'reemplazará': <gensim.models.keyedvectors.Vocab at 0x261c2189d30>,
#  'desaparecido': <gensim.models.keyedvectors.Vocab at 0x261c2189d68>,
#  'consejo': <gensim.models.keyedvectors.Vocab at 0x261c2189e10>,
#  'magistratura': <gensim.models.keyedvectors.Vocab at 0x261c2189e48>,
#  'cnm': <gensim.models.keyedvectors.Vocab at 0x261c2189e80>,
#  'desactivado': <gensim.models.keyedvectors.Vocab at 0x261c2189eb8>,
#  'audios': <gensim.models.keyedvectors.Vocab at 0x261c2189ef0>,
#  'vergüenza': <gensim.models.keyedvectors.Vocab at 0x261c2189f98>,
#  'exintegrantes': <gensim.models.keyedvectors.Vocab at 0x261c2189fd0>,
#  'escuchaba': <gensim.models.keyedvectors.Vocab at 0x261a2fd2208>,
#  'comprometedoras': <gensim.models.keyedvectors.Vocab at 0x261a2fd2358>,
#  'situación': <gensim.models.keyedvectors.Vocab at 0x261a2fd2550>,
#  'corrupción': <gensim.models.keyedvectors.Vocab at 0x261a2fd2668>,
#  'encargará': <gensim.models.keyedvectors.Vocab at 0x261a2fd26d8>,
#  'nombrar': <gensim.models.keyedvectors.Vocab at 0x261a2fd27b8>,
#  'destituir': <gensim.models.keyedvectors.Vocab at 0x261a2fd2978>,
#  'jueces': <gensim.models.keyedvectors.Vocab at 0x261a2fd2a20>,
#  'fiscales': <gensim.models.keyedvectors.Vocab at 0x261a2fd2d30>,
#  'asimismo': <gensim.models.keyedvectors.Vocab at 0x261a2fd2da0>,
#  'facultad': <gensim.models.keyedvectors.Vocab at 0x261a2fd2e10>,
#  'renovar': <gensim.models.keyedvectors.Vocab at 0x261a2fd2e80>,
#  'cargo': <gensim.models.keyedvectors.Vocab at 0x261a1e79278>,
#  'jefe': <gensim.models.keyedvectors.Vocab at 0x261a2282048>,
#  'onpe': <gensim.models.keyedvectors.Vocab at 0x261a22824e0>,
#  'reniec': <gensim.models.keyedvectors.Vocab at 0x261a2282c88>,
#  'doctor': <gensim.models.keyedvectors.Vocab at 0x261a22ef9e8>,
#  'juan': <gensim.models.keyedvectors.Vocab at 0x261a22efac8>,
#  'herrera': <gensim.models.keyedvectors.Vocab at 0x261a22efc50>,
#  'director': <gensim.models.keyedvectors.Vocab at 0x261a2486208>,
#  'general': <gensim.models.keyedvectors.Vocab at 0x261a2486240>,
#  'operaciones': <gensim.models.keyedvectors.Vocab at 0x261a21e74e0>,
#  'salud': <gensim.models.keyedvectors.Vocab at 0x261a24cc0b8>,
#  'conversación': <gensim.models.keyedvectors.Vocab at 0x261a24cc780>,
#  'atv': <gensim.models.keyedvectors.Vocab at 0x261a24cc940>,
#  'separó': <gensim.models.keyedvectors.Vocab at 0x261a24ccb38>,
#  'responsables': <gensim.models.keyedvectors.Vocab at 0x261a24ccdd8>,
#  'difundir': <gensim.models.keyedvectors.Vocab at 0x261a24ccf60>,
#  'fallecido': <gensim.models.keyedvectors.Vocab at 0x261a22c6ba8>,
#  'expresidente': <gensim.models.keyedvectors.Vocab at 0x261a2370f98>,
#  'alan': <gensim.models.keyedvectors.Vocab at 0x261a3e9ac50>,
#  'garcía': <gensim.models.keyedvectors.Vocab at 0x261a3e9acc0>,
#  'casimiro': <gensim.models.keyedvectors.Vocab at 0x261a3e9ae80>,
#  'ulloa': <gensim.models.keyedvectors.Vocab at 0x261a3e9afd0>,
#  'sistema': <gensim.models.keyedvectors.Vocab at 0x261a3e9a048>,
#  'identificados': <gensim.models.keyedvectors.Vocab at 0x261a3e9a080>,
#  'vía': <gensim.models.keyedvectors.Vocab at 0x261a3e9a128>,
#  'administrativas': <gensim.models.keyedvectors.Vocab at 0x261a3e9a198>,
#  'activada': <gensim.models.keyedvectors.Vocab at 0x261a3e9a208>,
#  'sanción': <gensim.models.keyedvectors.Vocab at 0x261a3e9a3c8>,
#  'correspondiente': <gensim.models.keyedvectors.Vocab at 0x261a3e9a550>,
#  'tema': <gensim.models.keyedvectors.Vocab at 0x261a3e9a6d8>,
#  'respeto': <gensim.models.keyedvectors.Vocab at 0x261a3e9a710>,
#  'nombre': <gensim.models.keyedvectors.Vocab at 0x261a3e9a8d0>,
#  'detalle': <gensim.models.keyedvectors.Vocab at 0x261a3e9a908>,
#  'grupo': <gensim.models.keyedvectors.Vocab at 0x261a3e9a9e8>,
#  'ocupacional': <gensim.models.keyedvectors.Vocab at 0x261a3e9ab00>,
#  'lamentable': <gensim.models.keyedvectors.Vocab at 0x261a3e9ab38>,
#  'precisó': <gensim.models.keyedvectors.Vocab at 0x261a1fa5208>,
#  'involucrados': <gensim.models.keyedvectors.Vocab at 0x261a1fa5518>,
#  'separados': <gensim.models.keyedvectors.Vocab at 0x261a1fa5978>,
#  'nosocomio': <gensim.models.keyedvectors.Vocab at 0x261a209fb00>,
#  'preliminar': <gensim.models.keyedvectors.Vocab at 0x261a209f518>,
#  'entidad': <gensim.models.keyedvectors.Vocab at 0x261a2289ba8>,
#  'proceso': <gensim.models.keyedvectors.Vocab at 0x261a22899b0>,
#  'administrativos': <gensim.models.keyedvectors.Vocab at 0x261a2099dd8>,
#  'corresponde': <gensim.models.keyedvectors.Vocab at 0x261a23dc470>,
#  'definitiva': <gensim.models.keyedvectors.Vocab at 0x261a23dc4a8>,
#  'mal': <gensim.models.keyedvectors.Vocab at 0x261a23dc588>,
#  'recuerdo': <gensim.models.keyedvectors.Vocab at 0x261a23dca58>,
#  'suspensión': <gensim.models.keyedvectors.Vocab at 0x261a23dca90>,
#  'procurador': <gensim.models.keyedvectors.Vocab at 0x261a23dccf8>,
#  'tomando': <gensim.models.keyedvectors.Vocab at 0x261a2731048>,
#  'acciones': <gensim.models.keyedvectors.Vocab at 0x261a2731080>,
#  'administrativa': <gensim.models.keyedvectors.Vocab at 0x261a27310b8>,
#  'aseveró': <gensim.models.keyedvectors.Vocab at 0x261a27310f0>,
#  'diagnóstico': <gensim.models.keyedvectors.Vocab at 0x261a2731128>,
#  '17': <gensim.models.keyedvectors.Vocab at 0x261a2731160>,
#  'abril': <gensim.models.keyedvectors.Vocab at 0x261a2731198>,
#  'exmandatario': <gensim.models.keyedvectors.Vocab at 0x261a27311d0>,
#  'tomó': <gensim.models.keyedvectors.Vocab at 0x261a2731208>,
#  'fatal': <gensim.models.keyedvectors.Vocab at 0x261a2731240>,
#  'decisión': <gensim.models.keyedvectors.Vocab at 0x261a2731278>,
#  'quitarse': <gensim.models.keyedvectors.Vocab at 0x261a27312b0>,
#  'disparándose': <gensim.models.keyedvectors.Vocab at 0x261a27312e8>,
#  'cabeza': <gensim.models.keyedvectors.Vocab at 0x261a2731320>,
#  'impacto': <gensim.models.keyedvectors.Vocab at 0x261a2731358>,
#  'proyectil': <gensim.models.keyedvectors.Vocab at 0x261a2731390>,
#  'arma': <gensim.models.keyedvectors.Vocab at 0x261a27313c8>,
#  'orificio': <gensim.models.keyedvectors.Vocab at 0x261a2731400>,
#  'entrada': <gensim.models.keyedvectors.Vocab at 0x261a2731438>,
#  'salida': <gensim.models.keyedvectors.Vocab at 0x261a2731470>,
#  'cráneo': <gensim.models.keyedvectors.Vocab at 0x261a27314a8>,
#  'ingresó': <gensim.models.keyedvectors.Vocab at 0x261a27314e0>,
#  'sala': <gensim.models.keyedvectors.Vocab at 0x261a2731518>,
#  '0717': <gensim.models.keyedvectors.Vocab at 0x261a2731550>,
#  'am': <gensim.models.keyedvectors.Vocab at 0x261a2731588>,
#  'vano': <gensim.models.keyedvectors.Vocab at 0x261a27315c0>,
#  'muerte': <gensim.models.keyedvectors.Vocab at 0x261a27315f8>,
#  'consecuencia': <gensim.models.keyedvectors.Vocab at 0x261a2731630>,
#  'hemorragia': <gensim.models.keyedvectors.Vocab at 0x261a2731668>,
#  'cerebral': <gensim.models.keyedvectors.Vocab at 0x261a27316a0>,
#  'masiva': <gensim.models.keyedvectors.Vocab at 0x261a27316d8>,
#  'paro': <gensim.models.keyedvectors.Vocab at 0x261a2731710>,
#  'cardiorespiratorio': <gensim.models.keyedvectors.Vocab at 0x261a2731748>,
#  'john': <gensim.models.keyedvectors.Vocab at 0x261a2731780>,
#  'galliquio': <gensim.models.keyedvectors.Vocab at 0x261a27317b8>,
#  'exjugador': <gensim.models.keyedvectors.Vocab at 0x261a27317f0>,
#  'selección': <gensim.models.keyedvectors.Vocab at 0x261a2731828>,
#  'peruana': <gensim.models.keyedvectors.Vocab at 0x261a2731860>,
#  'apareció': <gensim.models.keyedvectors.Vocab at 0x261a27318d0>,
#  'evento': <gensim.models.keyedvectors.Vocab at 0x261a2731908>,
#  'deportivo': <gensim.models.keyedvectors.Vocab at 0x261a2731940>,
#  'san': <gensim.models.keyedvectors.Vocab at 0x261a2731978>,
#  'miraflores': <gensim.models.keyedvectors.Vocab at 0x261a27319b0>,
#  'consultado': <gensim.models.keyedvectors.Vocab at 0x261a27319e8>,
#  'denuncia': <gensim.models.keyedvectors.Vocab at 0x261a2731a20>,
#  'exesposa': <gensim.models.keyedvectors.Vocab at 0x261a2731a58>,
#  'karla': <gensim.models.keyedvectors.Vocab at 0x261a2731a90>,
#  'gómez': <gensim.models.keyedvectors.Vocab at 0x261a2731ac8>,
#  'prefirió': <gensim.models.keyedvectors.Vocab at 0x261a2731b00>,
#  'declarar': <gensim.models.keyedvectors.Vocab at 0x261a2731b38>,
#  'aprecia': <gensim.models.keyedvectors.Vocab at 0x261a2731b70>,
#  'imágenes': <gensim.models.keyedvectors.Vocab at 0x261a2731ba8>,
#  'programa': <gensim.models.keyedvectors.Vocab at 0x261a2731be0>,
#  'magaly': <gensim.models.keyedvectors.Vocab at 0x261a2731c18>,
#  'medina': <gensim.models.keyedvectors.Vocab at 0x261a2731c50>,
#  'tyson': <gensim.models.keyedvectors.Vocab at 0x261a2731c88>,
#  'hablaría': <gensim.models.keyedvectors.Vocab at 0x261a2731cc0>,
#  'privada': <gensim.models.keyedvectors.Vocab at 0x261a2731cf8>,
#  'evadió': <gensim.models.keyedvectors.Vocab at 0x261a2731d30>,
#  'consultadas': <gensim.models.keyedvectors.Vocab at 0x261a2731dd8>,
#  'reportero': <gensim.models.keyedvectors.Vocab at 0x261a2731e10>,
#  'presentes': <gensim.models.keyedvectors.Vocab at 0x261a2731e48>,
#  'paolo': <gensim.models.keyedvectors.Vocab at 0x261a2731e80>,
#  'maldonado': <gensim.models.keyedvectors.Vocab at 0x261a2731eb8>,
#  'manuel': <gensim.models.keyedvectors.Vocab at 0x261a2731ef0>,
#  'vargas': <gensim.models.keyedvectors.Vocab at 0x261a2731f28>,
#  'mostró': <gensim.models.keyedvectors.Vocab at 0x261a2731f60>,
#  'risueño': <gensim.models.keyedvectors.Vocab at 0x261a2731f98>,
#  'principio': <gensim.models.keyedvectors.Vocab at 0x261a2731fd0>,
#  'propiedades': <gensim.models.keyedvectors.Vocab at 0x261a272ccf8>,
#  'denuncias': <gensim.models.keyedvectors.Vocab at 0x261a272cd30>,
#  'incómodo': <gensim.models.keyedvectors.Vocab at 0x261a272cd68>,
#  'disculpa': <gensim.models.keyedvectors.Vocab at 0x261a272cda0>,
#  'hablo': <gensim.models.keyedvectors.Vocab at 0x261a272cdd8>,
#  'favor': <gensim.models.keyedvectors.Vocab at 0x261a272ce10>,
#  'agradezco': <gensim.models.keyedvectors.Vocab at 0x261a272ce48>,
#  'montón': <gensim.models.keyedvectors.Vocab at 0x261a272ce80>,
#  'hablar': <gensim.models.keyedvectors.Vocab at 0x261a272ceb8>,
#  'ustedes': <gensim.models.keyedvectors.Vocab at 0x261a272cf28>,
#  'contigo': <gensim.models.keyedvectors.Vocab at 0x261a272cf60>,
#  'gracias': <gensim.models.keyedvectors.Vocab at 0x261a272cf98>,
#  'puedes': <gensim.models.keyedvectors.Vocab at 0x261a272cfd0>,
#  'obligar': <gensim.models.keyedvectors.Vocab at 0x261a272c048>,
#  'hable': <gensim.models.keyedvectors.Vocab at 0x261a272c080>,
#  'declaró': <gensim.models.keyedvectors.Vocab at 0x261a272c0b8>,
#  'jhon': <gensim.models.keyedvectors.Vocab at 0x261a272c0f0>,
#  'recordar': <gensim.models.keyedvectors.Vocab at 0x261a272c128>,
#  'medidas': <gensim.models.keyedvectors.Vocab at 0x261a272c160>,
#  'protección': <gensim.models.keyedvectors.Vocab at 0x261a272c198>,
#  'pisco': <gensim.models.keyedvectors.Vocab at 0x261a272c208>,
#  'denunciar': <gensim.models.keyedvectors.Vocab at 0x261a272c278>,
#  'agentes': <gensim.models.keyedvectors.Vocab at 0x261a272c2b0>,
#  'ignoran': <gensim.models.keyedvectors.Vocab at 0x261a272c2e8>,
#  'informa': <gensim.models.keyedvectors.Vocab at 0x261a272c320>,
#  'marzo': <gensim.models.keyedvectors.Vocab at 0x261a272c358>,
#  'denunciado': <gensim.models.keyedvectors.Vocab at 0x261a272c390>,
#  'doméstica': <gensim.models.keyedvectors.Vocab at 0x261a272c3c8>,
#  'querido': <gensim.models.keyedvectors.Vocab at 0x261a272c400>,
#  'ahogar': <gensim.models.keyedvectors.Vocab at 0x261a272c438>,
#  'mar': <gensim.models.keyedvectors.Vocab at 0x261a272c470>,
#  'discusión': <gensim.models.keyedvectors.Vocab at 0x261a272c4a8>,
#  'pateaba': <gensim.models.keyedvectors.Vocab at 0x261a272c4e0>,
#  'punto': <gensim.models.keyedvectors.Vocab at 0x261a272c518>,
#  'hacerme': <gensim.models.keyedvectors.Vocab at 0x261a272c550>,
#  'vomitar': <gensim.models.keyedvectors.Vocab at 0x261a272c588>,
#  'sangre': <gensim.models.keyedvectors.Vocab at 0x261a272c5c0>,
#  'rompe': <gensim.models.keyedvectors.Vocab at 0x261a272c5f8>,
#  'mandíbula': <gensim.models.keyedvectors.Vocab at 0x261a272c668>,
#  'patea': <gensim.models.keyedvectors.Vocab at 0x261a272c6a0>,
#  'calle': <gensim.models.keyedvectors.Vocab at 0x261a272c6d8>,
#  'esperando': <gensim.models.keyedvectors.Vocab at 0x261a272c710>,
#  'mate': <gensim.models.keyedvectors.Vocab at 0x261a272c748>,
#  'medio': <gensim.models.keyedvectors.Vocab at 0x261a272c780>,
#  'lágrimas': <gensim.models.keyedvectors.Vocab at 0x261a272c7b8>,
#  'denunciante': <gensim.models.keyedvectors.Vocab at 0x261a272c7f0>,
#  'jugador': <gensim.models.keyedvectors.Vocab at 0x261a272c828>,
#  'aparece': <gensim.models.keyedvectors.Vocab at 0x261a272c860>,
#  'cuchillo': <gensim.models.keyedvectors.Vocab at 0x261a272c898>,
#  'audio': <gensim.models.keyedvectors.Vocab at 0x261a272c8d0>,
#  'cárcel': <gensim.models.keyedvectors.Vocab at 0x261a272c940>,
#  'matar': <gensim.models.keyedvectors.Vocab at 0x261a272c978>,
#  'duras': <gensim.models.keyedvectors.Vocab at 0x261a272c9b0>,
#  'críticas': <gensim.models.keyedvectors.Vocab at 0x261a272c9e8>,
#  'recibiendo': <gensim.models.keyedvectors.Vocab at 0x261a272ca20>,
#  'comentarista': <gensim.models.keyedvectors.Vocab at 0x261a272ca58>,
#  'silvio': <gensim.models.keyedvectors.Vocab at 0x261a272ca90>,
#  'valencia': <gensim.models.keyedvectors.Vocab at 0x261a272cac8>,
#  'vivo': <gensim.models.keyedvectors.Vocab at 0x261a272cb00>,
#  'hinchas': <gensim.models.keyedvectors.Vocab at 0x261a272cb38>,
#  'sport': <gensim.models.keyedvectors.Vocab at 0x261a272cb70>,
#  'boys': <gensim.models.keyedvectors.Vocab at 0x261a272cba8>,
#  'plato': <gensim.models.keyedvectors.Vocab at 0x261a272cbe0>,
#  'comida': <gensim.models.keyedvectors.Vocab at 0x261a272cc18>,
#  'penosas': <gensim.models.keyedvectors.Vocab at 0x261a272cc50>,
#  'declaraciones': <gensim.models.keyedvectors.Vocab at 0x261a272cc88>,
#  'difundió': <gensim.models.keyedvectors.Vocab at 0x261a272ccc0>,
#  'espacio': <gensim.models.keyedvectors.Vocab at 0x261a2724320>,
#  'televisivo': <gensim.models.keyedvectors.Vocab at 0x261a2724358>,
#  'conduce': <gensim.models.keyedvectors.Vocab at 0x261a2724390>,
#  'conductores': <gensim.models.keyedvectors.Vocab at 0x261a27243c8>,
#  'cobra': <gensim.models.keyedvectors.Vocab at 0x261a2724438>,
#  'entradas': <gensim.models.keyedvectors.Vocab at 0x261a2724470>,
#  'asistentes': <gensim.models.keyedvectors.Vocab at 0x261a27244a8>,
#  'estrategia': <gensim.models.keyedvectors.Vocab at 0x261a27244e0>,
#  'misilera': <gensim.models.keyedvectors.Vocab at 0x261a2724518>,
#  'consiste': <gensim.models.keyedvectors.Vocab at 0x261a2724550>,
#  'pago': <gensim.models.keyedvectors.Vocab at 0x261a2724588>,
#  'voluntario': <gensim.models.keyedvectors.Vocab at 0x261a27245c0>,
#  'concepto': <gensim.models.keyedvectors.Vocab at 0x261a27245f8>,
#  'precio': <gensim.models.keyedvectors.Vocab at 0x261a2724630>,
#  'compañeros': <gensim.models.keyedvectors.Vocab at 0x261a2724668>,
#  'sostuvo': <gensim.models.keyedvectors.Vocab at 0x261a27246a0>,
#  'montos': <gensim.models.keyedvectors.Vocab at 0x261a2724710>,
#  'cobran': <gensim.models.keyedvectors.Vocab at 0x261a2724748>,
#  'recuperan': <gensim.models.keyedvectors.Vocab at 0x261a2724780>,
#  'venta': <gensim.models.keyedvectors.Vocab at 0x261a27247b8>,
#  'estadio': <gensim.models.keyedvectors.Vocab at 0x261a27247f0>,
#  'miguel': <gensim.models.keyedvectors.Vocab at 0x261a2724828>,
#  'grau': <gensim.models.keyedvectors.Vocab at 0x261a2724860>,
#  'callao': <gensim.models.keyedvectors.Vocab at 0x261a2724898>,
#  'táctica': <gensim.models.keyedvectors.Vocab at 0x261a27248d0>,
#  'busca': <gensim.models.keyedvectors.Vocab at 0x261a2724908>,
#  'asistencia': <gensim.models.keyedvectors.Vocab at 0x261a2724940>,
#  'personas': <gensim.models.keyedvectors.Vocab at 0x261a2724978>,
#  'alentar': <gensim.models.keyedvectors.Vocab at 0x261a27249b0>,
#  'equipo': <gensim.models.keyedvectors.Vocab at 0x261a27249e8>,
#  'evitar': <gensim.models.keyedvectors.Vocab at 0x261a2724a20>,
#  'descenso': <gensim.models.keyedvectors.Vocab at 0x261a2724a58>,
#  'división': <gensim.models.keyedvectors.Vocab at 0x261a2724a90>,
#  'incorrecta': <gensim.models.keyedvectors.Vocab at 0x261a2724ac8>,
#  'postura': <gensim.models.keyedvectors.Vocab at 0x261a2724b38>,
#  'gente': <gensim.models.keyedvectors.Vocab at 0x261a2724b70>,
#  'chicos': <gensim.models.keyedvectors.Vocab at 0x261a2724ba8>,
#  'paran': <gensim.models.keyedvectors.Vocab at 0x261a2724be0>,
#  '5': <gensim.models.keyedvectors.Vocab at 0x261a2724c18>,
#  '3': <gensim.models.keyedvectors.Vocab at 0x261a2724c50>,
#  'soles': <gensim.models.keyedvectors.Vocab at 0x261a2724c88>,
#  'pagar': <gensim.models.keyedvectors.Vocab at 0x261a2724cc0>,
#  'menú': <gensim.models.keyedvectors.Vocab at 0x261a2724cf8>,
#  'actualización': <gensim.models.keyedvectors.Vocab at 0x261a2724d68>,
#  'fiscal': <gensim.models.keyedvectors.Vocab at 0x261a2724da0>,
#  'josé': <gensim.models.keyedvectors.Vocab at 0x261a2724dd8>,
#  'domingo': <gensim.models.keyedvectors.Vocab at 0x261a2724e10>,
#  'pérez': <gensim.models.keyedvectors.Vocab at 0x261a2724e48>,
#  'reprogramó': <gensim.models.keyedvectors.Vocab at 0x261a2724e80>,
#  'interrogatorio': <gensim.models.keyedvectors.Vocab at 0x261a2724eb8>,
#  'exasesor': <gensim.models.keyedvectors.Vocab at 0x261a2724ef0>,
#  'presidencial': <gensim.models.keyedvectors.Vocab at 0x261a2724f28>,
#  'vladimiro': <gensim.models.keyedvectors.Vocab at 0x261a2724f60>,
#  'montesinos': <gensim.models.keyedvectors.Vocab at 0x261a2724f98>,
#  'lunes': <gensim.models.keyedvectors.Vocab at 0x261a2724fd0>,
#  '7': <gensim.models.keyedvectors.Vocab at 0x261a2724278>,
#  'octubre': <gensim.models.keyedvectors.Vocab at 0x261a2724048>,
#  'disposición': <gensim.models.keyedvectors.Vocab at 0x261a2724080>,
#  'accedió': <gensim.models.keyedvectors.Vocab at 0x261a27240b8>,
#  'cambio': <gensim.models.keyedvectors.Vocab at 0x261a27240f0>,
#  'fecha': <gensim.models.keyedvectors.Vocab at 0x261a2724128>,
#  'participar': <gensim.models.keyedvectors.Vocab at 0x261a2724160>,
#  'audiencias': <gensim.models.keyedvectors.Vocab at 0x261a2724198>,
#  'convocadas': <gensim.models.keyedvectors.Vocab at 0x261a27241d0>,
#  'penal': <gensim.models.keyedvectors.Vocab at 0x261a2724208>,
#  'superior': <gensim.models.keyedvectors.Vocab at 0x261a2724240>,
#  'transitoria': <gensim.models.keyedvectors.Vocab at 0x261a23727b8>,
#  'corte': <gensim.models.keyedvectors.Vocab at 0x261a23725c0>,
#  'especializada': <gensim.models.keyedvectors.Vocab at 0x261a2372780>,
#  'analizar': <gensim.models.keyedvectors.Vocab at 0x261a2372d68>,
#  'casos': <gensim.models.keyedvectors.Vocab at 0x261a23314e0>,
#  'derechos': <gensim.models.keyedvectors.Vocab at 0x261a226ca58>,
#  'humanos': <gensim.models.keyedvectors.Vocab at 0x261a226cc50>,
#  'pedro': <gensim.models.keyedvectors.Vocab at 0x261a226c048>,
#  'huilca': <gensim.models.keyedvectors.Vocab at 0x261a226c4a8>,
#  'mariella': <gensim.models.keyedvectors.Vocab at 0x261a226c6a0>,
#  'barreto': <gensim.models.keyedvectors.Vocab at 0x261a226c908>,
#  'imposible': <gensim.models.keyedvectors.Vocab at 0x261a23deac8>,
#  'doc': <gensim.models.keyedvectors.Vocab at 0x261a23deda0>,
#  'responder': <gensim.models.keyedvectors.Vocab at 0x261a23defd0>,
#  'interrogantes': <gensim.models.keyedvectors.Vocab at 0x261a23de080>,
#  'documento': <gensim.models.keyedvectors.Vocab at 0x261a23de128>,
#  'señala': <gensim.models.keyedvectors.Vocab at 0x261a23de470>,
#  '14': <gensim.models.keyedvectors.Vocab at 0x261a23de5c0>,
#  'tomará': <gensim.models.keyedvectors.Vocab at 0x261a23de748>,
#  'declaración': <gensim.models.keyedvectors.Vocab at 0x261a23de860>,
#  'eduardo': <gensim.models.keyedvectors.Vocab at 0x261a3f06048>,
#  'felipe': <gensim.models.keyedvectors.Vocab at 0x261a3f06080>,
#  'cabrera': <gensim.models.keyedvectors.Vocab at 0x261a3f060f0>,
#  'ganoza': <gensim.models.keyedvectors.Vocab at 0x261a3f06128>,
#  'congresista': <gensim.models.keyedvectors.Vocab at 0x261a3f06160>,
#  'república': <gensim.models.keyedvectors.Vocab at 0x261a3f06198>,
#  'ica': <gensim.models.keyedvectors.Vocab at 0x261a3f061d0>,
#  'representando': <gensim.models.keyedvectors.Vocab at 0x261a3f06278>,
#  'fuerza': <gensim.models.keyedvectors.Vocab at 0x261a3f062b0>,
#  '2011': <gensim.models.keyedvectors.Vocab at 0x261a3f06320>,
#  'postuló': <gensim.models.keyedvectors.Vocab at 0x261a3f06358>,
#  'presidente': <gensim.models.keyedvectors.Vocab at 0x261a3f06390>,
#  'regional': <gensim.models.keyedvectors.Vocab at 0x261a3f06438>,
#  'nota': <gensim.models.keyedvectors.Vocab at 0x261a3f065f8>,
#  'original': <gensim.models.keyedvectors.Vocab at 0x261a3f06630>,
#  'martes': <gensim.models.keyedvectors.Vocab at 0x261a3f066d8>,
#  'irá': <gensim.models.keyedvectors.Vocab at 0x261a3f06748>,
#  'base': <gensim.models.keyedvectors.Vocab at 0x261a3f067b8>,
#  'naval': <gensim.models.keyedvectors.Vocab at 0x261a3f06860>,
#  'interrogar': <gensim.models.keyedvectors.Vocab at 0x261a3f06898>,
#  'purga': <gensim.models.keyedvectors.Vocab at 0x261a3f06908>,
#  'condena': <gensim.models.keyedvectors.Vocab at 0x261a3f06940>,
#  'distintos': <gensim.models.keyedvectors.Vocab at 0x261a3f069b0>,
#  'delitos': <gensim.models.keyedvectors.Vocab at 0x261a3f06a58>,
#  'cometidos': <gensim.models.keyedvectors.Vocab at 0x261a3f06a90>,
#  'gobierno': <gensim.models.keyedvectors.Vocab at 0x261a3f06ac8>,
#  'alberto': <gensim.models.keyedvectors.Vocab at 0x261a3f06b00>,
#  'fujimori': <gensim.models.keyedvectors.Vocab at 0x261a3f06b38>,
#  'diligencia': <gensim.models.keyedvectors.Vocab at 0x261a3f06c18>,
#  'fijada': <gensim.models.keyedvectors.Vocab at 0x261a3f06c50>,
#  '10': <gensim.models.keyedvectors.Vocab at 0x261a3f06d68>,
#  'mañana': <gensim.models.keyedvectors.Vocab at 0x261a3f06da0>,
#  'especial': <gensim.models.keyedvectors.Vocab at 0x261a3f06dd8>,
#  'lava': <gensim.models.keyedvectors.Vocab at 0x261a3f06eb8>,
#  'jato': <gensim.models.keyedvectors.Vocab at 0x261a3f06f28>,
#  'formulará': <gensim.models.keyedvectors.Vocab at 0x261a2502d68>,
#  'pliego': <gensim.models.keyedvectors.Vocab at 0x261a2502da0>,
#  'preguntas': <gensim.models.keyedvectors.Vocab at 0x261a2502e48>,
#  'encontrar': <gensim.models.keyedvectors.Vocab at 0x261a2502128>,
#  'luces': <gensim.models.keyedvectors.Vocab at 0x261a25021d0>,
#  'verdadero': <gensim.models.keyedvectors.Vocab at 0x261a2502278>,
#  'rol': <gensim.models.keyedvectors.Vocab at 0x261a25023c8>,
#  'cumplió': <gensim.models.keyedvectors.Vocab at 0x261a2502748>,
#  'abogado': <gensim.models.keyedvectors.Vocab at 0x261a2502860>,
#  'vicente': <gensim.models.keyedvectors.Vocab at 0x261a2502908>,
#  'silva': <gensim.models.keyedvectors.Vocab at 0x261a25029e8>,
#  'checa': <gensim.models.keyedvectors.Vocab at 0x261a2502d30>,
#  'campaña': <gensim.models.keyedvectors.Vocab at 0x261a3e82978>,
#  '2016': <gensim.models.keyedvectors.Vocab at 0x261a3e829b0>,
#  'tesis': <gensim.models.keyedvectors.Vocab at 0x261a3e82a20>,
#  'lidera': <gensim.models.keyedvectors.Vocab at 0x261a3e82a90>,
#  'keiko': <gensim.models.keyedvectors.Vocab at 0x261a3e82ac8>,
#  'recibido': <gensim.models.keyedvectors.Vocab at 0x261a3e82b00>,
#  'aportes': <gensim.models.keyedvectors.Vocab at 0x261a3e82b38>,
#  'irregulares': <gensim.models.keyedvectors.Vocab at 0x261a3e82b70>,
#  'constructora': <gensim.models.keyedvectors.Vocab at 0x261a3e82c18>,
#  'brasileña': <gensim.models.keyedvectors.Vocab at 0x261a3e82c50>,
#  'odebrecht': <gensim.models.keyedvectors.Vocab at 0x261a3e82cf8>,
#  'financiamiento': <gensim.models.keyedvectors.Vocab at 0x261a3e82d30>,
#  'motivo': <gensim.models.keyedvectors.Vocab at 0x261a3e82da0>,
#  'lideresa': <gensim.models.keyedvectors.Vocab at 0x261a3e82fd0>,
#  'cumple': <gensim.models.keyedvectors.Vocab at 0x261a3e82080>,
#  'orden': <gensim.models.keyedvectors.Vocab at 0x261a3e820b8>,
#  'prisión': <gensim.models.keyedvectors.Vocab at 0x261a3e82160>,
#  'preventiva': <gensim.models.keyedvectors.Vocab at 0x261a3e82198>,
#  '18': <gensim.models.keyedvectors.Vocab at 0x261a3e82240>,
#  'lavado': <gensim.models.keyedvectors.Vocab at 0x261a3e822e8>,
#  'activos': <gensim.models.keyedvectors.Vocab at 0x261a3e82320>,
#  'ministerio': <gensim.models.keyedvectors.Vocab at 0x261a3e823c8>,
#  'público': <gensim.models.keyedvectors.Vocab at 0x261a3e82470>,
#  'sindica': <gensim.models.keyedvectors.Vocab at 0x261a3e82550>,
#  'asesor': <gensim.models.keyedvectors.Vocab at 0x261a3e82588>,
#  'sombras': <gensim.models.keyedvectors.Vocab at 0x261a3e826a0>,
#  'higuchi': <gensim.models.keyedvectors.Vocab at 0x261a3e826d8>,
#  'consiguiente': <gensim.models.keyedvectors.Vocab at 0x261a3e82710>,
#  'presunta': <gensim.models.keyedvectors.Vocab at 0x261a3e827b8>,
#  'organización': <gensim.models.keyedvectors.Vocab at 0x261a3e82860>,
#  'criminal': <gensim.models.keyedvectors.Vocab at 0x261a3e82898>,
#  'enquistado': <gensim.models.keyedvectors.Vocab at 0x261a3e828d0>,
#  'relación': <gensim.models.keyedvectors.Vocab at 0x261a3e7e7f0>,
#  'señalado': <gensim.models.keyedvectors.Vocab at 0x261a3e7e0b8>,
#  'testaferros': <gensim.models.keyedvectors.Vocab at 0x261a3e7e198>,
#  'vladivideo': <gensim.models.keyedvectors.Vocab at 0x261a3e7e2e8>,
#  'compra': <gensim.models.keyedvectors.Vocab at 0x261a3e7e358>,
#  'línea': <gensim.models.keyedvectors.Vocab at 0x261a3e7e390>,
#  'editorial': <gensim.models.keyedvectors.Vocab at 0x261a3e7e5c0>,
#  'cable': <gensim.models.keyedvectors.Vocab at 0x261a3e7e898>,
#  'canal': <gensim.models.keyedvectors.Vocab at 0x261a3e7ea90>,
#  'noticias': <gensim.models.keyedvectors.Vocab at 0x261a3e7eb70>,
#  'ccn': <gensim.models.keyedvectors.Vocab at 0x261a3e7ec18>,
#  'yolanda': <gensim.models.keyedvectors.Vocab at 0x261a3e7ec88>,
#  'rivera': <gensim.models.keyedvectors.Vocab at 0x261a3e7ee80>,
#  'mujer': <gensim.models.keyedvectors.Vocab at 0x261a3e7eef0>,
#  'murió': <gensim.models.keyedvectors.Vocab at 0x261a3e7ef98>,
#  'atacada': <gensim.models.keyedvectors.Vocab at 0x261a3e7efd0>,
#  'delincuentes': <gensim.models.keyedvectors.Vocab at 0x261a3e7f160>,
#  'huían': <gensim.models.keyedvectors.Vocab at 0x261a3e7f2b0>,
#  'policía': <gensim.models.keyedvectors.Vocab at 0x261a3e7f358>,
#  'distrito': <gensim.models.keyedvectors.Vocab at 0x261a3e7f518>,
#  'surco': <gensim.models.keyedvectors.Vocab at 0x261a3e7f7b8>,
#  'pidió': <gensim.models.keyedvectors.Vocab at 0x261a3e7f828>,
#  'realicen': <gensim.models.keyedvectors.Vocab at 0x261a3e7f860>,
#  'necesarias': <gensim.models.keyedvectors.Vocab at 0x261a3e7f978>,
#  'capturar': <gensim.models.keyedvectors.Vocab at 0x261a3e7f9e8>,
#  'criminales': <gensim.models.keyedvectors.Vocab at 0x261a3e7fb38>,
#  'hija': <gensim.models.keyedvectors.Vocab at 0x261a3e7fe48>,
#  'hombre': <gensim.models.keyedvectors.Vocab at 0x261a23a8c18>,
#  'conmocionado': <gensim.models.keyedvectors.Vocab at 0x261a23a8d30>,
#  'determina': <gensim.models.keyedvectors.Vocab at 0x261a23a8d68>,
#  'bala': <gensim.models.keyedvectors.Vocab at 0x261a23a8eb8>,
#  'impactó': <gensim.models.keyedvectors.Vocab at 0x261a23a8f98>,
#  'policías': <gensim.models.keyedvectors.Vocab at 0x261a23a8550>,
#  'ladrones': <gensim.models.keyedvectors.Vocab at 0x261a23a89e8>,
#  'culparse': <gensim.models.keyedvectors.Vocab at 0x261a23a8128>,
#  'efectivos': <gensim.models.keyedvectors.Vocab at 0x261a23a8b00>,
#  'cumplían': <gensim.models.keyedvectors.Vocab at 0x261a225dc18>,
#  'culpen': <gensim.models.keyedvectors.Vocab at 0x261a225d2b0>,
#  'colegas': <gensim.models.keyedvectors.Vocab at 0x261a225d438>,
#  'seguiré': <gensim.models.keyedvectors.Vocab at 0x261a225d828>,
#  'siéndolo': <gensim.models.keyedvectors.Vocab at 0x261a25bbac8>,
#  'muera': <gensim.models.keyedvectors.Vocab at 0x261a25bb2b0>,
#  'oficial': <gensim.models.keyedvectors.Vocab at 0x261a25bb2e8>,
#  'retiro': <gensim.models.keyedvectors.Vocab at 0x261a25bb320>,
#  'necesita': <gensim.models.keyedvectors.Vocab at 0x261a25bb358>,
#  'urgencia': <gensim.models.keyedvectors.Vocab at 0x261a25bb3c8>,
#  'país': <gensim.models.keyedvectors.Vocab at 0x261a25bb400>,
#  'empezando': <gensim.models.keyedvectors.Vocab at 0x261a25bb438>,
#  'falta': <gensim.models.keyedvectors.Vocab at 0x261a25bb4a8>,
#  'intervengan': <gensim.models.keyedvectors.Vocab at 0x261a25bb550>,
#  'vendan': <gensim.models.keyedvectors.Vocab at 0x261a25bb5c0>,
#  'dinero': <gensim.models.keyedvectors.Vocab at 0x261a25bb710>,
#  'impartan': <gensim.models.keyedvectors.Vocab at 0x261a25bb748>,
#  'quiénes': <gensim.models.keyedvectors.Vocab at 0x261a25bb828>,
#  'corruptos': <gensim.models.keyedvectors.Vocab at 0x261a25bb860>,
#  'corrupta': <gensim.models.keyedvectors.Vocab at 0x261a25bb898>,
#  'manipulan': <gensim.models.keyedvectors.Vocab at 0x261a25bb8d0>,
#  'juez': <gensim.models.keyedvectors.Vocab at 0x261a25bb908>,
#  'pobre': <gensim.models.keyedvectors.Vocab at 0x261a25bb940>,
#  'mete': <gensim.models.keyedvectors.Vocab at 0x261a25bb9e8>,
#  'balazo': <gensim.models.keyedvectors.Vocab at 0x261a25bba20>,
#  'choro': <gensim.models.keyedvectors.Vocab at 0x261a25bbb00>,
#  'queda': <gensim.models.keyedvectors.Vocab at 0x261a25bbb38>,
#  'preso': <gensim.models.keyedvectors.Vocab at 0x261a25bbb70>,
#  'pido': <gensim.models.keyedvectors.Vocab at 0x261a25bbba8>,
#  'luchen': <gensim.models.keyedvectors.Vocab at 0x261a25bbc18>,
#  'quiero': <gensim.models.keyedvectors.Vocab at 0x261a25bbc50>,
#  'capture': <gensim.models.keyedvectors.Vocab at 0x261a25bbc88>,
#  'interesa': <gensim.models.keyedvectors.Vocab at 0x261a25bbcf8>,
#  'balas': <gensim.models.keyedvectors.Vocab at 0x261a25bbd30>,
#  'muerta': <gensim.models.keyedvectors.Vocab at 0x261a25bbd68>,
#  'culpa': <gensim.models.keyedvectors.Vocab at 0x261a25bbda0>,
#  'única': <gensim.models.keyedvectors.Vocab at 0x261a25bbe10>,
#  'quebrarse': <gensim.models.keyedvectors.Vocab at 0x261a25bbe80>,
#  'datos': <gensim.models.keyedvectors.Vocab at 0x261a25bbeb8>,
#  '29': <gensim.models.keyedvectors.Vocab at 0x261a25bbef0>,
#  'casquillos': <gensim.models.keyedvectors.Vocab at 0x261a25bbf28>,
#  'encontraron': <gensim.models.keyedvectors.Vocab at 0x261a25bbf98>,
#  'balacera': <gensim.models.keyedvectors.Vocab at 0x261a25bb048>,
#  'molina': <gensim.models.keyedvectors.Vocab at 0x261a25bb080>,
#  'esposo': <gensim.models.keyedvectors.Vocab at 0x261a25bb0f0>,
#  'herido': <gensim.models.keyedvectors.Vocab at 0x261a25bb160>,
#  'brazo': <gensim.models.keyedvectors.Vocab at 0x261a25bb1d0>,
#  'exjuez': <gensim.models.keyedvectors.Vocab at 0x261a25bb240>,
#  'supremo': <gensim.models.keyedvectors.Vocab at 0x261a25bba90>,
#  'césar': <gensim.models.keyedvectors.Vocab at 0x261a2659630>,
#  'hinostroza': <gensim.models.keyedvectors.Vocab at 0x261a2659048>,
#  'confirmó': <gensim.models.keyedvectors.Vocab at 0x261a2659128>,
#  'recurrirá': <gensim.models.keyedvectors.Vocab at 0x261a2659160>,
#  'tribunal': <gensim.models.keyedvectors.Vocab at 0x261a2659198>,
#  'constitucional': <gensim.models.keyedvectors.Vocab at 0x261a26592b0>,
#  'españa': <gensim.models.keyedvectors.Vocab at 0x261a2659320>,
#  'buscar': <gensim.models.keyedvectors.Vocab at 0x261a2659390>,
#  'anular': <gensim.models.keyedvectors.Vocab at 0x261a26593c8>,
#  'extradición': <gensim.models.keyedvectors.Vocab at 0x261a2659438>,
#  'aprobada': <gensim.models.keyedvectors.Vocab at 0x261a2659470>,
#  'audiencia': <gensim.models.keyedvectors.Vocab at 0x261a26594a8>,
#  'difundido': <gensim.models.keyedvectors.Vocab at 0x261a2659550>,
#  'rpp': <gensim.models.keyedvectors.Vocab at 0x261a2659588>,
#  'asegura': <gensim.models.keyedvectors.Vocab at 0x261a26595c0>,
#  'sentencia': <gensim.models.keyedvectors.Vocab at 0x261a26595f8>,
#  'rechazó': <gensim.models.keyedvectors.Vocab at 0x261a2659668>,
#  'repatriación': <gensim.models.keyedvectors.Vocab at 0x261a26596d8>,
#  'cuestionó': <gensim.models.keyedvectors.Vocab at 0x261a2659710>,
#  'aceptado': <gensim.models.keyedvectors.Vocab at 0x261a2659780>,
#  'imputan': <gensim.models.keyedvectors.Vocab at 0x261a2659860>,
#  'conformes': <gensim.models.keyedvectors.Vocab at 0x261a2659898>,
#  'rechazo': <gensim.models.keyedvectors.Vocab at 0x261a26598d0>,
#  'patrocinio': <gensim.models.keyedvectors.Vocab at 0x261a2659908>,
#  'ilegal': <gensim.models.keyedvectors.Vocab at 0x261a2659978>,
#  'tráfico': <gensim.models.keyedvectors.Vocab at 0x261a26599e8>,
#  'influencias': <gensim.models.keyedvectors.Vocab at 0x261a2659a20>,
#  'negociación': <gensim.models.keyedvectors.Vocab at 0x261a2659a58>,
#  'incompatible': <gensim.models.keyedvectors.Vocab at 0x261a2659a90>,
#  'españoles': <gensim.models.keyedvectors.Vocab at 0x261a2659b00>,
#  'erróneamente': <gensim.models.keyedvectors.Vocab at 0x261a2659b38>,
#  'interpretado': <gensim.models.keyedvectors.Vocab at 0x261a2659b70>,
#  'exmagistrado': <gensim.models.keyedvectors.Vocab at 0x261a2659ba8>,
#  'interponer': <gensim.models.keyedvectors.Vocab at 0x261a2659be0>,
#  'recurso': <gensim.models.keyedvectors.Vocab at 0x261a2659c18>,
#  'amparo': <gensim.models.keyedvectors.Vocab at 0x261a2659c50>,
#  'español': <gensim.models.keyedvectors.Vocab at 0x261a2659c88>,
#  'eventualmente': <gensim.models.keyedvectors.Vocab at 0x261a2659cc0>,
#  'europeo': <gensim.models.keyedvectors.Vocab at 0x261a2659cf8>,
#  'defensa': <gensim.models.keyedvectors.Vocab at 0x261a2659d68>,
#  'carácter': <gensim.models.keyedvectors.Vocab at 0x261a2659dd8>,
#  'universal': <gensim.models.keyedvectors.Vocab at 0x261a2659e10>,
#  'reiteró': <gensim.models.keyedvectors.Vocab at 0x261a2659e48>,
#  'imputados': <gensim.models.keyedvectors.Vocab at 0x261a2659e80>,
#  'aprobados': <gensim.models.keyedvectors.Vocab at 0x261a2659f28>,
#  'congreso': <gensim.models.keyedvectors.Vocab at 0x261a2659f60>,
#  'actuó': <gensim.models.keyedvectors.Vocab at 0x261a2659fd0>,
#  'presión': <gensim.models.keyedvectors.Vocab at 0x261a271d518>,
#  'ley': <gensim.models.keyedvectors.Vocab at 0x261a271d6d8>,
#  'española': <gensim.models.keyedvectors.Vocab at 0x261a271d710>,
#  'penalistas': <gensim.models.keyedvectors.Vocab at 0x261a271d748>,
#  'sindicado': <gensim.models.keyedvectors.Vocab at 0x261a271d7b8>,
#  'cabecilla': <gensim.models.keyedvectors.Vocab at 0x261a271d7f0>,
#  'cuellos': <gensim.models.keyedvectors.Vocab at 0x261a271d828>,
#  'blancos': <gensim.models.keyedvectors.Vocab at 0x261a271d860>,
#  'puerto': <gensim.models.keyedvectors.Vocab at 0x261a271d898>,
#  'pesan': <gensim.models.keyedvectors.Vocab at 0x261a271d8d0>,
#  'órdenes': <gensim.models.keyedvectors.Vocab at 0x261a271d908>,
#  'caso': <gensim.models.keyedvectors.Vocab at 0x261a271d940>,
#  'salido': <gensim.models.keyedvectors.Vocab at 0x261a271d978>,
#  'pese': <gensim.models.keyedvectors.Vocab at 0x261a271d9b0>,
#  'impedimento': <gensim.models.keyedvectors.Vocab at 0x261a271d9e8>,
#  'abandonar': <gensim.models.keyedvectors.Vocab at 0x261a271da20>,
#  'perú': <gensim.models.keyedvectors.Vocab at 0x261a271da58>,
#  'salir': <gensim.models.keyedvectors.Vocab at 0x261a271da90>,
#  'internacional': <gensim.models.keyedvectors.Vocab at 0x261a271dac8>,
#  'respetan': <gensim.models.keyedvectors.Vocab at 0x261a271db00>,
#  'evadir': <gensim.models.keyedvectors.Vocab at 0x261a271db38>,
#  'fugar': <gensim.models.keyedvectors.Vocab at 0x261a271db70>,
#  'falsamente': <gensim.models.keyedvectors.Vocab at 0x261a271dba8>,
#  'menciona': <gensim.models.keyedvectors.Vocab at 0x261a271dbe0>,
#  'saludado': <gensim.models.keyedvectors.Vocab at 0x261a271dc18>,
#  'extraditarlo': <gensim.models.keyedvectors.Vocab at 0x261a271dc50>,
#  'sigan': <gensim.models.keyedvectors.Vocab at 0x261a271dc88>,
#  'acusando': <gensim.models.keyedvectors.Vocab at 0x261a271dcc0>,
#  'espero': <gensim.models.keyedvectors.Vocab at 0x261a271dcf8>,
#  'dejen': <gensim.models.keyedvectors.Vocab at 0x261a271dd30>,
#  'dignidad': <gensim.models.keyedvectors.Vocab at 0x261a271dd68>,
#  'humana': <gensim.models.keyedvectors.Vocab at 0x261a271ddd8>,
#  'horas': <gensim.models.keyedvectors.Vocab at 0x261a271de10>,
#  'oficina': <gensim.models.keyedvectors.Vocab at 0x261a271de48>,
#  'volvían': <gensim.models.keyedvectors.Vocab at 0x261a271de80>,
#  'eternas': <gensim.models.keyedvectors.Vocab at 0x261a271deb8>,
# ...
#  'inconclusos': <gensim.models.keyedvectors.Vocab at 0x261a271d438>,
#  'finalizar': <gensim.models.keyedvectors.Vocab at 0x261a271d470>,
#  'escuela': <gensim.models.keyedvectors.Vocab at 0x261a271d4a8>,
#  'cocinero': <gensim.models.keyedvectors.Vocab at 0x261a271d4e0>,
#  'regresaría': <gensim.models.keyedvectors.Vocab at 0x261a271d550>,
#  'tarde': <gensim.models.keyedvectors.Vocab at 0x261a271d588>,
#  'perteneció': <gensim.models.keyedvectors.Vocab at 0x261a271d5c0>,
#  'empresas': <gensim.models.keyedvectors.Vocab at 0x261a271d5f8>,
#  'importantes': <gensim.models.keyedvectors.Vocab at 0x261a271d630>,
#  'semanas': <gensim.models.keyedvectors.Vocab at 0x261a271d668>,
#  'llegaban': <gensim.models.keyedvectors.Vocab at 0x261a271d6a0>,
#  'ajenas': <gensim.models.keyedvectors.Vocab at 0x261a22328d0>,
#  'debía': <gensim.models.keyedvectors.Vocab at 0x261a22b07f0>,
#  'encaminar': <gensim.models.keyedvectors.Vocab at 0x261a2481198>,
#  'pensó': <gensim.models.keyedvectors.Vocab at 0x261a2481240>,
#  'destino': <gensim.models.keyedvectors.Vocab at 0x261a2481390>,
#  'saco': <gensim.models.keyedvectors.Vocab at 0x261a2481710>,
#  'corbata': <gensim.models.keyedvectors.Vocab at 0x261a2481780>,
#  'sentado': <gensim.models.keyedvectors.Vocab at 0x261a2481c50>,
#  'frente': <gensim.models.keyedvectors.Vocab at 0x261a2481be0>,
#  'pantalla': <gensim.models.keyedvectors.Vocab at 0x261a23ea668>,
#  'escritorio': <gensim.models.keyedvectors.Vocab at 0x261a23ea860>,
#  'viaje': <gensim.models.keyedvectors.Vocab at 0x261a23eaac8>,
#  'sao': <gensim.models.keyedvectors.Vocab at 0x261a23eadd8>,
#  'paulo': <gensim.models.keyedvectors.Vocab at 0x261a22615c0>,
#  'probó': <gensim.models.keyedvectors.Vocab at 0x261a2261a90>,
#  'pizza': <gensim.models.keyedvectors.Vocab at 0x261a2261b00>,
#  'común': <gensim.models.keyedvectors.Vocab at 0x261a2261d68>,
#  'insumos': <gensim.models.keyedvectors.Vocab at 0x261a2642ba8>,
#  'brasileños': <gensim.models.keyedvectors.Vocab at 0x261a2642cc0>,
#  'masa': <gensim.models.keyedvectors.Vocab at 0x261a2642cf8>,
#  'tradicional': <gensim.models.keyedvectors.Vocab at 0x261a2642d30>,
#  'dejando': <gensim.models.keyedvectors.Vocab at 0x261a2642d68>,
#  'típica': <gensim.models.keyedvectors.Vocab at 0x261a2642da0>,
#  'americana': <gensim.models.keyedvectors.Vocab at 0x261a2642e10>,
#  'pepperoni': <gensim.models.keyedvectors.Vocab at 0x261a2642e48>,
#  'allí': <gensim.models.keyedvectors.Vocab at 0x261a2642048>,
#  'supo': <gensim.models.keyedvectors.Vocab at 0x261a2642080>,
#  'cuál': <gensim.models.keyedvectors.Vocab at 0x261a26420b8>,
#  'camino': <gensim.models.keyedvectors.Vocab at 0x261a26420f0>,
#  'jefes': <gensim.models.keyedvectors.Vocab at 0x261a2642128>,
#  'inauguró': <gensim.models.keyedvectors.Vocab at 0x261a2642198>,
#  'oficialmente': <gensim.models.keyedvectors.Vocab at 0x261a26421d0>,
#  'agosto': <gensim.models.keyedvectors.Vocab at 0x261a2642208>,
#  '2017': <gensim.models.keyedvectors.Vocab at 0x261a2642240>,
#  'surquillo': <gensim.models.keyedvectors.Vocab at 0x261a26422b0>,
#  'ahorros': <gensim.models.keyedvectors.Vocab at 0x261a2642eb8>,
#  'bastaron': <gensim.models.keyedvectors.Vocab at 0x261a2642f28>,
#  'alquilar': <gensim.models.keyedvectors.Vocab at 0x261a2642f60>,
#  'local': <gensim.models.keyedvectors.Vocab at 0x261a2642fd0>,
#  'adquirir': <gensim.models.keyedvectors.Vocab at 0x261a2642c88>,
#  'maquinaria': <gensim.models.keyedvectors.Vocab at 0x261a26422e8>,
#  'preguntaba': <gensim.models.keyedvectors.Vocab at 0x261a2642320>,
#  'metido': <gensim.models.keyedvectors.Vocab at 0x261a2642358>,
#  'mano': <gensim.models.keyedvectors.Vocab at 0x261a2642390>,
#  'empezó': <gensim.models.keyedvectors.Vocab at 0x261a26423c8>,
#  'platos': <gensim.models.keyedvectors.Vocab at 0x261a2642400>,
#  'adecuarlos': <gensim.models.keyedvectors.Vocab at 0x261a2642470>,
#  'vea': <gensim.models.keyedvectors.Vocab at 0x261a26424a8>,
#  'sepa': <gensim.models.keyedvectors.Vocab at 0x261a26424e0>,
#  'decidió': <gensim.models.keyedvectors.Vocab at 0x261a2642518>,
#  'negocio': <gensim.models.keyedvectors.Vocab at 0x261a2642550>,
#  'demandar': <gensim.models.keyedvectors.Vocab at 0x261a2642588>,
#  'tantas': <gensim.models.keyedvectors.Vocab at 0x261a26425c0>,
#  'creó': <gensim.models.keyedvectors.Vocab at 0x261a26425f8>,
#  'cocina': <gensim.models.keyedvectors.Vocab at 0x261a2642630>,
#  'fantasma': <gensim.models.keyedvectors.Vocab at 0x261a2642668>,
#  'producción': <gensim.models.keyedvectors.Vocab at 0x261a26426a0>,
#  'repartida': <gensim.models.keyedvectors.Vocab at 0x261a26426d8>,
#  'horario': <gensim.models.keyedvectors.Vocab at 0x261a2642710>,
#  '6': <gensim.models.keyedvectors.Vocab at 0x261a2642748>,
#  '11': <gensim.models.keyedvectors.Vocab at 0x261a2642780>,
#  'pm': <gensim.models.keyedvectors.Vocab at 0x261a26427f0>,
#  'intención': <gensim.models.keyedvectors.Vocab at 0x261a2642828>,
#  'imitar': <gensim.models.keyedvectors.Vocab at 0x261a2642860>,
#  'corriente': <gensim.models.keyedvectors.Vocab at 0x261a26428d0>,
#  'proviene': <gensim.models.keyedvectors.Vocab at 0x261a2642940>,
#  'europa': <gensim.models.keyedvectors.Vocab at 0x261a2642978>,
#  'asia': <gensim.models.keyedvectors.Vocab at 0x261a26429b0>,
#  'unidos': <gensim.models.keyedvectors.Vocab at 0x261a26429e8>,
#  'aplicó': <gensim.models.keyedvectors.Vocab at 0x261a2642a20>,
#  'teoría': <gensim.models.keyedvectors.Vocab at 0x261a2642a58>,
#  'empresa': <gensim.models.keyedvectors.Vocab at 0x261a2642a90>,
#  'presencia': <gensim.models.keyedvectors.Vocab at 0x261a2642ac8>,
#  'aplicaciones': <gensim.models.keyedvectors.Vocab at 0x261a2642b38>,
#  'físico': <gensim.models.keyedvectors.Vocab at 0x261a2642be0>,
#  'emprendimiento': <gensim.models.keyedvectors.Vocab at 0x261a2642c18>,
#  'agregado': <gensim.models.keyedvectors.Vocab at 0x261a2642c50>,
#  'cajas': <gensim.models.keyedvectors.Vocab at 0x261a2459908>,
#  'obras': <gensim.models.keyedvectors.Vocab at 0x261a2459ac8>,
#  'arte': <gensim.models.keyedvectors.Vocab at 0x261a2459e80>,
#  'exhibe': <gensim.models.keyedvectors.Vocab at 0x261a2459080>,
#  'creaciones': <gensim.models.keyedvectors.Vocab at 0x261a24590b8>,
#  'ilustradores': <gensim.models.keyedvectors.Vocab at 0x261a24592e8>,
#  'temas': <gensim.models.keyedvectors.Vocab at 0x261a2459518>,
#  'nacionales': <gensim.models.keyedvectors.Vocab at 0x261a2459860>,
#  'lema': <gensim.models.keyedvectors.Vocab at 0x261a23b1dd8>,
#  'consenso': <gensim.models.keyedvectors.Vocab at 0x261a23b1f98>,
#  'u': <gensim.models.keyedvectors.Vocab at 0x261a23b13c8>,
#  'cambie': <gensim.models.keyedvectors.Vocab at 0x261a23b14a8>,
#  'lote': <gensim.models.keyedvectors.Vocab at 0x261a23b1748>,
#  'primeras': <gensim.models.keyedvectors.Vocab at 0x261a23b1780>,
#  'diseñadas': <gensim.models.keyedvectors.Vocab at 0x261a22b5748>,
#  'rojas': <gensim.models.keyedvectors.Vocab at 0x261a22b5898>,
#  'perros': <gensim.models.keyedvectors.Vocab at 0x261a22b5c88>,
#  'alpaca': <gensim.models.keyedvectors.Vocab at 0x261a22b5d68>,
#  'temporada': <gensim.models.keyedvectors.Vocab at 0x261a25c4048>,
#  'alegre': <gensim.models.keyedvectors.Vocab at 0x261a25c4198>,
#  'llegue': <gensim.models.keyedvectors.Vocab at 0x261a25c41d0>,
#  'hogares': <gensim.models.keyedvectors.Vocab at 0x261a25c42b0>,
#  'limeños': <gensim.models.keyedvectors.Vocab at 0x261a25c42e8>,
#  'aureola': <gensim.models.keyedvectors.Vocab at 0x261a25c4320>,
#  'princesa': <gensim.models.keyedvectors.Vocab at 0x261a25c4390>,
#  'promueve': <gensim.models.keyedvectors.Vocab at 0x261a25c43c8>,
#  'peruano': <gensim.models.keyedvectors.Vocab at 0x261a25c4438>,
#  'voltee': <gensim.models.keyedvectors.Vocab at 0x261a25c4470>,
#  'éxito': <gensim.models.keyedvectors.Vocab at 0x261a25c44a8>,
#  'vertiginoso': <gensim.models.keyedvectors.Vocab at 0x261a25c4518>,
#  '2x1': <gensim.models.keyedvectors.Vocab at 0x261a25c4588>,
#  'distribuir': <gensim.models.keyedvectors.Vocab at 0x261a25c45c0>,
#  'pizzas': <gensim.models.keyedvectors.Vocab at 0x261a25c45f8>,
#  'comensales': <gensim.models.keyedvectors.Vocab at 0x261a25c46a0>,
#  'enamoraron': <gensim.models.keyedvectors.Vocab at 0x261a25c4710>,
#  'sabores': <gensim.models.keyedvectors.Vocab at 0x261a25c4828>,
#  'langostinos': <gensim.models.keyedvectors.Vocab at 0x261a25c4940>,
#  'anticucheros': <gensim.models.keyedvectors.Vocab at 0x261a25c49b0>,
#  'lanzado': <gensim.models.keyedvectors.Vocab at 0x261a25c4ac8>,
#  'verano': <gensim.models.keyedvectors.Vocab at 0x261a25c4c50>,
#  'quedado': <gensim.models.keyedvectors.Vocab at 0x261a25c4c88>,
#  'butifarra': <gensim.models.keyedvectors.Vocab at 0x261a25c4cc0>,
#  'huachana': <gensim.models.keyedvectors.Vocab at 0x261a25c4d68>,
#  'llegar': <gensim.models.keyedvectors.Vocab at 0x261a25c4dd8>,
#  'plasmar': <gensim.models.keyedvectors.Vocab at 0x261a25c4e10>,
#  'idea': <gensim.models.keyedvectors.Vocab at 0x261a25c4e48>,
#  'unir': <gensim.models.keyedvectors.Vocab at 0x261a25c4eb8>,
#  'tradiciones': <gensim.models.keyedvectors.Vocab at 0x261a25c4ef0>,
#  'italiana': <gensim.models.keyedvectors.Vocab at 0x261a25c4f28>,
#  'difícil': <gensim.models.keyedvectors.Vocab at 0x261a25c4f60>,
#  'constante': <gensim.models.keyedvectors.Vocab at 0x261a25c4f98>,
#  'prueba': <gensim.models.keyedvectors.Vocab at 0x261a25c4fd0>,
#  'error': <gensim.models.keyedvectors.Vocab at 0x261a25c6048>,
#  'parecían': <gensim.models.keyedvectors.Vocab at 0x261a25c6080>,
#  'contundentes': <gensim.models.keyedvectors.Vocab at 0x261a25c6160>,
#  'faltaba': <gensim.models.keyedvectors.Vocab at 0x261a25c6198>,
#  'arroz': <gensim.models.keyedvectors.Vocab at 0x261a25c6208>,
#  'bota': <gensim.models.keyedvectors.Vocab at 0x261a25c6240>,
#  'carcajada': <gensim.models.keyedvectors.Vocab at 0x261a25c6278>,
#  'cómplice': <gensim.models.keyedvectors.Vocab at 0x261a25c62e8>,
#  'colaboradores': <gensim.models.keyedvectors.Vocab at 0x261a25c6320>,
#  'desarrollado': <gensim.models.keyedvectors.Vocab at 0x261a25c6358>,
#  'entramos': <gensim.models.keyedvectors.Vocab at 0x261a25c6390>,
#  'fase': <gensim.models.keyedvectors.Vocab at 0x261a25c63c8>,
#  'multiplicar': <gensim.models.keyedvectors.Vocab at 0x261a25c6400>,
#  'planea': <gensim.models.keyedvectors.Vocab at 0x261a25c6438>,
#  'meta': <gensim.models.keyedvectors.Vocab at 0x261a25c6470>,
#  'denominación': <gensim.models.keyedvectors.Vocab at 0x261a25c64a8>,
#  'mundial': <gensim.models.keyedvectors.Vocab at 0x261a25c64e0>,
#  'gringo': <gensim.models.keyedvectors.Vocab at 0x261a25c6630>,
#  'diga': <gensim.models.keyedvectors.Vocab at 0x261a25c6668>,
#  'are': <gensim.models.keyedvectors.Vocab at 0x261a25c66a0>,
#  'you': <gensim.models.keyedvectors.Vocab at 0x261a25c6748>,
#  'eating': <gensim.models.keyedvectors.Vocab at 0x261a25c67b8>,
#  'respondas': <gensim.models.keyedvectors.Vocab at 0x261a25c67f0>,
#  'rapidez': <gensim.models.keyedvectors.Vocab at 0x261a25c6828>,
#  'calidad': <gensim.models.keyedvectors.Vocab at 0x261a25c6898>,
#  'maneja': <gensim.models.keyedvectors.Vocab at 0x261a25c68d0>,
#  'fast': <gensim.models.keyedvectors.Vocab at 0x261a25c6940>,
#  'food': <gensim.models.keyedvectors.Vocab at 0x261a25c69e8>,
#  'estándares': <gensim.models.keyedvectors.Vocab at 0x261a25c6a20>,
#  'exactos': <gensim.models.keyedvectors.Vocab at 0x261a25c6a90>,
#  'señalización': <gensim.models.keyedvectors.Vocab at 0x261a25c6ac8>,
#  'porciones': <gensim.models.keyedvectors.Vocab at 0x261a25c6b70>,
#  'tiempos': <gensim.models.keyedvectors.Vocab at 0x261a25c6ba8>,
#  'digital': <gensim.models.keyedvectors.Vocab at 0x261a25c6c50>,
#  'facebook': <gensim.models.keyedvectors.Vocab at 0x261a25c6cc0>,
#  'lapiczaperu': <gensim.models.keyedvectors.Vocab at 0x261a25c6cf8>,
#  'rappi': <gensim.models.keyedvectors.Vocab at 0x261a25c6d30>,
#  'vital': <gensim.models.keyedvectors.Vocab at 0x261a25c6e10>,
#  'dejar': <gensim.models.keyedvectors.Vocab at 0x261a25c6e80>,
#  'escuchar': <gensim.models.keyedvectors.Vocab at 0x261a25c6ef0>,
#  'aconseja': <gensim.models.keyedvectors.Vocab at 0x261a25c6f28>,
#  'recomendaciones': <gensim.models.keyedvectors.Vocab at 0x261a25c6f60>,
#  'emprender': <gensim.models.keyedvectors.Vocab at 0x261a25c6f98>,
#  'resuelve': <gensim.models.keyedvectors.Vocab at 0x261a252f828>,
#  'pensar': <gensim.models.keyedvectors.Vocab at 0x261a252f048>,
#  'locura': <gensim.models.keyedvectors.Vocab at 0x261a252f080>,
#  'números': <gensim.models.keyedvectors.Vocab at 0x261a252f0b8>,
#  'equilibrio': <gensim.models.keyedvectors.Vocab at 0x261a252f0f0>,
#  'proyecciones': <gensim.models.keyedvectors.Vocab at 0x261a252f128>,
#  'futuro': <gensim.models.keyedvectors.Vocab at 0x261a252f198>,
#  'piensa': <gensim.models.keyedvectors.Vocab at 0x261a252f1d0>,
#  'generar': <gensim.models.keyedvectors.Vocab at 0x261a252f208>,
#  'franquicias': <gensim.models.keyedvectors.Vocab at 0x261a252f240>,
#  'caiga': <gensim.models.keyedvectors.Vocab at 0x261a252f278>,
#  'peso': <gensim.models.keyedvectors.Vocab at 0x261a252f320>,
#  'anhela': <gensim.models.keyedvectors.Vocab at 0x261a252f390>,
#  'imite': <gensim.models.keyedvectors.Vocab at 0x261a252f400>,
#  'cree': <gensim.models.keyedvectors.Vocab at 0x261a252f4e0>,
#  'genérico': <gensim.models.keyedvectors.Vocab at 0x261a252f5c0>,
#  'metió': <gensim.models.keyedvectors.Vocab at 0x261a252f630>,
#  'masificar': <gensim.models.keyedvectors.Vocab at 0x261a252f668>,
#  'producto': <gensim.models.keyedvectors.Vocab at 0x261a252f860>,
#  'sabor': <gensim.models.keyedvectors.Vocab at 0x261a252f898>,
#  'proporciones': <gensim.models.keyedvectors.Vocab at 0x261a252f908>,
#  'generosas': <gensim.models.keyedvectors.Vocab at 0x261a252f978>,
#  'gusta': <gensim.models.keyedvectors.Vocab at 0x261a252f9b0>,
#  'principal': <gensim.models.keyedvectors.Vocab at 0x261a252fa20>,
#  'motivación': <gensim.models.keyedvectors.Vocab at 0x261a252fac8>,
#  'cuestionas': <gensim.models.keyedvectors.Vocab at 0x261a252fb00>,
#  'veía': <gensim.models.keyedvectors.Vocab at 0x261a252fb70>,
#  'trabajando': <gensim.models.keyedvectors.Vocab at 0x261a252fba8>,
#  'empleado': <gensim.models.keyedvectors.Vocab at 0x261a252fc18>,
#  'di': <gensim.models.keyedvectors.Vocab at 0x261a252fc88>,
#  'quise': <gensim.models.keyedvectors.Vocab at 0x261a252fcc0>,
#  'aprobar': <gensim.models.keyedvectors.Vocab at 0x261a252fcf8>,
#  'dificultad': <gensim.models.keyedvectors.Vocab at 0x261a252fda0>,
#  'encontraste': <gensim.models.keyedvectors.Vocab at 0x261a252ff28>,
#  'superaste': <gensim.models.keyedvectors.Vocab at 0x261a252ff98>,
#  'cercana': <gensim.models.keyedvectors.Vocab at 0x261a3f540b8>,
#  'ayude': <gensim.models.keyedvectors.Vocab at 0x261a3f540f0>,
#  'asesorarse': <gensim.models.keyedvectors.Vocab at 0x261a3f54160>,
#  'pedir': <gensim.models.keyedvectors.Vocab at 0x261a3f54198>,
#  'ayuda': <gensim.models.keyedvectors.Vocab at 0x261a3f541d0>,
#  'ahorrado': <gensim.models.keyedvectors.Vocab at 0x261a3f542b0>,
#  'comprarme': <gensim.models.keyedvectors.Vocab at 0x261a3f542e8>,
#  'depa': <gensim.models.keyedvectors.Vocab at 0x261a3f54390>,
#  'decidí': <gensim.models.keyedvectors.Vocab at 0x261a3f543c8>,
#  'invertir': <gensim.models.keyedvectors.Vocab at 0x261a3f54438>,
#  'plata': <gensim.models.keyedvectors.Vocab at 0x261a3f54470>,
#  'contratan': <gensim.models.keyedvectors.Vocab at 0x261a3f54630>,
#  'decirles': <gensim.models.keyedvectors.Vocab at 0x261a3f546d8>,
#  'fortaleza': <gensim.models.keyedvectors.Vocab at 0x261a3f54710>,
#  'creer': <gensim.models.keyedvectors.Vocab at 0x261a3f54748>,
#  'crear': <gensim.models.keyedvectors.Vocab at 0x261a3f54860>,
#  'día': <gensim.models.keyedvectors.Vocab at 0x261a3f548d0>,
#  'casa': <gensim.models.keyedvectors.Vocab at 0x261a3f54908>,
#  'haga': <gensim.models.keyedvectors.Vocab at 0x261a3f54940>,
#  'vacilón': <gensim.models.keyedvectors.Vocab at 0x261a3f54978>,
#  'salchicha': <gensim.models.keyedvectors.Vocab at 0x261a3f549e8>,
#  'huacho': <gensim.models.keyedvectors.Vocab at 0x261a3f54a58>,
#  'gastronomía': <gensim.models.keyedvectors.Vocab at 0x261a3f54ac8>,
#  'mallory': <gensim.models.keyedvectors.Vocab at 0x261a3f54b38>,
#  'aco': <gensim.models.keyedvectors.Vocab at 0x261a3f54b70>,
#  'logró': <gensim.models.keyedvectors.Vocab at 0x261a3f54be0>,
#  'medalla': <gensim.models.keyedvectors.Vocab at 0x261a3f54c18>,
#  ...}

# %%
model.save('w2v300_5.model')

# %% [markdown]
# ### sizemodel 300 window 6

# %%
sentences = word2vec.Text8Corpus('corpus_general_news.txt')
sizeModel = 300
model = word2vec.Word2Vec(sentences, size=sizeModel, window=6, min_count=2, workers=cpu_count())

# %%
model.wv.vocab
# Out:
# {'presentadora': <gensim.models.keyedvectors.Vocab at 0x261a6571780>,
#  'exjurado': <gensim.models.keyedvectors.Vocab at 0x261a6963128>,
#  'artista': <gensim.models.keyedvectors.Vocab at 0x261a69633c8>,
#  'año': <gensim.models.keyedvectors.Vocab at 0x261a6963780>,
#  'fiorella': <gensim.models.keyedvectors.Vocab at 0x261a69637b8>,
#  'rodríguez': <gensim.models.keyedvectors.Vocab at 0x261a69637f0>,
#  '45': <gensim.models.keyedvectors.Vocab at 0x261a6963898>,
#  'presentó': <gensim.models.keyedvectors.Vocab at 0x261a69639b0>,
#  'dueño': <gensim.models.keyedvectors.Vocab at 0x261a6963a20>,
#  'corazón': <gensim.models.keyedvectors.Vocab at 0x261a6963ef0>,
#  'fotografías': <gensim.models.keyedvectors.Vocab at 0x261a678bc50>,
#  'instagram': <gensim.models.keyedvectors.Vocab at 0x261a678b668>,
#  'fanáticos': <gensim.models.keyedvectors.Vocab at 0x261a678b6a0>,
#  'tardaron': <gensim.models.keyedvectors.Vocab at 0x261a678beb8>,
#  'llenarle': <gensim.models.keyedvectors.Vocab at 0x261a678bfd0>,
#  'publicación': <gensim.models.keyedvectors.Vocab at 0x261a678b048>,
#  'emoticones': <gensim.models.keyedvectors.Vocab at 0x261a678b400>,
#  'corazones': <gensim.models.keyedvectors.Vocab at 0x261a678b4a8>,
#  'fotos': <gensim.models.keyedvectors.Vocab at 0x261a678b5f8>,
#  'observa': <gensim.models.keyedvectors.Vocab at 0x261a6777d68>,
#  'abrazando': <gensim.models.keyedvectors.Vocab at 0x261a67775f8>,
#  'muchacho': <gensim.models.keyedvectors.Vocab at 0x261a68b04e0>,
#  'mira': <gensim.models.keyedvectors.Vocab at 0x261a68b0588>,
#  'ternura': <gensim.models.keyedvectors.Vocab at 0x261a68b07f0>,
#  'captura': <gensim.models.keyedvectors.Vocab at 0x261a68b0908>,
#  'sonríe': <gensim.models.keyedvectors.Vocab at 0x261a68b0a90>,
#  'compartiendo': <gensim.models.keyedvectors.Vocab at 0x261a68b0e80>,
#  'mirada': <gensim.models.keyedvectors.Vocab at 0x261a68b0f98>,
#  'completa': <gensim.models.keyedvectors.Vocab at 0x261a68b0128>,
#  'complicidad': <gensim.models.keyedvectors.Vocab at 0x261a68b02e8>,
#  'meses': <gensim.models.keyedvectors.Vocab at 0x261a75ef048>,
#  'amor': <gensim.models.keyedvectors.Vocab at 0x261a75ef0b8>,
#  'bonito': <gensim.models.keyedvectors.Vocab at 0x261a75ef0f0>,
#  'mensaje': <gensim.models.keyedvectors.Vocab at 0x261a75ef278>,
#  'acompaña': <gensim.models.keyedvectors.Vocab at 0x261a75ef2b0>,
#  'mantuvo': <gensim.models.keyedvectors.Vocab at 0x261a75ef320>,
#  'matrimonio': <gensim.models.keyedvectors.Vocab at 0x261a75ef358>,
#  '15': <gensim.models.keyedvectors.Vocab at 0x261a75ef438>,
#  'años': <gensim.models.keyedvectors.Vocab at 0x261a75ef470>,
#  'cineasta': <gensim.models.keyedvectors.Vocab at 0x261a75ef518>,
#  'sandro': <gensim.models.keyedvectors.Vocab at 0x261a75ef668>,
#  'ventura': <gensim.models.keyedvectors.Vocab at 0x261a75ef6a0>,
#  'mediados': <gensim.models.keyedvectors.Vocab at 0x261a75ef748>,
#  '2018': <gensim.models.keyedvectors.Vocab at 0x261a75ef780>,
#  'anunciaron': <gensim.models.keyedvectors.Vocab at 0x261a75ef7f0>,
#  'separación': <gensim.models.keyedvectors.Vocab at 0x261a75ef828>,
#  'quedaron': <gensim.models.keyedvectors.Vocab at 0x261a75ef898>,
#  'términos': <gensim.models.keyedvectors.Vocab at 0x261a75ef8d0>,
#  'amigo': <gensim.models.keyedvectors.Vocab at 0x261a75ef9e8>,
#  'hermosos': <gensim.models.keyedvectors.Vocab at 0x261a75efa58>,
#  'basados': <gensim.models.keyedvectors.Vocab at 0x261a75efa90>,
#  'comunicación': <gensim.models.keyedvectors.Vocab at 0x261a75efb00>,
#  'cariño': <gensim.models.keyedvectors.Vocab at 0x261a75efb70>,
#  'entrega': <gensim.models.keyedvectors.Vocab at 0x261a75efda0>,
#  'absoluta': <gensim.models.keyedvectors.Vocab at 0x261a75efe10>,
#  'persona': <gensim.models.keyedvectors.Vocab at 0x261a75efe48>,
#  'importante': <gensim.models.keyedvectors.Vocab at 0x261a75efe80>,
#  'vida': <gensim.models.keyedvectors.Vocab at 0x261a75eff60>,
#  'oportunidad': <gensim.models.keyedvectors.Vocab at 0x261a6b0d0b8>,
#  'cerrar': <gensim.models.keyedvectors.Vocab at 0x261a6b0d0f0>,
#  'etapa': <gensim.models.keyedvectors.Vocab at 0x261a6b0d128>,
#  'abrir': <gensim.models.keyedvectors.Vocab at 0x261a6b0d160>,
#  'emoción': <gensim.models.keyedvectors.Vocab at 0x261a6b0d198>,
#  'expectativa': <gensim.models.keyedvectors.Vocab at 0x261a6b0d1d0>,
#  'seguir': <gensim.models.keyedvectors.Vocab at 0x261a6b0d208>,
#  'persiguiendo': <gensim.models.keyedvectors.Vocab at 0x261a6b0d240>,
#  'sueños': <gensim.models.keyedvectors.Vocab at 0x261a6b0d278>,
#  'febrero': <gensim.models.keyedvectors.Vocab at 0x261a6b0d2b0>,
#  'entrevista': <gensim.models.keyedvectors.Vocab at 0x261a6b0d2e8>,
#  'perú21': <gensim.models.keyedvectors.Vocab at 0x261a6b0d320>,
#  'enriquez': <gensim.models.keyedvectors.Vocab at 0x261a6b0d358>,
#  'luque': <gensim.models.keyedvectors.Vocab at 0x261a6b0d390>,
#  '25': <gensim.models.keyedvectors.Vocab at 0x261a6b0d3c8>,
#  'detenido': <gensim.models.keyedvectors.Vocab at 0x261a6b0d438>,
#  'arrojado': <gensim.models.keyedvectors.Vocab at 0x261a6b0d518>,
#  'thinner': <gensim.models.keyedvectors.Vocab at 0x261a6b0d550>,
#  'padre': <gensim.models.keyedvectors.Vocab at 0x261a6b0d588>,
#  'posteriormente': <gensim.models.keyedvectors.Vocab at 0x261a6b0d5c0>,
#  'prenderle': <gensim.models.keyedvectors.Vocab at 0x261a6b0d5f8>,
#  'fuego': <gensim.models.keyedvectors.Vocab at 0x261a6b0d630>,
#  'acuerdo': <gensim.models.keyedvectors.Vocab at 0x261a6b0d668>,
#  'diversos': <gensim.models.keyedvectors.Vocab at 0x261a6b0d6a0>,
#  'medios': <gensim.models.keyedvectors.Vocab at 0x261a6b0d6d8>,
#  'locales': <gensim.models.keyedvectors.Vocab at 0x261a6b0d710>,
#  'parricidio': <gensim.models.keyedvectors.Vocab at 0x261a6b0d748>,
#  'ocurrió': <gensim.models.keyedvectors.Vocab at 0x261a6b0d780>,
#  'vivienda': <gensim.models.keyedvectors.Vocab at 0x261a6b0d7f0>,
#  'agraviado': <gensim.models.keyedvectors.Vocab at 0x261a6b0d898>,
#  'ubicada': <gensim.models.keyedvectors.Vocab at 0x261a6b0d940>,
#  'provincia': <gensim.models.keyedvectors.Vocab at 0x261a6b0d978>,
#  'convención': <gensim.models.keyedvectors.Vocab at 0x261a6b0d9b0>,
#  'cusco': <gensim.models.keyedvectors.Vocab at 0x261a6b0d9e8>,
#  'vecinos': <gensim.models.keyedvectors.Vocab at 0x261a6b0da58>,
#  'zona': <gensim.models.keyedvectors.Vocab at 0x261a6b0da90>,
#  'aviso': <gensim.models.keyedvectors.Vocab at 0x261a6b0dac8>,
#  'autoridades': <gensim.models.keyedvectors.Vocab at 0x261a6b0db00>,
#  'inmediatamente': <gensim.models.keyedvectors.Vocab at 0x261a6b0db38>,
#  'llegaron': <gensim.models.keyedvectors.Vocab at 0x261a6b0db70>,
#  'hechos': <gensim.models.keyedvectors.Vocab at 0x261a6b0dba8>,
#  'domicilio': <gensim.models.keyedvectors.Vocab at 0x261a6b0dbe0>,
#  'joven': <gensim.models.keyedvectors.Vocab at 0x261a6b0dc18>,
#  'negó': <gensim.models.keyedvectors.Vocab at 0x261a6b0dc50>,
#  'incendiado': <gensim.models.keyedvectors.Vocab at 0x261a6b0dd68>,
#  'identificado': <gensim.models.keyedvectors.Vocab at 0x261a6b0dda0>,
#  'víctor': <gensim.models.keyedvectors.Vocab at 0x261a6b0ddd8>,
#  'carrion': <gensim.models.keyedvectors.Vocab at 0x261a6b0de10>,
#  '68': <gensim.models.keyedvectors.Vocab at 0x261a6b0de48>,
#  'obstante': <gensim.models.keyedvectors.Vocab at 0x261a6b0de80>,
#  'graves': <gensim.models.keyedvectors.Vocab at 0x261a6b0deb8>,
#  'quemaduras': <gensim.models.keyedvectors.Vocab at 0x261a6b0def0>,
#  'grado': <gensim.models.keyedvectors.Vocab at 0x261a6b0df28>,
#  'salió': <gensim.models.keyedvectors.Vocab at 0x261a6b0df60>,
#  'desmentir': <gensim.models.keyedvectors.Vocab at 0x261a6b0dc88>,
#  'versión': <gensim.models.keyedvectors.Vocab at 0x261a66d2470>,
#  'hijo': <gensim.models.keyedvectors.Vocab at 0x261a66d27b8>,
#  'finalmente': <gensim.models.keyedvectors.Vocab at 0x261a66d29e8>,
#  'trasladado': <gensim.models.keyedvectors.Vocab at 0x261a66d2b38>,
#  'comisaría': <gensim.models.keyedvectors.Vocab at 0x261a66d2d30>,
#  'santa': <gensim.models.keyedvectors.Vocab at 0x261a64c8f60>,
#  'teresa': <gensim.models.keyedvectors.Vocab at 0x261a64c8dd8>,
#  'intervención': <gensim.models.keyedvectors.Vocab at 0x261a64c8e10>,
#  'víctima': <gensim.models.keyedvectors.Vocab at 0x261a664f4a8>,
#  'llevado': <gensim.models.keyedvectors.Vocab at 0x261a664f4e0>,
#  'hospital': <gensim.models.keyedvectors.Vocab at 0x261a664f898>,
#  'central': <gensim.models.keyedvectors.Vocab at 0x261a6745748>,
#  'ciudad': <gensim.models.keyedvectors.Vocab at 0x261a6745c50>,
#  'quillabamba': <gensim.models.keyedvectors.Vocab at 0x261a6745da0>,
#  'viene': <gensim.models.keyedvectors.Vocab at 0x261a6745f28>,
#  'recuperándose': <gensim.models.keyedvectors.Vocab at 0x261a6745160>,
#  'lesiones': <gensim.models.keyedvectors.Vocab at 0x261a73f1160>,
#  'fiscalía': <gensim.models.keyedvectors.Vocab at 0x261a73f12b0>,
#  'turno': <gensim.models.keyedvectors.Vocab at 0x261a73f15f8>,
#  'dispuso': <gensim.models.keyedvectors.Vocab at 0x261a73f1710>,
#  'diligencias': <gensim.models.keyedvectors.Vocab at 0x261a73f1780>,
#  'preliminares': <gensim.models.keyedvectors.Vocab at 0x261a73f1860>,
#  'correspondientes': <gensim.models.keyedvectors.Vocab at 0x261a73f1ac8>,
#  'permanecerá': <gensim.models.keyedvectors.Vocab at 0x261a73f1ba8>,
#  'investigaciones': <gensim.models.keyedvectors.Vocab at 0x261a73f1d30>,
#  'deberá': <gensim.models.keyedvectors.Vocab at 0x261a73f1d68>,
#  'enfrentar': <gensim.models.keyedvectors.Vocab at 0x261a73f1e48>,
#  'cargos': <gensim.models.keyedvectors.Vocab at 0x261a73f1f98>,
#  'presunto': <gensim.models.keyedvectors.Vocab at 0x261a65dc4e0>,
#  'delito': <gensim.models.keyedvectors.Vocab at 0x261a66ace48>,
#  'violencia': <gensim.models.keyedvectors.Vocab at 0x261a66ac4a8>,
#  'familiar': <gensim.models.keyedvectors.Vocab at 0x261a66ac6a0>,
#  'luis': <gensim.models.keyedvectors.Vocab at 0x261a66b9d30>,
#  'bedoya': <gensim.models.keyedvectors.Vocab at 0x261a66b9eb8>,
#  'reyes': <gensim.models.keyedvectors.Vocab at 0x261a662c4a8>,
#  'fundadores': <gensim.models.keyedvectors.Vocab at 0x261a662c518>,
#  'históricos': <gensim.models.keyedvectors.Vocab at 0x261a662c5c0>,
#  'partido': <gensim.models.keyedvectors.Vocab at 0x261a6a1b048>,
#  'popular': <gensim.models.keyedvectors.Vocab at 0x261a6a1b0b8>,
#  'cristiano': <gensim.models.keyedvectors.Vocab at 0x261a6a1b0f0>,
#  'ppc': <gensim.models.keyedvectors.Vocab at 0x261a6a1b128>,
#  'pronunció': <gensim.models.keyedvectors.Vocab at 0x261a6a1b160>,
#  'acerca': <gensim.models.keyedvectors.Vocab at 0x261a6a1b198>,
#  'convocatoria': <gensim.models.keyedvectors.Vocab at 0x261a6a1b1d0>,
#  'integrar': <gensim.models.keyedvectors.Vocab at 0x261a6a1b208>,
#  'junta': <gensim.models.keyedvectors.Vocab at 0x261a6a1b240>,
#  'nacional': <gensim.models.keyedvectors.Vocab at 0x261a6a1b278>,
#  'justicia': <gensim.models.keyedvectors.Vocab at 0x261a6a1b2b0>,
#  'jnj': <gensim.models.keyedvectors.Vocab at 0x261a6a1b2e8>,
#  'pequeño': <gensim.models.keyedvectors.Vocab at 0x261a6a1b390>,
#  'discurso': <gensim.models.keyedvectors.Vocab at 0x261a6a1b3c8>,
#  'importancia': <gensim.models.keyedvectors.Vocab at 0x261a6a1b400>,
#  'significa': <gensim.models.keyedvectors.Vocab at 0x261a6a1b470>,
#  'órgano': <gensim.models.keyedvectors.Vocab at 0x261a6a1b4a8>,
#  'político': <gensim.models.keyedvectors.Vocab at 0x261a6a1b4e0>,
#  '100': <gensim.models.keyedvectors.Vocab at 0x261a6a1b518>,
#  'edad': <gensim.models.keyedvectors.Vocab at 0x261a6a1b550>,
#  'grabó': <gensim.models.keyedvectors.Vocab at 0x261a6a1b5c0>,
#  'video': <gensim.models.keyedvectors.Vocab at 0x261a6a1b5f8>,
#  'explica': <gensim.models.keyedvectors.Vocab at 0x261a6a1b630>,
#  'razones': <gensim.models.keyedvectors.Vocab at 0x261a6a1b6a0>,
#  'llama': <gensim.models.keyedvectors.Vocab at 0x261a6a1b6d8>,
#  'juristas': <gensim.models.keyedvectors.Vocab at 0x261a6a1b748>,
#  'abogados': <gensim.models.keyedvectors.Vocab at 0x261a6a1b780>,
#  'especialistas': <gensim.models.keyedvectors.Vocab at 0x261a6a1b7f0>,
#  'derecho': <gensim.models.keyedvectors.Vocab at 0x261a6a1b860>,
#  'ojalá': <gensim.models.keyedvectors.Vocab at 0x261a6a1b898>,
#  'acostumbren': <gensim.models.keyedvectors.Vocab at 0x261a6a1b8d0>,
#  'acertar': <gensim.models.keyedvectors.Vocab at 0x261a6a1b940>,
#  'postulantes': <gensim.models.keyedvectors.Vocab at 0x261a6a1b978>,
#  'merezcan': <gensim.models.keyedvectors.Vocab at 0x261a6a1b9e8>,
#  'elegidos': <gensim.models.keyedvectors.Vocab at 0x261a6a1ba20>,
#  'razón': <gensim.models.keyedvectors.Vocab at 0x261a6a1ba58>,
#  'condiciones': <gensim.models.keyedvectors.Vocab at 0x261a6a1bb38>,
#  'cualidades': <gensim.models.keyedvectors.Vocab at 0x261a6a1bba8>,
#  'juntaremos': <gensim.models.keyedvectors.Vocab at 0x261a6a1bbe0>,
#  'peruanos': <gensim.models.keyedvectors.Vocab at 0x261a6a1bc18>,
#  'vivir': <gensim.models.keyedvectors.Vocab at 0x261a6a1bcc0>,
#  'discrepando': <gensim.models.keyedvectors.Vocab at 0x261a6a1bda0>,
#  'institución': <gensim.models.keyedvectors.Vocab at 0x261a6a1bdd8>,
#  'reemplazará': <gensim.models.keyedvectors.Vocab at 0x261a6a1be80>,
#  'desaparecido': <gensim.models.keyedvectors.Vocab at 0x261a6a1beb8>,
#  'consejo': <gensim.models.keyedvectors.Vocab at 0x261a6a1bef0>,
#  'magistratura': <gensim.models.keyedvectors.Vocab at 0x261a6a1bf28>,
#  'cnm': <gensim.models.keyedvectors.Vocab at 0x261a6a1bf98>,
#  'desactivado': <gensim.models.keyedvectors.Vocab at 0x261a7482cc0>,
#  'audios': <gensim.models.keyedvectors.Vocab at 0x261a7482e48>,
#  'vergüenza': <gensim.models.keyedvectors.Vocab at 0x261a7482ef0>,
#  'exintegrantes': <gensim.models.keyedvectors.Vocab at 0x261a7482f28>,
#  'escuchaba': <gensim.models.keyedvectors.Vocab at 0x261a74820f0>,
#  'comprometedoras': <gensim.models.keyedvectors.Vocab at 0x261a7482198>,
#  'situación': <gensim.models.keyedvectors.Vocab at 0x261a74822b0>,
#  'corrupción': <gensim.models.keyedvectors.Vocab at 0x261a7482470>,
#  'encargará': <gensim.models.keyedvectors.Vocab at 0x261a74824a8>,
#  'nombrar': <gensim.models.keyedvectors.Vocab at 0x261a74824e0>,
#  'destituir': <gensim.models.keyedvectors.Vocab at 0x261a7482550>,
#  'jueces': <gensim.models.keyedvectors.Vocab at 0x261a7482668>,
#  'fiscales': <gensim.models.keyedvectors.Vocab at 0x261a7482748>,
#  'asimismo': <gensim.models.keyedvectors.Vocab at 0x261a7482b70>,
#  'facultad': <gensim.models.keyedvectors.Vocab at 0x261a7482ba8>,
#  'renovar': <gensim.models.keyedvectors.Vocab at 0x261a7482828>,
#  'cargo': <gensim.models.keyedvectors.Vocab at 0x261a7482978>,
#  'jefe': <gensim.models.keyedvectors.Vocab at 0x261a6ad8048>,
#  'onpe': <gensim.models.keyedvectors.Vocab at 0x261a6ad8080>,
#  'reniec': <gensim.models.keyedvectors.Vocab at 0x261a6ad80f0>,
#  'doctor': <gensim.models.keyedvectors.Vocab at 0x261a6ad8128>,
#  'juan': <gensim.models.keyedvectors.Vocab at 0x261a6ad8160>,
#  'herrera': <gensim.models.keyedvectors.Vocab at 0x261a6ad8198>,
#  'director': <gensim.models.keyedvectors.Vocab at 0x261a6ad81d0>,
#  'general': <gensim.models.keyedvectors.Vocab at 0x261a6ad8208>,
#  'operaciones': <gensim.models.keyedvectors.Vocab at 0x261a6ad8240>,
#  'salud': <gensim.models.keyedvectors.Vocab at 0x261a6ad8278>,
#  'conversación': <gensim.models.keyedvectors.Vocab at 0x261a6ad82e8>,
#  'atv': <gensim.models.keyedvectors.Vocab at 0x261a6ad8320>,
#  'separó': <gensim.models.keyedvectors.Vocab at 0x261a6ad8358>,
#  'responsables': <gensim.models.keyedvectors.Vocab at 0x261a6ad8390>,
#  'difundir': <gensim.models.keyedvectors.Vocab at 0x261a6ad8400>,
#  'fallecido': <gensim.models.keyedvectors.Vocab at 0x261a6ad8438>,
#  'expresidente': <gensim.models.keyedvectors.Vocab at 0x261a6ad84a8>,
#  'alan': <gensim.models.keyedvectors.Vocab at 0x261a6ad84e0>,
#  'garcía': <gensim.models.keyedvectors.Vocab at 0x261a6ad8550>,
#  'casimiro': <gensim.models.keyedvectors.Vocab at 0x261a6ad8588>,
#  'ulloa': <gensim.models.keyedvectors.Vocab at 0x261a6ad8630>,
#  'sistema': <gensim.models.keyedvectors.Vocab at 0x261a6ad8668>,
#  'identificados': <gensim.models.keyedvectors.Vocab at 0x261a6ad86d8>,
#  'vía': <gensim.models.keyedvectors.Vocab at 0x261a6ad8710>,
#  'administrativas': <gensim.models.keyedvectors.Vocab at 0x261a6ad87b8>,
#  'activada': <gensim.models.keyedvectors.Vocab at 0x261a6ad87f0>,
#  'sanción': <gensim.models.keyedvectors.Vocab at 0x261a6ad8828>,
#  'correspondiente': <gensim.models.keyedvectors.Vocab at 0x261a6ad8860>,
#  'tema': <gensim.models.keyedvectors.Vocab at 0x261a6ad88d0>,
#  'respeto': <gensim.models.keyedvectors.Vocab at 0x261a6ad8978>,
#  'nombre': <gensim.models.keyedvectors.Vocab at 0x261a6ad89b0>,
#  'detalle': <gensim.models.keyedvectors.Vocab at 0x261a6ad89e8>,
#  'grupo': <gensim.models.keyedvectors.Vocab at 0x261a6ad8a20>,
#  'ocupacional': <gensim.models.keyedvectors.Vocab at 0x261a6ad8a58>,
#  'lamentable': <gensim.models.keyedvectors.Vocab at 0x261a6ad8a90>,
#  'precisó': <gensim.models.keyedvectors.Vocab at 0x261a6ad8ac8>,
#  'involucrados': <gensim.models.keyedvectors.Vocab at 0x261a6ad8b38>,
#  'separados': <gensim.models.keyedvectors.Vocab at 0x261a6ad8b70>,
#  'nosocomio': <gensim.models.keyedvectors.Vocab at 0x261a6ad8be0>,
#  'preliminar': <gensim.models.keyedvectors.Vocab at 0x261a6ad8c18>,
#  'entidad': <gensim.models.keyedvectors.Vocab at 0x261a6ad8c88>,
#  'proceso': <gensim.models.keyedvectors.Vocab at 0x261a6ad8cc0>,
#  'administrativos': <gensim.models.keyedvectors.Vocab at 0x261a6ad8dd8>,
#  'corresponde': <gensim.models.keyedvectors.Vocab at 0x261a6ad8eb8>,
#  'definitiva': <gensim.models.keyedvectors.Vocab at 0x261a6ad8f28>,
#  'mal': <gensim.models.keyedvectors.Vocab at 0x261a6ad8fd0>,
#  'recuerdo': <gensim.models.keyedvectors.Vocab at 0x261a687b128>,
#  'suspensión': <gensim.models.keyedvectors.Vocab at 0x261a687b550>,
#  'procurador': <gensim.models.keyedvectors.Vocab at 0x261a687b828>,
#  'tomando': <gensim.models.keyedvectors.Vocab at 0x261a687b9b0>,
#  'acciones': <gensim.models.keyedvectors.Vocab at 0x261a687ba20>,
#  'administrativa': <gensim.models.keyedvectors.Vocab at 0x261a687ba58>,
#  'aseveró': <gensim.models.keyedvectors.Vocab at 0x261a67b10f0>,
#  'diagnóstico': <gensim.models.keyedvectors.Vocab at 0x261a67b1860>,
#  '17': <gensim.models.keyedvectors.Vocab at 0x261a67b1c18>,
#  'abril': <gensim.models.keyedvectors.Vocab at 0x261a6b96048>,
#  'exmandatario': <gensim.models.keyedvectors.Vocab at 0x261a6b96080>,
#  'tomó': <gensim.models.keyedvectors.Vocab at 0x261a6b960b8>,
#  'fatal': <gensim.models.keyedvectors.Vocab at 0x261a6b960f0>,
#  'decisión': <gensim.models.keyedvectors.Vocab at 0x261a6b96128>,
#  'quitarse': <gensim.models.keyedvectors.Vocab at 0x261a6b96160>,
#  'disparándose': <gensim.models.keyedvectors.Vocab at 0x261a6b96198>,
#  'cabeza': <gensim.models.keyedvectors.Vocab at 0x261a6b961d0>,
#  'impacto': <gensim.models.keyedvectors.Vocab at 0x261a6b96208>,
#  'proyectil': <gensim.models.keyedvectors.Vocab at 0x261a6b96240>,
#  'arma': <gensim.models.keyedvectors.Vocab at 0x261a6b96278>,
#  'orificio': <gensim.models.keyedvectors.Vocab at 0x261a6b962b0>,
#  'entrada': <gensim.models.keyedvectors.Vocab at 0x261a6b962e8>,
#  'salida': <gensim.models.keyedvectors.Vocab at 0x261a6b96320>,
#  'cráneo': <gensim.models.keyedvectors.Vocab at 0x261a6b96358>,
#  'ingresó': <gensim.models.keyedvectors.Vocab at 0x261a6b96390>,
#  'sala': <gensim.models.keyedvectors.Vocab at 0x261a6b963c8>,
#  '0717': <gensim.models.keyedvectors.Vocab at 0x261a6b96400>,
#  'am': <gensim.models.keyedvectors.Vocab at 0x261a6b96438>,
#  'vano': <gensim.models.keyedvectors.Vocab at 0x261a6b96470>,
#  'muerte': <gensim.models.keyedvectors.Vocab at 0x261a6b964a8>,
#  'consecuencia': <gensim.models.keyedvectors.Vocab at 0x261a6b964e0>,
#  'hemorragia': <gensim.models.keyedvectors.Vocab at 0x261a6b96518>,
#  'cerebral': <gensim.models.keyedvectors.Vocab at 0x261a6b96550>,
#  'masiva': <gensim.models.keyedvectors.Vocab at 0x261a6b96588>,
#  'paro': <gensim.models.keyedvectors.Vocab at 0x261a6b965c0>,
#  'cardiorespiratorio': <gensim.models.keyedvectors.Vocab at 0x261a6b965f8>,
#  'john': <gensim.models.keyedvectors.Vocab at 0x261a6b96630>,
#  'galliquio': <gensim.models.keyedvectors.Vocab at 0x261a6b96668>,
#  'exjugador': <gensim.models.keyedvectors.Vocab at 0x261a6b966a0>,
#  'selección': <gensim.models.keyedvectors.Vocab at 0x261a6b966d8>,
#  'peruana': <gensim.models.keyedvectors.Vocab at 0x261a6b96710>,
#  'apareció': <gensim.models.keyedvectors.Vocab at 0x261a6b96748>,
#  'evento': <gensim.models.keyedvectors.Vocab at 0x261a6b96780>,
#  'deportivo': <gensim.models.keyedvectors.Vocab at 0x261a6b967b8>,
#  'san': <gensim.models.keyedvectors.Vocab at 0x261a6b967f0>,
#  'miraflores': <gensim.models.keyedvectors.Vocab at 0x261a6b96828>,
#  'consultado': <gensim.models.keyedvectors.Vocab at 0x261a6b96860>,
#  'denuncia': <gensim.models.keyedvectors.Vocab at 0x261a6b96898>,
#  'exesposa': <gensim.models.keyedvectors.Vocab at 0x261a6b96908>,
#  'karla': <gensim.models.keyedvectors.Vocab at 0x261a6b96940>,
#  'gómez': <gensim.models.keyedvectors.Vocab at 0x261a6b96978>,
#  'prefirió': <gensim.models.keyedvectors.Vocab at 0x261a6b969b0>,
#  'declarar': <gensim.models.keyedvectors.Vocab at 0x261a6b969e8>,
#  'aprecia': <gensim.models.keyedvectors.Vocab at 0x261a6b96a20>,
#  'imágenes': <gensim.models.keyedvectors.Vocab at 0x261a6b96a58>,
#  'programa': <gensim.models.keyedvectors.Vocab at 0x261a6b96a90>,
#  'magaly': <gensim.models.keyedvectors.Vocab at 0x261a6b96ac8>,
#  'medina': <gensim.models.keyedvectors.Vocab at 0x261a6b96b00>,
#  'tyson': <gensim.models.keyedvectors.Vocab at 0x261a6b96b38>,
#  'hablaría': <gensim.models.keyedvectors.Vocab at 0x261a6b96b70>,
#  'privada': <gensim.models.keyedvectors.Vocab at 0x261a6b96ba8>,
#  'evadió': <gensim.models.keyedvectors.Vocab at 0x261a6b96be0>,
#  'consultadas': <gensim.models.keyedvectors.Vocab at 0x261a6b96c18>,
#  'reportero': <gensim.models.keyedvectors.Vocab at 0x261a6b96c50>,
#  'presentes': <gensim.models.keyedvectors.Vocab at 0x261a6b96c88>,
#  'paolo': <gensim.models.keyedvectors.Vocab at 0x261a6b96cc0>,
#  'maldonado': <gensim.models.keyedvectors.Vocab at 0x261a6b96cf8>,
#  'manuel': <gensim.models.keyedvectors.Vocab at 0x261a6b96d68>,
#  'vargas': <gensim.models.keyedvectors.Vocab at 0x261a6b96da0>,
#  'mostró': <gensim.models.keyedvectors.Vocab at 0x261a6b96dd8>,
#  'risueño': <gensim.models.keyedvectors.Vocab at 0x261a6b96e10>,
#  'principio': <gensim.models.keyedvectors.Vocab at 0x261a6b96e48>,
#  'propiedades': <gensim.models.keyedvectors.Vocab at 0x261a6b96e80>,
#  'denuncias': <gensim.models.keyedvectors.Vocab at 0x261a6b96eb8>,
#  'incómodo': <gensim.models.keyedvectors.Vocab at 0x261a6b96ef0>,
#  'disculpa': <gensim.models.keyedvectors.Vocab at 0x261a6b96f28>,
#  'hablo': <gensim.models.keyedvectors.Vocab at 0x261a6b96f60>,
#  'favor': <gensim.models.keyedvectors.Vocab at 0x261a6b96f98>,
#  'agradezco': <gensim.models.keyedvectors.Vocab at 0x261a6b96fd0>,
#  'montón': <gensim.models.keyedvectors.Vocab at 0x261a6ba6048>,
#  'hablar': <gensim.models.keyedvectors.Vocab at 0x261a6ba6080>,
#  'ustedes': <gensim.models.keyedvectors.Vocab at 0x261a6ba60b8>,
#  'contigo': <gensim.models.keyedvectors.Vocab at 0x261a6ba60f0>,
#  'gracias': <gensim.models.keyedvectors.Vocab at 0x261a6ba6128>,
#  'puedes': <gensim.models.keyedvectors.Vocab at 0x261a6ba6198>,
#  'obligar': <gensim.models.keyedvectors.Vocab at 0x261a6ba61d0>,
#  'hable': <gensim.models.keyedvectors.Vocab at 0x261a6ba6208>,
#  'declaró': <gensim.models.keyedvectors.Vocab at 0x261a6ba6240>,
#  'jhon': <gensim.models.keyedvectors.Vocab at 0x261a6ba6278>,
#  'recordar': <gensim.models.keyedvectors.Vocab at 0x261a6ba62b0>,
#  'medidas': <gensim.models.keyedvectors.Vocab at 0x261a6ba62e8>,
#  'protección': <gensim.models.keyedvectors.Vocab at 0x261a6ba6320>,
#  'pisco': <gensim.models.keyedvectors.Vocab at 0x261a6ba6358>,
#  'denunciar': <gensim.models.keyedvectors.Vocab at 0x261a6ba6390>,
#  'agentes': <gensim.models.keyedvectors.Vocab at 0x261a6ba63c8>,
#  'ignoran': <gensim.models.keyedvectors.Vocab at 0x261a6ba6400>,
#  'informa': <gensim.models.keyedvectors.Vocab at 0x261a6ba6438>,
#  'marzo': <gensim.models.keyedvectors.Vocab at 0x261a6ba6470>,
#  'denunciado': <gensim.models.keyedvectors.Vocab at 0x261a6ba64a8>,
#  'doméstica': <gensim.models.keyedvectors.Vocab at 0x261a6ba64e0>,
#  'querido': <gensim.models.keyedvectors.Vocab at 0x261a6ba6518>,
#  'ahogar': <gensim.models.keyedvectors.Vocab at 0x261a6ba6550>,
#  'mar': <gensim.models.keyedvectors.Vocab at 0x261a6ba6588>,
#  'discusión': <gensim.models.keyedvectors.Vocab at 0x261a6ba65f8>,
#  'pateaba': <gensim.models.keyedvectors.Vocab at 0x261a6ba6630>,
#  'punto': <gensim.models.keyedvectors.Vocab at 0x261a6ba6668>,
#  'hacerme': <gensim.models.keyedvectors.Vocab at 0x261a6ba66a0>,
#  'vomitar': <gensim.models.keyedvectors.Vocab at 0x261a6ba66d8>,
#  'sangre': <gensim.models.keyedvectors.Vocab at 0x261a6ba6710>,
#  'rompe': <gensim.models.keyedvectors.Vocab at 0x261a6ba6748>,
#  'mandíbula': <gensim.models.keyedvectors.Vocab at 0x261a6ba6780>,
#  'patea': <gensim.models.keyedvectors.Vocab at 0x261a6ba67b8>,
#  'calle': <gensim.models.keyedvectors.Vocab at 0x261a6ba67f0>,
#  'esperando': <gensim.models.keyedvectors.Vocab at 0x261a6ba6828>,
#  'mate': <gensim.models.keyedvectors.Vocab at 0x261a6ba6860>,
#  'medio': <gensim.models.keyedvectors.Vocab at 0x261a6ba68d0>,
#  'lágrimas': <gensim.models.keyedvectors.Vocab at 0x261a6ba6908>,
#  'denunciante': <gensim.models.keyedvectors.Vocab at 0x261a6ba6940>,
#  'jugador': <gensim.models.keyedvectors.Vocab at 0x261a6ba6978>,
#  'aparece': <gensim.models.keyedvectors.Vocab at 0x261a6ba69b0>,
#  'cuchillo': <gensim.models.keyedvectors.Vocab at 0x261a6ba69e8>,
#  'audio': <gensim.models.keyedvectors.Vocab at 0x261a6ba6a20>,
#  'cárcel': <gensim.models.keyedvectors.Vocab at 0x261a6ba6a58>,
#  'matar': <gensim.models.keyedvectors.Vocab at 0x261a6ba6ac8>,
#  'duras': <gensim.models.keyedvectors.Vocab at 0x261a6ba6b00>,
#  'críticas': <gensim.models.keyedvectors.Vocab at 0x261a6ba6b38>,
#  'recibiendo': <gensim.models.keyedvectors.Vocab at 0x261a6ba6b70>,
#  'comentarista': <gensim.models.keyedvectors.Vocab at 0x261a6ba6ba8>,
#  'silvio': <gensim.models.keyedvectors.Vocab at 0x261a6ba6be0>,
#  'valencia': <gensim.models.keyedvectors.Vocab at 0x261a6ba6c50>,
#  'vivo': <gensim.models.keyedvectors.Vocab at 0x261a6ba6c88>,
#  'hinchas': <gensim.models.keyedvectors.Vocab at 0x261a6ba6cc0>,
#  'sport': <gensim.models.keyedvectors.Vocab at 0x261a6ba6d68>,
#  'boys': <gensim.models.keyedvectors.Vocab at 0x261a6ba6da0>,
#  'plato': <gensim.models.keyedvectors.Vocab at 0x261a6ba6dd8>,
#  'comida': <gensim.models.keyedvectors.Vocab at 0x261a6ba6e10>,
#  'penosas': <gensim.models.keyedvectors.Vocab at 0x261a6ba6e48>,
#  'declaraciones': <gensim.models.keyedvectors.Vocab at 0x261a6ba6e80>,
#  'difundió': <gensim.models.keyedvectors.Vocab at 0x261a6ba6eb8>,
#  'espacio': <gensim.models.keyedvectors.Vocab at 0x261a6ba6ef0>,
#  'televisivo': <gensim.models.keyedvectors.Vocab at 0x261a6ba6f28>,
#  'conduce': <gensim.models.keyedvectors.Vocab at 0x261a6ba6f60>,
#  'conductores': <gensim.models.keyedvectors.Vocab at 0x261a6ba6f98>,
#  'cobra': <gensim.models.keyedvectors.Vocab at 0x261a6ba6fd0>,
#  'entradas': <gensim.models.keyedvectors.Vocab at 0x261a67ba940>,
#  'asistentes': <gensim.models.keyedvectors.Vocab at 0x261a67bae80>,
#  'estrategia': <gensim.models.keyedvectors.Vocab at 0x261a67babe0>,
#  'misilera': <gensim.models.keyedvectors.Vocab at 0x261a67ba1d0>,
#  'consiste': <gensim.models.keyedvectors.Vocab at 0x261a68e57f0>,
#  'pago': <gensim.models.keyedvectors.Vocab at 0x261a68e5860>,
#  'voluntario': <gensim.models.keyedvectors.Vocab at 0x261a68e5a58>,
#  'concepto': <gensim.models.keyedvectors.Vocab at 0x261a68e5ac8>,
#  'precio': <gensim.models.keyedvectors.Vocab at 0x261a68e5b70>,
#  'compañeros': <gensim.models.keyedvectors.Vocab at 0x261a68e5e10>,
#  'sostuvo': <gensim.models.keyedvectors.Vocab at 0x261a68e5e80>,
#  'montos': <gensim.models.keyedvectors.Vocab at 0x261a68e5ef0>,
#  'cobran': <gensim.models.keyedvectors.Vocab at 0x261a68e5f60>,
#  'recuperan': <gensim.models.keyedvectors.Vocab at 0x261a68e5400>,
#  'venta': <gensim.models.keyedvectors.Vocab at 0x261a68e5470>,
#  'estadio': <gensim.models.keyedvectors.Vocab at 0x261a68e5588>,
#  'miguel': <gensim.models.keyedvectors.Vocab at 0x261a68e55f8>,
#  'grau': <gensim.models.keyedvectors.Vocab at 0x261a68e5668>,
#  'callao': <gensim.models.keyedvectors.Vocab at 0x261a68e5710>,
#  'táctica': <gensim.models.keyedvectors.Vocab at 0x261a6773c18>,
#  'busca': <gensim.models.keyedvectors.Vocab at 0x261a6773048>,
#  'asistencia': <gensim.models.keyedvectors.Vocab at 0x261a6773198>,
#  'personas': <gensim.models.keyedvectors.Vocab at 0x261a6773320>,
#  'alentar': <gensim.models.keyedvectors.Vocab at 0x261a6773358>,
#  'equipo': <gensim.models.keyedvectors.Vocab at 0x261a67736a0>,
#  'evitar': <gensim.models.keyedvectors.Vocab at 0x261a6773940>,
#  'descenso': <gensim.models.keyedvectors.Vocab at 0x261a6773978>,
#  'división': <gensim.models.keyedvectors.Vocab at 0x261a6773b00>,
#  'incorrecta': <gensim.models.keyedvectors.Vocab at 0x261a6773b38>,
#  'postura': <gensim.models.keyedvectors.Vocab at 0x261a66913c8>,
#  'gente': <gensim.models.keyedvectors.Vocab at 0x261a6691828>,
#  'chicos': <gensim.models.keyedvectors.Vocab at 0x261a66918d0>,
#  'paran': <gensim.models.keyedvectors.Vocab at 0x261a6691048>,
#  '5': <gensim.models.keyedvectors.Vocab at 0x261a66f3048>,
#  '3': <gensim.models.keyedvectors.Vocab at 0x261a66f3a20>,
#  'soles': <gensim.models.keyedvectors.Vocab at 0x261a66f3c18>,
#  'pagar': <gensim.models.keyedvectors.Vocab at 0x261a66f3e48>,
#  'menú': <gensim.models.keyedvectors.Vocab at 0x261a666e0f0>,
#  'actualización': <gensim.models.keyedvectors.Vocab at 0x261a666eb70>,
#  'fiscal': <gensim.models.keyedvectors.Vocab at 0x261a666eba8>,
#  'josé': <gensim.models.keyedvectors.Vocab at 0x261a6bc4048>,
#  'domingo': <gensim.models.keyedvectors.Vocab at 0x261a6bc4080>,
#  'pérez': <gensim.models.keyedvectors.Vocab at 0x261a6bc40b8>,
#  'reprogramó': <gensim.models.keyedvectors.Vocab at 0x261a6bc40f0>,
#  'interrogatorio': <gensim.models.keyedvectors.Vocab at 0x261a6bc4128>,
#  'exasesor': <gensim.models.keyedvectors.Vocab at 0x261a6bc4160>,
#  'presidencial': <gensim.models.keyedvectors.Vocab at 0x261a6bc4198>,
#  'vladimiro': <gensim.models.keyedvectors.Vocab at 0x261a6bc41d0>,
#  'montesinos': <gensim.models.keyedvectors.Vocab at 0x261a6bc4208>,
#  'lunes': <gensim.models.keyedvectors.Vocab at 0x261a6bc4240>,
#  '7': <gensim.models.keyedvectors.Vocab at 0x261a6bc4278>,
#  'octubre': <gensim.models.keyedvectors.Vocab at 0x261a6bc42b0>,
#  'disposición': <gensim.models.keyedvectors.Vocab at 0x261a6bc42e8>,
#  'accedió': <gensim.models.keyedvectors.Vocab at 0x261a6bc4320>,
#  'cambio': <gensim.models.keyedvectors.Vocab at 0x261a6bc4358>,
#  'fecha': <gensim.models.keyedvectors.Vocab at 0x261a6bc4390>,
#  'participar': <gensim.models.keyedvectors.Vocab at 0x261a6bc43c8>,
#  'audiencias': <gensim.models.keyedvectors.Vocab at 0x261a6bc4400>,
#  'convocadas': <gensim.models.keyedvectors.Vocab at 0x261a6bc4438>,
#  'penal': <gensim.models.keyedvectors.Vocab at 0x261a6bc4470>,
#  'superior': <gensim.models.keyedvectors.Vocab at 0x261a6bc44a8>,
#  'transitoria': <gensim.models.keyedvectors.Vocab at 0x261a6bc44e0>,
#  'corte': <gensim.models.keyedvectors.Vocab at 0x261a6bc4518>,
#  'especializada': <gensim.models.keyedvectors.Vocab at 0x261a6bc4550>,
#  'analizar': <gensim.models.keyedvectors.Vocab at 0x261a6bc4588>,
#  'casos': <gensim.models.keyedvectors.Vocab at 0x261a6bc45c0>,
#  'derechos': <gensim.models.keyedvectors.Vocab at 0x261a6bc45f8>,
#  'humanos': <gensim.models.keyedvectors.Vocab at 0x261a6bc4630>,
#  'pedro': <gensim.models.keyedvectors.Vocab at 0x261a6bc4668>,
#  'huilca': <gensim.models.keyedvectors.Vocab at 0x261a6bc46a0>,
#  'mariella': <gensim.models.keyedvectors.Vocab at 0x261a6bc46d8>,
#  'barreto': <gensim.models.keyedvectors.Vocab at 0x261a6bc4710>,
#  'imposible': <gensim.models.keyedvectors.Vocab at 0x261a6bc4748>,
#  'doc': <gensim.models.keyedvectors.Vocab at 0x261a6bc4780>,
#  'responder': <gensim.models.keyedvectors.Vocab at 0x261a6bc47b8>,
#  'interrogantes': <gensim.models.keyedvectors.Vocab at 0x261a6bc47f0>,
#  'documento': <gensim.models.keyedvectors.Vocab at 0x261a6bc4828>,
#  'señala': <gensim.models.keyedvectors.Vocab at 0x261a6bc4860>,
#  '14': <gensim.models.keyedvectors.Vocab at 0x261a6bc4898>,
#  'tomará': <gensim.models.keyedvectors.Vocab at 0x261a6bc48d0>,
#  'declaración': <gensim.models.keyedvectors.Vocab at 0x261a6bc4908>,
#  'eduardo': <gensim.models.keyedvectors.Vocab at 0x261a6bc4940>,
#  'felipe': <gensim.models.keyedvectors.Vocab at 0x261a6bc4978>,
#  'cabrera': <gensim.models.keyedvectors.Vocab at 0x261a6bc49b0>,
#  'ganoza': <gensim.models.keyedvectors.Vocab at 0x261a6bc49e8>,
#  'congresista': <gensim.models.keyedvectors.Vocab at 0x261a6bc4a20>,
#  'república': <gensim.models.keyedvectors.Vocab at 0x261a6bc4a58>,
#  'ica': <gensim.models.keyedvectors.Vocab at 0x261a6bc4ac8>,
#  'representando': <gensim.models.keyedvectors.Vocab at 0x261a6bc4b00>,
#  'fuerza': <gensim.models.keyedvectors.Vocab at 0x261a6bc4b38>,
#  '2011': <gensim.models.keyedvectors.Vocab at 0x261a6bc4b70>,
#  'postuló': <gensim.models.keyedvectors.Vocab at 0x261a6bc4ba8>,
#  'presidente': <gensim.models.keyedvectors.Vocab at 0x261a6bc4be0>,
#  'regional': <gensim.models.keyedvectors.Vocab at 0x261a6bc4c18>,
#  'nota': <gensim.models.keyedvectors.Vocab at 0x261a6bc4c50>,
#  'original': <gensim.models.keyedvectors.Vocab at 0x261a6bc4c88>,
#  'martes': <gensim.models.keyedvectors.Vocab at 0x261a6bc4cc0>,
#  'irá': <gensim.models.keyedvectors.Vocab at 0x261a6bc4cf8>,
#  'base': <gensim.models.keyedvectors.Vocab at 0x261a6bc4d30>,
#  'naval': <gensim.models.keyedvectors.Vocab at 0x261a6bc4d68>,
#  'interrogar': <gensim.models.keyedvectors.Vocab at 0x261a6bc4dd8>,
#  'purga': <gensim.models.keyedvectors.Vocab at 0x261a6bc4e10>,
#  'condena': <gensim.models.keyedvectors.Vocab at 0x261a6bc4e48>,
#  'distintos': <gensim.models.keyedvectors.Vocab at 0x261a6bc4e80>,
#  'delitos': <gensim.models.keyedvectors.Vocab at 0x261a6bc4eb8>,
#  'cometidos': <gensim.models.keyedvectors.Vocab at 0x261a6bc4ef0>,
#  'gobierno': <gensim.models.keyedvectors.Vocab at 0x261a6bc4f28>,
#  'alberto': <gensim.models.keyedvectors.Vocab at 0x261a6bc4f60>,
#  'fujimori': <gensim.models.keyedvectors.Vocab at 0x261a6bc4f98>,
#  'diligencia': <gensim.models.keyedvectors.Vocab at 0x261a6bc4fd0>,
#  'fijada': <gensim.models.keyedvectors.Vocab at 0x261a65f25f8>,
#  '10': <gensim.models.keyedvectors.Vocab at 0x261a75369e8>,
#  'mañana': <gensim.models.keyedvectors.Vocab at 0x261a75365f8>,
#  'especial': <gensim.models.keyedvectors.Vocab at 0x261a7536780>,
#  'lava': <gensim.models.keyedvectors.Vocab at 0x261a75367f0>,
#  'jato': <gensim.models.keyedvectors.Vocab at 0x261a75368d0>,
#  'formulará': <gensim.models.keyedvectors.Vocab at 0x261a7536908>,
#  'pliego': <gensim.models.keyedvectors.Vocab at 0x261a7536978>,
#  'preguntas': <gensim.models.keyedvectors.Vocab at 0x261a75369b0>,
#  'encontrar': <gensim.models.keyedvectors.Vocab at 0x261a7536a20>,
#  'luces': <gensim.models.keyedvectors.Vocab at 0x261a7536a58>,
#  'verdadero': <gensim.models.keyedvectors.Vocab at 0x261a7536c50>,
#  'rol': <gensim.models.keyedvectors.Vocab at 0x261a7536c88>,
#  'cumplió': <gensim.models.keyedvectors.Vocab at 0x261a7536cc0>,
#  'abogado': <gensim.models.keyedvectors.Vocab at 0x261a7536cf8>,
#  'vicente': <gensim.models.keyedvectors.Vocab at 0x261a7536d68>,
#  'silva': <gensim.models.keyedvectors.Vocab at 0x261a7536da0>,
#  'checa': <gensim.models.keyedvectors.Vocab at 0x261a7536e48>,
#  'campaña': <gensim.models.keyedvectors.Vocab at 0x261a7536e80>,
#  '2016': <gensim.models.keyedvectors.Vocab at 0x261a7536f28>,
#  'tesis': <gensim.models.keyedvectors.Vocab at 0x261a7536f60>,
#  'lidera': <gensim.models.keyedvectors.Vocab at 0x261a75360f0>,
#  'keiko': <gensim.models.keyedvectors.Vocab at 0x261a7536160>,
#  'recibido': <gensim.models.keyedvectors.Vocab at 0x261a7536208>,
#  'aportes': <gensim.models.keyedvectors.Vocab at 0x261a7536240>,
#  'irregulares': <gensim.models.keyedvectors.Vocab at 0x261a75362b0>,
#  'constructora': <gensim.models.keyedvectors.Vocab at 0x261a75362e8>,
#  'brasileña': <gensim.models.keyedvectors.Vocab at 0x261a7536400>,
#  'odebrecht': <gensim.models.keyedvectors.Vocab at 0x261a7536470>,
#  'financiamiento': <gensim.models.keyedvectors.Vocab at 0x261a6a22c18>,
#  'motivo': <gensim.models.keyedvectors.Vocab at 0x261a6a22c50>,
#  'lideresa': <gensim.models.keyedvectors.Vocab at 0x261a6a22cc0>,
#  'cumple': <gensim.models.keyedvectors.Vocab at 0x261a6a22cf8>,
#  'orden': <gensim.models.keyedvectors.Vocab at 0x261a6a22d68>,
#  'prisión': <gensim.models.keyedvectors.Vocab at 0x261a6a22e10>,
#  'preventiva': <gensim.models.keyedvectors.Vocab at 0x261a6a22eb8>,
#  '18': <gensim.models.keyedvectors.Vocab at 0x261a6a22f28>,
#  'lavado': <gensim.models.keyedvectors.Vocab at 0x261a6a22f60>,
#  'activos': <gensim.models.keyedvectors.Vocab at 0x261a6a22f98>,
#  'ministerio': <gensim.models.keyedvectors.Vocab at 0x261a6a22048>,
#  'público': <gensim.models.keyedvectors.Vocab at 0x261a6a22080>,
#  'sindica': <gensim.models.keyedvectors.Vocab at 0x261a6a22160>,
#  'asesor': <gensim.models.keyedvectors.Vocab at 0x261a6a22198>,
#  'sombras': <gensim.models.keyedvectors.Vocab at 0x261a6a22208>,
#  'higuchi': <gensim.models.keyedvectors.Vocab at 0x261a6a222b0>,
#  'consiguiente': <gensim.models.keyedvectors.Vocab at 0x261a6a223c8>,
#  'presunta': <gensim.models.keyedvectors.Vocab at 0x261a6a22400>,
#  'organización': <gensim.models.keyedvectors.Vocab at 0x261a6a22438>,
#  'criminal': <gensim.models.keyedvectors.Vocab at 0x261a6a224a8>,
#  'enquistado': <gensim.models.keyedvectors.Vocab at 0x261a6a22518>,
#  'relación': <gensim.models.keyedvectors.Vocab at 0x261a6a22550>,
#  'señalado': <gensim.models.keyedvectors.Vocab at 0x261a6a22588>,
#  'testaferros': <gensim.models.keyedvectors.Vocab at 0x261a6a225c0>,
#  'vladivideo': <gensim.models.keyedvectors.Vocab at 0x261a6a226a0>,
#  'compra': <gensim.models.keyedvectors.Vocab at 0x261a6a22748>,
#  'línea': <gensim.models.keyedvectors.Vocab at 0x261a6a227b8>,
#  'editorial': <gensim.models.keyedvectors.Vocab at 0x261a6a227f0>,
#  'cable': <gensim.models.keyedvectors.Vocab at 0x261a6a22860>,
#  'canal': <gensim.models.keyedvectors.Vocab at 0x261a6a22898>,
#  'noticias': <gensim.models.keyedvectors.Vocab at 0x261a6a228d0>,
#  'ccn': <gensim.models.keyedvectors.Vocab at 0x261a6a22908>,
#  'yolanda': <gensim.models.keyedvectors.Vocab at 0x261a6a22940>,
#  'rivera': <gensim.models.keyedvectors.Vocab at 0x261a6a229b0>,
#  'mujer': <gensim.models.keyedvectors.Vocab at 0x261a6a22a20>,
#  'murió': <gensim.models.keyedvectors.Vocab at 0x261a6a22a58>,
#  'atacada': <gensim.models.keyedvectors.Vocab at 0x261a6a22a90>,
#  'delincuentes': <gensim.models.keyedvectors.Vocab at 0x261a6a22ac8>,
#  'huían': <gensim.models.keyedvectors.Vocab at 0x261a6a22b00>,
#  'policía': <gensim.models.keyedvectors.Vocab at 0x261a6a22b38>,
#  'distrito': <gensim.models.keyedvectors.Vocab at 0x261a6a22ba8>,
#  'surco': <gensim.models.keyedvectors.Vocab at 0x261a7529080>,
#  'pidió': <gensim.models.keyedvectors.Vocab at 0x261a75290b8>,
#  'realicen': <gensim.models.keyedvectors.Vocab at 0x261a7529128>,
#  'necesarias': <gensim.models.keyedvectors.Vocab at 0x261a75291d0>,
#  'capturar': <gensim.models.keyedvectors.Vocab at 0x261a7529470>,
#  'criminales': <gensim.models.keyedvectors.Vocab at 0x261a7529588>,
#  'hija': <gensim.models.keyedvectors.Vocab at 0x261a75295f8>,
#  'hombre': <gensim.models.keyedvectors.Vocab at 0x261a7529630>,
#  'conmocionado': <gensim.models.keyedvectors.Vocab at 0x261a75296d8>,
#  'determina': <gensim.models.keyedvectors.Vocab at 0x261a7529860>,
#  'bala': <gensim.models.keyedvectors.Vocab at 0x261a7529940>,
#  'impactó': <gensim.models.keyedvectors.Vocab at 0x261a7529978>,
#  'policías': <gensim.models.keyedvectors.Vocab at 0x261a75299b0>,
#  'ladrones': <gensim.models.keyedvectors.Vocab at 0x261a75299e8>,
#  'culparse': <gensim.models.keyedvectors.Vocab at 0x261a7529a90>,
#  'efectivos': <gensim.models.keyedvectors.Vocab at 0x261a7529ac8>,
#  'cumplían': <gensim.models.keyedvectors.Vocab at 0x261a7529b00>,
#  'culpen': <gensim.models.keyedvectors.Vocab at 0x261a7529c18>,
#  'colegas': <gensim.models.keyedvectors.Vocab at 0x261a7529c50>,
#  'seguiré': <gensim.models.keyedvectors.Vocab at 0x261a7529c88>,
#  'siéndolo': <gensim.models.keyedvectors.Vocab at 0x261a7529d68>,
#  'muera': <gensim.models.keyedvectors.Vocab at 0x261a7529e10>,
#  'oficial': <gensim.models.keyedvectors.Vocab at 0x261a7529eb8>,
#  'retiro': <gensim.models.keyedvectors.Vocab at 0x261a7529ef0>,
#  'necesita': <gensim.models.keyedvectors.Vocab at 0x261a7529fd0>,
#  'urgencia': <gensim.models.keyedvectors.Vocab at 0x261a66b8a58>,
#  'país': <gensim.models.keyedvectors.Vocab at 0x261a66b8a90>,
#  'empezando': <gensim.models.keyedvectors.Vocab at 0x261a65f0a90>,
#  'falta': <gensim.models.keyedvectors.Vocab at 0x261a6454da0>,
#  'intervengan': <gensim.models.keyedvectors.Vocab at 0x261a62d8978>,
#  'vendan': <gensim.models.keyedvectors.Vocab at 0x261a65b3278>,
#  'dinero': <gensim.models.keyedvectors.Vocab at 0x261a65b36a0>,
#  'impartan': <gensim.models.keyedvectors.Vocab at 0x261a65b3128>,
#  'quiénes': <gensim.models.keyedvectors.Vocab at 0x261a623ef28>,
#  'corruptos': <gensim.models.keyedvectors.Vocab at 0x261a689f1d0>,
#  'corrupta': <gensim.models.keyedvectors.Vocab at 0x261a689f400>,
#  'manipulan': <gensim.models.keyedvectors.Vocab at 0x261a689f470>,
#  'juez': <gensim.models.keyedvectors.Vocab at 0x261a689f780>,
#  'pobre': <gensim.models.keyedvectors.Vocab at 0x261a689f940>,
#  'mete': <gensim.models.keyedvectors.Vocab at 0x261a689fa58>,
#  'balazo': <gensim.models.keyedvectors.Vocab at 0x261a689fcc0>,
#  'choro': <gensim.models.keyedvectors.Vocab at 0x261a689fda0>,
#  'queda': <gensim.models.keyedvectors.Vocab at 0x261a689fdd8>,
#  'preso': <gensim.models.keyedvectors.Vocab at 0x261a6652198>,
#  'pido': <gensim.models.keyedvectors.Vocab at 0x261a6655630>,
#  'luchen': <gensim.models.keyedvectors.Vocab at 0x261a75141d0>,
#  'quiero': <gensim.models.keyedvectors.Vocab at 0x261a7514208>,
#  'capture': <gensim.models.keyedvectors.Vocab at 0x261a7514438>,
#  'interesa': <gensim.models.keyedvectors.Vocab at 0x261a7514588>,
#  'balas': <gensim.models.keyedvectors.Vocab at 0x261a75145f8>,
#  'muerta': <gensim.models.keyedvectors.Vocab at 0x261a75146a0>,
#  'culpa': <gensim.models.keyedvectors.Vocab at 0x261a7514048>,
#  'única': <gensim.models.keyedvectors.Vocab at 0x261a7514080>,
#  'quebrarse': <gensim.models.keyedvectors.Vocab at 0x261a75140b8>,
#  'datos': <gensim.models.keyedvectors.Vocab at 0x261a7514908>,
#  '29': <gensim.models.keyedvectors.Vocab at 0x261a7514a58>,
#  'casquillos': <gensim.models.keyedvectors.Vocab at 0x261a7514a90>,
#  'encontraron': <gensim.models.keyedvectors.Vocab at 0x261a7514b38>,
#  'balacera': <gensim.models.keyedvectors.Vocab at 0x261a7514c18>,
#  'molina': <gensim.models.keyedvectors.Vocab at 0x261a7514c88>,
#  'esposo': <gensim.models.keyedvectors.Vocab at 0x261a7514da0>,
#  'herido': <gensim.models.keyedvectors.Vocab at 0x261a7514f60>,
#  'brazo': <gensim.models.keyedvectors.Vocab at 0x261a7514940>,
#  'exjuez': <gensim.models.keyedvectors.Vocab at 0x261a658a7b8>,
#  'supremo': <gensim.models.keyedvectors.Vocab at 0x261a658ab70>,
#  'césar': <gensim.models.keyedvectors.Vocab at 0x261a658a2e8>,
#  'hinostroza': <gensim.models.keyedvectors.Vocab at 0x261a658a400>,
#  'confirmó': <gensim.models.keyedvectors.Vocab at 0x261a658a588>,
#  'recurrirá': <gensim.models.keyedvectors.Vocab at 0x261a6617ba8>,
#  'tribunal': <gensim.models.keyedvectors.Vocab at 0x261a6617160>,
#  'constitucional': <gensim.models.keyedvectors.Vocab at 0x261a66826a0>,
#  'españa': <gensim.models.keyedvectors.Vocab at 0x261a66827f0>,
#  'buscar': <gensim.models.keyedvectors.Vocab at 0x261a66829e8>,
#  'anular': <gensim.models.keyedvectors.Vocab at 0x261a6682b00>,
#  'extradición': <gensim.models.keyedvectors.Vocab at 0x261a66824a8>,
#  'aprobada': <gensim.models.keyedvectors.Vocab at 0x261a74ca048>,
#  'audiencia': <gensim.models.keyedvectors.Vocab at 0x261a74ca160>,
#  'difundido': <gensim.models.keyedvectors.Vocab at 0x261a74ca198>,
#  'rpp': <gensim.models.keyedvectors.Vocab at 0x261a74ca400>,
#  'asegura': <gensim.models.keyedvectors.Vocab at 0x261a74ca470>,
#  'sentencia': <gensim.models.keyedvectors.Vocab at 0x261a74ca4e0>,
#  'rechazó': <gensim.models.keyedvectors.Vocab at 0x261a74ca588>,
#  'repatriación': <gensim.models.keyedvectors.Vocab at 0x261a74ca6d8>,
#  'cuestionó': <gensim.models.keyedvectors.Vocab at 0x261a74ca860>,
#  'aceptado': <gensim.models.keyedvectors.Vocab at 0x261a74ca908>,
#  'imputan': <gensim.models.keyedvectors.Vocab at 0x261a74ca978>,
#  'conformes': <gensim.models.keyedvectors.Vocab at 0x261a74cab38>,
#  'rechazo': <gensim.models.keyedvectors.Vocab at 0x261a74caba8>,
#  'patrocinio': <gensim.models.keyedvectors.Vocab at 0x261a74cac50>,
#  'ilegal': <gensim.models.keyedvectors.Vocab at 0x261a74cacf8>,
#  'tráfico': <gensim.models.keyedvectors.Vocab at 0x261a74cadd8>,
#  'influencias': <gensim.models.keyedvectors.Vocab at 0x261a74cae10>,
#  'negociación': <gensim.models.keyedvectors.Vocab at 0x261a74cafd0>,
#  'incompatible': <gensim.models.keyedvectors.Vocab at 0x261a74ca898>,
#  'españoles': <gensim.models.keyedvectors.Vocab at 0x261a7534f98>,
#  'erróneamente': <gensim.models.keyedvectors.Vocab at 0x261a75340b8>,
#  'interpretado': <gensim.models.keyedvectors.Vocab at 0x261a7534128>,
#  'exmagistrado': <gensim.models.keyedvectors.Vocab at 0x261a7534198>,
#  'interponer': <gensim.models.keyedvectors.Vocab at 0x261a7534208>,
#  'recurso': <gensim.models.keyedvectors.Vocab at 0x261a7534358>,
#  'amparo': <gensim.models.keyedvectors.Vocab at 0x261a7534400>,
#  'español': <gensim.models.keyedvectors.Vocab at 0x261a7534588>,
#  'eventualmente': <gensim.models.keyedvectors.Vocab at 0x261a75345f8>,
#  'europeo': <gensim.models.keyedvectors.Vocab at 0x261a7534748>,
#  'defensa': <gensim.models.keyedvectors.Vocab at 0x261a7534780>,
#  'carácter': <gensim.models.keyedvectors.Vocab at 0x261a75348d0>,
#  'universal': <gensim.models.keyedvectors.Vocab at 0x261a7534908>,
#  'reiteró': <gensim.models.keyedvectors.Vocab at 0x261a7534940>,
#  'imputados': <gensim.models.keyedvectors.Vocab at 0x261a7534a58>,
#  'aprobados': <gensim.models.keyedvectors.Vocab at 0x261a7534a90>,
#  'congreso': <gensim.models.keyedvectors.Vocab at 0x261a7534ac8>,
#  'actuó': <gensim.models.keyedvectors.Vocab at 0x261a7534b00>,
#  'presión': <gensim.models.keyedvectors.Vocab at 0x261a7534b38>,
#  'ley': <gensim.models.keyedvectors.Vocab at 0x261a7534be0>,
#  'española': <gensim.models.keyedvectors.Vocab at 0x261a7534da0>,
#  'penalistas': <gensim.models.keyedvectors.Vocab at 0x261a7534dd8>,
#  'sindicado': <gensim.models.keyedvectors.Vocab at 0x261a6ae2e48>,
#  'cabecilla': <gensim.models.keyedvectors.Vocab at 0x261a6ae2e80>,
#  'cuellos': <gensim.models.keyedvectors.Vocab at 0x261a6ae2ef0>,
#  'blancos': <gensim.models.keyedvectors.Vocab at 0x261a6ae2f28>,
#  'puerto': <gensim.models.keyedvectors.Vocab at 0x261a6ae2f98>,
#  'pesan': <gensim.models.keyedvectors.Vocab at 0x261a6ae2048>,
#  'órdenes': <gensim.models.keyedvectors.Vocab at 0x261a6ae2080>,
#  'caso': <gensim.models.keyedvectors.Vocab at 0x261a6ae20b8>,
#  'salido': <gensim.models.keyedvectors.Vocab at 0x261a6ae20f0>,
#  'pese': <gensim.models.keyedvectors.Vocab at 0x261a6ae2128>,
#  'impedimento': <gensim.models.keyedvectors.Vocab at 0x261a6ae2278>,
#  'abandonar': <gensim.models.keyedvectors.Vocab at 0x261a6ae22b0>,
#  'perú': <gensim.models.keyedvectors.Vocab at 0x261a6ae22e8>,
#  'salir': <gensim.models.keyedvectors.Vocab at 0x261a6ae2320>,
#  'internacional': <gensim.models.keyedvectors.Vocab at 0x261a6ae2358>,
#  'respetan': <gensim.models.keyedvectors.Vocab at 0x261a6ae2390>,
#  'evadir': <gensim.models.keyedvectors.Vocab at 0x261a6ae23c8>,
#  'fugar': <gensim.models.keyedvectors.Vocab at 0x261a6ae2400>,
#  'falsamente': <gensim.models.keyedvectors.Vocab at 0x261a6ae24a8>,
#  'menciona': <gensim.models.keyedvectors.Vocab at 0x261a6ae2518>,
#  'saludado': <gensim.models.keyedvectors.Vocab at 0x261a6ae2588>,
#  'extraditarlo': <gensim.models.keyedvectors.Vocab at 0x261a6ae25c0>,
#  'sigan': <gensim.models.keyedvectors.Vocab at 0x261a6ae2630>,
#  'acusando': <gensim.models.keyedvectors.Vocab at 0x261a6ae2668>,
#  'espero': <gensim.models.keyedvectors.Vocab at 0x261a6ae26d8>,
#  'dejen': <gensim.models.keyedvectors.Vocab at 0x261a6ae2748>,
#  'dignidad': <gensim.models.keyedvectors.Vocab at 0x261a6ae27b8>,
#  'humana': <gensim.models.keyedvectors.Vocab at 0x261a6ae2860>,
#  'horas': <gensim.models.keyedvectors.Vocab at 0x261a6ae2898>,
#  'oficina': <gensim.models.keyedvectors.Vocab at 0x261a6ae28d0>,
#  'volvían': <gensim.models.keyedvectors.Vocab at 0x261a6ae2908>,
#  'eternas': <gensim.models.keyedvectors.Vocab at 0x261a6ae2940>,
# ...
#  'inconclusos': <gensim.models.keyedvectors.Vocab at 0x261a6a3cbe0>,
#  'finalizar': <gensim.models.keyedvectors.Vocab at 0x261a6a3cc88>,
#  'escuela': <gensim.models.keyedvectors.Vocab at 0x261a6a3ccc0>,
#  'cocinero': <gensim.models.keyedvectors.Vocab at 0x261a6a3ccf8>,
#  'regresaría': <gensim.models.keyedvectors.Vocab at 0x261a6a3cd30>,
#  'tarde': <gensim.models.keyedvectors.Vocab at 0x261a6a3ce10>,
#  'perteneció': <gensim.models.keyedvectors.Vocab at 0x261a6a3ce48>,
#  'empresas': <gensim.models.keyedvectors.Vocab at 0x261a6a3cf28>,
#  'importantes': <gensim.models.keyedvectors.Vocab at 0x261a6a3cf60>,
#  'semanas': <gensim.models.keyedvectors.Vocab at 0x261a6a3cfd0>,
#  'llegaban': <gensim.models.keyedvectors.Vocab at 0x261a6a3c048>,
#  'ajenas': <gensim.models.keyedvectors.Vocab at 0x261a6a3c080>,
#  'debía': <gensim.models.keyedvectors.Vocab at 0x261a6a3c0b8>,
#  'encaminar': <gensim.models.keyedvectors.Vocab at 0x261a6a3c0f0>,
#  'pensó': <gensim.models.keyedvectors.Vocab at 0x261a6a3c128>,
#  'destino': <gensim.models.keyedvectors.Vocab at 0x261a6a3c160>,
#  'saco': <gensim.models.keyedvectors.Vocab at 0x261a6a3c198>,
#  'corbata': <gensim.models.keyedvectors.Vocab at 0x261a6a3c1d0>,
#  'sentado': <gensim.models.keyedvectors.Vocab at 0x261a6a3c278>,
#  'frente': <gensim.models.keyedvectors.Vocab at 0x261a6a3c2b0>,
#  'pantalla': <gensim.models.keyedvectors.Vocab at 0x261a6a3c2e8>,
#  'escritorio': <gensim.models.keyedvectors.Vocab at 0x261a6a3c358>,
#  'viaje': <gensim.models.keyedvectors.Vocab at 0x261a6a3c3c8>,
#  'sao': <gensim.models.keyedvectors.Vocab at 0x261a6a3c400>,
#  'paulo': <gensim.models.keyedvectors.Vocab at 0x261a6a3c438>,
#  'probó': <gensim.models.keyedvectors.Vocab at 0x261a6a3c4a8>,
#  'pizza': <gensim.models.keyedvectors.Vocab at 0x261a6a3c550>,
#  'común': <gensim.models.keyedvectors.Vocab at 0x261a6a3c588>,
#  'insumos': <gensim.models.keyedvectors.Vocab at 0x261a6a3c5c0>,
#  'brasileños': <gensim.models.keyedvectors.Vocab at 0x261a6a3c5f8>,
#  'masa': <gensim.models.keyedvectors.Vocab at 0x261a6a3c630>,
#  'tradicional': <gensim.models.keyedvectors.Vocab at 0x261a6a3c668>,
#  'dejando': <gensim.models.keyedvectors.Vocab at 0x261a6a3c6a0>,
#  'típica': <gensim.models.keyedvectors.Vocab at 0x261a6a3c710>,
#  'americana': <gensim.models.keyedvectors.Vocab at 0x261a6a3c748>,
#  'pepperoni': <gensim.models.keyedvectors.Vocab at 0x261a6a3c7b8>,
#  'allí': <gensim.models.keyedvectors.Vocab at 0x261a6a3c860>,
#  'supo': <gensim.models.keyedvectors.Vocab at 0x261a6a3c898>,
#  'cuál': <gensim.models.keyedvectors.Vocab at 0x261a6a3c8d0>,
#  'camino': <gensim.models.keyedvectors.Vocab at 0x261a6a3c940>,
#  'jefes': <gensim.models.keyedvectors.Vocab at 0x261a6a3c9b0>,
#  'inauguró': <gensim.models.keyedvectors.Vocab at 0x261a6442710>,
#  'oficialmente': <gensim.models.keyedvectors.Vocab at 0x261a65191d0>,
#  'agosto': <gensim.models.keyedvectors.Vocab at 0x261a65195c0>,
#  '2017': <gensim.models.keyedvectors.Vocab at 0x261a65197f0>,
#  'surquillo': <gensim.models.keyedvectors.Vocab at 0x261a66760f0>,
#  'ahorros': <gensim.models.keyedvectors.Vocab at 0x261a6676438>,
#  'bastaron': <gensim.models.keyedvectors.Vocab at 0x261a66765f8>,
#  'alquilar': <gensim.models.keyedvectors.Vocab at 0x261a6676748>,
#  'local': <gensim.models.keyedvectors.Vocab at 0x261a6676780>,
#  'adquirir': <gensim.models.keyedvectors.Vocab at 0x261a67a8f60>,
#  'maquinaria': <gensim.models.keyedvectors.Vocab at 0x261a67a8e10>,
#  'preguntaba': <gensim.models.keyedvectors.Vocab at 0x261a67a80b8>,
#  'metido': <gensim.models.keyedvectors.Vocab at 0x261a67a89b0>,
#  'mano': <gensim.models.keyedvectors.Vocab at 0x261a67a8c50>,
#  'empezó': <gensim.models.keyedvectors.Vocab at 0x261a67a8dd8>,
#  'platos': <gensim.models.keyedvectors.Vocab at 0x261a6b7b6a0>,
#  'adecuarlos': <gensim.models.keyedvectors.Vocab at 0x261a6b7bf98>,
#  'vea': <gensim.models.keyedvectors.Vocab at 0x261a6b7b278>,
#  'sepa': <gensim.models.keyedvectors.Vocab at 0x261a6b7b240>,
#  'decidió': <gensim.models.keyedvectors.Vocab at 0x261a6b7b2b0>,
#  'negocio': <gensim.models.keyedvectors.Vocab at 0x261a6b7b2e8>,
#  'demandar': <gensim.models.keyedvectors.Vocab at 0x261a6b7b320>,
#  'tantas': <gensim.models.keyedvectors.Vocab at 0x261a6b7b358>,
#  'creó': <gensim.models.keyedvectors.Vocab at 0x261a6b7b390>,
#  'cocina': <gensim.models.keyedvectors.Vocab at 0x261a6b7b3c8>,
#  'fantasma': <gensim.models.keyedvectors.Vocab at 0x261a6b7b400>,
#  'producción': <gensim.models.keyedvectors.Vocab at 0x261a6b7b438>,
#  'repartida': <gensim.models.keyedvectors.Vocab at 0x261a6b7b470>,
#  'horario': <gensim.models.keyedvectors.Vocab at 0x261a6b7b4a8>,
#  '6': <gensim.models.keyedvectors.Vocab at 0x261a6b7b4e0>,
#  '11': <gensim.models.keyedvectors.Vocab at 0x261a6b7b518>,
#  'pm': <gensim.models.keyedvectors.Vocab at 0x261a6b7b550>,
#  'intención': <gensim.models.keyedvectors.Vocab at 0x261a6b7b588>,
#  'imitar': <gensim.models.keyedvectors.Vocab at 0x261a6b7b5f8>,
#  'corriente': <gensim.models.keyedvectors.Vocab at 0x261a6b7b630>,
#  'proviene': <gensim.models.keyedvectors.Vocab at 0x261a6b7b668>,
#  'europa': <gensim.models.keyedvectors.Vocab at 0x261a6b7b048>,
#  'asia': <gensim.models.keyedvectors.Vocab at 0x261a6b7b0b8>,
#  'unidos': <gensim.models.keyedvectors.Vocab at 0x261a6b7b0f0>,
#  'aplicó': <gensim.models.keyedvectors.Vocab at 0x261a6b7b128>,
#  'teoría': <gensim.models.keyedvectors.Vocab at 0x261a6b7b160>,
#  'empresa': <gensim.models.keyedvectors.Vocab at 0x261a6b7b198>,
#  'presencia': <gensim.models.keyedvectors.Vocab at 0x261a6b7b1d0>,
#  'aplicaciones': <gensim.models.keyedvectors.Vocab at 0x261a6b7b6d8>,
#  'físico': <gensim.models.keyedvectors.Vocab at 0x261a6b7b710>,
#  'emprendimiento': <gensim.models.keyedvectors.Vocab at 0x261a6b7b748>,
#  'agregado': <gensim.models.keyedvectors.Vocab at 0x261a6b7b780>,
#  'cajas': <gensim.models.keyedvectors.Vocab at 0x261a6b7b7b8>,
#  'obras': <gensim.models.keyedvectors.Vocab at 0x261a6b7b7f0>,
#  'arte': <gensim.models.keyedvectors.Vocab at 0x261a6b7b828>,
#  'exhibe': <gensim.models.keyedvectors.Vocab at 0x261a6b7b860>,
#  'creaciones': <gensim.models.keyedvectors.Vocab at 0x261a6b7b8d0>,
#  'ilustradores': <gensim.models.keyedvectors.Vocab at 0x261a6b7b908>,
#  'temas': <gensim.models.keyedvectors.Vocab at 0x261a6b7b940>,
#  'nacionales': <gensim.models.keyedvectors.Vocab at 0x261a6b7b978>,
#  'lema': <gensim.models.keyedvectors.Vocab at 0x261a6b7b9b0>,
#  'consenso': <gensim.models.keyedvectors.Vocab at 0x261a6b7b9e8>,
#  'u': <gensim.models.keyedvectors.Vocab at 0x261a6b7ba20>,
#  'cambie': <gensim.models.keyedvectors.Vocab at 0x261a6b7ba58>,
#  'lote': <gensim.models.keyedvectors.Vocab at 0x261a6b7ba90>,
#  'primeras': <gensim.models.keyedvectors.Vocab at 0x261a6b7bac8>,
#  'diseñadas': <gensim.models.keyedvectors.Vocab at 0x261a6b7bb00>,
#  'rojas': <gensim.models.keyedvectors.Vocab at 0x261a6b7bb38>,
#  'perros': <gensim.models.keyedvectors.Vocab at 0x261a6b7bb70>,
#  'alpaca': <gensim.models.keyedvectors.Vocab at 0x261a6b7bba8>,
#  'temporada': <gensim.models.keyedvectors.Vocab at 0x261a6b7bbe0>,
#  'alegre': <gensim.models.keyedvectors.Vocab at 0x261a6b7bc18>,
#  'llegue': <gensim.models.keyedvectors.Vocab at 0x261a6b7bc50>,
#  'hogares': <gensim.models.keyedvectors.Vocab at 0x261a6b7bc88>,
#  'limeños': <gensim.models.keyedvectors.Vocab at 0x261a6b7bcc0>,
#  'aureola': <gensim.models.keyedvectors.Vocab at 0x261a6b7bcf8>,
#  'princesa': <gensim.models.keyedvectors.Vocab at 0x261a6b7bd30>,
#  'promueve': <gensim.models.keyedvectors.Vocab at 0x261a6b7bd68>,
#  'peruano': <gensim.models.keyedvectors.Vocab at 0x261a6b7bda0>,
#  'voltee': <gensim.models.keyedvectors.Vocab at 0x261a6b7bdd8>,
#  'éxito': <gensim.models.keyedvectors.Vocab at 0x261a6b7be10>,
#  'vertiginoso': <gensim.models.keyedvectors.Vocab at 0x261a6b7be48>,
#  '2x1': <gensim.models.keyedvectors.Vocab at 0x261a6b7be80>,
#  'distribuir': <gensim.models.keyedvectors.Vocab at 0x261a6b7beb8>,
#  'pizzas': <gensim.models.keyedvectors.Vocab at 0x261a6b7bef0>,
#  'comensales': <gensim.models.keyedvectors.Vocab at 0x261a6b7bf28>,
#  'enamoraron': <gensim.models.keyedvectors.Vocab at 0x261a6b7bf60>,
#  'sabores': <gensim.models.keyedvectors.Vocab at 0x261a6b7bfd0>,
#  'langostinos': <gensim.models.keyedvectors.Vocab at 0x261a6b9c048>,
#  'anticucheros': <gensim.models.keyedvectors.Vocab at 0x261a6b9c080>,
#  'lanzado': <gensim.models.keyedvectors.Vocab at 0x261a6b9c0b8>,
#  'verano': <gensim.models.keyedvectors.Vocab at 0x261a6b9c0f0>,
#  'quedado': <gensim.models.keyedvectors.Vocab at 0x261a6b9c128>,
#  'butifarra': <gensim.models.keyedvectors.Vocab at 0x261a6b9c160>,
#  'huachana': <gensim.models.keyedvectors.Vocab at 0x261a6b9c198>,
#  'llegar': <gensim.models.keyedvectors.Vocab at 0x261a6b9c1d0>,
#  'plasmar': <gensim.models.keyedvectors.Vocab at 0x261a6b9c208>,
#  'idea': <gensim.models.keyedvectors.Vocab at 0x261a6b9c240>,
#  'unir': <gensim.models.keyedvectors.Vocab at 0x261a6b9c278>,
#  'tradiciones': <gensim.models.keyedvectors.Vocab at 0x261a6b9c2b0>,
#  'italiana': <gensim.models.keyedvectors.Vocab at 0x261a6b9c2e8>,
#  'difícil': <gensim.models.keyedvectors.Vocab at 0x261a6b9c320>,
#  'constante': <gensim.models.keyedvectors.Vocab at 0x261a6b9c358>,
#  'prueba': <gensim.models.keyedvectors.Vocab at 0x261a6b9c390>,
#  'error': <gensim.models.keyedvectors.Vocab at 0x261a6b9c3c8>,
#  'parecían': <gensim.models.keyedvectors.Vocab at 0x261a6b9c400>,
#  'contundentes': <gensim.models.keyedvectors.Vocab at 0x261a6b9c438>,
#  'faltaba': <gensim.models.keyedvectors.Vocab at 0x261a6b9c470>,
#  'arroz': <gensim.models.keyedvectors.Vocab at 0x261a6b9c4a8>,
#  'bota': <gensim.models.keyedvectors.Vocab at 0x261a6b9c4e0>,
#  'carcajada': <gensim.models.keyedvectors.Vocab at 0x261a6b9c518>,
#  'cómplice': <gensim.models.keyedvectors.Vocab at 0x261a6b9c550>,
#  'colaboradores': <gensim.models.keyedvectors.Vocab at 0x261a6b9c588>,
#  'desarrollado': <gensim.models.keyedvectors.Vocab at 0x261a6b9c5c0>,
#  'entramos': <gensim.models.keyedvectors.Vocab at 0x261a6b9c5f8>,
#  'fase': <gensim.models.keyedvectors.Vocab at 0x261a6b9c630>,
#  'multiplicar': <gensim.models.keyedvectors.Vocab at 0x261a6b9c668>,
#  'planea': <gensim.models.keyedvectors.Vocab at 0x261a6b9c6a0>,
#  'meta': <gensim.models.keyedvectors.Vocab at 0x261a6b9c6d8>,
#  'denominación': <gensim.models.keyedvectors.Vocab at 0x261a6b9c710>,
#  'mundial': <gensim.models.keyedvectors.Vocab at 0x261a6b9c748>,
#  'gringo': <gensim.models.keyedvectors.Vocab at 0x261a6b9c780>,
#  'diga': <gensim.models.keyedvectors.Vocab at 0x261a6b9c7b8>,
#  'are': <gensim.models.keyedvectors.Vocab at 0x261a6b9c7f0>,
#  'you': <gensim.models.keyedvectors.Vocab at 0x261a6b9c828>,
#  'eating': <gensim.models.keyedvectors.Vocab at 0x261a6b9c860>,
#  'respondas': <gensim.models.keyedvectors.Vocab at 0x261a6b9c898>,
#  'rapidez': <gensim.models.keyedvectors.Vocab at 0x261a6b9c8d0>,
#  'calidad': <gensim.models.keyedvectors.Vocab at 0x261a6b9c908>,
#  'maneja': <gensim.models.keyedvectors.Vocab at 0x261a6b9c978>,
#  'fast': <gensim.models.keyedvectors.Vocab at 0x261a6b9c9b0>,
#  'food': <gensim.models.keyedvectors.Vocab at 0x261a6b9c9e8>,
#  'estándares': <gensim.models.keyedvectors.Vocab at 0x261a6b9ca20>,
#  'exactos': <gensim.models.keyedvectors.Vocab at 0x261a6b9ca58>,
#  'señalización': <gensim.models.keyedvectors.Vocab at 0x261a6b9ca90>,
#  'porciones': <gensim.models.keyedvectors.Vocab at 0x261a6b9cac8>,
#  'tiempos': <gensim.models.keyedvectors.Vocab at 0x261a6b9cb00>,
#  'digital': <gensim.models.keyedvectors.Vocab at 0x261a6b9cb38>,
#  'facebook': <gensim.models.keyedvectors.Vocab at 0x261a6b9cb70>,
#  'lapiczaperu': <gensim.models.keyedvectors.Vocab at 0x261a6b9cba8>,
#  'rappi': <gensim.models.keyedvectors.Vocab at 0x261a6b9cbe0>,
#  'vital': <gensim.models.keyedvectors.Vocab at 0x261a6b9cc18>,
#  'dejar': <gensim.models.keyedvectors.Vocab at 0x261a6b9cc50>,
#  'escuchar': <gensim.models.keyedvectors.Vocab at 0x261a6b9cc88>,
#  'aconseja': <gensim.models.keyedvectors.Vocab at 0x261a6b9ccf8>,
#  'recomendaciones': <gensim.models.keyedvectors.Vocab at 0x261a6b9cd30>,
#  'emprender': <gensim.models.keyedvectors.Vocab at 0x261a6b9cd68>,
#  'resuelve': <gensim.models.keyedvectors.Vocab at 0x261a6b9cda0>,
#  'pensar': <gensim.models.keyedvectors.Vocab at 0x261a6b9cdd8>,
#  'locura': <gensim.models.keyedvectors.Vocab at 0x261a6b9ce10>,
#  'números': <gensim.models.keyedvectors.Vocab at 0x261a6b9ce48>,
#  'equilibrio': <gensim.models.keyedvectors.Vocab at 0x261a6b9ce80>,
#  'proyecciones': <gensim.models.keyedvectors.Vocab at 0x261a6b9ceb8>,
#  'futuro': <gensim.models.keyedvectors.Vocab at 0x261a6b9cef0>,
#  'piensa': <gensim.models.keyedvectors.Vocab at 0x261a6b9cf28>,
#  'generar': <gensim.models.keyedvectors.Vocab at 0x261a6b9cf60>,
#  'franquicias': <gensim.models.keyedvectors.Vocab at 0x261a6b9cf98>,
#  'caiga': <gensim.models.keyedvectors.Vocab at 0x261a6b9cfd0>,
#  'peso': <gensim.models.keyedvectors.Vocab at 0x261a6766b70>,
#  'anhela': <gensim.models.keyedvectors.Vocab at 0x261a6766cc0>,
#  'imite': <gensim.models.keyedvectors.Vocab at 0x261a64ee208>,
#  'cree': <gensim.models.keyedvectors.Vocab at 0x261a64ee9e8>,
#  'genérico': <gensim.models.keyedvectors.Vocab at 0x261a64eee48>,
#  'metió': <gensim.models.keyedvectors.Vocab at 0x261a62ade48>,
#  'masificar': <gensim.models.keyedvectors.Vocab at 0x261a668bb00>,
#  'producto': <gensim.models.keyedvectors.Vocab at 0x261a668bf28>,
#  'sabor': <gensim.models.keyedvectors.Vocab at 0x261a6bad978>,
#  'proporciones': <gensim.models.keyedvectors.Vocab at 0x261a6bad940>,
#  'generosas': <gensim.models.keyedvectors.Vocab at 0x261a6bad9b0>,
#  'gusta': <gensim.models.keyedvectors.Vocab at 0x261a6bad9e8>,
#  'principal': <gensim.models.keyedvectors.Vocab at 0x261a6bada20>,
#  'motivación': <gensim.models.keyedvectors.Vocab at 0x261a6bada58>,
#  'cuestionas': <gensim.models.keyedvectors.Vocab at 0x261a6bada90>,
#  'veía': <gensim.models.keyedvectors.Vocab at 0x261a6badac8>,
#  'trabajando': <gensim.models.keyedvectors.Vocab at 0x261a6badb00>,
#  'empleado': <gensim.models.keyedvectors.Vocab at 0x261a6badb38>,
#  'di': <gensim.models.keyedvectors.Vocab at 0x261a6badb70>,
#  'quise': <gensim.models.keyedvectors.Vocab at 0x261a6badba8>,
#  'aprobar': <gensim.models.keyedvectors.Vocab at 0x261a6badbe0>,
#  'dificultad': <gensim.models.keyedvectors.Vocab at 0x261a6badc18>,
#  'encontraste': <gensim.models.keyedvectors.Vocab at 0x261a6badc50>,
#  'superaste': <gensim.models.keyedvectors.Vocab at 0x261a6badc88>,
#  'cercana': <gensim.models.keyedvectors.Vocab at 0x261a6badcc0>,
#  'ayude': <gensim.models.keyedvectors.Vocab at 0x261a6badcf8>,
#  'asesorarse': <gensim.models.keyedvectors.Vocab at 0x261a6badd30>,
#  'pedir': <gensim.models.keyedvectors.Vocab at 0x261a6badd68>,
#  'ayuda': <gensim.models.keyedvectors.Vocab at 0x261a6badda0>,
#  'ahorrado': <gensim.models.keyedvectors.Vocab at 0x261a6baddd8>,
#  'comprarme': <gensim.models.keyedvectors.Vocab at 0x261a6bade10>,
#  'depa': <gensim.models.keyedvectors.Vocab at 0x261a6bade48>,
#  'decidí': <gensim.models.keyedvectors.Vocab at 0x261a6badeb8>,
#  'invertir': <gensim.models.keyedvectors.Vocab at 0x261a6bade80>,
#  'plata': <gensim.models.keyedvectors.Vocab at 0x261a6badef0>,
#  'contratan': <gensim.models.keyedvectors.Vocab at 0x261a6badf28>,
#  'decirles': <gensim.models.keyedvectors.Vocab at 0x261a6badf60>,
#  'fortaleza': <gensim.models.keyedvectors.Vocab at 0x261a6badf98>,
#  'creer': <gensim.models.keyedvectors.Vocab at 0x261a6badfd0>,
#  'crear': <gensim.models.keyedvectors.Vocab at 0x261a6bad048>,
#  'día': <gensim.models.keyedvectors.Vocab at 0x261a6bad080>,
#  'casa': <gensim.models.keyedvectors.Vocab at 0x261a6bad0b8>,
#  'haga': <gensim.models.keyedvectors.Vocab at 0x261a6bad0f0>,
#  'vacilón': <gensim.models.keyedvectors.Vocab at 0x261a6bad128>,
#  'salchicha': <gensim.models.keyedvectors.Vocab at 0x261a6bad160>,
#  'huacho': <gensim.models.keyedvectors.Vocab at 0x261a6bad198>,
#  'gastronomía': <gensim.models.keyedvectors.Vocab at 0x261a6bad1d0>,
#  'mallory': <gensim.models.keyedvectors.Vocab at 0x261a6bad208>,
#  'aco': <gensim.models.keyedvectors.Vocab at 0x261a6bad240>,
#  'logró': <gensim.models.keyedvectors.Vocab at 0x261a6bad278>,
#  'medalla': <gensim.models.keyedvectors.Vocab at 0x261a6bad2b0>,
#  ...}

# %%
model.save('w2v300_6.model')
