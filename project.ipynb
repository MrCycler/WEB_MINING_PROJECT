# %% [markdown]
# ## 1. Recolección de datos

# %%
import pandas as pd
import numpy as pn
import ast

data = pd.read_csv('el_comercio_test.csv')

# %% [markdown]
# ## 2. Análisis de la exploración de datos

# %%
data.head()
# Out:
#                                               Titulo  \
# 0  [AHORA] América vs. Pumas UNAM EN VIVO transmi...
# 1  América vs. Pumas UNAM: Sebastián Córdova fue ...
# 2  [EN VIVO] América vs. Pumas UNAM VER AQUÍ EN D...
# 3  Keiko Fujimori fue internada en clínica local ...
# 4  Sporting Cristal vs. Municipal: duelo por la j...
#
#                                              Resumen       Categoria  \
# 0  \nAmérica vs. Pumas UNAM EN VIVO | ONLINE sigu...  Fútbol mundial
# 1  Juan Pablo Vigón fue el jugador de Pumas UNAM ...  Fútbol mundial
# 2  \nAmérica vs. Pumas EN VIVO EN DIRECTO | Sigue...  Fútbol mundial
# 3  Información fue confirmada por su abogada Giul...        Política
# 4  \nSporting Cristal visita este domingo (04:00 ...  Fútbol peruano
#
#              Autor                      Fecha  \
# 0    Redacción DT   2019-09-14T22:51:00-05:00
# 1    Redacción DT   2019-09-14T22:50:19-05:00
# 2    Redacción DT   2019-09-14T22:50:00-05:00
# 3             None  2019-09-14T22:43:07-05:00
# 4    Redacción DT   2019-09-14T22:35:41-05:00
#
#                                            Contenido  \
# 0  ['América vs. Pumas UNAM EN VIVO | ONLINE sigu...
# 1  ["El choque entre América y Pumas UNAM se desv...
# 2  ['América vs. Pumas EN VIVO EN DIRECTO se mide...
# 3  ['La lideresa de Fuerza Popular, Keiko Fujimor...
# 4  ['Sporting Cristal vs. Municipal EN VIVO ONLIN...
#
#                                            Etiquetas  \
# 0               ['América', 'Liga MX', 'Pumas UNAM']
# 1  ['América de México', 'Pumas UNAM', 'Liga MX 2...
# 2               ['América', 'Liga MX', 'Pumas UNAM']
# 3                                 ['Keiko Fujimori']
# 4  ['Liga 1', 'Sporting Cristal', 'Deportivo Muni...
#
#                                               Enlace       Fuente
# 0  https://elcomercio.pe/deporte-total/futbol-mun...  El Comercio
# 1  https://elcomercio.pe/deporte-total/futbol-mun...  El Comercio
# 2  https://elcomercio.pe/deporte-total/futbol-mun...  El Comercio
# 3  https://elcomercio.pe/politica/keiko-fujimori-...  El Comercio
# 4  https://elcomercio.pe/deporte-total/futbol-per...  El Comercio

# %% [markdown]
# #### Diccionario de datos
# - Titulo
# - Resumen
# - Categoria
# - Fecha
# - Contenido
# - Etiquetas
# - Enlace
# - Fuente

# %% [markdown]
# #### Total de columnas y filas

# %%
data.shape
# Out:
# (1000, 9)

# %% [markdown]
# #### Ver la información del conjunto de datos

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
# Titulo       1000 non-null object
# Resumen      1000 non-null object
# Categoria    1000 non-null object
# Autor        1000 non-null object
# Fecha        1000 non-null object
# Contenido    1000 non-null object
# Etiquetas    1000 non-null object
# Enlace       1000 non-null object
# Fuente       1000 non-null object
# dtypes: object(9)
# memory usage: 70.4+ KB

# %% [markdown]
# ## 3. Procesamiento de datos

# %%
data = data.drop(["Resumen", "Categoria", "Autor", "Etiquetas"], axis=1)

# %%
data.head()
# Out:
#                                               Titulo  \
# 0  [AHORA] América vs. Pumas UNAM EN VIVO transmi...
# 1  América vs. Pumas UNAM: Sebastián Córdova fue ...
# 2  [EN VIVO] América vs. Pumas UNAM VER AQUÍ EN D...
# 3  Keiko Fujimori fue internada en clínica local ...
# 4  Sporting Cristal vs. Municipal: duelo por la j...
#
#                        Fecha  \
# 0  2019-09-14T22:51:00-05:00
# 1  2019-09-14T22:50:19-05:00
# 2  2019-09-14T22:50:00-05:00
# 3  2019-09-14T22:43:07-05:00
# 4  2019-09-14T22:35:41-05:00
#
#                                            Contenido  \
# 0  ['América vs. Pumas UNAM EN VIVO | ONLINE sigu...
# 1  ["El choque entre América y Pumas UNAM se desv...
# 2  ['América vs. Pumas EN VIVO EN DIRECTO se mide...
# 3  ['La lideresa de Fuerza Popular, Keiko Fujimor...
# 4  ['Sporting Cristal vs. Municipal EN VIVO ONLIN...
#
#                                               Enlace       Fuente
# 0  https://elcomercio.pe/deporte-total/futbol-mun...  El Comercio
# 1  https://elcomercio.pe/deporte-total/futbol-mun...  El Comercio
# 2  https://elcomercio.pe/deporte-total/futbol-mun...  El Comercio
# 3  https://elcomercio.pe/politica/keiko-fujimori-...  El Comercio
# 4  https://elcomercio.pe/deporte-total/futbol-per...  El Comercio

# %%
content_temp = [];
for contenido in data["Contenido"]:
    contenido = ast.literal_eval(contenido)
    content = ''
    for item in contenido:
        content = content + ' ' + str(item)
    content_temp.append(content)

# %%
data["Contenido"] = content_temp

# %%
data.head()
# Out:
#                                               Titulo  \
# 0  [AHORA] América vs. Pumas UNAM EN VIVO transmi...
# 1  América vs. Pumas UNAM: Sebastián Córdova fue ...
# 2  [EN VIVO] América vs. Pumas UNAM VER AQUÍ EN D...
# 3  Keiko Fujimori fue internada en clínica local ...
# 4  Sporting Cristal vs. Municipal: duelo por la j...
#
#                        Fecha  \
# 0  2019-09-14T22:51:00-05:00
# 1  2019-09-14T22:50:19-05:00
# 2  2019-09-14T22:50:00-05:00
# 3  2019-09-14T22:43:07-05:00
# 4  2019-09-14T22:35:41-05:00
#
#                                            Contenido  \
# 0   América vs. Pumas UNAM EN VIVO | ONLINE sigue...
# 1   El choque entre América y Pumas UNAM se desvi...
# 2   América vs. Pumas EN VIVO EN DIRECTO se miden...
# 3   La lideresa de Fuerza Popular, Keiko Fujimori...
# 4   Sporting Cristal vs. Municipal EN VIVO ONLINE...
#
#                                               Enlace       Fuente
# 0  https://elcomercio.pe/deporte-total/futbol-mun...  El Comercio
# 1  https://elcomercio.pe/deporte-total/futbol-mun...  El Comercio
# 2  https://elcomercio.pe/deporte-total/futbol-mun...  El Comercio
# 3  https://elcomercio.pe/politica/keiko-fujimori-...  El Comercio
# 4  https://elcomercio.pe/deporte-total/futbol-per...  El Comercio

# %% [markdown]
# #### Falta limpiar la data, titulo quitar el [ahora], [en vivo], etc; parsear fecha, procesar contenido

# %% [markdown]
# ## 4. Word2Vec

# %%
#from gensim.models import word2vec # se debe instalar gensim (pip install gensim)
from gensim.test.utils import common_texts, get_tmpfile
from gensim.models import Word2Vec, Phrases
import numpy as np
import gensim
from multiprocessing import cpu_count
from nltk.tokenize import sent_tokenize, word_tokenize 
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/carlos/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
cpu = cpu_count()

# %%
first_sentence = [['a', 'a']]
model = Word2Vec(first_sentence, min_count=2,size=100,workers=cpu)
for contenido in data["Contenido"]:
    content_temp = [] 
    for i in sent_tokenize(contenido): 
        temp = [] 
        # tokenize the sentence into words 
        for j in word_tokenize(i): 
            temp.append(j.lower()) 

        content_temp.append(temp)
    model.build_vocab(content_temp,update=True)

# %%
model.wv.vocab
# Out:
# {'a': <gensim.models.keyedvectors.Vocab at 0x7fa5e7c01dd8>,
#  'américa': <gensim.models.keyedvectors.Vocab at 0x7fa5e7c01eb8>,
#  'vs.': <gensim.models.keyedvectors.Vocab at 0x7fa5ee592c50>,
#  'pumas': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a57898>,
#  'unam': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a57978>,
#  'en': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a57c88>,
#  'vivo': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a57cf8>,
#  '|': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5f1d0>,
#  'online': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5f208>,
#  'sigue': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a63828>,
#  'el': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a63a20>,
#  'partido': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a651d0>,
#  'de': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a65208>,
#  'este': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a65240>,
#  'sábado': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a65278>,
#  '14': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a652b0>,
#  'septiembre': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a652e8>,
#  '(': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a65320>,
#  '9:06': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a65358>,
#  '.': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a65390>,
#  'directo': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a653c8>,
#  'tudn': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a65400>,
#  ')': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a65438>,
#  'estadio': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a65470>,
#  'azteca': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a654a8>,
#  'por': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a654e0>,
#  'la': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a67128>,
#  'novena': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a67160>,
#  'jornada': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a67198>,
#  'liga': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a671d0>,
#  'mx': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a67208>,
#  'apertura': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a67240>,
#  '2019': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a67278>,
#  'desde': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a672b0>,
#  'con': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a672e8>,
#  'del': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a67320>,
#  ':': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a67358>,
#  '“': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a67390>,
#  'entrenador': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a673c8>,
#  '”': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a67400>,
#  'duelo': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a67438>,
#  'entre': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a67470>,
#  'y': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a674a8>,
#  'los': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a674e0>,
#  'más': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a67518>,
#  'minuto': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a67550>,
#  ',': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a67588>,
#  'que': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a675c0>,
#  'las': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a675f8>,
#  '‘': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a67630>,
#  'águilas': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a67668>,
#  '’': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a676a0>,
#  'clásico': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a676d8>,
#  'ocho': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a67710>,
#  'torneo': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a67748>,
#  'sin': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a67780>,
#  'contra': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a677b8>,
#  'pasan': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a677f0>,
#  'años': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a67828>,
#  'equipo': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a67860>,
#  'para': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a67898>,
#  'vencer': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a678d0>,
#  'todos': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a67908>,
#  'quieren': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a67940>,
#  'un': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a67978>,
#  'juego': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a679b0>,
#  'es': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a679e8>,
#  'aseguró': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a67a20>,
#  'guillermo': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a67a58>,
#  'ochoa': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a67a90>,
#  'quien': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a67ac8>,
#  'al': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a67b00>,
#  'su': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a67b38>,
#  'español': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a67b70>,
#  'míchel': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a67ba8>,
#  'rival': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a67be0>,
#  'muy': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a67c18>,
#  'grande': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a67c50>,
#  'no': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a67c88>,
#  'méxico': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a67cc0>,
#  'sino': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a67cf8>,
#  'va': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a67d30>,
#  'ser': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a67d68>,
#  'dt': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a67da0>,
#  'argentino': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a67dd8>,
#  'guido': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a67e10>,
#  'rodríguez': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a67e48>,
#  'partidos': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a67e80>,
#  'ante': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a67eb8>,
#  'se': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a67ef0>,
#  'como': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a67f28>,
#  'lo': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a67f60>,
#  'solo': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a67f98>,
#  'chivas': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a67fd0>,
#  'guadalajara': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a6b048>,
#  'fútbol': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a6b080>,
#  'pero': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a6b0b8>,
#  '``': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a6b0f0>,
#  'respeto': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a6b128>,
#  'mí': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a6b160>,
#  ';': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a6b198>,
#  'así': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a6b1d0>,
#  'eso': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a6b208>,
#  'esperan': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a6b240>,
#  "''": <gensim.models.keyedvectors.Vocab at 0x7fa5e7a6b278>,
#  'ver': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a6b2b0>,
#  'miedo': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a6b2e8>,
#  'sí': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a6b320>,
#  'sé': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a6b358>,
#  'si': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a6b390>,
#  '10:06': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a6b3c8>,
#  '11:06': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a6b400>,
#  'gonzález': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a6b438>,
#  'pablo': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a6b470>,
#  '...': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a6b4a8>,
#  'jugará': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5e710>,
#  '?': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a59278>,
#  'tras': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a59e48>,
#  'varios': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a59400>,
#  'jugadores': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a598d0>,
#  'lesionados': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a59fd0>,
#  'cuando': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a59908>,
#  '15': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a59da0>,
#  'una': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a66320>,
#  'puntos': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5f908>,
#  'tabla': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5f940>,
#  'puesto': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a63160>,
#  'herrera': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a63198>,
#  'le': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a631d0>,
#  'henry': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a63208>,
#  'dos': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a63240>,
#  'nicolás': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a63278>,
#  'andrés': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a632b0>,
#  'además': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a632e8>,
#  'renato': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a63320>,
#  'ibarra': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a63358>,
#  'bruno': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a63390>,
#  'son': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a633c8>,
#  'dijo': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a63400>,
#  'último': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a63438>,
#  'toluca': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a63470>,
#  'porque': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a634a8>,
#  'keiko': <gensim.models.keyedvectors.Vocab at 0x7fa5e7c01e10>,
#  'fujimori': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5a198>,
#  'trasladada': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5a208>,
#  'clínica': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5a0b8>,
#  'centenario': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5a128>,
#  'prisión': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5a0f0>,
#  'preventiva': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5a1d0>,
#  'loza': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a60160>,
#  'confirmó': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a60080>,
#  'información': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a60fd0>,
#  'problemas': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5d9e8>,
#  'días': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5da20>,
#  'salud': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5da58>,
#  'sporting': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5a048>,
#  'cristal': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5ab00>,
#  'municipal': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5ab38>,
#  '4:00': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5aba8>,
#  'cargo': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5ae80>,
#  'deportivo': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5a9e8>,
#  'resultados': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5ae10>,
#  '-': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5e128>,
#  '5:00': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a664e0>,
#  '6:00': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a66518>,
#  'tendrá': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a66550>,
#  'manuel': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a665c0>,
#  'barreto': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a665f8>,
#  'primera': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a66630>,
#  'división': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a66668>,
#  'afirmó': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a666a0>,
#  'ello': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a666d8>,
#  'hay': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a66710>,
#  'mejores': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a66748>,
#  'día': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a57e48>,
#  'hace': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a57be0>,
#  '19': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a57e80>,
#  'video': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a57f28>,
#  'efecto': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a65198>,
#  'régimen': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5a6a0>,
#  'alberto': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5a748>,
#  'hotel': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a78e10>,
#  'canal': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a78fd0>,
#  'n': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a7a048>,
#  'entonces': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a7a080>,
#  'congresista': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a7a0b8>,
#  'kouri': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a7a0f0>,
#  'salita': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a7a128>,
#  'asesor': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a7a160>,
#  'vladimiro': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a7a198>,
#  'montesinos': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a7a1d0>,
#  'pase': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a7a208>,
#  'bancada': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a7a240>,
#  'fujimorista': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a7a278>,
#  'us': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a7a2b0>,
#  '$': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a7afd0>,
#  'mil': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a70048>,
#  'ese': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a70080>,
#  'primer': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a700b8>,
#  "'vladivideo": <gensim.models.keyedvectors.Vocab at 0x7fa5e7a700f0>,
#  "'": <gensim.models.keyedvectors.Vocab at 0x7fa5e7a70128>,
#  'vhs': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a70160>,
#  'fue': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a70198>,
#  'conferencia': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a701d0>,
#  'prensa': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a70208>,
#  'olivera': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a70240>,
#  'luis': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a70278>,
#  'iberico': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a702b0>,
#  'fim': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a702e8>,
#  'veía': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a70320>,
#  'perú': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a70358>,
#  '2000': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a70390>,
#  'diez': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a703c8>,
#  'parlamentario': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a70400>,
#  'dinero': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a70438>,
#  'país': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a70470>,
#  'vio': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a704a8>,
#  'e': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a704e0>,
#  'corrupción': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a70518>,
#  'había': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a70550>,
#  'siguiente': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a70588>,
#  'golpe': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a705c0>,
#  'después': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a705f8>,
#  'anunciar': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a70630>,
#  'elecciones': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a70668>,
#  'meses': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a706a0>,
#  'yo': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a706d8>,
#  'final': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a70710>,
#  'congreso': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a70748>,
#  'barrera': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a70780>,
#  "'el": <gensim.models.keyedvectors.Vocab at 0x7fa5e7a707b8>,
#  'patriota': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a707f0>,
#  'cinta': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a70828>,
#  'pinchi': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a70860>,
#  'videos': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a70898>,
#  'estaban': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a708d0>,
#  'casa': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a70908>,
#  'setiembre': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a70940>,
#  'compra': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a70978>,
#  'tenía': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a709b0>,
#  'cuatro': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a709e8>,
#  'inicialmente': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a70a20>,
#  'dio': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a70a58>,
#  'plata': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a70a90>,
#  'empresario': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a70ac8>,
#  'palacios': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a70b00>,
#  'también': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a70b38>,
#  'presentar': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a70b70>,
#  'era': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a70ba8>,
#  'seguridad': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a70be0>,
#  'bien': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a70c18>,
#  'entregó': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a70c50>,
#  'difusión': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a70c88>,
#  'manifestó': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a70cc0>,
#  'esa': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a70cf8>,
#  'segundo': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a594e0>,
#  'historia': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a59320>,
#  'baloncesto': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a59c88>,
#  'scola': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a59cf8>,
#  'pese': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a59438>,
#  'selección': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a63048>,
#  'argentina': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a639b0>,
#  'encima': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a63978>,
#  'mundial': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a639e8>,
#  'nigeria': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a78278>,
#  'hasta': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a7a4a8>,
#  'momento': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a7ac50>,
#  'líder': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a7ac88>,
#  'sus': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a7acc0>,
#  'conseguir': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a7acf8>,
#  'hito': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a7ad30>,
#  'semanas': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a7ad68>,
#  'tenemos': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a7ada0>,
#  'trabajo': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a7add8>,
#  'ha': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a7ae10>,
#  'campo': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a7ae48>,
#  'palmo': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a7ae80>,
#  'sergio': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a7aeb8>,
#  'hernández': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a7aef0>,
#  'frente': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a7af28>,
#  'tiene': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a7af60>,
#  'está': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a7af98>,
#  'tratando': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a7a4e0>,
#  'mejorar': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a7a518>,
#  'demás': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a7a550>,
#  'movimientos': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a7a5c0>,
#  'triple': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a7a5f8>,
#  'forma': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a7a630>,
#  'nuevo': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a7a668>,
#  'nuestro': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a7a6a0>,
#  'club': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a7a6d8>,
#  'españa': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a57e10>,
#  'aquí': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a57ef0>,
#  'domingo': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a57dd8>,
#  '7:00': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5dcc0>,
#  'directv': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5e160>,
#  'sports': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5e198>,
#  'wukesong': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5fc18>,
#  'sport': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5fbe0>,
#  'center': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5fc88>,
#  'beijing': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5fcc0>,
#  'básquet': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5f390>,
#  'china': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5f198>,
#  'a.m.': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5f240>,
#  'título': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5f400>,
#  'donde': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5f278>,
#  '9:00': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5feb8>,
#  '8:00': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5fef0>,
#  'uno': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5f9b0>,
#  'única': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5f710>,
#  '2004': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5f978>,
#  'ni': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5fe80>,
#  'siquiera': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5fa20>,
#  'europea': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a75048>,
#  'camino': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a75080>,
#  'fase': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a750b8>,
#  'están': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a750f0>,
#  'australia': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a75128>,
#  '20191ra': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a75160>,
#  'universitario': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a67080>,
#  'deportes': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a67048>,
#  'monumental': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5a400>,
#  '2-0': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5a438>,
#  'binacional': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5a5c0>,
#  'alejandro': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5a3c8>,
#  'hohberg': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a65fd0>,
#  'minutos': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a65908>,
#  'goles': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a65940>,
#  'vez': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a65828>,
#  'campeón': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a657b8>,
#  'luego': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a65cc0>,
#  'jersson': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5fdd8>,
#  'vásquez': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5fe48>,
#  'huancayo': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5ff28>,
#  'lima': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5f2b0>,
#  '10:00': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5f320>,
#  'alianza': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5f358>,
#  'victoria': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5ff60>,
#  'aldo': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5fb38>,
#  'corzo': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5fba8>,
#  'quintero': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a75400>,
#  'javier': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a75358>,
#  'supernatural': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a57eb8>,
#  'hermanos': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a60d68>,
#  'winchester': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a60f28>,
#  'jared': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a60e10>,
#  'padalecki': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a75588>,
#  'jensen': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a75550>,
#  'ackles': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a7fa90>,
#  'misha': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a7fac8>,
#  'collins': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a7fb00>,
#  'través': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a7fb38>,
#  'décimo': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a7fb70>,
#  'quinta': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a7fba8>,
#  'temporada': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a7fbe0>,
#  'última': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a7ff28>,
#  'decirle': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a7ff60>,
#  'estamos': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a7ff98>,
#  'será': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a823c8>,
#  'programa': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a82400>,
#  'cambiado': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a82438>,
#  'mi': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a82470>,
#  'vida': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a824a8>,
#  'decir': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a824e0>,
#  'próximo': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a82518>,
#  'año': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a82550>,
#  'poco': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a82588>,
#  'toda': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a825c0>,
#  'agregó': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a825f8>,
#  'esta': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a82630>,
#  'the': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a82668>,
#  'cw': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a826a0>,
#  'episodios': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a826d8>,
#  'tiempo': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a82710>,
#  'protagonistas': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a82748>,
#  'pesar': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a82780>,
#  'familia': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a827b8>,
#  'parte': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a827f0>,
#  'esto': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a82828>,
#  'todo': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a82860>,
#  'sabemos': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a82898>,
#  'últimos': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a828d0>,
#  '20': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a82908>,
#  'show': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a82940>,
#  'sam': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a82978>,
#  'dean': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a829b0>,
#  'dabb': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a829e8>,
#  'reveló': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a82a20>,
#  'comenzarán': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a82a58>,
#  'entrega': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a82a90>,
#  'chuck': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a82ac8>,
#  'estado': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a82b00>,
#  'ansiosos': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a82b38>,
#  'durante': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a82b70>,
#  'sobre': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a82ba8>,
#  'vidas': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a82be0>,
#  'dios': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a82c18>,
#  'personajes': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a82c50>,
#  'pasado': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a82c88>,
#  'papel': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a82cc0>,
#  'infierno': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a82cf8>,
#  'pregunta': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a82d30>,
#  'comic-con': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a82d68>,
#  '@': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a82da0>,
#  'ligue': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a59eb8>,
#  'estrasburgo': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a59a58>,
#  'neymar': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a59978>,
#  '1-0': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a59ac8>,
#  'atlético': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a65e48>,
#  'nacional': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5e630>,
#  'cúcuta': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5ef98>,
#  '7:45': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5e438>,
#  'incidencias': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5e390>,
#  'lugar': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5e400>,
#  'atanasio': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5e668>,
#  '8:45': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5eda0>,
#  '9:45': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5e6d8>,
#  'copa': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a759e8>,
#  'blanco': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a75a20>,
#  'angulo': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a65080>,
#  'necaxa': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a65eb8>,
#  'monterrey': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a65be0>,
#  'fecha': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a65e10>,
#  'mexicana': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a65518>,
#  'tanto': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a65550>,
#  'sentenció': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a65e80>,
#  'ocasión': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a650b8>,
#  'encuentros': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a80208>,
#  'bbva': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a80240>,
#  '12': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a80278>,
#  'unidades': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a802b0>,
#  '►': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a802e8>,
#  'barovero': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a80320>,
#  'tiro': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a80358>,
#  'rasante': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a80390>,
#  'fuera': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a803c8>,
#  'bancomer': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a80400>,
#  'derrota': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a80438>,
#  'juárez': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a80470>,
#  'previa': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a804a8>,
#  'empate': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a804e0>,
#  '2-1': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a80518>,
#  'estrellas': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5dd30>,
#  'seguir': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5d0f0>,
#  '0-0': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5d198>,
#  '9': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5d588>,
#  '21:06': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5d3c8>,
#  'horas': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5f7b8>,
#  'haber': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5f860>,
#  'anterior': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5f780>,
#  'g.': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5f828>,
#  'j.': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5f898>,
#  'c.': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5f048>,
#  'p.': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5f080>,
#  'f.': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5f0b8>,
#  'l.': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a6bd30>,
#  'r.': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a6bcc0>,
#  'a.': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a6b588>,
#  '23:06': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a6b630>,
#  '22:06': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a6b668>,
#  'vs': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a6b6d8>,
#  'horario': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a75b70>,
#  'tipo': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a663c8>,
#  'cambio': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a66358>,
#  'comerciales': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a66438>,
#  'estados': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a667b8>,
#  'unidos': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a66860>,
#  'mercados': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a66898>,
#  'dólar': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a66400>,
#  'pesos': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a66f28>,
#  'jueves': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a66f60>,
#  'terreno': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a66978>,
#  'cynthia': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5a4e0>,
#  'hudson': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5a470>,
#  'ángeles': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5a550>,
#  'estadounidense': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5aa58>,
#  'hablar': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a88198>,
#  'todas': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a881d0>,
#  'sangres': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a8a780>,
#  'arguedas': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a8ec18>,
#  'cnn': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a8f0f0>,
#  'recibir': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a8f128>,
#  'proyecto': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a8f160>,
#  'humano': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a8f198>,
#  'campaña': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a8f1d0>,
#  'multiplataforma': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a8f208>,
#  'discriminación': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a8f240>,
#  'duras': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a8f278>,
#  'políticas': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a8f2b0>,
#  'migratorias': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a8f2e8>,
#  'donald': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a8f320>,
#  'trump': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a8f358>,
#  'migratorios': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a8fa20>,
#  'él': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a8fa58>,
#  'ee.uu': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a8fa90>,
#  'qué': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a92160>,
#  'decide': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a92198>,
#  'temas': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a921d0>,
#  'gobierno': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a92208>,
#  'presidente': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a92240>,
#  'hacia': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a92278>,
#  'inmigrantes': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a922b0>,
#  'latinos': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a922e8>,
#  'me': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a92320>,
#  'algunos': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a92358>,
#  'o': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a92390>,
#  'cómo': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a923c8>,
#  'nos': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a92400>,
#  'nosotros': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a92438>,
#  'podemos': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a92470>,
#  'solamente': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a924a8>,
#  '¿qué': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a924e0>,
#  'quiere': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a92518>,
#  'realmente': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a92550>,
#  'poder': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a92588>,
#  'creo': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a925c0>,
#  'personas': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a925f8>,
#  'importante': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a92630>,
#  'enseñar': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a92668>,
#  'deber': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a926a0>,
#  'mismo': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a926d8>,
#  'canción': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a92710>,
#  'otro': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a92748>,
#  'cada': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a92780>,
#  'algo': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a927b8>,
#  'mundo': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a927f0>,
#  'aún': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a92828>,
#  'tenga': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a92860>,
#  'digo': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a92898>,
#  'cierto': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a928d0>,
#  'verdad': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a92908>,
#  'gente': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a92940>,
#  'estos': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a92978>,
#  'niños': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a929b0>,
#  'siempre': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a929e8>,
#  '—¿cómo': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a92a20>,
#  'sabe': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a92a58>,
#  'propaganda': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a92a90>,
#  'alguna': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a92ac8>,
#  'manera': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a92b00>,
#  'tienen': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a92b38>,
#  'hoy': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a92b70>,
#  've': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a92ba8>,
#  'gran': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a92be0>,
#  'ee.uu.': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a92c18>,
#  'ya': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a92c50>,
#  'quién': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a92c88>,
#  'fox': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a92cc0>,
#  'news': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a92cf8>,
#  'reportando': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a92d30>,
#  'noticias': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a92d68>,
#  'opinión': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a92da0>,
#  'fake': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a92dd8>,
#  'noticia': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a92e10>,
#  'periodismo': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a92e48>,
#  'crear': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a92e80>,
#  'porqué': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a92eb8>,
#  'empresa': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a92ef0>,
#  'himno': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a65860>,
#  'álvarez': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a65a90>,
#  'cantar': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a65f60>,
#  'pelea': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a65f28>,
#  'pues': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a65c50>,
#  'cambió': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5fda0>,
#  'público': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5f748>,
#  'olvidó': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a66128>,
#  'letra': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a66160>,
#  'jorge': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a78400>,
#  'coque': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a78438>,
#  'ana': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a78470>,
#  'bárbara': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a786d8>,
#  'estaba': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a78710>,
#  'copenhague': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5d2e8>,
#  'unos': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5dd68>,
#  'millones': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5df98>,
#  'euros': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a70dd8>,
#  'dinamarca': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a70e48>,
#  'plantar': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a70f98>,
#  'árboles': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a70fd0>,
#  'coronas': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a70ef0>,
#  '%': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5f518>,
#  'televisión': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5fac8>,
#  'millón': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5f588>,
#  'puede': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5fd30>,
#  'afp': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5f4e0>,
#  'nielsen': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a85978>,
#  'según': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a85550>,
#  'finales': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a85128>,
#  'venezuela': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5d4e0>,
#  'today': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5d080>,
#  'anuncio': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a7aba8>,
#  'maduro': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a7abe0>,
#  'asamblea': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a7a2e8>,
#  'general': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a7ab70>,
#  'naciones': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a7aa90>,
#  'unidas': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a7a748>,
#  'precio': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a7a828>,
#  'bolívares': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a604e0>,
#  'canciller': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a78ac8>,
#  'sanciones': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a78b00>,
#  'impuestas': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a78eb8>,
#  'trujillo': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a78ef0>,
#  'duque': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a78f28>,
#  'realizará': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5dda0>,
#  'calango': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a66e10>,
#  'actividad': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a66c50>,
#  'mala': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a66f98>,
#  'camarones': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a662b0>,
#  'tu': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5db70>,
#  'relación': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a60710>,
#  'hora': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a60828>,
#  'nuevos': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a60c88>,
#  'mes': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a60da0>,
#  'descubrir': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a60320>,
#  'irá': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a603c8>,
#  'amor': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5f128>,
#  'nueva': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5f160>,
#  'caso': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5f5f8>,
#  'frutas': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a70d30>,
#  'cuerpo': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a70f60>,
#  'potasio': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a70f28>,
#  'excelente': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a59898>,
#  'mejor': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a59b00>,
#  'hacer': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a59a90>,
#  'deporte': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a59dd8>,
#  'ayuda': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a7a358>,
#  'hipertensión': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a78be0>,
#  'agua': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a85e10>,
#  'especialmente': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a855f8>,
#  'inflamaciones': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a85710>,
#  'buena': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a85dd8>,
#  'mañana': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a80080>,
#  'quita': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a800b8>,
#  'hambre': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a800f0>,
#  'manzana': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a80550>,
#  'zanahoria': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a806a0>,
#  'piña': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a80780>,
#  'extracto': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a805c0>,
#  'brasileño': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a59ef0>,
#  'psg': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5f5c0>,
#  'página': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5f470>,
#  'cerrada': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a78630>,
#  'parisinos': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a78128>,
#  'soy': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a8c1d0>,
#  'jugador': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a8cb38>,
#  'voy': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a8c048>,
#  'dar': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a8c080>,
#  'cancha': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a8c0b8>,
#  'abucheos': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a8c0f0>,
#  'nada': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a8c128>,
#  'hinchas': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a8c160>,
#  'declaró': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a8c710>,
#  'griten': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5a240>,
#  'stranger': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a6b518>,
#  'things': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a6bb00>,
#  '4': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a6bb70>,
#  'estreno': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a6bf98>,
#  'netflix': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a6b898>,
#  'pasará': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a6b8d0>,
#  'actores': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a6bfd0>,
#  'misterios': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a6ba90>,
#  'teorías': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a6bc88>,
#  'aunque': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a6b710>,
#  'cuarta': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a6b940>,
#  'escena': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5f4a8>,
#  'post-créditos': <gensim.models.keyedvectors.Vocab at 0x7fa5e79d9940>,
#  'tercera': <gensim.models.keyedvectors.Vocab at 0x7fa5e79d5978>,
#  'probable': <gensim.models.keyedvectors.Vocab at 0x7fa5e79d5940>,
#  'eleven': <gensim.models.keyedvectors.Vocab at 0x7fa5e79dab70>,
#  'hawkins': <gensim.models.keyedvectors.Vocab at 0x7fa5e79e0ef0>,
#  'hecho': <gensim.models.keyedvectors.Vocab at 0x7fa5e79e0f28>,
#  'serie': <gensim.models.keyedvectors.Vocab at 0x7fa5e79e5b38>,
#  'ficción': <gensim.models.keyedvectors.Vocab at 0x7fa5e79e5b70>,
#  'menos': <gensim.models.keyedvectors.Vocab at 0x7fa5e79e7588>,
#  'temporadas': <gensim.models.keyedvectors.Vocab at 0x7fa5e79e75c0>,
#  'jóvenes': <gensim.models.keyedvectors.Vocab at 0x7fa5e79e75f8>,
#  'héroes': <gensim.models.keyedvectors.Vocab at 0x7fa5e79e7630>,
#  'murieron': <gensim.models.keyedvectors.Vocab at 0x7fa5e79e7668>,
#  'otros': <gensim.models.keyedvectors.Vocab at 0x7fa5e79e76a0>,
#  'fueron': <gensim.models.keyedvectors.Vocab at 0x7fa5e79e7c50>,
#  'mientras': <gensim.models.keyedvectors.Vocab at 0x7fa5e79e7c88>,
#  'muchos': <gensim.models.keyedvectors.Vocab at 0x7fa5e79e7cc0>,
#  'upside': <gensim.models.keyedvectors.Vocab at 0x7fa5e79e7cf8>,
#  'down': <gensim.models.keyedvectors.Vocab at 0x7fa5e79e7d30>,
#  'revés': <gensim.models.keyedvectors.Vocab at 0x7fa5e79e8438>,
#  'realidad': <gensim.models.keyedvectors.Vocab at 0x7fa5e79e8470>,
#  'posibilidad': <gensim.models.keyedvectors.Vocab at 0x7fa5e79e84a8>,
#  '2017': <gensim.models.keyedvectors.Vocab at 0x7fa5e79e84e0>,
#  'estaría': <gensim.models.keyedvectors.Vocab at 0x7fa5e79e8518>,
#  'pensado': <gensim.models.keyedvectors.Vocab at 0x7fa5e79e8550>,
#  'agosto': <gensim.models.keyedvectors.Vocab at 0x7fa5e79e8588>,
#  'matt': <gensim.models.keyedvectors.Vocab at 0x7fa5e79e85c0>,
#  'ross': <gensim.models.keyedvectors.Vocab at 0x7fa5e79e85f8>,
#  'duffer': <gensim.models.keyedvectors.Vocab at 0x7fa5e79e8630>,
#  'creadores': <gensim.models.keyedvectors.Vocab at 0x7fa5e79e8668>,
#  'podría': <gensim.models.keyedvectors.Vocab at 0x7fa5e79e86a0>,
#  'hermano': <gensim.models.keyedvectors.Vocab at 0x7fa5e79e86d8>,
#  'malo': <gensim.models.keyedvectors.Vocab at 0x7fa5e79e8710>,
#  'sucediendo': <gensim.models.keyedvectors.Vocab at 0x7fa5e79e8748>,
#  'embargo': <gensim.models.keyedvectors.Vocab at 0x7fa5e79e8780>,
#  'entrevista': <gensim.models.keyedvectors.Vocab at 0x7fa5e79e87b8>,
#  'entertainment': <gensim.models.keyedvectors.Vocab at 0x7fa5e79e87f0>,
#  'weekly': <gensim.models.keyedvectors.Vocab at 0x7fa5e79e8828>,
#  'shawn': <gensim.models.keyedvectors.Vocab at 0x7fa5e79e8860>,
#  'levy': <gensim.models.keyedvectors.Vocab at 0x7fa5e79e8898>,
#  'habría': <gensim.models.keyedvectors.Vocab at 0x7fa5e79e88d0>,
#  'definitivamente': <gensim.models.keyedvectors.Vocab at 0x7fa5e79e8908>,
#  'existe': <gensim.models.keyedvectors.Vocab at 0x7fa5e79e8940>,
#  'allá': <gensim.models.keyedvectors.Vocab at 0x7fa5e79e8978>,
#  'parece': <gensim.models.keyedvectors.Vocab at 0x7fa5e79e89b0>,
#  'poderes': <gensim.models.keyedvectors.Vocab at 0x7fa5e79e89e8>,
#  'persona': <gensim.models.keyedvectors.Vocab at 0x7fa5e79e8a20>,
#  '3': <gensim.models.keyedvectors.Vocab at 0x7fa5e79e8a58>,
#  'vista': <gensim.models.keyedvectors.Vocab at 0x7fa5e79e8a90>,
#  'capítulo': <gensim.models.keyedvectors.Vocab at 0x7fa5e79e8ac8>,
#  'capítulos': <gensim.models.keyedvectors.Vocab at 0x7fa5e79e8b00>,
#  'tendría': <gensim.models.keyedvectors.Vocab at 0x7fa5e79e8b38>,
#  'tampoco': <gensim.models.keyedvectors.Vocab at 0x7fa5e79e8b70>,
#  'seguro': <gensim.models.keyedvectors.Vocab at 0x7fa5e79e8ba8>,
#  'ew': <gensim.models.keyedvectors.Vocab at 0x7fa5e79e8be0>,
#  'acuerdo': <gensim.models.keyedvectors.Vocab at 0x7fa5e79e8c18>,
#  'octubre': <gensim.models.keyedvectors.Vocab at 0x7fa5e79e8c50>,
#  '2020': <gensim.models.keyedvectors.Vocab at 0x7fa5e79e8c88>,
#  'muerte': <gensim.models.keyedvectors.Vocab at 0x7fa5e79e8cc0>,
#  'hopper': <gensim.models.keyedvectors.Vocab at 0x7fa5e79e8cf8>,
#  'joyce': <gensim.models.keyedvectors.Vocab at 0x7fa5e79e8d30>,
#  'junto': <gensim.models.keyedvectors.Vocab at 0x7fa5e79e8d68>,
#  'hijos': <gensim.models.keyedvectors.Vocab at 0x7fa5e79e8da0>,
#  'mencionan': <gensim.models.keyedvectors.Vocab at 0x7fa5e79e8dd8>,
#  'renueva': <gensim.models.keyedvectors.Vocab at 0x7fa5e79e8e10>,
#  'probablemente': <gensim.models.keyedvectors.Vocab at 0x7fa5e79e8e48>,
#  'sea': <gensim.models.keyedvectors.Vocab at 0x7fa5e79e8e80>,
#  'perdió': <gensim.models.keyedvectors.Vocab at 0x7fa5e79e8eb8>,
#  'misterio': <gensim.models.keyedvectors.Vocab at 0x7fa5e79e8ef0>,
#  'pasó': <gensim.models.keyedvectors.Vocab at 0x7fa5e79e8f28>,
#  'portal': <gensim.models.keyedvectors.Vocab at 0x7fa5e79e8f60>,
#  'científicos': <gensim.models.keyedvectors.Vocab at 0x7fa5e79e8f98>,
#  'soviéticos': <gensim.models.keyedvectors.Vocab at 0x7fa5e79e8fd0>,
#  'explosión': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a19048>,
#  'jefe': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a19080>,
# ...
#  'saber': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a19400>,
#  'cosas': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a19438>,
#  'futuro': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a19470>,
#  'señaló': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a194a8>,
#  'joven': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a194e0>,
#  'actriz': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a19518>,
#  'idea': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a19550>,
#  'algunas': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a19588>,
#  'medio': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a195c0>,
#  'diferente': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a195f8>,
#  'seis': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a19630>,
#  'escritores': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a19668>,
#  'tenían': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a196a0>,
#  'grandes': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a196d8>,
#  'trazos': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a19710>,
#  'próximos': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a19748>,
#  'eventos': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a19780>,
#  'compañía': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a197b8>,
#  'segunda': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a197f0>,
#  'sabíamos': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a19828>,
#  'billy': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a19860>,
#  'centro': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a19898>,
#  'esas': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a198d0>,
#  'ahora': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a19908>,
#  'trata': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a19940>,
#  'suceder': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a19978>,
#  'emocionante': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a199b0>,
#  'apuntó': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a199e8>,
#  'abrirá': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a19a20>,
#  'términos': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a19a58>,
#  'marco': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a19a90>,
#  'rusia': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a19ac8>,
#  'esos': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a19b00>,
#  'celda': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a19b38>,
#  'haciendo': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a19b70>,
#  'obviamente': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a19ba8>,
#  'trama': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a19be0>,
#  'hubiera': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a19c18>,
#  'veremos': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a19c50>,
#  'pierna': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a19c88>,
#  'mind': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a19cc0>,
#  'adolescente': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a19cf8>,
#  'pensó': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a19d30>,
#  'perdido': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a19d68>,
#  'explorar': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a19da0>,
#  '2': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a19dd8>,
#  'jim': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a19e10>,
#  'máquina': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a19e48>,
#  "'mundo": <gensim.models.keyedvectors.Vocab at 0x7fa5e7a19e80>,
#  'murió': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a19eb8>,
#  'creen': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a19ef0>,
#  'amigos': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a19f28>,
#  'muchas': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a19f60>,
#  'han': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a19f98>,
#  'respecto': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a19fd0>,
#  'nunca': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a1b048>,
#  'encontrado': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a1b080>,
#  'fans': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a1b0b8>,
#  'lanzado': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a1b0f0>,
#  'capturado': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a1b128>,
#  'teoría': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a1b160>,
#  'dice': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a1b198>,
#  'heroes': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a1b1d0>,
#  'originalmente': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a1b208>,
#  'david': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a1b240>,
#  'prueba': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a1b278>,
#  'will': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a1b2b0>,
#  'byers': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a1b2e8>,
#  'supuesto': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a1b320>,
#  'verdadero': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a1b358>,
#  'atrapado': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a1b390>,
#  'dejó': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a1b3c8>,
#  'padre': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a1b400>,
#  'ella': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a1b438>,
#  'actor': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a1b470>,
#  'harbour': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a1b4a8>,
#  'sería': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a1b4e0>,
#  'asegurar': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a1b518>,
#  'retorno': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a1b550>,
#  'sido': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a1b588>,
#  'cuenta': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a1b5c0>,
#  'propio': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a1b5f8>,
#  'detener': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a1b630>,
#  'puedo': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a1b668>,
#  'decirte': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a1b6a0>,
#  'verlo': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a1b6d8>,
#  'juntos': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a1b710>,
#  'bastante': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a1b748>,
#  'arco': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a1b780>,
#  'todavía': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a1b7b8>,
#  'estar': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a1b7f0>,
#  'lleva': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a1b828>,
#  'dicho': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a1b860>,
#  'posible': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a1b898>,
#  'película': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a1b8d0>,
#  'steve': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a1b908>,
#  'menciona': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a1b940>,
#  'seguidores': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a1b978>,
#  'similar': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a1b9b0>,
#  'personaje': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a1b9e8>,
#  'murray': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a1ba20>,
#  'mensaje': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a1ba58>,
#  'esperanza': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a1ba90>,
#  'bauman': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a1bac8>,
#  'eres': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a1bb00>,
#  'tú': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a1bb38>,
#  '5': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a1bb70>,
#  '6': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a1bba8>,
#  'antes': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a1bbe0>,
#  'tengo': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a1bc18>,
#  'bueno': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a1bc50>,
#  'laboratorio': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a1bc88>,
#  'nadie': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a1bcc0>,
#  '¿cómo': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a1bcf8>,
#  'tan': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a1bd30>,
#  'rápido': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a1bd68>,
#  '¿quién': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a1bda0>,
#  'ambientada': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a1bdd8>,
#  'kamchatka': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a1be10>,
#  'unión': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a1be48>,
#  'unas': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a1be80>,
#  'abrir': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a1beb8>,
#  '¿hopper': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a1bef0>,
#  'sobrevivió': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a1bf28>,
#  'línea': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a1bf60>,
#  'ruso': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a1bf98>,
#  'debate': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a1bfd0>,
#  'identidad': <gensim.models.keyedvectors.Vocab at 0x7fa5e79ec048>,
#  'interpreta': <gensim.models.keyedvectors.Vocab at 0x7fa5e79ec080>,
#  'cualquier': <gensim.models.keyedvectors.Vocab at 0x7fa5e79ec0b8>,
#  'tal': <gensim.models.keyedvectors.Vocab at 0x7fa5e79ec0f0>,
#  'completamente': <gensim.models.keyedvectors.Vocab at 0x7fa5e79ec128>,
#  'sostuvo': <gensim.models.keyedvectors.Vocab at 0x7fa5e79ec160>,
#  'revelado': <gensim.models.keyedvectors.Vocab at 0x7fa5e79ec198>,
#  'propósito': <gensim.models.keyedvectors.Vocab at 0x7fa5e79ec1d0>,
#  'experimentos': <gensim.models.keyedvectors.Vocab at 0x7fa5e79ec208>,
#  'pensar': <gensim.models.keyedvectors.Vocab at 0x7fa5e79ec240>,
#  'ciudad': <gensim.models.keyedvectors.Vocab at 0x7fa5e79ec278>,
#  'dustin': <gensim.models.keyedvectors.Vocab at 0x7fa5e79ec2b0>,
#  'gorra': <gensim.models.keyedvectors.Vocab at 0x7fa5e79ec2e8>,
#  'científico': <gensim.models.keyedvectors.Vocab at 0x7fa5e79ec320>,
#  '¿dónde': <gensim.models.keyedvectors.Vocab at 0x7fa5e79ec358>,
#  'suzie': <gensim.models.keyedvectors.Vocab at 0x7fa5e79ec390>,
#  'surgió': <gensim.models.keyedvectors.Vocab at 0x7fa5e79ec3c8>,
#  'dr.': <gensim.models.keyedvectors.Vocab at 0x7fa5e79ec400>,
#  'owens': <gensim.models.keyedvectors.Vocab at 0x7fa5e79ec438>,
#  'siente': <gensim.models.keyedvectors.Vocab at 0x7fa5e79ec470>,
#  'desastre': <gensim.models.keyedvectors.Vocab at 0x7fa5e79ec4a8>,
#  'lucas': <gensim.models.keyedvectors.Vocab at 0x7fa5e79ec4e0>,
#  'max': <gensim.models.keyedvectors.Vocab at 0x7fa5e79ec518>,
#  'caleb': <gensim.models.keyedvectors.Vocab at 0x7fa5e79ec550>,
#  'tener': <gensim.models.keyedvectors.Vocab at 0x7fa5e79ec588>,
#  'diálogo': <gensim.models.keyedvectors.Vocab at 0x7fa5e79ec5c0>,
#  'comentó': <gensim.models.keyedvectors.Vocab at 0x7fa5e79ec5f8>,
#  'ahí': <gensim.models.keyedvectors.Vocab at 0x7fa5e79ec630>,
#  'allí': <gensim.models.keyedvectors.Vocab at 0x7fa5e79ec668>,
#  'opinó': <gensim.models.keyedvectors.Vocab at 0x7fa5e79ec6a0>,
#  'parecía': <gensim.models.keyedvectors.Vocab at 0x7fa5e79ec6d8>,
#  'tres': <gensim.models.keyedvectors.Vocab at 0x7fa5e79ec710>,
#  'perder': <gensim.models.keyedvectors.Vocab at 0x7fa5e79ec748>,
#  'cierta': <gensim.models.keyedvectors.Vocab at 0x7fa5e79ec780>,
#  'víctima': <gensim.models.keyedvectors.Vocab at 0x7fa5e79ec7b8>,
#  'amiga': <gensim.models.keyedvectors.Vocab at 0x7fa5e79ec7f0>,
#  'sacrificó': <gensim.models.keyedvectors.Vocab at 0x7fa5e79ec828>,
#  'salvar': <gensim.models.keyedvectors.Vocab at 0x7fa5e79ec860>,
#  'robin': <gensim.models.keyedvectors.Vocab at 0x7fa5e79ec898>,
#  'sexual': <gensim.models.keyedvectors.Vocab at 0x7fa5e79ec8d0>,
#  'niño': <gensim.models.keyedvectors.Vocab at 0x7fa5e79ec908>,
#  'elenco': <gensim.models.keyedvectors.Vocab at 0x7fa5e79ec940>,
#  'asimismo': <gensim.models.keyedvectors.Vocab at 0x7fa5e79ec978>,
#  'explotó': <gensim.models.keyedvectors.Vocab at 0x7fa5e79ec9b0>,
#  'extraño': <gensim.models.keyedvectors.Vocab at 0x7fa5e79ec9e8>,
#  'sobrevivido': <gensim.models.keyedvectors.Vocab at 0x7fa5e79eca20>,
#  'suerte': <gensim.models.keyedvectors.Vocab at 0x7fa5e79eca58>,
#  'drama': <gensim.models.keyedvectors.Vocab at 0x7fa5e79eca90>,
#  'pasar': <gensim.models.keyedvectors.Vocab at 0x7fa5e79ecac8>,
#  'debemos': <gensim.models.keyedvectors.Vocab at 0x7fa5e79ecb00>,
#  'alexei': <gensim.models.keyedvectors.Vocab at 0x7fa5e79ecb38>,
#  'descartarse': <gensim.models.keyedvectors.Vocab at 0x7fa5e79ecb70>,
#  'igual': <gensim.models.keyedvectors.Vocab at 0x7fa5e79ecba8>,
#  'algún': <gensim.models.keyedvectors.Vocab at 0x7fa5e79ecbe0>,
#  '1986': <gensim.models.keyedvectors.Vocab at 0x7fa5e79ecc18>,
#  'comenzó': <gensim.models.keyedvectors.Vocab at 0x7fa5e79ecc50>,
#  'diferentes': <gensim.models.keyedvectors.Vocab at 0x7fa5e79ecc88>,
#  'mal': <gensim.models.keyedvectors.Vocab at 0x7fa5e79eccc0>,
#  'chernóbil': <gensim.models.keyedvectors.Vocab at 0x7fa5e79eccf8>,
#  'suposición': <gensim.models.keyedvectors.Vocab at 0x7fa5e79ecd30>,
#  'espía': <gensim.models.keyedvectors.Vocab at 0x7fa5e79ecd68>,
#  'rusa': <gensim.models.keyedvectors.Vocab at 0x7fa5e79ecda0>,
#  'villana': <gensim.models.keyedvectors.Vocab at 0x7fa5e79ecdd8>,
#  'reddit': <gensim.models.keyedvectors.Vocab at 0x7fa5e79ece10>,
#  'partir': <gensim.models.keyedvectors.Vocab at 0x7fa5e79ece48>,
#  'infección': <gensim.models.keyedvectors.Vocab at 0x7fa5e79ece80>,
#  'indica': <gensim.models.keyedvectors.Vocab at 0x7fa5e79eceb8>,
#  'flayer': <gensim.models.keyedvectors.Vocab at 0x7fa5e79ecef0>,
#  'haría': <gensim.models.keyedvectors.Vocab at 0x7fa5e79ecf28>,
#  'explicaría': <gensim.models.keyedvectors.Vocab at 0x7fa5e79ecf60>,
#  'amenaza': <gensim.models.keyedvectors.Vocab at 0x7fa5e79ecf98>,
#  'hizo': <gensim.models.keyedvectors.Vocab at 0x7fa5e79ecfd0>,
#  'endgame': <gensim.models.keyedvectors.Vocab at 0x7fa5e79f0048>,
#  'grupo': <gensim.models.keyedvectors.Vocab at 0x7fa5e79f0080>,
#  'brenner': <gensim.models.keyedvectors.Vocab at 0x7fa5e79f00b8>,
#  'propone': <gensim.models.keyedvectors.Vocab at 0x7fa5e79f00f0>,
#  'pelota': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a66828>,
#  'gol': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a5f438>,
#  'añadido': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a66cf8>,
#  'triunfo': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a66a90>,
#  'parís': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a660b8>,
#  'saint': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a8add8>,
#  'germain': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a434a8>,
#  'parisino': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a434e0>,
#  'marcado': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a37748>,
#  'afición': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a37780>,
#  'keylor': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a377b8>,
#  'navas': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a377f0>,
#  'francia': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a37828>,
#  'alto': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a37860>,
#  'mostró': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a45470>,
#  'parque': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a454a8>,
#  'príncipes': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a454e0>,
#  'estuvo': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a45518>,
#  'francés': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a45550>,
#  'jugó': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a45908>,
#  'colombia': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a45940>,
#  'once': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a45978>,
#  'thomas': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a459b0>,
#  'tuchel': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a459e8>,
#  'inicio': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a45a20>,
#  'pudo': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a45a58>,
#  'punto': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a45a90>,
#  'real': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a45b00>,
#  'madrid': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a45b38>,
#  'izquierda': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a45b70>,
#  'abdou': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a45ba8>,
#  'diallo': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a45be0>,
#  'matz': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a45c18>,
#  'paris': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a45c50>,
#  '1': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a45c88>,
#  'strasbourg': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a45cc0>,
#  'var': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a45cf8>,
#  'mauro': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a45d30>,
#  'icardi': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a45d68>,
#  'intentó': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a45dd8>,
#  'profundidad': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a45e10>,
#  'ángel': <gensim.models.keyedvectors.Vocab at 0x7fa5e7a45e48>,
#  ...}

# %%
len(model.wv.vocab)
# Out:
# 10508

# %%
def getFV(document):
    words=document.split()
    s=np.zeros(100)
    k=0
    for word in words:
        word = word.lower()
        if word in model.wv.vocab:
            s=s+model[word]
            k=k+1
    
    return s/k

# %%
feature_vectors = []
for contenido in data["Contenido"]:
    feature_vectors.append(getFV(contenido))
# Out:
# /home/carlos/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# /home/carlos/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: RuntimeWarning: invalid value encountered in true_divide
#   # This is added back by InteractiveShellApp.init_path()

# %%
data["Vectores caracteristicos"] = feature_vectors

# %%
data.head()
# Out:
#                                               Titulo  \
# 0  [AHORA] América vs. Pumas UNAM EN VIVO transmi...
# 1  América vs. Pumas UNAM: Sebastián Córdova fue ...
# 2  [EN VIVO] América vs. Pumas UNAM VER AQUÍ EN D...
# 3  Keiko Fujimori fue internada en clínica local ...
# 4  Sporting Cristal vs. Municipal: duelo por la j...
#
#                        Fecha  \
# 0  2019-09-14T22:51:00-05:00
# 1  2019-09-14T22:50:19-05:00
# 2  2019-09-14T22:50:00-05:00
# 3  2019-09-14T22:43:07-05:00
# 4  2019-09-14T22:35:41-05:00
#
#                                            Contenido  \
# 0   América vs. Pumas UNAM EN VIVO | ONLINE sigue...
# 1   El choque entre América y Pumas UNAM se desvi...
# 2   América vs. Pumas EN VIVO EN DIRECTO se miden...
# 3   La lideresa de Fuerza Popular, Keiko Fujimori...
# 4   Sporting Cristal vs. Municipal EN VIVO ONLINE...
#
#                                               Enlace       Fuente  \
# 0  https://elcomercio.pe/deporte-total/futbol-mun...  El Comercio
# 1  https://elcomercio.pe/deporte-total/futbol-mun...  El Comercio
# 2  https://elcomercio.pe/deporte-total/futbol-mun...  El Comercio
# 3  https://elcomercio.pe/politica/keiko-fujimori-...  El Comercio
# 4  https://elcomercio.pe/deporte-total/futbol-per...  El Comercio
#
#                             Vectores caracteristicos
# 0  [0.0002982040181203546, 0.0008879126352966326,...
# 1  [1.1815638476706992e-05, 0.0005618193173225001...
# 2  [0.0003034419416705709, 0.0008539550188255635,...
# 3  [0.00035112819224166505, 0.0010889378005642005...
# 4  [0.0002712506747078199, 0.0010278125478837157,...

# %%
from nltk.cluster import KMeansClusterer

NUM_CLUSTERS=10
kclusterer = KMeansClusterer(NUM_CLUSTERS, distance=nltk.cluster.util.cosine_distance, repeats=20, avoid_empty_clusters='true')
assigned_clusters = kclusterer.cluster(data["Vectores caracteristicos"], assign_clusters=True)

# %%
print(assigned_clusters)

# %% [markdown]
# ## Agregar nuevo item

# %%
notice = "VER ONLINE AMÉRICA VS. PUMAS | VER GRATIS | LIGA MX EN VIVO | CANAL DE LAS ESTRELLAS EN VIVO | TUDN EN VIVO | SEGUIR EN DIRECTO ONLINE |\xa0Club\xa0América 0-0\xa0Pumas UNAM se enfrentarán hoy por la fecha 9 del Torneo Apertura de la Liga MX. El estadio que acogerá este emocionante partido será el mítico Azteca, donde se jugará a partir de las 21:06 horas en Perú y en México con transmisión vía Canal de las Estrellas, TUDN, TUDN En Vivo en el país del ‘Tri’.', 'Las ‘Águilas’ llegan al duelo luego de haber disputado un amistoso con Chivas el último fin de semana (0-0) y de haber caído por goleada 3-0 frente al Atlas en la anterior jornada del certamen doméstico, un resultado amargo que lo mantuvo con 15 puntos.', '▷ Fútbol en vivo: seguir todos los partidos programados para esta semana▷ Champions League 2019-2020 en vivo: fixture y horarios para ver todos los partidos de la fase de grupos', 'Ahora, ante Pumas, el Club América, en calidad de local, está decidido a reencontrarse con la victoria para darle una alegría a su hinchada; sin embargo, reconoce que la tarea no será nada fácil.', 'Y es que los ‘Auriazules’ afrontarán el compromiso por el Torneo Apertura de la Liga MX tras vencer 2-1 a Toluca en la fecha anterior, que les valió para llegar a los 12 puntos y seguir en la pelea por los primeros lugares.', 'Pumas sabe que ante el América tiene una gran oportunidad de seguir sumando en la tabla y no la piensa desaprovechar. ¿Cómo quedará el partido? Pronto lo sabremos.', 'América: G. Ochoa, J. Sánchez, C. Vargas, E. Aguilera, P. Aguilar, G. Rodríguez, F. González, F. Córdova, L. López, R. Ibarra y R. Martínez.DT: Miguel Herrera.', 'Pumas: A. Saldívar, A. Mozo, L. Quintana, N. Freire, J. Angulo, J. Vigón, A. Iniestra, D. Cabrera, P. Barrera, C. González e I. Malcorra.DT: Míchel.', 'Perú: 21:06 horas España: 04:06 horas del domingo 15 de septiembreMéxico: 21:06 horas en Ciudad de MéxicoArgentina: 23:06 horas Brasil: 23:06 horas en BrasiliaColombia: 21:06 horas Chile: 23:06 horas en Santiago Ecuador: 21:06 horas en Quito Uruguay: 23:06 horas Venezuela: 22:06 horas Bolivia: 22:06 horas', 'DEPOR |\xa0¡Por TUDN desde México! Sigue EN VIVO y EN DIRECTO de los partidos del Apertura Liga MX 2019 por fecha 9EL BOCÓN |\xa0Liga MX EN VIVO: sigue los partidos y resultados de la fecha 9 del Torneo Apertura 2019MEDIO TIEMPO |\xa0América vs Pumas: Horario para ver EN VIVO la Jornada 9 del Apertura 2019MILENIO | Horario y dónde ver el América vs Pumas de Liga MX"

data = data.append({'Titulo' : 'sdsads' , 'Fecha' : '', 'Contenido': notice, 'Enlace': '', 'Fuente': '', 'Vectores caracteristicos': getFV(notice)} , ignore_index=True)
# Out:
# /home/carlos/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).

# %%
assigned_clusters2 = kclusterer.cluster(data["Vectores caracteristicos"], assign_clusters=True)
print (assigned_clusters2)
# Out:
# Warning: means will be discarded for subsequent trials
# [1, 0, 1, 0, 0, 1, 1, 1, 0, 1, 1, 1, 1, 1]
